# %% [markdown]
# Taken directly from https://github.com/PPerdomoQ/rare-disease-explainer

# %% [markdown]
# ## **Import**

# %%
import re
import pandas as pd

# %% [markdown]
# ## **Drug-Target Information**

# %% [markdown]
# ### **Load Files**

# %% [markdown]
# Load the information from Drug Central and Monarch:

# %%
df = pd.read_csv('../data/drug.target.interaction.tsv', header=0, index_col=0, sep='\t')
nodes = pd.read_csv('monarch/prev_hd_monarch_nodes_2024-06-24.csv', header=0)

# %%
print(len(nodes))
nodes.head(5)
# Out:
# 14618
#                            id semantic_groups  \
# 0  ENSEMBL:ENSOANG00000050636            ORTH
# 1        PomBase:SPAC1093.06c            GENO
# 2                  MP:0001901            DISO
# 3                  ZP:0010084            DISO
# 4     Xenbase:XB-GENE-5918988            ORTH
#
#                                                 name
# 0                         ENSEMBL:ENSOANG00000050636
# 1                                               dhc1
# 2         absence of NMDA-mediated synaptic currents
# 3  whole organism lacks all parts of type telence...
# 4                                             sqstm1

# %%
df
# Out:
#                  STRUCT_ID                                        TARGET_NAME  \
# DRUG_NAME
# levobupivacaine          4  Potassium voltage-gated channel subfamily H me...
# levobupivacaine          4        Sodium channel protein type 1 subunit alpha
# levobupivacaine          4        Sodium channel protein type 4 subunit alpha
# levobupivacaine          4              Prostaglandin E2 receptor EP1 subtype
# levobupivacaine          4                                Cytochrome P450 2D6
# ...                    ...                                                ...
# samidorphan           5460                         Delta-type opioid receptor
# sotorasib             5461                                        GTPase KRas
# ibrexafungerp         5462       Beta-1,3-glucan synthase catalytic subunit 1
# ibrexafungerp         5462          1,3-Beta-D-glucan-UDP glucosyltransferase
# ibrexafungerp         5462          1,3-Beta-D-glucan-UDP glucosyltransferase
#
#                 TARGET_CLASS ACCESSION    GENE     SWISSPROT  ACT_VALUE  \
# DRUG_NAME
# levobupivacaine  Ion channel    Q12809   KCNH2   KCNH2_HUMAN      4.890
# levobupivacaine  Ion channel    P35498   SCN1A   SCN1A_HUMAN      5.790
# levobupivacaine  Ion channel    P35499   SCN4A   SCN4A_HUMAN        NaN
# levobupivacaine         GPCR    P34995  PTGER1   PE2R1_HUMAN        NaN
# levobupivacaine       Enzyme    P10635  CYP2D6   CP2D6_HUMAN      6.707
# ...                      ...       ...     ...           ...        ...
# samidorphan             GPCR    P41143   OPRD1    OPRD_HUMAN      8.590
# sotorasib             Enzyme    P01116    KRAS    RASK_HUMAN      7.030
# ibrexafungerp         Enzyme    O13428    GSC1  O13428_CANAX      8.350
# ibrexafungerp         Enzyme    Q6FTN8    FKS1  Q6FTN8_CANGA      7.830
# ibrexafungerp         Enzyme    P87204     FKS  P87204_ASPFM      8.970
#
#                  ACT_UNIT ACT_TYPE  \
# DRUG_NAME
# levobupivacaine       NaN     IC50
# levobupivacaine       NaN     IC50
# levobupivacaine       NaN      NaN
# levobupivacaine       NaN      NaN
# levobupivacaine       NaN     IC50
# ...                   ...      ...
# samidorphan           NaN       Ki
# sotorasib             NaN     IC50
# ibrexafungerp         NaN     IC50
# ibrexafungerp         NaN     IC50
# ibrexafungerp         NaN     IC50
#
#                                                        ACT_COMMENT  \
# DRUG_NAME
# levobupivacaine  Inhibition of wild-type human ERG channel expr...
# levobupivacaine                                                NaN
# levobupivacaine                                                NaN
# levobupivacaine                                                NaN
# levobupivacaine  DRUGMATRIX: CYP450, 2D6 enzyme inhibition (sub...
# ...                                                            ...
# samidorphan                                                    NaN
# sotorasib                                       KRAS G12C mutation
# ibrexafungerp    MoA - inhibits the biosynthesis of beta-(1,3)-...
# ibrexafungerp    MoA - inhibits the biosynthesis of beta-(1,3)-...
# ibrexafungerp    MoA - inhibits the biosynthesis of beta-(1,3)-...
#
#                             ACT_SOURCE RELATION  MOA             MOA_SOURCE  \
# DRUG_NAME
# levobupivacaine                 CHEMBL        =  NaN                    NaN
# levobupivacaine              WOMBAT-PK        =  NaN                    NaN
# levobupivacaine              WOMBAT-PK      NaN  1.0                 CHEMBL
# levobupivacaine              WOMBAT-PK      NaN  NaN                    NaN
# levobupivacaine            DRUG MATRIX        =  NaN                    NaN
# ...                                ...      ...  ...                    ...
# samidorphan                 DRUG LABEL        =  NaN                    NaN
# sotorasib                   DRUG LABEL        =  1.0             DRUG LABEL
# ibrexafungerp    SCIENTIFIC LITERATURE        =  1.0             DRUG LABEL
# ibrexafungerp    SCIENTIFIC LITERATURE        =  1.0  SCIENTIFIC LITERATURE
# ibrexafungerp    SCIENTIFIC LITERATURE        =  1.0  SCIENTIFIC LITERATURE
#
#                                                     ACT_SOURCE_URL  \
# DRUG_NAME
# levobupivacaine                                                NaN
# levobupivacaine                                                NaN
# levobupivacaine                                                NaN
# levobupivacaine                                                NaN
# levobupivacaine                                                NaN
# ...                                                            ...
# samidorphan      https://www.accessdata.fda.gov/drugsatfda_docs...
# sotorasib        https://www.accessdata.fda.gov/drugsatfda_docs...
# ibrexafungerp             https://pubmed.ncbi.nlm.nih.gov/24323472
# ibrexafungerp             https://pubmed.ncbi.nlm.nih.gov/24323472
# ibrexafungerp             https://pubmed.ncbi.nlm.nih.gov/24323472
#
#                                                     MOA_SOURCE_URL  \
# DRUG_NAME
# levobupivacaine                                                NaN
# levobupivacaine                                                NaN
# levobupivacaine  https://www.ebi.ac.uk/chembl/compound/inspect/...
# levobupivacaine                                                NaN
# levobupivacaine                                                NaN
# ...                                                            ...
# samidorphan                                                    NaN
# sotorasib        https://www.accessdata.fda.gov/drugsatfda_docs...
# ibrexafungerp    https://www.accessdata.fda.gov/drugsatfda_docs...
# ibrexafungerp    https://www.accessdata.fda.gov/drugsatfda_docs...
# ibrexafungerp    https://www.accessdata.fda.gov/drugsatfda_docs...
#
#                      ACTION_TYPE    TDL              ORGANISM
# DRUG_NAME
# levobupivacaine              NaN  Tclin          Homo sapiens
# levobupivacaine              NaN  Tclin          Homo sapiens
# levobupivacaine          BLOCKER  Tclin          Homo sapiens
# levobupivacaine              NaN  Tclin          Homo sapiens
# levobupivacaine              NaN  Tclin          Homo sapiens
# ...                          ...    ...                   ...
# samidorphan      PARTIAL AGONIST  Tclin          Homo sapiens
# sotorasib              INHIBITOR  Tchem          Homo sapiens
# ibrexafungerp          INHIBITOR    NaN      Candida albicans
# ibrexafungerp          INHIBITOR    NaN      Candida glabrata
# ibrexafungerp          INHIBITOR    NaN  Neosartorya fumigata
#
# [19378 rows x 19 columns]

# %%
df['NEW_ID'] = ''

# %% [markdown]
# ### **Uniprot to Monarch IDs**

# %% [markdown]
# Use Uniprot API to obtain new target IDs:

# %%
"""
    @description: This module maps UniProt accession IDs to other databases depending on taxon. 
    @source: https://www.uniprot.org/help/id_mapping
    @author: Rosa Zwart
"""

import requests
import time

RETRIES = 3
POLLING_S_INTERVAL = 5

FROM_DB = 'UniProtKB_AC-ID'
DEFAULT_TO_DB = 'Ensembl'

db_mapper = {
    'Homo sapiens': 'HGNC',
    'Rattus norvegicus': 'RGD',
    'Mus musculus': 'MGI',
    'Drosophila melanogaster': 'FlyBase',
    'Caenorhabditis elegans': 'WormBase',
    'Danio rerio': 'ZFIN',
    'Escherichia coli': 'EnsemblGenome',
    'Xenopus tropicalis': 'Xenbase',
    'Dictyostelium discoideum': 'dictyBase',
    'Saccharomyces cerevisiae S288C': 'SGD',
    'Schizosaccharomyces pombe': 'PomBase'
}

class IdMapper:
    def __init__(self, ids_to_map: list, to_db = DEFAULT_TO_DB, from_db = FROM_DB):
        self.url = 'https://rest.uniprot.org'
        self.job_id = self.submit_id_mapping(ids_to_map, to_db, from_db)

        if self.check_job_ready():
            self.results = self.get_results()
        
    def submit_id_mapping(self, id_list, to_db, from_db):
        print(f'Map to database {to_db}')
        
        data_params = {
            'from': from_db,
            'to': to_db,
            'ids': ','.join(id_list)
        }
        
        for i in range(RETRIES):
            try:  
                response = requests.post(f'{self.url}/idmapping/run', data=data_params)
                response.raise_for_status()
                return response.json()['jobId']
            except Exception as e:
                if (i < RETRIES - 1):
                    print(f'Retrying in {POLLING_S_INTERVAL}s')
                    time.sleep(POLLING_S_INTERVAL)
                    continue
                else:
                    print(f'After all attempts, request could not be submitted due to {e}')
                    return None
                
    def check_job_ready(self):
        while self.job_id:
            try:
                response = requests.get(f'{self.url}/idmapping/status/{self.job_id}')
                response.raise_for_status()
                response_values = response.json()
                if 'jobStatus' in response_values:
                    if response_values['jobStatus'] == 'RUNNING':
                        print(f'Check again after {POLLING_S_INTERVAL}s')
                        time.sleep(POLLING_S_INTERVAL)
                    
                    elif response_values['jobStatus'] == 'FINISHED':
                        print('Job is finished')
                        return True
                    
                    else:
                        print(f'Job {self.job_id} had status {response_values["jobStatus"]}, stopped checking if job is ready.')
                        return False
                elif 'results' in response_values:
                        return True
                else:
                    return False
            except Exception as e:
                print(f'Failed to check whether job is finished due to {e}, try again after {POLLING_S_INTERVAL}s...')
                time.sleep(POLLING_S_INTERVAL)
                
    def get_results(self):
        for i in range(RETRIES):
            try:  
                response = requests.get(f'{self.url}/idmapping/stream/{self.job_id}')
                response.raise_for_status()
                return response.json()['results']
            except Exception as e:
                if (i < RETRIES - 1):
                    print(f'Retrying in {POLLING_S_INTERVAL}s')
                    time.sleep(POLLING_S_INTERVAL)
                    continue
                else:
                    print(f'After all attempts, request could not be submitted due to {e}')
                    return None

# %%
def get_single_id(id):
    """
        Get from list of IDs split by `|`, one ID.
        :return Single ID value
    """
    split_id = id.split('|')
    if len(split_id) > 1:
        return split_id[0]
    else:
        return id

def fetch_id_mappings(entries: pd.DataFrame, map_to_db):
    """
        Get ID mappings of IDs present in given dataframe. Mappings are based on given database to which the IDs need to be mapped.
        :param entries: Dataframe containing column name `ACCESSION`
        :param map_to_db: Name of database to which the given IDs need to be mapped
    """
    if (entries.shape[0] > 0):
        id_entries_to_map = entries.copy()
        id_entries_to_map['ACCESSION'] = entries.apply(lambda row: get_single_id(row['ACCESSION']), axis=1)
        
        mapper = IdMapper(ids_to_map=id_entries_to_map['ACCESSION'].to_list(), to_db=map_to_db)
        if hasattr(mapper, 'results'):
            return mapper.results
        else:
            return []
    else:
        return []

def get_mapped_ids(drug_targets):
    """
        Get mapped IDs for all included databases.
        :param drug_targets: Dataframe that contains column name `ORGANISM` and `ACCESSION`
    """
    all_mapped_id_results = []
    all_taxon_names = list(db_mapper.keys())
    
    for taxon in all_taxon_names:
        relevant_entries = drug_targets[drug_targets['ORGANISM'].str.contains(taxon)]
        id_mappings = fetch_id_mappings(relevant_entries, db_mapper[taxon])
        all_mapped_id_results = all_mapped_id_results + id_mappings

    # Map entity ids of leftover organisms to default database
    other_relevant_entries = drug_targets[~drug_targets['ORGANISM'].isin(all_taxon_names)]
    other_id_mappings = fetch_id_mappings(other_relevant_entries, DEFAULT_TO_DB)
    all_mapped_id_results = all_mapped_id_results + other_id_mappings
                
    return all_mapped_id_results

results = get_mapped_ids(drug_targets=df)
# Out:
# Map to database HGNC
# Map to database RGD
# Map to database MGI
# Map to database FlyBase
# Map to database WormBase
# Map to database ZFIN
# Map to database EnsemblGenome
# Retrying in 5s
# Retrying in 5s
# After all attempts, request could not be submitted due to 400 Client Error:  for url: https://rest.uniprot.org/idmapping/run
# Map to database PomBase
# Map to database Ensembl

# %%
def check_split_values(value, id_value):
    parts = value.split('|')
    return all(part == id_value for part in parts)

for mapping_result in results:
    original_id = mapping_result['from']
    new_id = mapping_result['to']
    
    df.loc[df['ACCESSION'].apply(check_split_values, id_value=original_id), 'NEW_ID'] = new_id

# %%
df['NEW_ID'] = df['NEW_ID'].replace('', np.nan)

# %%
print(f'Matched IDs to ACCESSION IDs for {len(df)} rows.')
# Out:
# Matched IDs to ACCESSION IDs for 19378 rows.

# %% [markdown]
# Drop rows that don't have a new ID:

# %%
df = df.dropna(subset=['NEW_ID'])

# %%
print(f'All found matched IDs to ACCESSION IDs for {len(df)} rows.')
# Out:
# All found matched IDs to ACCESSION IDs for 16141 rows.

# %% [markdown]
# Keep only rows whose the target is in the Monarch nodes:

# %%
df = df[df['NEW_ID'].isin(list(nodes['id']))]
print(f'All targets that match with Monarch nodes consisting of {len(df)} rows.')
# Out:
# All targets that match with Monarch nodes consisting of 316 rows.

# %% [markdown]
# Save the Drug-Target dataframe as .csv:

# %%
df.to_csv('drug.target.final.ELA.csv', encoding = 'utf-8-sig')

# %% [markdown]
# Create and save a dataframe containing the drug nodes:

# %%
df['DRUG_NAME'] = df.index
df_drugs = df[['DRUG_NAME', 'STRUCT_ID']]
df_drugs = df_drugs.drop_duplicates()
df_drugs.to_csv('drug_nodes_ELA.csv', encoding = 'utf-8-sig')

# %%
df_drugs.head(10)
# Out:
#                                      DRUG_NAME  STRUCT_ID
# DRUG_NAME
# adenosine                            adenosine         90
# adenosine triphosphate  adenosine triphosphate         91
# alfentanil                          alfentanil        114
# alvimopan                            alvimopan        143
# amiodarone                          amiodarone        176
# amodiaquine                        amodiaquine        186
# anileridine                        anileridine        220
# astemizole                          astemizole        249
# bacitracin                          bacitracin        281
# bortezomib                          bortezomib        391

# %% [markdown]
# ## **Drug-Disease Information**

# %% [markdown]
# ### **Text to CSV**

# %% [markdown]
# If already saved, run only the cell of this section, otherwise continue:

# %% [markdown]
# Create a Dataframe that will contain the Drug-Disease information:

# %%
column_names = ["DRUG_ID", "DRUG_NAME", "DISEASES", 'PHASE']

df = pd.DataFrame(columns = column_names)

# %% [markdown]
# Read the .txt file downloaded from TTD and convert it into a pandas dataframe:

# %%
with open('../data/P1-05-Drug_disease.txt') as f:
  lines = f.readlines()[22:]

# %%
i = 0
id = ''
name = ''
disease = ''
phase = ''

for line in lines: 
  if line.startswith('DRUGNAME'): 
    result = re.search('\t(.*)\n', line)
    name = result.group(1)
  elif line.startswith('TTDDRUID'): 
    result = re.search('\t(.*)\n', line)
    id = result.group(1)
  elif line.startswith('INDICATI'): 
    result = re.search('\t(.*)\[', line)
    result2 = re.search('\](.*)', line)
    disease = result.group(1) 
    phase = result2.group(1) 
    df.loc[i] = [id,name,disease, phase]
    i += 1
  elif line.startswith('\n'): 
    id = ''
    name = ''
    disease = ''
    phase = ''
# Out:
# <>:15: SyntaxWarning: invalid escape sequence '\['
# <>:16: SyntaxWarning: invalid escape sequence '\]'
# <>:15: SyntaxWarning: invalid escape sequence '\['
# <>:16: SyntaxWarning: invalid escape sequence '\]'
# C:\Users\rzwart\AppData\Local\Temp\ipykernel_17444\1061029482.py:15: SyntaxWarning: invalid escape sequence '\['
#   result = re.search('\t(.*)\[', line)
# C:\Users\rzwart\AppData\Local\Temp\ipykernel_17444\1061029482.py:16: SyntaxWarning: invalid escape sequence '\]'
#   result2 = re.search('\](.*)', line)

# %%
df
# Out:
#       DRUG_ID     DRUG_NAME                                   DISEASES  \
# 0      D00ABE       ALD-301                                  Ischemia
# 1      D00ABE       ALD-301               Peripheral arterial disease
# 2      D00ABO       KW-2449                   Acute myeloid leukaemia
# 3      D00ABW      Opterone                        Hormone deficiency
# 4      D00ACC        ND1251                                Depression
# ...       ...           ...                                        ...
# 28973  DZTX12        ASC-J9                   End-stage renal disease
# 28974  DZU72C       OKI 179                       Solid tumour/cancer
# 28975  DZVF15       TRN-110  Attention deficit hyperactivity disorder
# 28976  DZW53X    GSK4069889                Non-small cell lung cancer
# 28977  DZY4R2  JNJ-74699157                       Solid tumour/cancer
#
#                           PHASE
# 0                       Phase 2
# 1                       Phase 2
# 2                       Phase 1
# 3       Discontinued in Phase 1
# 4       Discontinued in Phase 1
# ...                         ...
# 28973                   Phase 2
# 28974                   Phase 1
# 28975            Clinical Trial
# 28976                   Phase 2
# 28977                   Phase 1
#
# [28978 rows x 4 columns]

# %%
df.to_csv('drug_to_disease.csv', encoding = 'utf-8-sig')

# %% [markdown]
# Run only this cell if you have already saved the Drug-Disease interactions:

# %%
df = pd.read_csv('drug_to_disease.csv', header=0, index_col=0)

# %%
df
# Out:
#       DRUG_ID     DRUG_NAME                                   DISEASES  \
# 0      D00ABE       ALD-301                                  Ischemia
# 1      D00ABE       ALD-301               Peripheral arterial disease
# 2      D00ABO       KW-2449                   Acute myeloid leukaemia
# 3      D00ABW      Opterone                        Hormone deficiency
# 4      D00ACC        ND1251                                Depression
# ...       ...           ...                                        ...
# 28973  DZTX12        ASC-J9                   End-stage renal disease
# 28974  DZU72C       OKI 179                       Solid tumour/cancer
# 28975  DZVF15       TRN-110  Attention deficit hyperactivity disorder
# 28976  DZW53X    GSK4069889                Non-small cell lung cancer
# 28977  DZY4R2  JNJ-74699157                       Solid tumour/cancer
#
#                           PHASE
# 0                       Phase 2
# 1                       Phase 2
# 2                       Phase 1
# 3       Discontinued in Phase 1
# 4       Discontinued in Phase 1
# ...                         ...
# 28973                   Phase 2
# 28974                   Phase 1
# 28975            Clinical Trial
# 28976                   Phase 2
# 28977                   Phase 1
#
# [28978 rows x 4 columns]

# %%
df.to_csv('drug_to_disease.csv', encoding = 'utf-8-sig')

# %% [markdown]
# ### **Load CSVs**

# %% [markdown]
# Load the drug nodes (obtained from Drug Central) and the Monarch nodes:

# %%
graph_drugs = pd.read_csv('drug_nodes_ELA.csv', header=0)
nodes = pd.read_csv('monarch/prev_hd_monarch_nodes_2024-06-24.csv', header=0)

# %% [markdown]
# Get list of unique drugs and diseases:

# %%
graph_diseases = nodes[nodes['semantic_groups'] == 'DISO']

unique_diseases = graph_diseases['name'].unique()
unique_dis_id = graph_diseases['id'].unique()
unique_diseases = [x.lower() for x in unique_diseases]

print(f'There are {len(unique_diseases)} diseases found in Monarch nodes.')
# Out:
# There are 6002 diseases found in Monarch nodes.

# %%
unique_drugs = graph_drugs['DRUG_NAME'].unique()
unique_drugs = [x.lower() for x in unique_drugs]
print(f'There are {len(unique_drugs)} drugs found in DrugCentral entries.')
# Out:
# There are 215 drugs found in DrugCentral entries.

# %% [markdown]
# At this point you should use SORTA tool (https://sorta.molgeniscloud.org/menu/main/sorta?) to match the IDs of TTD to Human Phenotype Ontology (HPO). The file is also available in the project's Github:

# %%
matched = pd.read_csv('../data/matched_phenotypes.csv', header = 0, delimiter = ';')

# %%
matched
# Out:
#                                                    Name  \
# 0                                   respiratory failure
# 1                                    sexual dysfunction
# 2                                        achondroplasia
# 3                                  glabellar frown line
# 4                           testicular germ cell tumour
# ...                                                 ...
# 1796                              systemic mastocytosis
# 1797                    acute iron or aluminum toxicity
# 1798  chronic inflammatory demyelinating polyneuropathy
# 1799                                    aortic aneurysm
# 1800                                              fever
#
#                           ontologyTermName  \
# 0                      Respiratory failure
# 1                  Male sexual dysfunction
# 2                         Bronchodysplasia
# 3                       Prominent glabella
# 4                      Testicular neoplasm
# ...                                    ...
# 1796                          Mastocytosis
# 1797  Abnormal total iron binding capacity
# 1798    Acute demyelinating polyneuropathy
# 1799                       Aortic aneurysm
# 1800                                 Fever
#
#                                 ontologyTermIRI   score  validated  review
# 0     http://purl.obolibrary.org/obo/HP_0002878  100.00      False   False
# 1     http://purl.obolibrary.org/obo/HP_0040307   86.49      False   False
# 2     http://purl.obolibrary.org/obo/HP_0006533   62.50      False   False
# 3     http://purl.obolibrary.org/obo/HP_0002057   59.46      False   False
# 4     http://purl.obolibrary.org/obo/HP_0010788   71.11      False   False
# ...                                         ...     ...        ...     ...
# 1796  http://purl.obolibrary.org/obo/HP_0100495   77.42      False   False
# 1797  http://purl.obolibrary.org/obo/HP_0033212   48.15      False   False
# 1798  http://purl.obolibrary.org/obo/HP_0007131   64.86      False   False
# 1799  http://purl.obolibrary.org/obo/HP_0004942  100.00      False   False
# 1800  http://purl.obolibrary.org/obo/HP_0001945  100.00      False   False
#
# [1801 rows x 6 columns]

# %% [markdown]
# Select only those IDs with a score greater than 80:

# %%
matched = matched[matched['score'] > 80]

# %% [markdown]
# Create the final ID:

# %%
matched['ID'] = matched['ontologyTermIRI'].str.split('/obo/').str[1]
# Out:
# C:\Users\rzwart\AppData\Local\Temp\ipykernel_17444\1934371214.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched['ID'] = matched['ontologyTermIRI'].str.split('/obo/').str[1]

# %%
new_id = []
for i in matched['ID']: 
  id = re.sub("[^0-9a-zA-Z]+", ":", i)
  new_id.append(id)
matched['ID'] = new_id
# Out:
# C:\Users\rzwart\AppData\Local\Temp\ipykernel_17444\2151810182.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched['ID'] = new_id

# %%
matched.head(10)
# Out:
#                                         Name  \
# 0                        respiratory failure
# 1                         sexual dysfunction
# 6                                pollakiuria
# 17                             dental caries
# 22   hematopoietic stem cell transplantation
# 25                                 gastritis
# 26                                arthralgia
# 27  attention deficit hyperactivity disorder
# 28                       female hypogonadism
# 29                     vitamin b1 deficiency
#
#                             ontologyTermName  \
# 0                        Respiratory failure
# 1                    Male sexual dysfunction
# 6                               Pollakisuria
# 17                             Carious teeth
# 22         History of bone marrow transplant
# 25                                 Gastritis
# 26                                Arthralgia
# 27  Attention deficit hyperactivity disorder
# 28                       Female hypogonadism
# 29                  Low levels of vitamin B1
#
#                               ontologyTermIRI   score  validated  review  \
# 0   http://purl.obolibrary.org/obo/HP_0002878  100.00      False   False
# 1   http://purl.obolibrary.org/obo/HP_0040307   86.49      False   False
# 6   http://purl.obolibrary.org/obo/HP_0100515   88.00      False   False
# 17  http://purl.obolibrary.org/obo/HP_0000670  100.00      False   False
# 22  http://purl.obolibrary.org/obo/HP_0032557   85.71      False   False
# 25  http://purl.obolibrary.org/obo/HP_0005263  100.00      False   False
# 26  http://purl.obolibrary.org/obo/HP_0002829  100.00      False   False
# 27  http://purl.obolibrary.org/obo/HP_0007018  100.00      False   False
# 28  http://purl.obolibrary.org/obo/HP_0000134  100.00      False   False
# 29  http://purl.obolibrary.org/obo/HP_0100503  100.00      False   False
#
#             ID
# 0   HP:0002878
# 1   HP:0040307
# 6   HP:0100515
# 17  HP:0000670
# 22  HP:0032557
# 25  HP:0005263
# 26  HP:0002829
# 27  HP:0007018
# 28  HP:0000134
# 29  HP:0100503

# %%
i = 0
for index, row in df.iterrows(): 
  if row['DRUG_NAME'].lower() in unique_drugs: 
    if row['DISEASES'].lower() in unique_diseases: 
      i += 1

# %% [markdown]
# ### **Merging**

# %%
modified = []
for d in df['DISEASES']: 
  new_string = re.sub("[^0-9a-zA-Z]+", " ", d)
  modified.append(new_string.lower())

# %%
df['Name'] = modified

# %%
df['Name'] = df['Name'].str.strip()
matched['Name'] = matched['Name'].str.strip()
# Out:
# C:\Users\rzwart\AppData\Local\Temp\ipykernel_17444\140104363.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched['Name'] = matched['Name'].str.strip()

# %%
final = pd.merge(df, matched, on = 'Name', how = 'left')

# %%
final
# Out:
#       DRUG_ID     DRUG_NAME                                   DISEASES  \
# 0      D00ABE       ALD-301                                  Ischemia
# 1      D00ABE       ALD-301               Peripheral arterial disease
# 2      D00ABO       KW-2449                   Acute myeloid leukaemia
# 3      D00ABW      Opterone                        Hormone deficiency
# 4      D00ACC        ND1251                                Depression
# ...       ...           ...                                        ...
# 29562  DZU72C       OKI 179                       Solid tumour/cancer
# 29563  DZVF15       TRN-110  Attention deficit hyperactivity disorder
# 29564  DZW53X    GSK4069889                Non-small cell lung cancer
# 29565  DZW53X    GSK4069889                Non-small cell lung cancer
# 29566  DZY4R2  JNJ-74699157                       Solid tumour/cancer
#
#                           PHASE                                      Name  \
# 0                       Phase 2                                  ischemia
# 1                       Phase 2               peripheral arterial disease
# 2                       Phase 1                   acute myeloid leukaemia
# 3       Discontinued in Phase 1                        hormone deficiency
# 4       Discontinued in Phase 1                                depression
# ...                         ...                                       ...
# 29562                   Phase 1                       solid tumour cancer
# 29563            Clinical Trial  attention deficit hyperactivity disorder
# 29564                   Phase 2                non small cell lung cancer
# 29565                   Phase 2                non small cell lung cancer
# 29566                   Phase 1                       solid tumour cancer
#
#                                ontologyTermName  \
# 0                                           NaN
# 1                  Peripheral arterial stenosis
# 2                        Acute myeloid leukemia
# 3                                           NaN
# 4                                  Depressivity
# ...                                         ...
# 29562                                       NaN
# 29563  Attention deficit hyperactivity disorder
# 29564             Non-small cell lung carcinoma
# 29565             Non-small cell lung carcinoma
# 29566                                       NaN
#
#                                  ontologyTermIRI  score validated review  \
# 0                                            NaN    NaN       NaN    NaN
# 1      http://purl.obolibrary.org/obo/HP_0004950  100.0     False  False
# 2      http://purl.obolibrary.org/obo/HP_0004808  100.0     False  False
# 3                                            NaN    NaN       NaN    NaN
# 4      http://purl.obolibrary.org/obo/HP_0000716  100.0     False  False
# ...                                          ...    ...       ...    ...
# 29562                                        NaN    NaN       NaN    NaN
# 29563  http://purl.obolibrary.org/obo/HP_0007018  100.0     False  False
# 29564  http://purl.obolibrary.org/obo/HP_0030358  100.0     False  False
# 29565  http://purl.obolibrary.org/obo/HP_0030358  100.0     False  False
# 29566                                        NaN    NaN       NaN    NaN
#
#                ID
# 0             NaN
# 1      HP:0004950
# 2      HP:0004808
# 3             NaN
# 4      HP:0000716
# ...           ...
# 29562         NaN
# 29563  HP:0007018
# 29564  HP:0030358
# 29565  HP:0030358
# 29566         NaN
#
# [29567 rows x 11 columns]

# %%
final.to_csv('drug_to_disease_HP.csv', encoding = 'utf-8-sig')

# %% [markdown]
# ### **Comparison**

# %%
final = pd.read_csv('drug_to_disease_HP.csv', header=0)

# %%
final_filtered = final[final['score'] > 80]

# %%
len(final_filtered)
# Out:
# 14760

# %%
final_filtered
# Out:
#        Unnamed: 0 DRUG_ID                                        DRUG_NAME  \
# 1               1  D00ABE                                          ALD-301
# 2               2  D00ABO                                          KW-2449
# 4               4  D00ACC                                           ND1251
# 5               5  D00ACH                                         HMR-4004
# 11             11  D00AHT  PRAME antigen-specific cancer immunotherapeutic
# ...           ...     ...                                              ...
# 29560       29560  DZTX12                                           ASC-J9
# 29561       29561  DZTX12                                           ASC-J9
# 29563       29563  DZVF15                                          TRN-110
# 29564       29564  DZW53X                                       GSK4069889
# 29565       29565  DZW53X                                       GSK4069889
#
#                                         DISEASES                     PHASE  \
# 1                   Peripheral arterial disease                    Phase 2
# 2                       Acute myeloid leukaemia                    Phase 1
# 4                                    Depression    Discontinued in Phase 1
# 5                           Bacterial infection                 Terminated
# 11                   Non-small-cell lung cancer                    Phase 2
# ...                                          ...                       ...
# 29560                                Thrombosis                    Phase 2
# 29561                   End-stage renal disease                    Phase 2
# 29563  Attention deficit hyperactivity disorder             Clinical Trial
# 29564                Non-small cell lung cancer                    Phase 2
# 29565                Non-small cell lung cancer                    Phase 2
#
#                                            Name  \
# 1                   peripheral arterial disease
# 2                       acute myeloid leukaemia
# 4                                    depression
# 5                           bacterial infection
# 11                   non small cell lung cancer
# ...                                         ...
# 29560                                thrombosis
# 29561                   end stage renal disease
# 29563  attention deficit hyperactivity disorder
# 29564                non small cell lung cancer
# 29565                non small cell lung cancer
#
#                                ontologyTermName  \
# 1                  Peripheral arterial stenosis
# 2                        Acute myeloid leukemia
# 4                                  Depressivity
# 5                                    Cellulitis
# 11                Non-small cell lung carcinoma
# ...                                         ...
# 29560                            Thrombocytosis
# 29561            Stage 5 chronic kidney disease
# 29563  Attention deficit hyperactivity disorder
# 29564             Non-small cell lung carcinoma
# 29565             Non-small cell lung carcinoma
#
#                                  ontologyTermIRI   score validated review  \
# 1      http://purl.obolibrary.org/obo/HP_0004950  100.00     False  False
# 2      http://purl.obolibrary.org/obo/HP_0004808  100.00     False  False
# 4      http://purl.obolibrary.org/obo/HP_0000716  100.00     False  False
# 5      http://purl.obolibrary.org/obo/HP_0100658   85.71     False  False
# 11     http://purl.obolibrary.org/obo/HP_0030358  100.00     False  False
# ...                                          ...     ...       ...    ...
# 29560  http://purl.obolibrary.org/obo/HP_0001894   83.33     False  False
# 29561  http://purl.obolibrary.org/obo/HP_0003774  100.00     False  False
# 29563  http://purl.obolibrary.org/obo/HP_0007018  100.00     False  False
# 29564  http://purl.obolibrary.org/obo/HP_0030358  100.00     False  False
# 29565  http://purl.obolibrary.org/obo/HP_0030358  100.00     False  False
#
#                ID
# 1      HP:0004950
# 2      HP:0004808
# 4      HP:0000716
# 5      HP:0100658
# 11     HP:0030358
# ...           ...
# 29560  HP:0001894
# 29561  HP:0003774
# 29563  HP:0007018
# 29564  HP:0030358
# 29565  HP:0030358
#
# [14760 rows x 12 columns]

# %%
unique_drugs
# Out:
# ['adenosine',
#  'adenosine triphosphate',
#  'alfentanil',
#  'alvimopan',
#  'amiodarone',
#  'amodiaquine',
#  'anileridine',
#  'astemizole',
#  'bacitracin',
#  'bortezomib',
#  'buprenorphine',
#  'butorphanol',
#  'candesartan cilexetil',
#  'carmofur',
#  'carvedilol',
#  'cefapirin',
#  'cerulenin',
#  'chloroquine',
#  'chlorpromazine',
#  'cianidanol',
#  'cinnarizine',
#  'clioquinol',
#  'clomifene',
#  'clotrimazole',
#  'clozapine',
#  'codeine',
#  'colchicine',
#  'cycloserine',
#  'cyproterone acetate',
#  'dactinomycin',
#  'danazol',
#  'dasatinib',
#  'dextropropoxyphene',
#  'dezocine',
#  'diacerein',
#  'diethylstilbestrol',
#  'difenoxin',
#  'alpha-ergocryptine',
#  'dihydrocodeine',
#  'dihydroergocristine',
#  'diphenoxylate',
#  'disulfiram',
#  'dobutamine',
#  'docetaxel',
#  'domperidone',
#  'ebastine',
#  'econazole',
#  'edetic acid',
#  'erlotinib',
#  'ethinylestradiol',
#  'everolimus',
#  'famotidine',
#  'felbamate',
#  'fentanyl',
#  'flunarizine',
#  'fluphenazine',
#  'formoterol',
#  'ganciclovir',
#  'gefitinib',
#  'glutamic acid',
#  'haloperidol',
#  'hesperetin',
#  'hexachlorophene',
#  'hydrocodone',
#  'hydromorphone',
#  'ifenprodil',
#  'imatinib',
#  'diiodohydroxyquinoline',
#  'fluostigmine',
#  'ketobemidone',
#  'lansoprazole',
#  'lapatinib',
#  'levallorphan',
#  'levodopa',
#  'levomethadyl acetate',
#  'levorphanol',
#  'loperamide',
#  'memantine',
#  'pethidine',
#  'meptazinol',
#  'methadone',
#  'acetylmethadol',
#  'methyldopa',
#  'methylthioninium chloride',
#  'naltrexone',
#  'miconazole',
#  'midodrine',
#  'mifepristone',
#  'miltefosine',
#  'mitoxantrone',
#  'montelukast',
#  'morphine',
#  'nalbuphine',
#  'nalmefene',
#  'nalorphine',
#  'naloxone',
#  'nelfinavir',
#  'niclosamide',
#  'octreotide',
#  'omapatrilat',
#  'omeprazole',
#  'orlistat',
#  'oxycodone',
#  'oxymorphone',
#  'paclitaxel',
#  'pantoprazole',
#  'penfluridol',
#  'perhexiline',
#  'phenazocine',
#  'phenelzine',
#  'pimozide',
#  'primaquine',
#  'promethazine',
#  'propiram',
#  'rabeprazole',
#  'raloxifene',
#  'remifentanil',
#  'reserpine',
#  'ritonavir',
#  'saquinavir',
#  'sirolimus',
#  'sorafenib',
#  'sufentanil',
#  'sulfaethidole',
#  'sulfasalazine',
#  'suloctidil',
#  'sunitinib',
#  'tacrine',
#  'tacrolimus',
#  'tamoxifen',
#  'terfenadine',
#  'thioguanine',
#  'thioridazine',
#  'tianeptine',
#  'tilidine',
#  'tramadol',
#  'tranylcypromine',
#  'vesnarinone',
#  'thiamine',
#  'nicotinic acid',
#  'zafirlukast',
#  'zotarolimus',
#  'bithionol',
#  'cetrimonium',
#  'diosmin',
#  'flusalan',
#  'pentazocine',
#  'quercetin',
#  'ruboxistaurin',
#  'rutoside',
#  'ciramadol',
#  'baicalin',
#  'tirilazad',
#  'pazopanib',
#  'gentian violet',
#  'temsirolimus',
#  'boceprevir',
#  'telaprevir',
#  'vandetanib',
#  'icatibant',
#  'crizotinib',
#  'hydroxyprogesterone caproate',
#  'ruxolitinib',
#  'axitinib',
#  'ingenol mebutate',
#  'tapentadol',
#  'florbetapir f-18',
#  'flutemetamol (18f)',
#  'afatinib',
#  'zinc chloride',
#  'bosutinib',
#  'cetrimide',
#  'cisplatin',
#  'colistin',
#  'carfilzomib',
#  'diosmetin',
#  'methylnaltrexone',
#  'rose bengal',
#  'nalfurafine',
#  'sodium aurothiomalate',
#  'cabozantinib',
#  'thiomersal',
#  'ridaforolimus',
#  'ibrutinib',
#  'florbetaben f18',
#  'naloxegol',
#  'ceritinib',
#  'dexrabeprazole',
#  'nintedanib',
#  'lenvatinib',
#  'cetuximab',
#  'panitumumab',
#  'eluxadoline',
#  'tannic acid',
#  'osimertinib',
#  'ixazomib',
#  'necitumumab',
#  'migalastat',
#  'chromic chloride',
#  'icotinib',
#  'olmutinib',
#  'naldemedine',
#  'midostaurin',
#  'brigatinib',
#  'neratinib',
#  'copanlisib',
#  'dacomitinib',
#  'fedratinib',
#  'brilliant blue g',
#  'bempedoic acid',
#  'selumetinib',
#  'tucatinib',
#  'oliceridine',
#  'trilaciclib',
#  'samidorphan']

# %%
column_names = ["DRUG_ID", "DRUG_NAME", "DISEASES", 'PHASE']

df = pd.DataFrame(columns = column_names)

df.head(10)
# Out:
# Empty DataFrame
# Columns: [DRUG_ID, DRUG_NAME, DISEASES, PHASE]
# Index: []

# %%
i = 0
for index, row in final_filtered.iterrows(): 

  if row['DRUG_NAME'].lower() not in unique_drugs or row['ID'] not in unique_dis_id:
   final_filtered = final_filtered.drop(labels = index, axis = 0)
   
len(final_filtered)
# Out:
# 39

# %%
i = 0
for index, row in final_filtered.iterrows(): 
  drug = row['DRUG_NAME'].lower()
  id = graph_drugs[graph_drugs['DRUG_NAME'] == drug]['STRUCT_ID'].values[0]
  final_filtered.at[index, 'DRUG_ID'] = id
len(final_filtered)
# Out:
# 39

# %%
final_filtered
# Out:
#        Unnamed: 0 DRUG_ID               DRUG_NAME  \
# 492           492    2172                Pimozide
# 1301         1301      91  Adenosine triphosphate
# 1302         1302      91  Adenosine triphosphate
# 2262         2262    2351              Raloxifene
# 2281         2281    1990              Omeprazole
# 2356         2356     621          Chlorpromazine
# 3652         3652     725                 Codeine
# 4664         4664     578               Cerulenin
# 5972         5972    1200             Flunarizine
# 6768         6768    1989             Omapatrilat
# 7027         7027     434           Buprenorphine
# 7028         7028     434           Buprenorphine
# 12007       12007    1353             Haloperidol
# 12748       12748    1762              Methyldopa
# 13453       13453    2080             Penfluridol
# 13486       13486    1599              Loperamide
# 13499       13499     700               Clomifene
# 13579       13579    1353             Haloperidol
# 13599       13599     522              Carvedilol
# 13953       13953    5382          Bempedoic acid
# 17354       17354     918           Diphenoxylate
# 17406       17406    2370               Reserpine
# 17544       17544     937              Dobutamine
# 18177       18177    3514               Quercetin
# 18485       18485    2817             VESNARINONE
# 20430       20430    4778           Ridaforolimus
# 21288       21288    2123              Phenelzine
# 23208       23208    1599              Loperamide
# 23377       23377    2286            Promethazine
# 23394       23394    1574             Levorphanol
# 23558       23558    2054            Pantoprazole
# 23674       23674    1996                Orlistat
# 23916       23916    2637            Thioridazine
# 24093       24093    4392               Cisplatin
# 24723       24723     621          Chlorpromazine
# 25467       25467     522              Carvedilol
# 25825       25825    1878                Naloxone
# 25826       25826    1878                Naloxone
# 26992       26992     722               Clozapine
#
#                                DISEASES                     PHASE  \
# 492                      Schizophrenia                   Approved
# 1301                     Heart disease                    Phase 2
# 1302                       Bradycardia    Discontinued in Phase 2
# 2262                      Osteoporosis                   Approved
# 2281   Gastroesophageal reflux disease                   Approved
# 2356                     Schizophrenia                   Approved
# 3652                             Cough                    Phase 1
# 4664                       Weight loss                   Approved
# 5972                          Migraine                   Approved
# 6768                      Hypertension                 Terminated
# 7027              Psychiatric disorder                    Phase 3
# 7028                          Migraine                    Phase 2
# 12007                    Schizophrenia                   Approved
# 12748                     Hypertension                   Approved
# 13453                    Schizophrenia                   Approved
# 13486                         Diarrhea                   Approved
# 13499               Female infertility                   Approved
# 13579                    Schizophrenia                   Approved
# 13599         Congestive heart failure                   Approved
# 13953    Familial hypercholesterolemia                   Approved
# 17354                         Diarrhea                   Approved
# 17406                     Hypertension                   Approved
# 17544                    Heart failure                   Approved
# 18177                          Obesity                   Approved
# 18485                  Cardiac failure                   Approved
# 20430                          Sarcoma                    Phase 3
# 21288                       Depression                   Approved
# 23208                         Diarrhea                   Approved
# 23377                           Nausea                   Approved
# 23394                  Ischemic stroke                 Terminated
# 23558  Gastroesophageal reflux disease                   Approved
# 23674                          Obesity                   Approved
# 23916                    Schizophrenia                   Approved
# 24093                     Osteosarcoma                    Phase 2
# 24723                    Schizophrenia      Withdrawn from market
# 25467         Congestive heart failure                   Approved
# 25825           Respiratory depression                    Phase 3
# 25826                         Pruritus                    Phase 3
# 26992                    Schizophrenia                   Approved
#
#                                   Name          ontologyTermName  \
# 492                      schizophrenia             Schizophrenia
# 1301                     heart disease            Cardiomyopathy
# 1302                       bradycardia               Bradycardia
# 2262                      osteoporosis              Osteoporosis
# 2281   gastroesophageal reflux disease   Gastroesophageal reflux
# 2356                     schizophrenia             Schizophrenia
# 3652                             cough                     Cough
# 4664                       weight loss               Weight loss
# 5972                          migraine                  Migraine
# 6768                      hypertension              Hypertension
# 7027              psychiatric disorder    Behavioral abnormality
# 7028                          migraine                  Migraine
# 12007                    schizophrenia             Schizophrenia
# 12748                     hypertension              Hypertension
# 13453                    schizophrenia             Schizophrenia
# 13486                         diarrhea                  Diarrhea
# 13499               female infertility        Female infertility
# 13579                    schizophrenia             Schizophrenia
# 13599         congestive heart failure  Congestive heart failure
# 13953    familial hypercholesterolemia      Hypercholesterolemia
# 17354                         diarrhea                  Diarrhea
# 17406                     hypertension              Hypertension
# 17544                    heart failure  Congestive heart failure
# 18177                          obesity                   Obesity
# 18485                  cardiac failure  Congestive heart failure
# 20430                          sarcoma                   Sarcoma
# 21288                       depression              Depressivity
# 23208                         diarrhea                  Diarrhea
# 23377                           nausea                    Nausea
# 23394                  ischemic stroke           Ischemic stroke
# 23558  gastroesophageal reflux disease   Gastroesophageal reflux
# 23674                          obesity                   Obesity
# 23916                    schizophrenia             Schizophrenia
# 24093                     osteosarcoma              Osteosarcoma
# 24723                    schizophrenia             Schizophrenia
# 25467         congestive heart failure  Congestive heart failure
# 25825           respiratory depression      Respiratory distress
# 25826                         pruritus                  Pruritus
# 26992                    schizophrenia             Schizophrenia
#
#                                  ontologyTermIRI   score validated review  \
# 492    http://purl.obolibrary.org/obo/HP_0100753  100.00     False  False
# 1301   http://purl.obolibrary.org/obo/HP_0001638   81.25     False  False
# 1302   http://purl.obolibrary.org/obo/HP_0001662  100.00     False  False
# 2262   http://purl.obolibrary.org/obo/HP_0000939  100.00     False  False
# 2281   http://purl.obolibrary.org/obo/HP_0002020  100.00     False  False
# 2356   http://purl.obolibrary.org/obo/HP_0100753  100.00     False  False
# 3652   http://purl.obolibrary.org/obo/HP_0012735  100.00     False  False
# 4664   http://purl.obolibrary.org/obo/HP_0001824  100.00     False  False
# 5972   http://purl.obolibrary.org/obo/HP_0002076  100.00     False  False
# 6768   http://purl.obolibrary.org/obo/HP_0000822  100.00     False  False
# 7027   http://purl.obolibrary.org/obo/HP_0000708  100.00     False  False
# 7028   http://purl.obolibrary.org/obo/HP_0002076  100.00     False  False
# 12007  http://purl.obolibrary.org/obo/HP_0100753  100.00     False  False
# 12748  http://purl.obolibrary.org/obo/HP_0000822  100.00     False  False
# 13453  http://purl.obolibrary.org/obo/HP_0100753  100.00     False  False
# 13486  http://purl.obolibrary.org/obo/HP_0002014  100.00     False  False
# 13499  http://purl.obolibrary.org/obo/HP_0008222  100.00     False  False
# 13579  http://purl.obolibrary.org/obo/HP_0100753  100.00     False  False
# 13599  http://purl.obolibrary.org/obo/HP_0001635  100.00     False  False
# 13953  http://purl.obolibrary.org/obo/HP_0003124   85.71     False  False
# 17354  http://purl.obolibrary.org/obo/HP_0002014  100.00     False  False
# 17406  http://purl.obolibrary.org/obo/HP_0000822  100.00     False  False
# 17544  http://purl.obolibrary.org/obo/HP_0001635  100.00     False  False
# 18177  http://purl.obolibrary.org/obo/HP_0001513  100.00     False  False
# 18485  http://purl.obolibrary.org/obo/HP_0001635  100.00     False  False
# 20430  http://purl.obolibrary.org/obo/HP_0100242  100.00     False  False
# 21288  http://purl.obolibrary.org/obo/HP_0000716  100.00     False  False
# 23208  http://purl.obolibrary.org/obo/HP_0002014  100.00     False  False
# 23377  http://purl.obolibrary.org/obo/HP_0002018  100.00     False  False
# 23394  http://purl.obolibrary.org/obo/HP_0002140  100.00     False  False
# 23558  http://purl.obolibrary.org/obo/HP_0002020  100.00     False  False
# 23674  http://purl.obolibrary.org/obo/HP_0001513  100.00     False  False
# 23916  http://purl.obolibrary.org/obo/HP_0100753  100.00     False  False
# 24093  http://purl.obolibrary.org/obo/HP_0002669  100.00     False  False
# 24723  http://purl.obolibrary.org/obo/HP_0100753  100.00     False  False
# 25467  http://purl.obolibrary.org/obo/HP_0001635  100.00     False  False
# 25825  http://purl.obolibrary.org/obo/HP_0002098   82.93     False  False
# 25826  http://purl.obolibrary.org/obo/HP_0000989  100.00     False  False
# 26992  http://purl.obolibrary.org/obo/HP_0100753  100.00     False  False
#
#                ID
# 492    HP:0100753
# 1301   HP:0001638
# 1302   HP:0001662
# 2262   HP:0000939
# 2281   HP:0002020
# 2356   HP:0100753
# 3652   HP:0012735
# 4664   HP:0001824
# 5972   HP:0002076
# 6768   HP:0000822
# 7027   HP:0000708
# 7028   HP:0002076
# 12007  HP:0100753
# 12748  HP:0000822
# 13453  HP:0100753
# 13486  HP:0002014
# 13499  HP:0008222
# 13579  HP:0100753
# 13599  HP:0001635
# 13953  HP:0003124
# 17354  HP:0002014
# 17406  HP:0000822
# 17544  HP:0001635
# 18177  HP:0001513
# 18485  HP:0001635
# 20430  HP:0100242
# 21288  HP:0000716
# 23208  HP:0002014
# 23377  HP:0002018
# 23394  HP:0002140
# 23558  HP:0002020
# 23674  HP:0001513
# 23916  HP:0100753
# 24093  HP:0002669
# 24723  HP:0100753
# 25467  HP:0001635
# 25825  HP:0002098
# 25826  HP:0000989
# 26992  HP:0100753

# %%
final_filtered = final_filtered.drop(labels = ['Unnamed: 0', 'score'], axis =1)

# %%
final_filtered.head(10)
# Out:
#      DRUG_ID               DRUG_NAME                          DISEASES  \
# 492     2172                Pimozide                    Schizophrenia
# 1301      91  Adenosine triphosphate                    Heart disease
# 1302      91  Adenosine triphosphate                      Bradycardia
# 2262    2351              Raloxifene                     Osteoporosis
# 2281    1990              Omeprazole  Gastroesophageal reflux disease
# 2356     621          Chlorpromazine                    Schizophrenia
# 3652     725                 Codeine                            Cough
# 4664     578               Cerulenin                      Weight loss
# 5972    1200             Flunarizine                         Migraine
# 6768    1989             Omapatrilat                     Hypertension
#
#                          PHASE                             Name  \
# 492                   Approved                    schizophrenia
# 1301                   Phase 2                    heart disease
# 1302   Discontinued in Phase 2                      bradycardia
# 2262                  Approved                     osteoporosis
# 2281                  Approved  gastroesophageal reflux disease
# 2356                  Approved                    schizophrenia
# 3652                   Phase 1                            cough
# 4664                  Approved                      weight loss
# 5972                  Approved                         migraine
# 6768                Terminated                     hypertension
#
#              ontologyTermName                            ontologyTermIRI  \
# 492             Schizophrenia  http://purl.obolibrary.org/obo/HP_0100753
# 1301           Cardiomyopathy  http://purl.obolibrary.org/obo/HP_0001638
# 1302              Bradycardia  http://purl.obolibrary.org/obo/HP_0001662
# 2262             Osteoporosis  http://purl.obolibrary.org/obo/HP_0000939
# 2281  Gastroesophageal reflux  http://purl.obolibrary.org/obo/HP_0002020
# 2356            Schizophrenia  http://purl.obolibrary.org/obo/HP_0100753
# 3652                    Cough  http://purl.obolibrary.org/obo/HP_0012735
# 4664              Weight loss  http://purl.obolibrary.org/obo/HP_0001824
# 5972                 Migraine  http://purl.obolibrary.org/obo/HP_0002076
# 6768             Hypertension  http://purl.obolibrary.org/obo/HP_0000822
#
#      validated review          ID
# 492      False  False  HP:0100753
# 1301     False  False  HP:0001638
# 1302     False  False  HP:0001662
# 2262     False  False  HP:0000939
# 2281     False  False  HP:0002020
# 2356     False  False  HP:0100753
# 3652     False  False  HP:0012735
# 4664     False  False  HP:0001824
# 5972     False  False  HP:0002076
# 6768     False  False  HP:0000822

# %%
final_filtered.to_csv('drug_to_disease_final_v2_ELA.csv', encoding = 'utf-8-sig')
