# %% [markdown]
# ## **Import**

# %%
import re
import numpy as np
import pandas as pd
import urllib.parse
import urllib.request
import requests

# %% [markdown]
# ## **Drug-Target Information**

# %% [markdown]
# ### **Load Files**

# %% [markdown]
# Load the information from Drug Central and Monarch:

# %%
df = pd.read_csv('../data/drug.target.interaction.tsv', header=0, index_col=0, sep='\t')
#nodes = pd.read_csv('graph_nodes_v2022-01-11.csv', header=0)
nodes = pd.read_csv('monarch/monarch_nodes_v2023-02-20.csv', header=0)

# %%
df['NEW_ID'] = ''

# %% [markdown]
# ### **Uniprot to Monarch IDs**

# %% [markdown]
# Use Uniprot API to obtain new target IDs:

# %%
import re
import time
import json
import zlib
from xml.etree import ElementTree
from urllib.parse import urlparse, parse_qs, urlencode
import requests
from requests.adapters import HTTPAdapter, Retry


POLLING_INTERVAL = 3
API_URL = "https://rest.uniprot.org"


retries = Retry(total=5, backoff_factor=0.25, status_forcelist=[500, 502, 503, 504])
session = requests.Session()
session.mount("https://", HTTPAdapter(max_retries=retries))


def check_response(response):
    try:
        response.raise_for_status()
    except requests.HTTPError:
        print(response.json())
        raise


def submit_id_mapping(from_db, to_db, ids):
    request = requests.post(
        f"{API_URL}/idmapping/run",
        data={"from": from_db, "to": to_db, "ids": ",".join(ids)},
    )
    check_response(request)
    return request.json()["jobId"]


def get_next_link(headers):
    re_next_link = re.compile(r'<(.+)>; rel="next"')
    if "Link" in headers:
        match = re_next_link.match(headers["Link"])
        if match:
            return match.group(1)


def check_id_mapping_results_ready(job_id):
    while True:
        request = session.get(f"{API_URL}/idmapping/status/{job_id}")
        check_response(request)
        j = request.json()
        if "jobStatus" in j:
            if j["jobStatus"] == "RUNNING":
                print(f"Retrying in {POLLING_INTERVAL}s")
                time.sleep(POLLING_INTERVAL)
            else:
                raise Exception(j["jobStatus"])
        else:
            return bool(j["results"] or j["failedIds"])


def get_batch(batch_response, file_format, compressed):
    batch_url = get_next_link(batch_response.headers)
    while batch_url:
        batch_response = session.get(batch_url)
        batch_response.raise_for_status()
        yield decode_results(batch_response, file_format, compressed)
        batch_url = get_next_link(batch_response.headers)


def combine_batches(all_results, batch_results, file_format):
    if file_format == "json":
        for key in ("results", "failedIds"):
            if key in batch_results and batch_results[key]:
                all_results[key] += batch_results[key]
    elif file_format == "tsv":
        return all_results + batch_results[1:]
    else:
        return all_results + batch_results
    return all_results


def get_id_mapping_results_link(job_id):
    url = f"{API_URL}/idmapping/details/{job_id}"
    request = session.get(url)
    check_response(request)
    return request.json()["redirectURL"]


def decode_results(response, file_format, compressed):
    if compressed:
        decompressed = zlib.decompress(response.content, 16 + zlib.MAX_WBITS)
        if file_format == "json":
            j = json.loads(decompressed.decode("utf-8"))
            return j
        elif file_format == "tsv":
            return [line for line in decompressed.decode("utf-8").split("\n") if line]
        elif file_format == "xlsx":
            return [decompressed]
        elif file_format == "xml":
            return [decompressed.decode("utf-8")]
        else:
            return decompressed.decode("utf-8")
    elif file_format == "json":
        return response.json()
    elif file_format == "tsv":
        return [line for line in response.text.split("\n") if line]
    elif file_format == "xlsx":
        return [response.content]
    elif file_format == "xml":
        return [response.text]
    return response.text


def get_xml_namespace(element):
    m = re.match(r"\{(.*)\}", element.tag)
    return m.groups()[0] if m else ""


def merge_xml_results(xml_results):
    merged_root = ElementTree.fromstring(xml_results[0])
    for result in xml_results[1:]:
        root = ElementTree.fromstring(result)
        for child in root.findall("{http://uniprot.org/uniprot}entry"):
            merged_root.insert(-1, child)
    ElementTree.register_namespace("", get_xml_namespace(merged_root[0]))
    return ElementTree.tostring(merged_root, encoding="utf-8", xml_declaration=True)


def print_progress_batches(batch_index, size, total):
    n_fetched = min((batch_index + 1) * size, total)
    print(f"Fetched: {n_fetched} / {total}")


def get_id_mapping_results_search(url):
    parsed = urlparse(url)
    query = parse_qs(parsed.query)
    file_format = query["format"][0] if "format" in query else "json"
    if "size" in query:
        size = int(query["size"][0])
    else:
        size = 500
        query["size"] = size
    compressed = (
        query["compressed"][0].lower() == "true" if "compressed" in query else False
    )
    parsed = parsed._replace(query=urlencode(query, doseq=True))
    url = parsed.geturl()
    request = session.get(url)
    check_response(request)
    results = decode_results(request, file_format, compressed)
    total = int(request.headers["x-total-results"])
    print_progress_batches(0, size, total)
    for i, batch in enumerate(get_batch(request, file_format, compressed), 1):
        results = combine_batches(results, batch, file_format)
        print_progress_batches(i, size, total)
    if file_format == "xml":
        return merge_xml_results(results)
    return results


def get_id_mapping_results_stream(url):
    if "/stream/" not in url:
        url = url.replace("/results/", "/results/stream/")
    request = session.get(url)
    check_response(request)
    parsed = urlparse(url)
    query = parse_qs(parsed.query)
    file_format = query["format"][0] if "format" in query else "json"
    compressed = (
        query["compressed"][0].lower() == "true" if "compressed" in query else False
    )
    return decode_results(request, file_format, compressed)


job_id = submit_id_mapping(
    from_db="UniProtKB_AC-ID", to_db="HGNC", ids=["Q12809"]
)
if check_id_mapping_results_ready(job_id):
    link = get_id_mapping_results_link(job_id)
    results = get_id_mapping_results_search(link)
    # Equivalently using the stream endpoint which is more demanding
    # on the API and so is less stable:
    # results = get_id_mapping_results_stream(link)

print(results)
# {'results': [{'from': 'P05067', 'to': 'CHEMBL2487'}], 'failedIds': ['P12345']}
# Out:
# Fetched: 1 / 1
# {'results': [{'from': 'Q12809', 'to': 'HGNC:6251'}]}

# %%
for i in range(0, df.shape[0]): 
  print('Going through row', i, ' out of', df.shape[0])

  id = df['ACCESSION'][i].split('|')[0]
  print(id)
  org = df['ORGANISM'][i]
  print(org)

  if org == 'Homo sapiens': 
    to = 'HGNC'
    pre = ''
  elif org == 'Rattus norvegicus': 
    to = 'RGD'
    pre = 'RGD:'
  elif org == 'Mus musculus': 
    to = 'MGI'
    pre = ''
  elif org == 'Drosophila melanogaster':
    to = 'FlyBase'
    pre = 'FlyBase'
  elif org == 'Caenorhabditis elegans': 
    to = 'WormBase'
    pre = 'WormBase:'
  elif org == 'Danio rerio': 
    to = 'ZFIN'
    pre = 'ZFIN:'
  elif org == 'Saccharomyces cerevisiae': 
    to = 'SGD'
    pre = 'SGD:'
  else:   
    to = 'Ensembl'
    pre = 'ENSEMBL:'
  
  
  job_id = submit_id_mapping(
  from_db="UniProtKB_AC-ID", to_db=to , ids=[id])

  try: 
    if check_id_mapping_results_ready(job_id):
        link = get_id_mapping_results_link(job_id)
        results = get_id_mapping_results_search(link)
        # Equivalently using the stream endpoint which is more demanding
        # on the API and so is less stable:
        # results = get_id_mapping_results_stream(link)
  except: 
    continue
  #print(results)
  if len(results['results'])>0: 
    df['NEW_ID'][i] = pre + results['results'][0]['to']
  else: 
    df['NEW_ID'][i] = 'NA'
# Out:
# Going through row 0  out of 19378
# Q12809
# Homo sapiens
# Fetched: 1 / 1
# Going through row 1  out of 19378
# P35498
# Homo sapiens
# C:\Users\rosa-\AppData\Local\Temp\ipykernel_31444\3624377136.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['NEW_ID'][i] = pre + results['results'][0]['to']
# Fetched: 1 / 1
# Going through row 2  out of 19378
# P35499
# Homo sapiens
# Fetched: 1 / 1
# Going through row 3  out of 19378
# P34995
# Homo sapiens
# Fetched: 1 / 1
# Going through row 4  out of 19378
# P10635
# Homo sapiens
# Fetched: 1 / 1
# Going through row 5  out of 19378
# P46098
# Homo sapiens
# Fetched: 1 / 1
# Going through row 6  out of 19378
# Q9UK17
# Homo sapiens
# Fetched: 1 / 1
# Going through row 7  out of 19378
# P22460
# Homo sapiens
# Fetched: 1 / 1
# Going through row 8  out of 19378
# Q01668
# Homo sapiens
# Fetched: 1 / 1
# Going through row 9  out of 19378
# O15554
# Homo sapiens
# Fetched: 1 / 1
# Going through row 10  out of 19378
# Q01668
# Homo sapiens
# Fetched: 1 / 1
# Going through row 11  out of 19378
# O60840
# Homo sapiens
# Fetched: 1 / 1
# Going through row 12  out of 19378
# P22002
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 13  out of 19378
# Q02485
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 14  out of 19378
# Q13936
# Homo sapiens
# Fetched: 1 / 1
# Going through row 15  out of 19378
# P08588
# Homo sapiens
# Fetched: 1 / 1
# Going through row 16  out of 19378
# P00375
# Mus musculus
# Fetched: 1 / 1
# Going through row 17  out of 19378
# P00381
# Lactobacillus casei
# Fetched: 0 / 0
# Going through row 18  out of 19378
# B0BL08
# Escherichia coli
# C:\Users\rosa-\AppData\Local\Temp\ipykernel_31444\3624377136.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['NEW_ID'][i] = 'NA'
# Fetched: 0 / 0
# Going through row 19  out of 19378
# P48760
# Mus musculus
# Fetched: 1 / 1
# Going through row 20  out of 19378
# P00374
# Homo sapiens
# Fetched: 1 / 1
# Going through row 21  out of 19378
# P15121
# Homo sapiens
# Fetched: 1 / 1
# Going through row 22  out of 19378
# Q92769
# Homo sapiens
# Fetched: 1 / 1
# Going through row 23  out of 19378
# Q13547
# Homo sapiens
# Fetched: 1 / 1
# Going through row 24  out of 19378
# Q9BY41
# Homo sapiens
# Fetched: 1 / 1
# Going through row 25  out of 19378
# P26358
# Homo sapiens
# Fetched: 1 / 1
# Going through row 26  out of 19378
# Q9Y6K1
# Homo sapiens
# Fetched: 1 / 1
# Going through row 27  out of 19378
# P04818
# Homo sapiens
# Fetched: 1 / 1
# Going through row 28  out of 19378
# O15440
# Homo sapiens
# Fetched: 1 / 1
# Going through row 29  out of 19378
# Q96J66
# Homo sapiens
# Fetched: 1 / 1
# Going through row 30  out of 19378
# P07607
# Mus musculus
# Fetched: 1 / 1
# Going through row 31  out of 19378
# P0A8F0
# Escherichia coli (strain K12)
# Fetched: 0 / 0
# Going through row 32  out of 19378
# O26232
# Methanothermobacter thermautotrophicus (strain ATCC 29096 / DSM 1053 / JCM 10044 / NBRC 100330 / Delta H)
# Fetched: 0 / 0
# Going through row 33  out of 19378
# P03962
# Saccharomyces cerevisiae
# Fetched: 1 / 1
# Going through row 34  out of 19378
# P22303
# Homo sapiens
# Fetched: 1 / 1
# Going through row 35  out of 19378
# P05177
# Homo sapiens
# Fetched: 1 / 1
# Going through row 36  out of 19378
# P21397
# Homo sapiens
# Fetched: 1 / 1
# Going through row 37  out of 19378
# O42713
# Agaricus bisporus
# Fetched: 0 / 0
# Going through row 38  out of 19378
# O42713
# Agaricus bisporus
# Fetched: 0 / 0
# Going through row 39  out of 19378
# P03369
# Human immunodeficiency virus type 1 group M subtype B (isolate ARV2/SF2)
# Retrying in 3s
# Fetched: 0 / 0
# Going through row 40  out of 19378
# Q72547
# Human immunodeficiency virus 1
# Retrying in 3s
# Fetched: 0 / 0
# Going through row 41  out of 19378
# Q9WKE8
# Human immunodeficiency virus 1
# Retrying in 3s
# Fetched: 0 / 0
# Going through row 42  out of 19378
# P30968
# Homo sapiens
# Retrying in 3s
# Fetched: 1 / 1
# Going through row 43  out of 19378
# P14867
# Homo sapiens
# Retrying in 3s
# Fetched: 1 / 1
# Going through row 44  out of 19378
# O15399
# Homo sapiens
# Retrying in 3s
# Fetched: 1 / 1
# Going through row 45  out of 19378
# O43451
# Homo sapiens
# Retrying in 3s
# Fetched: 1 / 1
# Going through row 46  out of 19378
# P04746
# Homo sapiens
# Retrying in 3s
# Fetched: 1 / 1
# Going through row 47  out of 19378
# P04745
# Homo sapiens
# Retrying in 3s
# Fetched: 3 / 3
# Going through row 48  out of 19378
# P10253
# Homo sapiens
# Retrying in 3s
# Fetched: 1 / 1
# Going through row 49  out of 19378
# P23739
# Rattus norvegicus
# Retrying in 3s
# Going through row 50  out of 19378
# Q6P7A9
# Rattus norvegicus
# Retrying in 3s
# Fetched: 1 / 1
# Going through row 51  out of 19378
# P94451
# Geobacillus stearothermophilus
# Retrying in 3s
# Fetched: 0 / 0
# Going through row 52  out of 19378
# P53051
# Saccharomyces cerevisiae (strain ATCC 204508 / S288c)
# Retrying in 3s
# Fetched: 0 / 0
# Going through row 53  out of 19378
# P00690
# Sus scrofa
# Retrying in 3s
# Going through row 54  out of 19378
# P14410
# Homo sapiens
# Retrying in 3s
# Fetched: 1 / 1
# Going through row 55  out of 19378
# P08588
# Homo sapiens
# Fetched: 1 / 1
# Going through row 56  out of 19378
# P07550
# Homo sapiens
# Retrying in 3s
# Fetched: 1 / 1
# Going through row 57  out of 19378
# P19327
# Rattus norvegicus
# Retrying in 3s
# Fetched: 1 / 1
# Going through row 58  out of 19378
# P02766
# Homo sapiens
# Retrying in 3s

# %%
df = pd.read_csv('drug-target-all.csv', header=0)

# %%
df
# Out:
#              DRUG_NAME  STRUCT_ID  \
# 0      levobupivacaine          4
# 1      levobupivacaine          4
# 2      levobupivacaine          4
# 3      levobupivacaine          4
# 4      levobupivacaine          4
# ...                ...        ...
# 19373      samidorphan       5460
# 19374        sotorasib       5461
# 19375    ibrexafungerp       5462
# 19376    ibrexafungerp       5462
# 19377    ibrexafungerp       5462
#
#                                              TARGET_NAME TARGET_CLASS  \
# 0      Potassium voltage-gated channel subfamily H me...  Ion channel
# 1            Sodium channel protein type 1 subunit alpha  Ion channel
# 2            Sodium channel protein type 4 subunit alpha  Ion channel
# 3                  Prostaglandin E2 receptor EP1 subtype         GPCR
# 4                                    Cytochrome P450 2D6       Enzyme
# ...                                                  ...          ...
# 19373                         Delta-type opioid receptor         GPCR
# 19374                                        GTPase KRas       Enzyme
# 19375       Beta-1,3-glucan synthase catalytic subunit 1       Enzyme
# 19376          1,3-Beta-D-glucan-UDP glucosyltransferase       Enzyme
# 19377          1,3-Beta-D-glucan-UDP glucosyltransferase       Enzyme
#
#       ACCESSION    GENE     SWISSPROT  ACT_VALUE  ACT_UNIT ACT_TYPE  ...  \
# 0        Q12809   KCNH2   KCNH2_HUMAN      4.890       NaN     IC50  ...
# 1        P35498   SCN1A   SCN1A_HUMAN      5.790       NaN     IC50  ...
# 2        P35499   SCN4A   SCN4A_HUMAN        NaN       NaN      NaN  ...
# 3        P34995  PTGER1   PE2R1_HUMAN        NaN       NaN      NaN  ...
# 4        P10635  CYP2D6   CP2D6_HUMAN      6.707       NaN     IC50  ...
# ...         ...     ...           ...        ...       ...      ...  ...
# 19373    P41143   OPRD1    OPRD_HUMAN      8.590       NaN       Ki  ...
# 19374    P01116    KRAS    RASK_HUMAN      7.030       NaN     IC50  ...
# 19375    O13428    GSC1  O13428_CANAX      8.350       NaN     IC50  ...
# 19376    Q6FTN8    FKS1  Q6FTN8_CANGA      7.830       NaN     IC50  ...
# 19377    P87204     FKS  P87204_ASPFM      8.970       NaN     IC50  ...
#
#                   ACT_SOURCE RELATION  MOA             MOA_SOURCE  \
# 0                     CHEMBL        =  NaN                    NaN
# 1                  WOMBAT-PK        =  NaN                    NaN
# 2                  WOMBAT-PK      NaN  1.0                 CHEMBL
# 3                  WOMBAT-PK      NaN  NaN                    NaN
# 4                DRUG MATRIX        =  NaN                    NaN
# ...                      ...      ...  ...                    ...
# 19373             DRUG LABEL        =  NaN                    NaN
# 19374             DRUG LABEL        =  1.0             DRUG LABEL
# 19375  SCIENTIFIC LITERATURE        =  1.0             DRUG LABEL
# 19376  SCIENTIFIC LITERATURE        =  1.0  SCIENTIFIC LITERATURE
# 19377  SCIENTIFIC LITERATURE        =  1.0  SCIENTIFIC LITERATURE
#
#                                           ACT_SOURCE_URL  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 19373  https://www.accessdata.fda.gov/drugsatfda_docs...
# 19374  https://www.accessdata.fda.gov/drugsatfda_docs...
# 19375           https://pubmed.ncbi.nlm.nih.gov/24323472
# 19376           https://pubmed.ncbi.nlm.nih.gov/24323472
# 19377           https://pubmed.ncbi.nlm.nih.gov/24323472
#
#                                           MOA_SOURCE_URL      ACTION_TYPE  \
# 0                                                    NaN              NaN
# 1                                                    NaN              NaN
# 2      https://www.ebi.ac.uk/chembl/compound/inspect/...          BLOCKER
# 3                                                    NaN              NaN
# 4                                                    NaN              NaN
# ...                                                  ...              ...
# 19373                                                NaN  PARTIAL AGONIST
# 19374  https://www.accessdata.fda.gov/drugsatfda_docs...        INHIBITOR
# 19375  https://www.accessdata.fda.gov/drugsatfda_docs...        INHIBITOR
# 19376  https://www.accessdata.fda.gov/drugsatfda_docs...        INHIBITOR
# 19377  https://www.accessdata.fda.gov/drugsatfda_docs...        INHIBITOR
#
#          TDL              ORGANISM      NEW_ID
# 0      Tclin          Homo sapiens   HGNC:6251
# 1      Tclin          Homo sapiens  HGNC:10585
# 2      Tclin          Homo sapiens  HGNC:10591
# 3      Tclin          Homo sapiens   HGNC:9593
# 4      Tclin          Homo sapiens   HGNC:2625
# ...      ...                   ...         ...
# 19373  Tclin          Homo sapiens   HGNC:8153
# 19374  Tchem          Homo sapiens   HGNC:6407
# 19375    NaN      Candida albicans         NaN
# 19376    NaN      Candida glabrata         NaN
# 19377    NaN  Neosartorya fumigata         NaN
#
# [19378 rows x 21 columns]

# %% [markdown]
# Drop rows that don't have a new ID:

# %%
df = df.drop(df[df.NEW_ID == 'NA'].index)

# %% [markdown]
# Keep only rows whose the target is in the Monarch nodes:

# %%
df = df[df['NEW_ID'].isin(list(nodes['id']))]

# %% [markdown]
# Save the Drug-Target dataframe as .csv:

# %%
df.to_csv('drug.target.final.ELA.csv', encoding = 'utf-8-sig')

# %% [markdown]
# Create and save a dataframe containing the drug nodes:

# %%
df_drugs = df[['DRUG_NAME', 'STRUCT_ID']]
df_drugs = df_drugs.drop_duplicates()
df_drugs.to_csv('drug_nodes_ELA.csv', encoding = 'utf-8-sig')

# %%
df
# Out:
#                  DRUG_NAME  STRUCT_ID                           TARGET_NAME  \
# 21     phenylbutanoic acid         24                      Aldose reductase
# 59             aceclofenac         43                      Aldose reductase
# 67              acemetacin         47              Lactoylglutathione lyase
# 174         acetylcysteine         66                          Cytochrome c
# 175         acetylcysteine         66  Vascular endothelial growth factor A
# ...                    ...        ...                                   ...
# 19194           lonafarnib       5414                           GTPase KRas
# 19218           vadadustat       5420  Vascular endothelial growth factor A
# 19220           vadadustat       5420  Vascular endothelial growth factor A
# 19302             estetrol       5450                Estrogen receptor beta
# 19374            sotorasib       5461                           GTPase KRas
#
#                    TARGET_CLASS ACCESSION    GENE    SWISSPROT  ACT_VALUE  \
# 21                       Enzyme    P15121  AKR1B1   ALDR_HUMAN       4.02
# 59                       Enzyme    P07943  Akr1b1     ALDR_RAT       5.89
# 67                       Enzyme    Q04760    GLO1   LGUL_HUMAN       4.89
# 174                      Enzyme    P99999    CYCS    CYC_HUMAN        NaN
# 175                    Secreted    P15692   VEGFA  VEGFA_HUMAN        NaN
# ...                         ...       ...     ...          ...        ...
# 19194                    Enzyme    P01116    KRAS   RASK_HUMAN       8.28
# 19218                  Secreted    P15692   VEGFA  VEGFA_HUMAN       5.12
# 19220              Unclassified    P15692   VEGFA  VEGFA_HUMAN       5.12
# 19302  Nuclear hormone receptor    Q92731    ESR2   ESR2_HUMAN       7.72
# 19374                    Enzyme    P01116    KRAS   RASK_HUMAN       7.03
#
#        ACT_UNIT ACT_TYPE  ...             ACT_SOURCE RELATION  MOA  \
# 21          NaN     IC50  ...                 CHEMBL        =  NaN
# 59          NaN     IC50  ...            DRUG MATRIX        =  NaN
# 67          NaN       Ki  ...                 CHEMBL        =  NaN
# 174         NaN      NaN  ...              WOMBAT-PK      NaN  NaN
# 175         NaN      NaN  ...              WOMBAT-PK      NaN  NaN
# ...         ...      ...  ...                    ...      ...  ...
# 19194       NaN     IC50  ...                 IUPHAR        =  NaN
# 19218       NaN     EC50  ...                 CHEMBL        =  NaN
# 19220       NaN     EC50  ...                 CHEMBL        =  NaN
# 19302       NaN       Ki  ...  SCIENTIFIC LITERATURE        =  1.0
# 19374       NaN     IC50  ...             DRUG LABEL        =  1.0
#
#        MOA_SOURCE                                     ACT_SOURCE_URL  \
# 21            NaN                                                NaN
# 59            NaN                                                NaN
# 67            NaN                                                NaN
# 174           NaN                                                NaN
# 175           NaN                                                NaN
# ...           ...                                                ...
# 19194         NaN                                                NaN
# 19218         NaN                                                NaN
# 19220         NaN                                                NaN
# 19302  DRUG LABEL           https://pubmed.ncbi.nlm.nih.gov/18464023
# 19374  DRUG LABEL  https://www.accessdata.fda.gov/drugsatfda_docs...
#
#                                           MOA_SOURCE_URL ACTION_TYPE    TDL  \
# 21                                                   NaN         NaN  Tclin
# 59                                                   NaN         NaN    NaN
# 67                                                   NaN         NaN  Tchem
# 174                                                  NaN         NaN   Tbio
# 175                                                  NaN         NaN  Tclin
# ...                                                  ...         ...    ...
# 19194                                                NaN   INHIBITOR  Tchem
# 19218                                                NaN         NaN  Tclin
# 19220                                                NaN         NaN  Tclin
# 19302  https://www.accessdata.fda.gov/drugsatfda_docs...   MODULATOR  Tclin
# 19374  https://www.accessdata.fda.gov/drugsatfda_docs...   INHIBITOR  Tchem
#
#                 ORGANISM      NEW_ID
# 21          Homo sapiens    HGNC:381
# 59     Rattus norvegicus    RGD:2092
# 67          Homo sapiens   HGNC:4323
# 174         Homo sapiens  HGNC:19986
# 175         Homo sapiens  HGNC:12680
# ...                  ...         ...
# 19194       Homo sapiens   HGNC:6407
# 19218       Homo sapiens  HGNC:12680
# 19220       Homo sapiens  HGNC:12680
# 19302       Homo sapiens   HGNC:3468
# 19374       Homo sapiens   HGNC:6407
#
# [330 rows x 21 columns]

# %% [markdown]
# ## **Drug-Disease Information**

# %% [markdown]
# ### **Text to CSV**

# %% [markdown]
# If already saved, run only the cell of this section, otherwise continue:

# %% [markdown]
# Create a Dataframe that will contain the Drug-Disease information:

# %%
column_names = ["DRUG_ID", "DRUG_NAME", "DISEASES", 'PHASE']

df = pd.DataFrame(columns = column_names)

# %% [markdown]
# Read the .txt file downloaded from TTD and convert it into a pandas dataframe:

# %%
with open('drug_to_disease.txt') as f:
  lines = f.readlines()

# %%
i = 0
id = ''
name = ''
disease = ''
phase = ''

for line in lines: 
  if line.startswith('DRUGNAME'): 
    result = re.search('\t(.*)\n', line)
    name = result.group(1)
  elif line.startswith('TTDDRUID'): 
    result = re.search('\t(.*)\n', line)
    id = result.group(1)
  elif line.startswith('INDICATI'): 
    result = re.search('\t(.*)\[', line)
    result2 = re.search('\](.*)', line)
    disease = result.group(1) 
    phase = result2.group(1) 
    df.loc[i] = [id,name,disease, phase]
    i += 1
  elif line.startswith('\n'): 
    id = ''
    name = ''
    disease = ''
    phase = ''

# %%
df
# Out:
#       DRUG_ID     DRUG_NAME                                   DISEASES  \
# 0      D00ABE       ALD-301                                  Ischemia
# 1      D00ABE       ALD-301               Peripheral arterial disease
# 2      D00ABO       KW-2449                   Acute myeloid leukaemia
# 3      D00ABW      Opterone                        Hormone deficiency
# 4      D00ACC        ND1251                                Depression
# ...       ...           ...                                        ...
# 28973  DZTX12        ASC-J9                   End-stage renal disease
# 28974  DZU72C       OKI 179                       Solid tumour/cancer
# 28975  DZVF15       TRN-110  Attention deficit hyperactivity disorder
# 28976  DZW53X    GSK4069889                Non-small cell lung cancer
# 28977  DZY4R2  JNJ-74699157                       Solid tumour/cancer
#
#                           PHASE
# 0                       Phase 2
# 1                       Phase 2
# 2                       Phase 1
# 3       Discontinued in Phase 1
# 4       Discontinued in Phase 1
# ...                         ...
# 28973                   Phase 2
# 28974                   Phase 1
# 28975            Clinical Trial
# 28976                   Phase 2
# 28977                   Phase 1
#
# [28978 rows x 4 columns]

# %%
df.to_csv('drug_to_disease (1).csv', encoding = 'utf-8-sig')

# %% [markdown]
# Run only this cell if you have already saved the Drug-Disease interactions:

# %%
df = pd.read_csv('drug_to_disease (1).csv', header=0, index_col=0)

# %%
df
# Out:
#       DRUG_ID     DRUG_NAME                                   DISEASES  \
# 0      D00ABE       ALD-301                                  Ischemia
# 1      D00ABE       ALD-301               Peripheral arterial disease
# 2      D00ABO       KW-2449                   Acute myeloid leukaemia
# 3      D00ABW      Opterone                        Hormone deficiency
# 4      D00ACC        ND1251                                Depression
# ...       ...           ...                                        ...
# 28973  DZTX12        ASC-J9                   End-stage renal disease
# 28974  DZU72C       OKI 179                       Solid tumour/cancer
# 28975  DZVF15       TRN-110  Attention deficit hyperactivity disorder
# 28976  DZW53X    GSK4069889                Non-small cell lung cancer
# 28977  DZY4R2  JNJ-74699157                       Solid tumour/cancer
#
#                           PHASE
# 0                       Phase 2
# 1                       Phase 2
# 2                       Phase 1
# 3       Discontinued in Phase 1
# 4       Discontinued in Phase 1
# ...                         ...
# 28973                   Phase 2
# 28974                   Phase 1
# 28975            Clinical Trial
# 28976                   Phase 2
# 28977                   Phase 1
#
# [28978 rows x 4 columns]

# %%
df.to_csv('drug_to_disease (1).csv', encoding = 'utf-8-sig')

# %% [markdown]
# ### **Load CSVs**

# %% [markdown]
# Load the drug nodes (obtained from Drug Central) and the Monarch nodes:

# %%
graph_drugs = pd.read_csv('drug_nodes_ELA.csv', header=0)
nodes = pd.read_csv('monarch_nodes_v2022-12-29.csv', header=0)

# %% [markdown]
# Get list of unique drugs and diseases:

# %%
graph_diseases = nodes[nodes['semantic_groups'] == 'DISO']
unique_diseases = graph_diseases['name'].unique()
unique_dis_id = graph_diseases['id'].unique()
unique_diseases = [x.lower() for x in unique_diseases]

# %%
unique_drugs = graph_drugs['DRUG_NAME'].unique()
unique_drugs = [x.lower() for x in unique_drugs]
len(unique_drugs)
# Out:
# 229

# %% [markdown]
# At this point you should use SORTA tool (https://sorta.molgeniscloud.org/menu/main/sorta?) to match the IDs of TTD to Human Phenotype Ontology (HPO). The file is also available in the project's Github:

# %%
matched = pd.read_csv('matched.csv', header = 0, delimiter = ';')

# %%
matched
# Out:
#                                                    Name  \
# 0                                   respiratory failure
# 1                                    sexual dysfunction
# 2                                        achondroplasia
# 3                                  glabellar frown line
# 4                           testicular germ cell tumour
# ...                                                 ...
# 1796                              systemic mastocytosis
# 1797                    acute iron or aluminum toxicity
# 1798  chronic inflammatory demyelinating polyneuropathy
# 1799                                    aortic aneurysm
# 1800                                              fever
#
#                           ontologyTermName  \
# 0                      Respiratory failure
# 1                  Male sexual dysfunction
# 2                         Bronchodysplasia
# 3                       Prominent glabella
# 4                      Testicular neoplasm
# ...                                    ...
# 1796                          Mastocytosis
# 1797  Abnormal total iron binding capacity
# 1798    Acute demyelinating polyneuropathy
# 1799                       Aortic aneurysm
# 1800                                 Fever
#
#                                 ontologyTermIRI   score  validated  review
# 0     http://purl.obolibrary.org/obo/HP_0002878  100.00      False   False
# 1     http://purl.obolibrary.org/obo/HP_0040307   86.49      False   False
# 2     http://purl.obolibrary.org/obo/HP_0006533   62.50      False   False
# 3     http://purl.obolibrary.org/obo/HP_0002057   59.46      False   False
# 4     http://purl.obolibrary.org/obo/HP_0010788   71.11      False   False
# ...                                         ...     ...        ...     ...
# 1796  http://purl.obolibrary.org/obo/HP_0100495   77.42      False   False
# 1797  http://purl.obolibrary.org/obo/HP_0033212   48.15      False   False
# 1798  http://purl.obolibrary.org/obo/HP_0007131   64.86      False   False
# 1799  http://purl.obolibrary.org/obo/HP_0004942  100.00      False   False
# 1800  http://purl.obolibrary.org/obo/HP_0001945  100.00      False   False
#
# [1801 rows x 6 columns]

# %% [markdown]
# Select only those IDs with a score greater than 80:

# %%
matched = matched[matched['score'] > 80]

# %% [markdown]
# Create the final ID:

# %%
matched['ID'] = matched['ontologyTermIRI'].str.split('/obo/').str[1]
# Out:
# <ipython-input-22-6ec74f41ff8d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched['ID'] = matched['ontologyTermIRI'].str.split('/obo/').str[1]

# %%
new_id = []
for i in matched['ID']: 
  id = re.sub("[^0-9a-zA-Z]+", ":", i)
  new_id.append(id)
matched['ID'] = new_id
# Out:
# <ipython-input-23-e1ef155d3368>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched['ID'] = new_id

# %%
i = 0
for index, row in df.iterrows(): 
  if row['DRUG_NAME'].lower() in unique_drugs: 
    if row['DISEASES'].lower() in unique_diseases: 
      i += 1

# %% [markdown]
# ### **Merging**

# %%
modified = []
for d in df['DISEASES']: 
  new_string = re.sub("[^0-9a-zA-Z]+", " ", d)
  modified.append(new_string.lower())

# %%
df['Name'] = modified

# %%
df['Name'] = df['Name'].str.strip()
matched['Name'] = matched['Name'].str.strip()
# Out:
# <ipython-input-27-be8c3938c6df>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched['Name'] = matched['Name'].str.strip()

# %%
final = pd.merge(df, matched, on = 'Name', how = 'left')

# %%
final
# Out:
#       DRUG_ID     DRUG_NAME                                   DISEASES  \
# 0      D00ABE       ALD-301                                  Ischemia
# 1      D00ABE       ALD-301               Peripheral arterial disease
# 2      D00ABO       KW-2449                   Acute myeloid leukaemia
# 3      D00ABW      Opterone                        Hormone deficiency
# 4      D00ACC        ND1251                                Depression
# ...       ...           ...                                        ...
# 29562  DZU72C       OKI 179                       Solid tumour/cancer
# 29563  DZVF15       TRN-110  Attention deficit hyperactivity disorder
# 29564  DZW53X    GSK4069889                Non-small cell lung cancer
# 29565  DZW53X    GSK4069889                Non-small cell lung cancer
# 29566  DZY4R2  JNJ-74699157                       Solid tumour/cancer
#
#                           PHASE                                      Name  \
# 0                       Phase 2                                  ischemia
# 1                       Phase 2               peripheral arterial disease
# 2                       Phase 1                   acute myeloid leukaemia
# 3       Discontinued in Phase 1                        hormone deficiency
# 4       Discontinued in Phase 1                                depression
# ...                         ...                                       ...
# 29562                   Phase 1                       solid tumour cancer
# 29563            Clinical Trial  attention deficit hyperactivity disorder
# 29564                   Phase 2                non small cell lung cancer
# 29565                   Phase 2                non small cell lung cancer
# 29566                   Phase 1                       solid tumour cancer
#
#                                ontologyTermName  \
# 0                                           NaN
# 1                  Peripheral arterial stenosis
# 2                        Acute myeloid leukemia
# 3                                           NaN
# 4                                  Depressivity
# ...                                         ...
# 29562                                       NaN
# 29563  Attention deficit hyperactivity disorder
# 29564             Non-small cell lung carcinoma
# 29565             Non-small cell lung carcinoma
# 29566                                       NaN
#
#                                  ontologyTermIRI  score validated review  \
# 0                                            NaN    NaN       NaN    NaN
# 1      http://purl.obolibrary.org/obo/HP_0004950  100.0     False  False
# 2      http://purl.obolibrary.org/obo/HP_0004808  100.0     False  False
# 3                                            NaN    NaN       NaN    NaN
# 4      http://purl.obolibrary.org/obo/HP_0000716  100.0     False  False
# ...                                          ...    ...       ...    ...
# 29562                                        NaN    NaN       NaN    NaN
# 29563  http://purl.obolibrary.org/obo/HP_0007018  100.0     False  False
# 29564  http://purl.obolibrary.org/obo/HP_0030358  100.0     False  False
# 29565  http://purl.obolibrary.org/obo/HP_0030358  100.0     False  False
# 29566                                        NaN    NaN       NaN    NaN
#
#                ID
# 0             NaN
# 1      HP:0004950
# 2      HP:0004808
# 3             NaN
# 4      HP:0000716
# ...           ...
# 29562         NaN
# 29563  HP:0007018
# 29564  HP:0030358
# 29565  HP:0030358
# 29566         NaN
#
# [29567 rows x 11 columns]

# %%
final.to_csv('drug_to_disease_HP.csv', encoding = 'utf-8-sig')

# %% [markdown]
# ### **Comparison**

# %%
final = pd.read_csv('drug_to_disease_HP.csv', header=0)

# %%
final_filtered = final[final['score'] == 100]

# %%
len(final_filtered)
# Out:
# 12151

# %%
final_filtered
# Out:
#        Unnamed: 0 DRUG_ID                                        DRUG_NAME  \
# 1               1  D00ABE                                          ALD-301
# 2               2  D00ABO                                          KW-2449
# 4               4  D00ACC                                           ND1251
# 11             11  D00AHT  PRAME antigen-specific cancer immunotherapeutic
# 12             12  D00AHT  PRAME antigen-specific cancer immunotherapeutic
# ...           ...     ...                                              ...
# 29556       29556  DZNH43                                          MT-3724
# 29561       29561  DZTX12                                           ASC-J9
# 29563       29563  DZVF15                                          TRN-110
# 29564       29564  DZW53X                                       GSK4069889
# 29565       29565  DZW53X                                       GSK4069889
#
#                                         DISEASES                     PHASE  \
# 1                   Peripheral arterial disease                    Phase 2
# 2                       Acute myeloid leukaemia                    Phase 1
# 4                                    Depression    Discontinued in Phase 1
# 11                   Non-small-cell lung cancer                    Phase 2
# 12                   Non-small-cell lung cancer                    Phase 2
# ...                                          ...                       ...
# 29556                           B-cell lymphoma                    Phase 1
# 29561                   End-stage renal disease                    Phase 2
# 29563  Attention deficit hyperactivity disorder             Clinical Trial
# 29564                Non-small cell lung cancer                    Phase 2
# 29565                Non-small cell lung cancer                    Phase 2
#
#                                            Name  \
# 1                   peripheral arterial disease
# 2                       acute myeloid leukaemia
# 4                                    depression
# 11                   non small cell lung cancer
# 12                   non small cell lung cancer
# ...                                         ...
# 29556                           b cell lymphoma
# 29561                   end stage renal disease
# 29563  attention deficit hyperactivity disorder
# 29564                non small cell lung cancer
# 29565                non small cell lung cancer
#
#                                ontologyTermName  \
# 1                  Peripheral arterial stenosis
# 2                        Acute myeloid leukemia
# 4                                  Depressivity
# 11                Non-small cell lung carcinoma
# 12                Non-small cell lung carcinoma
# ...                                         ...
# 29556                           B-cell lymphoma
# 29561            Stage 5 chronic kidney disease
# 29563  Attention deficit hyperactivity disorder
# 29564             Non-small cell lung carcinoma
# 29565             Non-small cell lung carcinoma
#
#                                  ontologyTermIRI  score validated review  \
# 1      http://purl.obolibrary.org/obo/HP_0004950  100.0     False  False
# 2      http://purl.obolibrary.org/obo/HP_0004808  100.0     False  False
# 4      http://purl.obolibrary.org/obo/HP_0000716  100.0     False  False
# 11     http://purl.obolibrary.org/obo/HP_0030358  100.0     False  False
# 12     http://purl.obolibrary.org/obo/HP_0030358  100.0     False  False
# ...                                          ...    ...       ...    ...
# 29556  http://purl.obolibrary.org/obo/HP_0012191  100.0     False  False
# 29561  http://purl.obolibrary.org/obo/HP_0003774  100.0     False  False
# 29563  http://purl.obolibrary.org/obo/HP_0007018  100.0     False  False
# 29564  http://purl.obolibrary.org/obo/HP_0030358  100.0     False  False
# 29565  http://purl.obolibrary.org/obo/HP_0030358  100.0     False  False
#
#                ID
# 1      HP:0004950
# 2      HP:0004808
# 4      HP:0000716
# 11     HP:0030358
# 12     HP:0030358
# ...           ...
# 29556  HP:0012191
# 29561  HP:0003774
# 29563  HP:0007018
# 29564  HP:0030358
# 29565  HP:0030358
#
# [12151 rows x 12 columns]

# %%
column_names = ["DRUG_ID", "DRUG_NAME", "DISEASES", 'PHASE']

df = pd.DataFrame(columns = column_names)

# %%
unique_drugs
# Out:
# ['phenylbutanoic acid',
#  'aceclofenac',
#  'acemetacin',
#  'acetylcysteine',
#  'acetyldigitoxin',
#  'adenosine',
#  'adenosine triphosphate',
#  'adenosine phosphate',
#  'aminopicoline',
#  'amodiaquine',
#  'androstenediol',
#  'apomorphine',
#  'aripiprazole',
#  'arsenic trioxide',
#  'atorvastatin',
#  'azathioprine',
#  'bendamustine',
#  'benserazide',
#  'betamethasone',
#  'bortezomib',
#  'bumetanide',
#  'carmustine',
#  'carvedilol',
#  'celecoxib',
#  'chlorambucil',
#  'chlorcyclizine',
#  'chloroquine',
#  'chlorotrianisene',
#  'chlorzoxazone',
#  'cianidanol',
#  'clioquinol',
#  'clomipramine',
#  'clotrimazole',
#  'clozapine',
#  'cortisone acetate',
#  'ciclosporin',
#  'dantrolene',
#  'dasatinib',
#  'delavirdine',
#  'demeclocycline',
#  'deslanoside',
#  'desoximetasone',
#  'dexamethasone',
#  'diazepam',
#  'dichlorophen',
#  'dicoumarol',
#  'diethylstilbestrol',
#  'digitoxin',
#  'digoxin',
#  'doxorubicin',
#  'econazole',
#  'edetic acid',
#  'epalrestat',
#  'estradiol',
#  'estramustine phosphate',
#  'estriol succinate',
#  'ethacrynic acid',
#  'ethinylestradiol',
#  'everolimus',
#  'famotidine',
#  'fludrocortisone acetate',
#  'flufenamic acid',
#  'flurbiprofen',
#  'formoterol',
#  'fulvestrant',
#  'furosemide',
#  'gemfibrozil',
#  'glutamic acid',
#  'glutathione',
#  'glibenclamide',
#  'glycyrrhizic acid',
#  'gossypol',
#  'haloperidol',
#  'hexachlorophene',
#  'hydrocortisone',
#  'hymecromone',
#  'ibuprofen',
#  'imatinib',
#  'indomethacin',
#  'ketorolac',
#  'lactose',
#  'arginine hydrochloride',
#  'aspartic acid',
#  'lovastatin',
#  'lysine',
#  'meclofenamic acid',
#  'medroxyprogesterone',
#  'mefenamic acid',
#  'menadione',
#  'menadione sodium bisulfite',
#  'meproscillarin',
#  'methotrexate',
#  'metildigoxin',
#  'methylthioninium chloride',
#  'methylprednisolone',
#  'mezlocillin',
#  'miconazole',
#  'midodrine',
#  'mifepristone',
#  'miltefosine',
#  'mitotane',
#  'mycophenolate mofetil',
#  'mycophenolic acid',
#  'naproxen',
#  'nicotinamide',
#  'nicardipine',
#  'niclosamide',
#  'nifedipine',
#  'nilotinib',
#  'nitazoxanide',
#  'nitrofurantoin',
#  'olanzapine',
#  'omapatrilat',
#  'omeprazole',
#  'ouabain',
#  'pantoprazole',
#  'pimecrolimus',
#  'pioglitazone',
#  'prednisolone',
#  'prednisone',
#  'primaquine',
#  'proscillaridin',
#  'pyrimethamine',
#  'quetiapine',
#  'rabeprazole',
#  'raloxifene',
#  'ribavirin',
#  'rifampicin',
#  'risperidone',
#  'rosiglitazone',
#  'ademetionine',
#  'salicylic acid',
#  'sirolimus',
#  'sorafenib',
#  'spironolactone',
#  'sulconazole',
#  'sulfadimidine',
#  'sulfaethidole',
#  'sulfasalazine',
#  'sulindac',
#  'sunitinib',
#  'tacrine',
#  'tacrolimus',
#  'tamoxifen',
#  'terfenadine',
#  'thiabendazole',
#  'thioguanine',
#  'levothyroxine',
#  'tienilic acid',
#  'tolmetin',
#  'tolrestat',
#  'tretinoin',
#  'triamcinolone',
#  'triamcinolone acetonide',
#  'troglitazone',
#  'ursodiol',
#  'valproic acid',
#  'vesnarinone',
#  'thiamine',
#  'nicotinic acid',
#  'pyridoxine',
#  'ziprasidone',
#  'zotarolimus',
#  'suramin',
#  'bithionol',
#  'bufexamac',
#  'enoxolone',
#  'estriol',
#  'estrone',
#  'exisulind',
#  'linoleic acid',
#  'oleic acid',
#  'quercetin',
#  'ruboxistaurin',
#  'rutoside',
#  'vitamin e',
#  'triclosan',
#  'dexibuprofen',
#  'ivermectin',
#  'pazopanib',
#  'romidepsin',
#  'auranofin',
#  'vorinostat',
#  'temsirolimus',
#  'vandetanib',
#  'vemurafenib',
#  'crizotinib',
#  'ruxolitinib',
#  'axitinib',
#  'florbetapir f-18',
#  'flutemetamol (18f)',
#  'lasofoxifene',
#  'bazedoxifene',
#  'zinc chloride',
#  'aurothioglucose',
#  'arginine glutamate',
#  'bosutinib',
#  'voclosporin',
#  'clobetasol propionate',
#  'carfilzomib',
#  'linolenic acid',
#  'phenylacetic acid',
#  'panobinostat',
#  'sodium aurothiomalate',
#  'thioctic acid',
#  'ethyl hydroxybenzoate',
#  'dabrafenib',
#  'florbetaben f18',
#  'conjugated estrogens',
#  'estrone sulphate',
#  'belinostat',
#  'iguratimod',
#  'nintedanib',
#  'pegaptanib',
#  'aflibercept',
#  'bevacizumab',
#  'ranibizumab',
#  'tannic acid',
#  'ixazomib',
#  'venetoclax',
#  'midostaurin',
#  'neratinib',
#  'fedratinib',
#  'brilliant blue g',
#  'brolucizumab',
#  'lonafarnib',
#  'vadadustat',
#  'estetrol',
#  'sotorasib']

# %%
i = 0
for index, row in final_filtered.iterrows(): 
  if row['DRUG_NAME'].lower() not in unique_drugs or row['ID'] not in unique_dis_id:
   final_filtered = final_filtered.drop(labels = index, axis = 0)
len(final_filtered)
# Out:
# 28

# %%
i = 0
for index, row in final_filtered.iterrows(): 
  drug = row['DRUG_NAME'].lower()
  id = graph_drugs[graph_drugs['DRUG_NAME'] == drug]['STRUCT_ID'].values[0]
  final_filtered.at[index, 'DRUG_ID'] = id
len(final_filtered)
# Out:
# 28

# %%
final_filtered
# Out:
#        Unnamed: 0 DRUG_ID               DRUG_NAME                   DISEASES  \
# 1302         1302      91  Adenosine triphosphate               Bradycardia
# 2262         2262    2351              Raloxifene              Osteoporosis
# 3015         3015     882                 Digoxin             Heart failure
# 3016         3016     882                 Digoxin                Arrhythmia
# 3978         3978    1021              Epalrestat                      Pain
# 4141         4141    2179            Pioglitazone                   Obesity
# 4323         4323     568               Celecoxib                      Pain
# 6768         6768    1989             Omapatrilat              Hypertension
# 9064         9064     813             Deslanoside             Heart failure
# 9065         9065     813             Deslanoside                Arrhythmia
# 9195         9195     960             Doxorubicin                    Tumour
# 11154       11154    4308            Lasofoxifene              Osteoporosis
# 11914       11914    4349         Aurothioglucose                 Arthritis
# 13599       13599     522              Carvedilol  Congestive heart failure
# 14035       14035    1883                Naproxen                      Pain
# 14723       14723    2475          Spironolactone  Congestive heart failure
# 18177       18177    3514               Quercetin                   Obesity
# 18485       18485    2817             VESNARINONE           Cardiac failure
# 19181       19181     881               Digitoxin             Heart failure
# 19182       19182     881               Digitoxin                Arrhythmia
# 21446       21446    1258              Furosemide  Congestive heart failure
# 22198       22198    1407               Ibuprofen                      Pain
# 22424       22424     427              Bumetanide  Congestive heart failure
# 23236       23236    1751            Methotrexate                 leukaemia
# 24029       24029    2414            Ademetionine          Hepatic fibrosis
# 24601       24601      67         Acetyldigitoxin  Congestive heart failure
# 25467       25467     522              Carvedilol  Congestive heart failure
# 27445       27445     701            Clomipramine                Depression
#
#                           PHASE                      Name  \
# 1302    Discontinued in Phase 2               bradycardia
# 2262                   Approved              osteoporosis
# 3015                   Approved             heart failure
# 3016                   Approved                arrhythmia
# 3978              Investigative                      pain
# 4141              Investigative                   obesity
# 4323                    Phase 3                      pain
# 6768                 Terminated              hypertension
# 9064                   Approved             heart failure
# 9065                   Approved                arrhythmia
# 9195              Investigative                    tumour
# 11154                  Approved              osteoporosis
# 11914     Withdrawn from market                 arthritis
# 13599                  Approved  congestive heart failure
# 14035                   Phase 2                      pain
# 14723                  Approved  congestive heart failure
# 18177                  Approved                   obesity
# 18485                  Approved           cardiac failure
# 19181                  Approved             heart failure
# 19182                  Approved                arrhythmia
# 21446                  Approved  congestive heart failure
# 22198                  Approved                      pain
# 22424                  Approved  congestive heart failure
# 23236                  Approved                 leukaemia
# 24029                  Approved          hepatic fibrosis
# 24601                  Approved  congestive heart failure
# 25467                  Approved  congestive heart failure
# 27445                  Approved                depression
#
#                ontologyTermName                            ontologyTermIRI  \
# 1302                Bradycardia  http://purl.obolibrary.org/obo/HP_0001662
# 2262               Osteoporosis  http://purl.obolibrary.org/obo/HP_0000939
# 3015   Congestive heart failure  http://purl.obolibrary.org/obo/HP_0001635
# 3016                 Arrhythmia  http://purl.obolibrary.org/obo/HP_0011675
# 3978                       Pain  http://purl.obolibrary.org/obo/HP_0012531
# 4141                    Obesity  http://purl.obolibrary.org/obo/HP_0001513
# 4323                       Pain  http://purl.obolibrary.org/obo/HP_0012531
# 6768               Hypertension  http://purl.obolibrary.org/obo/HP_0000822
# 9064   Congestive heart failure  http://purl.obolibrary.org/obo/HP_0001635
# 9065                 Arrhythmia  http://purl.obolibrary.org/obo/HP_0011675
# 9195                   Neoplasm  http://purl.obolibrary.org/obo/HP_0002664
# 11154              Osteoporosis  http://purl.obolibrary.org/obo/HP_0000939
# 11914                 Arthritis  http://purl.obolibrary.org/obo/HP_0001369
# 13599  Congestive heart failure  http://purl.obolibrary.org/obo/HP_0001635
# 14035                      Pain  http://purl.obolibrary.org/obo/HP_0012531
# 14723  Congestive heart failure  http://purl.obolibrary.org/obo/HP_0001635
# 18177                   Obesity  http://purl.obolibrary.org/obo/HP_0001513
# 18485  Congestive heart failure  http://purl.obolibrary.org/obo/HP_0001635
# 19181  Congestive heart failure  http://purl.obolibrary.org/obo/HP_0001635
# 19182                Arrhythmia  http://purl.obolibrary.org/obo/HP_0011675
# 21446  Congestive heart failure  http://purl.obolibrary.org/obo/HP_0001635
# 22198                      Pain  http://purl.obolibrary.org/obo/HP_0012531
# 22424  Congestive heart failure  http://purl.obolibrary.org/obo/HP_0001635
# 23236                  Leukemia  http://purl.obolibrary.org/obo/HP_0001909
# 24029          Hepatic fibrosis  http://purl.obolibrary.org/obo/HP_0001395
# 24601  Congestive heart failure  http://purl.obolibrary.org/obo/HP_0001635
# 25467  Congestive heart failure  http://purl.obolibrary.org/obo/HP_0001635
# 27445              Depressivity  http://purl.obolibrary.org/obo/HP_0000716
#
#        score validated review          ID
# 1302   100.0     False  False  HP:0001662
# 2262   100.0     False  False  HP:0000939
# 3015   100.0     False  False  HP:0001635
# 3016   100.0     False  False  HP:0011675
# 3978   100.0     False  False  HP:0012531
# 4141   100.0     False  False  HP:0001513
# 4323   100.0     False  False  HP:0012531
# 6768   100.0     False  False  HP:0000822
# 9064   100.0     False  False  HP:0001635
# 9065   100.0     False  False  HP:0011675
# 9195   100.0     False  False  HP:0002664
# 11154  100.0     False  False  HP:0000939
# 11914  100.0     False  False  HP:0001369
# 13599  100.0     False  False  HP:0001635
# 14035  100.0     False  False  HP:0012531
# 14723  100.0     False  False  HP:0001635
# 18177  100.0     False  False  HP:0001513
# 18485  100.0     False  False  HP:0001635
# 19181  100.0     False  False  HP:0001635
# 19182  100.0     False  False  HP:0011675
# 21446  100.0     False  False  HP:0001635
# 22198  100.0     False  False  HP:0012531
# 22424  100.0     False  False  HP:0001635
# 23236  100.0     False  False  HP:0001909
# 24029  100.0     False  False  HP:0001395
# 24601  100.0     False  False  HP:0001635
# 25467  100.0     False  False  HP:0001635
# 27445  100.0     False  False  HP:0000716

# %%
final_filtered = final_filtered.drop(labels = ['Unnamed: 0', 'score'], axis =1)

# %%
final_filtered
# Out:
#       DRUG_ID               DRUG_NAME                   DISEASES  \
# 1302       91  Adenosine triphosphate               Bradycardia
# 2262     2351              Raloxifene              Osteoporosis
# 3015      882                 Digoxin             Heart failure
# 3016      882                 Digoxin                Arrhythmia
# 3978     1021              Epalrestat                      Pain
# 4141     2179            Pioglitazone                   Obesity
# 4323      568               Celecoxib                      Pain
# 6768     1989             Omapatrilat              Hypertension
# 9064      813             Deslanoside             Heart failure
# 9065      813             Deslanoside                Arrhythmia
# 9195      960             Doxorubicin                    Tumour
# 11154    4308            Lasofoxifene              Osteoporosis
# 11914    4349         Aurothioglucose                 Arthritis
# 13599     522              Carvedilol  Congestive heart failure
# 14035    1883                Naproxen                      Pain
# 14723    2475          Spironolactone  Congestive heart failure
# 18177    3514               Quercetin                   Obesity
# 18485    2817             VESNARINONE           Cardiac failure
# 19181     881               Digitoxin             Heart failure
# 19182     881               Digitoxin                Arrhythmia
# 21446    1258              Furosemide  Congestive heart failure
# 22198    1407               Ibuprofen                      Pain
# 22424     427              Bumetanide  Congestive heart failure
# 23236    1751            Methotrexate                 leukaemia
# 24029    2414            Ademetionine          Hepatic fibrosis
# 24601      67         Acetyldigitoxin  Congestive heart failure
# 25467     522              Carvedilol  Congestive heart failure
# 27445     701            Clomipramine                Depression
#
#                           PHASE                      Name  \
# 1302    Discontinued in Phase 2               bradycardia
# 2262                   Approved              osteoporosis
# 3015                   Approved             heart failure
# 3016                   Approved                arrhythmia
# 3978              Investigative                      pain
# 4141              Investigative                   obesity
# 4323                    Phase 3                      pain
# 6768                 Terminated              hypertension
# 9064                   Approved             heart failure
# 9065                   Approved                arrhythmia
# 9195              Investigative                    tumour
# 11154                  Approved              osteoporosis
# 11914     Withdrawn from market                 arthritis
# 13599                  Approved  congestive heart failure
# 14035                   Phase 2                      pain
# 14723                  Approved  congestive heart failure
# 18177                  Approved                   obesity
# 18485                  Approved           cardiac failure
# 19181                  Approved             heart failure
# 19182                  Approved                arrhythmia
# 21446                  Approved  congestive heart failure
# 22198                  Approved                      pain
# 22424                  Approved  congestive heart failure
# 23236                  Approved                 leukaemia
# 24029                  Approved          hepatic fibrosis
# 24601                  Approved  congestive heart failure
# 25467                  Approved  congestive heart failure
# 27445                  Approved                depression
#
#                ontologyTermName                            ontologyTermIRI  \
# 1302                Bradycardia  http://purl.obolibrary.org/obo/HP_0001662
# 2262               Osteoporosis  http://purl.obolibrary.org/obo/HP_0000939
# 3015   Congestive heart failure  http://purl.obolibrary.org/obo/HP_0001635
# 3016                 Arrhythmia  http://purl.obolibrary.org/obo/HP_0011675
# 3978                       Pain  http://purl.obolibrary.org/obo/HP_0012531
# 4141                    Obesity  http://purl.obolibrary.org/obo/HP_0001513
# 4323                       Pain  http://purl.obolibrary.org/obo/HP_0012531
# 6768               Hypertension  http://purl.obolibrary.org/obo/HP_0000822
# 9064   Congestive heart failure  http://purl.obolibrary.org/obo/HP_0001635
# 9065                 Arrhythmia  http://purl.obolibrary.org/obo/HP_0011675
# 9195                   Neoplasm  http://purl.obolibrary.org/obo/HP_0002664
# 11154              Osteoporosis  http://purl.obolibrary.org/obo/HP_0000939
# 11914                 Arthritis  http://purl.obolibrary.org/obo/HP_0001369
# 13599  Congestive heart failure  http://purl.obolibrary.org/obo/HP_0001635
# 14035                      Pain  http://purl.obolibrary.org/obo/HP_0012531
# 14723  Congestive heart failure  http://purl.obolibrary.org/obo/HP_0001635
# 18177                   Obesity  http://purl.obolibrary.org/obo/HP_0001513
# 18485  Congestive heart failure  http://purl.obolibrary.org/obo/HP_0001635
# 19181  Congestive heart failure  http://purl.obolibrary.org/obo/HP_0001635
# 19182                Arrhythmia  http://purl.obolibrary.org/obo/HP_0011675
# 21446  Congestive heart failure  http://purl.obolibrary.org/obo/HP_0001635
# 22198                      Pain  http://purl.obolibrary.org/obo/HP_0012531
# 22424  Congestive heart failure  http://purl.obolibrary.org/obo/HP_0001635
# 23236                  Leukemia  http://purl.obolibrary.org/obo/HP_0001909
# 24029          Hepatic fibrosis  http://purl.obolibrary.org/obo/HP_0001395
# 24601  Congestive heart failure  http://purl.obolibrary.org/obo/HP_0001635
# 25467  Congestive heart failure  http://purl.obolibrary.org/obo/HP_0001635
# 27445              Depressivity  http://purl.obolibrary.org/obo/HP_0000716
#
#       validated review          ID
# 1302      False  False  HP:0001662
# 2262      False  False  HP:0000939
# 3015      False  False  HP:0001635
# 3016      False  False  HP:0011675
# 3978      False  False  HP:0012531
# 4141      False  False  HP:0001513
# 4323      False  False  HP:0012531
# 6768      False  False  HP:0000822
# 9064      False  False  HP:0001635
# 9065      False  False  HP:0011675
# 9195      False  False  HP:0002664
# 11154     False  False  HP:0000939
# 11914     False  False  HP:0001369
# 13599     False  False  HP:0001635
# 14035     False  False  HP:0012531
# 14723     False  False  HP:0001635
# 18177     False  False  HP:0001513
# 18485     False  False  HP:0001635
# 19181     False  False  HP:0001635
# 19182     False  False  HP:0011675
# 21446     False  False  HP:0001635
# 22198     False  False  HP:0012531
# 22424     False  False  HP:0001635
# 23236     False  False  HP:0001909
# 24029     False  False  HP:0001395
# 24601     False  False  HP:0001635
# 25467     False  False  HP:0001635
# 27445     False  False  HP:0000716

# %%
final_filtered.to_csv('drug_to_disease_final_v2_ELA.csv', encoding = 'utf-8-sig')
