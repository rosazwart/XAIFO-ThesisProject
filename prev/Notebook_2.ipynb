# %% [markdown]
# ## **Import**

# %%
import re
import numpy as np
import pandas as pd
import urllib.parse
import urllib.request
import requests

# %% [markdown]
# ## **Drug-Target Information**

# %% [markdown]
# ### **Load Files**

# %% [markdown]
# Load the information from Drug Central and Monarch:

# %%
df = pd.read_csv('../data/drug.target.interaction.tsv', header=0, index_col=0, sep='\t')
#nodes = pd.read_csv('graph_nodes_v2022-01-11.csv', header=0)
nodes = pd.read_csv('monarch/monarch_nodes_v2023-02-20.csv', header=0)

# %%
df['NEW_ID'] = ''

# %% [markdown]
# ### **Uniprot to Monarch IDs**

# %% [markdown]
# Use Uniprot API to obtain new target IDs:

# %%
import re
import time
import json
import zlib
from xml.etree import ElementTree
from urllib.parse import urlparse, parse_qs, urlencode
import requests
from requests.adapters import HTTPAdapter, Retry


POLLING_INTERVAL = 3
API_URL = "https://rest.uniprot.org"


retries = Retry(total=5, backoff_factor=0.25, status_forcelist=[500, 502, 503, 504])
session = requests.Session()
session.mount("https://", HTTPAdapter(max_retries=retries))


def check_response(response):
    try:
        response.raise_for_status()
    except requests.HTTPError:
        print(response.json())
        raise


def submit_id_mapping(from_db, to_db, ids):
    request = requests.post(
        f"{API_URL}/idmapping/run",
        data={"from": from_db, "to": to_db, "ids": ",".join(ids)},
    )
    check_response(request)
    return request.json()["jobId"]


def get_next_link(headers):
    re_next_link = re.compile(r'<(.+)>; rel="next"')
    if "Link" in headers:
        match = re_next_link.match(headers["Link"])
        if match:
            return match.group(1)


def check_id_mapping_results_ready(job_id):
    while True:
        request = session.get(f"{API_URL}/idmapping/status/{job_id}")
        check_response(request)
        j = request.json()
        if "jobStatus" in j:
            if j["jobStatus"] == "RUNNING":
                print(f"Retrying in {POLLING_INTERVAL}s")
                time.sleep(POLLING_INTERVAL)
            else:
                raise Exception(j["jobStatus"])
        else:
            return bool(j["results"] or j["failedIds"])


def get_batch(batch_response, file_format, compressed):
    batch_url = get_next_link(batch_response.headers)
    while batch_url:
        batch_response = session.get(batch_url)
        batch_response.raise_for_status()
        yield decode_results(batch_response, file_format, compressed)
        batch_url = get_next_link(batch_response.headers)


def combine_batches(all_results, batch_results, file_format):
    if file_format == "json":
        for key in ("results", "failedIds"):
            if key in batch_results and batch_results[key]:
                all_results[key] += batch_results[key]
    elif file_format == "tsv":
        return all_results + batch_results[1:]
    else:
        return all_results + batch_results
    return all_results


def get_id_mapping_results_link(job_id):
    url = f"{API_URL}/idmapping/details/{job_id}"
    request = session.get(url)
    check_response(request)
    return request.json()["redirectURL"]


def decode_results(response, file_format, compressed):
    if compressed:
        decompressed = zlib.decompress(response.content, 16 + zlib.MAX_WBITS)
        if file_format == "json":
            j = json.loads(decompressed.decode("utf-8"))
            return j
        elif file_format == "tsv":
            return [line for line in decompressed.decode("utf-8").split("\n") if line]
        elif file_format == "xlsx":
            return [decompressed]
        elif file_format == "xml":
            return [decompressed.decode("utf-8")]
        else:
            return decompressed.decode("utf-8")
    elif file_format == "json":
        return response.json()
    elif file_format == "tsv":
        return [line for line in response.text.split("\n") if line]
    elif file_format == "xlsx":
        return [response.content]
    elif file_format == "xml":
        return [response.text]
    return response.text


def get_xml_namespace(element):
    m = re.match(r"\{(.*)\}", element.tag)
    return m.groups()[0] if m else ""


def merge_xml_results(xml_results):
    merged_root = ElementTree.fromstring(xml_results[0])
    for result in xml_results[1:]:
        root = ElementTree.fromstring(result)
        for child in root.findall("{http://uniprot.org/uniprot}entry"):
            merged_root.insert(-1, child)
    ElementTree.register_namespace("", get_xml_namespace(merged_root[0]))
    return ElementTree.tostring(merged_root, encoding="utf-8", xml_declaration=True)


def print_progress_batches(batch_index, size, total):
    n_fetched = min((batch_index + 1) * size, total)
    print(f"Fetched: {n_fetched} / {total}")


def get_id_mapping_results_search(url):
    parsed = urlparse(url)
    query = parse_qs(parsed.query)
    file_format = query["format"][0] if "format" in query else "json"
    if "size" in query:
        size = int(query["size"][0])
    else:
        size = 500
        query["size"] = size
    compressed = (
        query["compressed"][0].lower() == "true" if "compressed" in query else False
    )
    parsed = parsed._replace(query=urlencode(query, doseq=True))
    url = parsed.geturl()
    request = session.get(url)
    check_response(request)
    results = decode_results(request, file_format, compressed)
    total = int(request.headers["x-total-results"])
    print_progress_batches(0, size, total)
    for i, batch in enumerate(get_batch(request, file_format, compressed), 1):
        results = combine_batches(results, batch, file_format)
        print_progress_batches(i, size, total)
    if file_format == "xml":
        return merge_xml_results(results)
    return results


def get_id_mapping_results_stream(url):
    if "/stream/" not in url:
        url = url.replace("/results/", "/results/stream/")
    request = session.get(url)
    check_response(request)
    parsed = urlparse(url)
    query = parse_qs(parsed.query)
    file_format = query["format"][0] if "format" in query else "json"
    compressed = (
        query["compressed"][0].lower() == "true" if "compressed" in query else False
    )
    return decode_results(request, file_format, compressed)


job_id = submit_id_mapping(
    from_db="UniProtKB_AC-ID", to_db="HGNC", ids=["Q12809"]
)
if check_id_mapping_results_ready(job_id):
    link = get_id_mapping_results_link(job_id)
    results = get_id_mapping_results_search(link)
    # Equivalently using the stream endpoint which is more demanding
    # on the API and so is less stable:
    # results = get_id_mapping_results_stream(link)

print(results)
# {'results': [{'from': 'P05067', 'to': 'CHEMBL2487'}], 'failedIds': ['P12345']}
# Out:
# Fetched: 1 / 1
# {'results': [{'from': 'Q12809', 'to': 'HGNC:6251'}]}

# %%
for i in range(0, df.shape[0]): 
  print('Going through row', i, ' out of', df.shape[0])

  id = df['ACCESSION'][i].split('|')[0]
  print(id)
  org = df['ORGANISM'][i]
  print(org)

  if org == 'Homo sapiens': 
    to = 'HGNC'
    pre = ''
  elif org == 'Rattus norvegicus': 
    to = 'RGD'
    pre = 'RGD:'
  elif org == 'Mus musculus': 
    to = 'MGI'
    pre = ''
  elif org == 'Drosophila melanogaster':
    to = 'FlyBase'
    pre = 'FlyBase'
  elif org == 'Caenorhabditis elegans': 
    to = 'WormBase'
    pre = 'WormBase:'
  elif org == 'Danio rerio': 
    to = 'ZFIN'
    pre = 'ZFIN:'
  elif org == 'Saccharomyces cerevisiae': 
    to = 'SGD'
    pre = 'SGD:'
  else:   
    to = 'Ensembl'
    pre = 'ENSEMBL:'
  
  
  job_id = submit_id_mapping(
  from_db="UniProtKB_AC-ID", to_db=to , ids=[id])

  try: 
    if check_id_mapping_results_ready(job_id):
        link = get_id_mapping_results_link(job_id)
        results = get_id_mapping_results_search(link)
        # Equivalently using the stream endpoint which is more demanding
        # on the API and so is less stable:
        # results = get_id_mapping_results_stream(link)
  except: 
    continue
  #print(results)
  if len(results['results'])>0: 
    df['NEW_ID'][i] = pre + results['results'][0]['to']
  else: 
    df['NEW_ID'][i] = 'NA'
# Out:
# Going through row 0  out of 19378
# Q12809
# Homo sapiens
# Fetched: 1 / 1
# Going through row 1  out of 19378
# P35498
# Homo sapiens
# C:\Users\rosa-\AppData\Local\Temp\ipykernel_14436\3624377136.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['NEW_ID'][i] = pre + results['results'][0]['to']
# Fetched: 1 / 1
# Going through row 2  out of 19378
# P35499
# Homo sapiens
# Fetched: 1 / 1
# Going through row 3  out of 19378
# P34995
# Homo sapiens
# Fetched: 1 / 1
# Going through row 4  out of 19378
# P10635
# Homo sapiens
# Fetched: 1 / 1
# Going through row 5  out of 19378
# P46098
# Homo sapiens
# Fetched: 1 / 1
# Going through row 6  out of 19378
# Q9UK17
# Homo sapiens
# Fetched: 1 / 1
# Going through row 7  out of 19378
# P22460
# Homo sapiens
# Fetched: 1 / 1
# Going through row 8  out of 19378
# Q01668
# Homo sapiens
# Fetched: 1 / 1
# Going through row 9  out of 19378
# O15554
# Homo sapiens
# Fetched: 1 / 1
# Going through row 10  out of 19378
# Q01668
# Homo sapiens
# Fetched: 1 / 1
# Going through row 11  out of 19378
# O60840
# Homo sapiens
# Fetched: 1 / 1
# Going through row 12  out of 19378
# P22002
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 13  out of 19378
# Q02485
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 14  out of 19378
# Q13936
# Homo sapiens
# Fetched: 1 / 1
# Going through row 15  out of 19378
# P08588
# Homo sapiens
# Fetched: 1 / 1
# Going through row 16  out of 19378
# P00375
# Mus musculus
# Fetched: 1 / 1
# Going through row 17  out of 19378
# P00381
# Lactobacillus casei
# Fetched: 0 / 0
# Going through row 18  out of 19378
# B0BL08
# Escherichia coli
# C:\Users\rosa-\AppData\Local\Temp\ipykernel_14436\3624377136.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['NEW_ID'][i] = 'NA'
# Fetched: 0 / 0
# Going through row 19  out of 19378
# P48760
# Mus musculus
# Fetched: 1 / 1
# Going through row 20  out of 19378
# P00374
# Homo sapiens
# Fetched: 1 / 1
# Going through row 21  out of 19378
# P15121
# Homo sapiens
# Fetched: 1 / 1
# Going through row 22  out of 19378
# Q92769
# Homo sapiens
# Fetched: 1 / 1
# Going through row 23  out of 19378
# Q13547
# Homo sapiens
# Fetched: 1 / 1
# Going through row 24  out of 19378
# Q9BY41
# Homo sapiens
# Fetched: 1 / 1
# Going through row 25  out of 19378
# P26358
# Homo sapiens
# Fetched: 1 / 1
# Going through row 26  out of 19378
# Q9Y6K1
# Homo sapiens
# Fetched: 1 / 1
# Going through row 27  out of 19378
# P04818
# Homo sapiens
# Fetched: 1 / 1
# Going through row 28  out of 19378
# O15440
# Homo sapiens
# Fetched: 1 / 1
# Going through row 29  out of 19378
# Q96J66
# Homo sapiens
# Fetched: 1 / 1
# Going through row 30  out of 19378
# P07607
# Mus musculus
# Fetched: 1 / 1
# Going through row 31  out of 19378
# P0A8F0
# Escherichia coli (strain K12)
# Fetched: 0 / 0
# Going through row 32  out of 19378
# O26232
# Methanothermobacter thermautotrophicus (strain ATCC 29096 / DSM 1053 / JCM 10044 / NBRC 100330 / Delta H)
# Fetched: 0 / 0
# Going through row 33  out of 19378
# P03962
# Saccharomyces cerevisiae
# Fetched: 1 / 1
# Going through row 34  out of 19378
# P22303
# Homo sapiens
# Fetched: 1 / 1
# Going through row 35  out of 19378
# P05177
# Homo sapiens
# Fetched: 1 / 1
# Going through row 36  out of 19378
# P21397
# Homo sapiens
# Fetched: 1 / 1
# Going through row 37  out of 19378
# O42713
# Agaricus bisporus
# Fetched: 0 / 0
# Going through row 38  out of 19378
# O42713
# Agaricus bisporus
# Fetched: 0 / 0
# Going through row 39  out of 19378
# P03369
# Human immunodeficiency virus type 1 group M subtype B (isolate ARV2/SF2)
# Fetched: 0 / 0
# Going through row 40  out of 19378
# Q72547
# Human immunodeficiency virus 1
# Fetched: 0 / 0
# Going through row 41  out of 19378
# Q9WKE8
# Human immunodeficiency virus 1
# Fetched: 0 / 0
# Going through row 42  out of 19378
# P30968
# Homo sapiens
# Fetched: 1 / 1
# Going through row 43  out of 19378
# P14867
# Homo sapiens
# Fetched: 1 / 1
# Going through row 44  out of 19378
# O15399
# Homo sapiens
# Fetched: 1 / 1
# Going through row 45  out of 19378
# O43451
# Homo sapiens
# Fetched: 1 / 1
# Going through row 46  out of 19378
# P04746
# Homo sapiens
# Fetched: 1 / 1
# Going through row 47  out of 19378
# P04745
# Homo sapiens
# Fetched: 3 / 3
# Going through row 48  out of 19378
# P10253
# Homo sapiens
# Fetched: 1 / 1
# Going through row 49  out of 19378
# P23739
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 50  out of 19378
# Q6P7A9
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 51  out of 19378
# P94451
# Geobacillus stearothermophilus
# Fetched: 0 / 0
# Going through row 52  out of 19378
# P53051
# Saccharomyces cerevisiae (strain ATCC 204508 / S288c)
# Fetched: 0 / 0
# Going through row 53  out of 19378
# P00690
# Sus scrofa
# Fetched: 0 / 0
# Going through row 54  out of 19378
# P14410
# Homo sapiens
# Fetched: 1 / 1
# Going through row 55  out of 19378
# P08588
# Homo sapiens
# Fetched: 1 / 1
# Going through row 56  out of 19378
# P07550
# Homo sapiens
# Fetched: 1 / 1
# Going through row 57  out of 19378
# P19327
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 58  out of 19378
# P02766
# Homo sapiens
# Fetched: 1 / 1
# Going through row 59  out of 19378
# P07943
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 60  out of 19378
# P28482
# Homo sapiens
# Fetched: 1 / 1
# Going through row 61  out of 19378
# P35354
# Homo sapiens
# Fetched: 1 / 1
# Going through row 62  out of 19378
# P16116
# Bos taurus
# Fetched: 0 / 0
# Going through row 63  out of 19378
# Q4Z710
# Plasmodium berghei (strain Anka)
# Fetched: 0 / 0
# Going through row 64  out of 19378
# A0A113T0T6
# Plasmodium berghei
# Fetched: 0 / 0
# Going through row 65  out of 19378
# P35354
# Homo sapiens
# Fetched: 1 / 1
# Going through row 66  out of 19378
# P23219
# Homo sapiens
# Fetched: 1 / 1
# Going through row 67  out of 19378
# Q04760
# Homo sapiens
# Fetched: 1 / 1
# Going through row 68  out of 19378
# Q6TEK4
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 69  out of 19378
# Q9BQB6
# Homo sapiens
# Fetched: 1 / 1
# Going through row 70  out of 19378
# P29275
# Homo sapiens
# Fetched: 1 / 1
# Going through row 71  out of 19378
# P35367
# Homo sapiens
# Fetched: 1 / 1
# Going through row 72  out of 19378
# P35354
# Homo sapiens
# Fetched: 1 / 1
# Going through row 73  out of 19378
# Q8NER1
# Homo sapiens
# Fetched: 1 / 1
# Going through row 74  out of 19378
# Q14994
# Homo sapiens
# Fetched: 1 / 1
# Going through row 75  out of 19378
# P00918
# Homo sapiens
# Fetched: 1 / 1
# Going through row 76  out of 19378
# P00915
# Homo sapiens
# Fetched: 1 / 1
# Going through row 77  out of 19378
# P22748
# Homo sapiens
# Fetched: 1 / 1
# Going through row 78  out of 19378
# Q16790
# Homo sapiens
# Fetched: 1 / 1
# Going through row 79  out of 19378
# O43570
# Homo sapiens
# Fetched: 1 / 1
# Going through row 80  out of 19378
# P43166
# Homo sapiens
# Fetched: 1 / 1
# Going through row 81  out of 19378
# P07451
# Homo sapiens
# Fetched: 1 / 1
# Going through row 82  out of 19378
# Q9ULX7
# Homo sapiens
# Fetched: 1 / 1
# Going through row 83  out of 19378
# P20292
# Homo sapiens
# Fetched: 1 / 1
# Going through row 84  out of 19378
# P12530
# Oryctolagus cuniculus
# Fetched: 0 / 0
# Going through row 85  out of 19378
# Q9D6N1
# Mus musculus
# Fetched: 1 / 1
# Going through row 86  out of 19378
# Q99N23
# Mus musculus
# Fetched: 1 / 1
# Going through row 87  out of 19378
# P02144
# Homo sapiens
# Fetched: 1 / 1
# Going through row 88  out of 19378
# P21554
# Homo sapiens
# Fetched: 1 / 1
# Going through row 89  out of 19378
# Q6XQN6
# Homo sapiens
# Fetched: 1 / 1
# Going through row 90  out of 19378
# Q9VTU8
# Drosophila melanogaster
# Fetched: 1 / 1
# Going through row 91  out of 19378
# Q9V396
# Drosophila melanogaster
# Fetched: 1 / 1
# Going through row 92  out of 19378
# P00918
# Homo sapiens
# Fetched: 1 / 1
# Going through row 93  out of 19378
# P00915
# Homo sapiens
# Fetched: 1 / 1
# Going through row 94  out of 19378
# P22748
# Homo sapiens
# Fetched: 1 / 1
# Going through row 95  out of 19378
# Q16790
# Homo sapiens
# Fetched: 1 / 1
# Going through row 96  out of 19378
# O43570
# Homo sapiens
# Fetched: 1 / 1
# Going through row 97  out of 19378
# P29972
# Homo sapiens
# Fetched: 1 / 1
# Going through row 98  out of 19378
# P35218
# Homo sapiens
# Fetched: 1 / 1
# Going through row 99  out of 19378
# Q9Y2D0
# Homo sapiens
# Fetched: 1 / 1
# Going through row 100  out of 19378
# P43166
# Homo sapiens
# Fetched: 1 / 1
# Going through row 101  out of 19378
# O24855
# Helicobacter pylori (strain ATCC 700392 / 26695)
# Fetched: 0 / 0
# Going through row 102  out of 19378
# P07451
# Homo sapiens
# Fetched: 1 / 1
# Going through row 103  out of 19378
# P23280
# Homo sapiens
# Fetched: 1 / 1
# Going through row 104  out of 19378
# Q9ULX7
# Homo sapiens
# Fetched: 1 / 1
# Going through row 105  out of 19378
# Q9D6N1
# Mus musculus
# Fetched: 1 / 1
# Going through row 106  out of 19378
# Q95323
# Bos taurus
# Fetched: 1 / 1
# Going through row 107  out of 19378
# Q9ERQ8
# Mus musculus
# Fetched: 1 / 1
# Going through row 108  out of 19378
# P40881
# Methanosarcina thermophila
# Fetched: 0 / 0
# Going through row 109  out of 19378
# Q50565
# Methanothermobacter thermautotrophicus (strain ATCC 29096 / DSM 1053 / JCM 10044 / NBRC 100330 / Delta H)
# Fetched: 0 / 0
# Going through row 110  out of 19378
# Q8N1Q1
# Homo sapiens
# Fetched: 1 / 1
# Going through row 111  out of 19378
# Q99N23
# Mus musculus
# Fetched: 1 / 1
# Going through row 112  out of 19378
# P53615
# Saccharomyces cerevisiae (strain ATCC 204508 / S288c)
# Fetched: 0 / 0
# Going through row 113  out of 19378
# Q5AJ71
# Candida albicans (strain SC5314 / ATCC MYA-2876)
# Fetched: 0 / 0
# Going through row 114  out of 19378
# P96878
# Mycobacterium tuberculosis (strain ATCC 25618 / H37Rv)
# Fetched: 0 / 0
# Going through row 115  out of 19378
# Q6FTL6
# Candida glabrata (strain ATCC 2001 / CBS 138 / JCM 3761 / NBRC 0622 / NRRL Y-65)
# Fetched: 0 / 0
# Going through row 116  out of 19378
# B5SU02
# Stylophora pistillata
# Fetched: 0 / 0
# Going through row 117  out of 19378
# P29029
# Saccharomyces cerevisiae (strain ATCC 204508 / S288c)
# Fetched: 0 / 0
# Going through row 118  out of 19378
# C0IX24
# Stylophora pistillata
# Fetched: 0 / 0
# Going through row 119  out of 19378
# Q3I4V7
# Cryptococcus neoformans var. grubii
# Fetched: 0 / 0
# Going through row 120  out of 19378
# Q2PCB5
# Dicentrarchus labrax
# Fetched: 0 / 0
# Going through row 121  out of 19378
# A6YCJ1
# Astrosclera willeyana
# Fetched: 0 / 0
# Going through row 122  out of 19378
# P9WPJ7
# Mycobacterium tuberculosis (strain ATCC 25618 / H37Rv)
# Fetched: 0 / 0
# Going through row 123  out of 19378
# Q5U9J1
# Thalassiosira weissflogii
# Fetched: 0 / 0
# Going through row 124  out of 19378
# P9WPJ9
# Mycobacterium tuberculosis (strain ATCC 25618 / H37Rv)
# Fetched: 0 / 0
# Going through row 125  out of 19378
# P00921
# Bos taurus
# Fetched: 0 / 0
# Going through row 126  out of 19378
# O43570
# Homo sapiens
# Fetched: 1 / 1
# Going through row 127  out of 19378
# P00921
# Bos taurus
# Fetched: 0 / 0
# Going through row 128  out of 19378
# P35218
# Homo sapiens
# Fetched: 1 / 1
# Going through row 129  out of 19378
# P46510
# Flaveria bidentis
# Fetched: 0 / 0
# Going through row 130  out of 19378
# Q3SZX4
# Bos taurus
# Fetched: 1 / 1
# Going through row 131  out of 19378
# Q5TU56
# Anopheles gambiae
# Fetched: 0 / 0
# Going through row 132  out of 19378
# Q9HVB9
# Pseudomonas aeruginosa (strain ATCC 15692 / DSM 22644 / CIP 104116 / JCM 14847 / LMG 12228 / 1C / PRS 101 / PAO1)
# Fetched: 0 / 0
# Going through row 133  out of 19378
# Q31FD6
# Hydrogenovibrio crunogenus (strain XCL-2)
# Fetched: 0 / 0
# Going through row 134  out of 19378
# B2V8E3
# Sulfurihydrogenibium sp. (strain YO3AOP1)
# Fetched: 0 / 0
# Going through row 135  out of 19378
# O75493
# Homo sapiens
# Fetched: 1 / 1
# Going through row 136  out of 19378
# Q09428
# Homo sapiens
# Fetched: 1 / 1
# Going through row 137  out of 19378
# P00918
# Homo sapiens
# Fetched: 1 / 1
# Going through row 138  out of 19378
# Q03282
# Escherichia coli
# Fetched: 0 / 0
# Going through row 139  out of 19378
# P07374
# Canavalia ensiformis
# Fetched: 0 / 0
# Going through row 140  out of 19378
# Q0PXQ5
# Helicobacter pylori
# Fetched: 0 / 0
# Going through row 141  out of 19378
# P14416
# Homo sapiens
# Fetched: 1 / 1
# Going through row 142  out of 19378
# P15207
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 143  out of 19378
# P12821
# Homo sapiens
# Fetched: 1 / 1
# Going through row 144  out of 19378
# P08473
# Homo sapiens
# Fetched: 1 / 1
# Going through row 145  out of 19378
# P12822
# Oryctolagus cuniculus
# Fetched: 0 / 0
# Going through row 146  out of 19378
# P07861
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 147  out of 19378
# P08049
# Oryctolagus cuniculus
# Fetched: 0 / 0
# Going through row 148  out of 19378
# P19621
# Sus scrofa
# Fetched: 0 / 0
# Going through row 149  out of 19378
# P42892
# Homo sapiens
# Fetched: 1 / 1
# Going through row 150  out of 19378
# P00800
# Bacillus thermoproteolyticus
# Fetched: 0 / 0
# Going through row 151  out of 19378
# P23141
# Homo sapiens
# Fetched: 1 / 1
# Going through row 152  out of 19378
# P14061
# Homo sapiens
# Fetched: 1 / 1
# Going through row 153  out of 19378
# P37059
# Homo sapiens
# Fetched: 1 / 1
# Going through row 154  out of 19378
# P80365
# Homo sapiens
# Fetched: 1 / 1
# Going through row 155  out of 19378
# P28845
# Homo sapiens
# Fetched: 1 / 1
# Going through row 156  out of 19378
# O00748
# Homo sapiens
# Fetched: 1 / 1
# Going through row 157  out of 19378
# P11229
# Homo sapiens
# Fetched: 1 / 1
# Going through row 158  out of 19378
# P08172
# Homo sapiens
# Fetched: 1 / 1
# Going through row 159  out of 19378
# P20309
# Homo sapiens
# Fetched: 1 / 1
# Going through row 160  out of 19378
# P08173
# Homo sapiens
# Fetched: 1 / 1
# Going through row 161  out of 19378
# P08912
# Homo sapiens
# Fetched: 1 / 1
# Going through row 162  out of 19378
# P36544
# Homo sapiens
# Fetched: 1 / 1
# Going through row 163  out of 19378
# P58154
# Lymnaea stagnalis
# Fetched: 0 / 0
# Going through row 164  out of 19378
# P02718
# Torpedo californica
# Fetched: 0 / 0
# Going through row 165  out of 19378
# Q05941
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 166  out of 19378
# P12389
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 167  out of 19378
# P04757
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 168  out of 19378
# P04757
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 169  out of 19378
# P09483
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 170  out of 19378
# P09483
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 171  out of 19378
# P17787
# Homo sapiens
# Fetched: 1 / 1
# Going through row 172  out of 19378
# P08482
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 173  out of 19378
# H6TY12
# Periplaneta americana
# Fetched: 0 / 0
# Going through row 174  out of 19378
# P99999
# Homo sapiens
# Fetched: 1 / 1
# Going through row 175  out of 19378
# P15692
# Homo sapiens
# Fetched: 1 / 1
# Going through row 176  out of 19378
# P04179
# Homo sapiens
# Fetched: 1 / 1
# Going through row 177  out of 19378
# P48637
# Homo sapiens
# Fetched: 1 / 1
# Going through row 178  out of 19378
# Q9UPY5
# Homo sapiens
# Fetched: 1 / 1
# Going through row 179  out of 19378
# P05023
# Homo sapiens
# Fetched: 1 / 1
# Going through row 180  out of 19378
# P21728
# Homo sapiens
# Fetched: 1 / 1
# Going through row 181  out of 19378
# P14416
# Homo sapiens
# Fetched: 1 / 1
# Going through row 182  out of 19378
# P04156
# Homo sapiens
# Fetched: 1 / 1
# Going through row 183  out of 19378
# P35354
# Homo sapiens
# Fetched: 1 / 1
# Going through row 184  out of 19378
# P23219
# Homo sapiens
# Fetched: 1 / 1
# Going through row 185  out of 19378
# P60045
# Naja sagittifera
# Fetched: 0 / 0
# Going through row 186  out of 19378
# P19440
# Homo sapiens
# Fetched: 1 / 1
# Going through row 187  out of 19378
# P05979
# Ovis aries
# Fetched: 0 / 0
# Going through row 188  out of 19378
# P79208
# Ovis aries
# Fetched: 0 / 0
# Going through row 189  out of 19378
# O62664
# Bos taurus
# Fetched: 0 / 0
# Going through row 190  out of 19378
# Q9UHC3
# Homo sapiens
# Fetched: 1 / 1
# Going through row 191  out of 19378
# Q6XQN6
# Homo sapiens
# Fetched: 1 / 1
# Going through row 192  out of 19378
# Q8TDS4
# Homo sapiens
# Fetched: 1 / 1
# Going through row 193  out of 19378
# P10276
# Homo sapiens
# Fetched: 1 / 1
# Going through row 194  out of 19378
# O95342
# Homo sapiens
# Fetched: 1 / 1
# Going through row 195  out of 19378
# P13631
# Homo sapiens
# Fetched: 1 / 1
# Going through row 196  out of 19378
# O70127
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 197  out of 19378
# P41595
# Homo sapiens
# Fetched: 1 / 1
# Going through row 198  out of 19378
# P08253
# Homo sapiens
# Fetched: 1 / 1
# Going through row 199  out of 19378
# P11387
# Homo sapiens
# Fetched: 1 / 1
# Going through row 200  out of 19378
# P11388
# Homo sapiens
# Fetched: 1 / 1
# Going through row 201  out of 19378
# P08172
# Homo sapiens
# Fetched: 1 / 1
# Going through row 202  out of 19378
# P08183
# Homo sapiens
# Fetched: 1 / 1
# Going through row 203  out of 19378
# P35367
# Homo sapiens
# Fetched: 1 / 1
# Going through row 204  out of 19378
# P31389
# Cavia porcellus
# Fetched: 0 / 0
# Going through row 205  out of 19378
# P00491
# Homo sapiens
# Fetched: 1 / 1
# Going through row 206  out of 19378
# P09250
# Varicella-zoster virus (strain Dumas)
# Fetched: 0 / 0
# Going through row 207  out of 19378
# P9WP01
# Mycobacterium tuberculosis (strain ATCC 25618 / H37Rv)
# Fetched: 0 / 0
# Going through row 208  out of 19378
# P00491
# Homo sapiens
# Fetched: 1 / 1
# Going through row 209  out of 19378
# P04293
# Human herpesvirus 1 (strain 17)
# Fetched: 0 / 0
# Going through row 210  out of 19378
# P09252
# Varicella-zoster virus (strain Dumas)
# Fetched: 0 / 0
# Going through row 211  out of 19378
# Q9QNF7
# Human herpesvirus 1
# Fetched: 0 / 0
# Going through row 212  out of 19378
# P04407
# Human herpesvirus 2 (strain 333)
# Fetched: 0 / 0
# Going through row 213  out of 19378
# P23415
# Homo sapiens
# Fetched: 1 / 1
# Going through row 214  out of 19378
# P10276
# Homo sapiens
# Fetched: 1 / 1
# Going through row 215  out of 19378
# P10826
# Homo sapiens
# Fetched: 1 / 1
# Going through row 216  out of 19378
# P13631
# Homo sapiens
# Fetched: 1 / 1
# Going through row 217  out of 19378
# Q9IF40
# Hepatitis B virus
# Fetched: 0 / 0
# Going through row 218  out of 19378
# P54098
# Homo sapiens
# Fetched: 1 / 1
# Going through row 219  out of 19378
# Q03732
# Hepatitis B virus
# Fetched: 0 / 0
# Going through row 220  out of 19378
# P47989
# Homo sapiens
# Fetched: 1 / 1
# Going through row 221  out of 19378
# P42356
# Homo sapiens
# Fetched: 1 / 1
# Going through row 222  out of 19378
# P29274
# Homo sapiens
# Fetched: 1 / 1
# Going through row 223  out of 19378
# P30542
# Homo sapiens
# Fetched: 1 / 1
# Going through row 224  out of 19378
# P29275
# Homo sapiens
# Fetched: 1 / 1
# Going through row 225  out of 19378
# P0DMS8
# Homo sapiens
# Fetched: 1 / 1
# Going through row 226  out of 19378
# P55263
# Homo sapiens
# Fetched: 1 / 1
# Going through row 227  out of 19378
# P00813
# Homo sapiens
# Fetched: 1 / 1
# Going through row 228  out of 19378
# P25099
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 229  out of 19378
# P30543
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 230  out of 19378
# P28647
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 231  out of 19378
# Q9TVW2
# Toxoplasma gondii
# Fetched: 0 / 0
# Going through row 232  out of 19378
# O43318
# Homo sapiens
# Fetched: 1 / 1
# Going through row 233  out of 19378
# P23526
# Homo sapiens
# Fetched: 1 / 1
# Going through row 234  out of 19378
# P29276
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 235  out of 19378
# Q9BTU6
# Homo sapiens
# Fetched: 1 / 1
# Going through row 236  out of 19378
# Q8TCG2
# Homo sapiens
# Fetched: 1 / 1
# Going through row 237  out of 19378
# P04406
# Homo sapiens
# Fetched: 1 / 1
# Going through row 238  out of 19378
# P00515
# Bos taurus
# Fetched: 1 / 1
# Going through row 239  out of 19378
# Q8TEK3
# Homo sapiens
# Fetched: 1 / 1
# Going through row 240  out of 19378
# P49652
# Meleagris gallopavo
# Fetched: 1 / 1
# Going through row 241  out of 19378
# P51575
# Homo sapiens
# Fetched: 1 / 1
# Going through row 242  out of 19378
# P51582
# Homo sapiens
# Fetched: 1 / 1
# Going through row 243  out of 19378
# O60674
# Homo sapiens
# Fetched: 1 / 1
# Going through row 244  out of 19378
# P47900
# Homo sapiens
# Fetched: 1 / 1
# Going through row 245  out of 19378
# P41231
# Homo sapiens
# Fetched: 1 / 1
# Going through row 246  out of 19378
# Q96G91
# Homo sapiens
# Fetched: 1 / 1
# Going through row 247  out of 19378
# Q8TD43
# Homo sapiens
# Fetched: 1 / 1
# Going through row 248  out of 19378
# Q9BPV8
# Homo sapiens
# Fetched: 1 / 1
# Going through row 249  out of 19378
# P41148
# Canis familiaris
# Fetched: 3 / 3
# Going through row 250  out of 19378
# P49137
# Homo sapiens
# Fetched: 1 / 1
# Going through row 251  out of 19378
# O43318
# Homo sapiens
# Fetched: 1 / 1
# Going through row 252  out of 19378
# Q99571
# Homo sapiens
# Fetched: 1 / 1
# Going through row 253  out of 19378
# Q13304
# Homo sapiens
# Fetched: 1 / 1
# Going through row 254  out of 19378
# P56373
# Homo sapiens
# Fetched: 1 / 1
# Going through row 255  out of 19378
# Q12931
# Homo sapiens
# Fetched: 1 / 1
# Going through row 256  out of 19378
# P29410
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 257  out of 19378
# P11142
# Homo sapiens
# Fetched: 1 / 1
# Going through row 258  out of 19378
# P0DMV8
# Homo sapiens
# Fetched: 1 / 1
# Going through row 259  out of 19378
# Q7TN37
# Mus musculus
# Fetched: 1 / 1
# Going through row 260  out of 19378
# P49653
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 261  out of 19378
# Q9JJX6
# Mus musculus
# Fetched: 1 / 1
# Going through row 262  out of 19378
# O35811
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 263  out of 19378
# P51577
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 264  out of 19378
# P51579
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 265  out of 19378
# P51578
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 266  out of 19378
# P51577
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 267  out of 19378
# O60674
# Homo sapiens
# Fetched: 1 / 1
# Going through row 268  out of 19378
# P09467
# Homo sapiens
# Fetched: 1 / 1
# Going through row 269  out of 19378
# P00636
# Sus scrofa
# Fetched: 9 / 9
# Going through row 270  out of 19378
# P12931
# Homo sapiens
# Fetched: 1 / 1
# Going through row 271  out of 19378
# O94759
# Homo sapiens
# Fetched: 1 / 1
# Going through row 272  out of 19378
# Q8TD43
# Homo sapiens
# Fetched: 1 / 1
# Going through row 273  out of 19378
# Q72874
# Human immunodeficiency virus 1
# Fetched: 0 / 0
# Going through row 274  out of 19378
# P00327
# Equus caballus
# Fetched: 0 / 0
# Going through row 275  out of 19378
# P00338
# Homo sapiens
# Fetched: 1 / 1
# Going through row 276  out of 19378
# P0A9J4
# Escherichia coli (strain K12)
# Fetched: 0 / 0
# Going through row 277  out of 19378
# P29410
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 278  out of 19378
# O43598
# Homo sapiens
# Fetched: 1 / 1
# Going through row 279  out of 19378
# O35820
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 280  out of 19378
# P30536
# Homo sapiens
# Fetched: 1 / 1
# Going through row 281  out of 19378
# O14764
# Homo sapiens
# Fetched: 1 / 1
# Going through row 282  out of 19378
# P31390
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 283  out of 19378
# P08482
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 284  out of 19378
# P28223
# Homo sapiens
# Fetched: 1 / 1
# Going through row 285  out of 19378
# P41595
# Homo sapiens
# Fetched: 1 / 1
# Going through row 286  out of 19378
# P48039
# Homo sapiens
# Fetched: 1 / 1
# Going through row 287  out of 19378
# P49285
# Gallus gallus
# Fetched: 2 / 2
# Going through row 288  out of 19378
# P28335
# Homo sapiens
# Fetched: 1 / 1
# Going through row 289  out of 19378
# P48039
# Homo sapiens
# Fetched: 1 / 1
# Going through row 290  out of 19378
# P49286
# Homo sapiens
# Fetched: 1 / 1
# Going through row 291  out of 19378
# Q14524
# Homo sapiens
# Fetched: 1 / 1
# Going through row 292  out of 19378
# P10635
# Homo sapiens
# Fetched: 1 / 1
# Going through row 293  out of 19378
# Q9UK17
# Homo sapiens
# Fetched: 1 / 1
# Going through row 294  out of 19378
# P22460
# Homo sapiens
# Fetched: 1 / 1
# Going through row 295  out of 19378
# P12821
# Homo sapiens
# Fetched: 1 / 1
# Going through row 296  out of 19378
# P0AFI2
# Escherichia coli (strain K12)
# Fetched: 0 / 0
# Going through row 297  out of 19378
# P0AES4
# Escherichia coli (strain K12)
# Fetched: 0 / 0
# Going through row 298  out of 19378
# P50719
# Haemonchus contortus
# Fetched: 0 / 0
# Going through row 299  out of 19378
# C4PKY4
# Echinococcus granulosus
# Fetched: 0 / 0
# Going through row 300  out of 19378
# F1L005
# Ascaris suum
# Fetched: 0 / 0
# Going through row 301  out of 19378
# P50719
# Haemonchus contortus
# Fetched: 0 / 0
# Going through row 302  out of 19378
# P08588
# Homo sapiens
# Fetched: 1 / 1
# Going through row 303  out of 19378
# P07550
# Homo sapiens
# Fetched: 1 / 1
# Going through row 304  out of 19378
# Q8K4Z4
# Cavia porcellus
# Fetched: 1 / 1
# Going through row 305  out of 19378
# Q28044
# Bos taurus
# Fetched: 1 / 1
# Going through row 306  out of 19378
# P35354
# Homo sapiens
# Fetched: 1 / 1
# Going through row 307  out of 19378
# P23219
# Homo sapiens
# Fetched: 1 / 1
# Going through row 308  out of 19378
# P11229
# Homo sapiens
# Fetched: 1 / 1
# Going through row 309  out of 19378
# P08172
# Homo sapiens
# Fetched: 1 / 1
# Going through row 310  out of 19378
# P20309
# Homo sapiens
# Fetched: 1 / 1
# Going through row 311  out of 19378
# P08173
# Homo sapiens
# Fetched: 1 / 1
# Going through row 312  out of 19378
# Q15822
# Homo sapiens
# Fetched: 1 / 1
# Going through row 313  out of 19378
# P36544
# Homo sapiens
# Fetched: 1 / 1
# Going through row 314  out of 19378
# P06199
# Sus scrofa
# Fetched: 11 / 11
# Going through row 315  out of 19378
# P02708
# Homo sapiens
# Fetched: 1 / 1
# Going through row 316  out of 19378
# P30926
# Homo sapiens
# Fetched: 1 / 1
# Going through row 317  out of 19378
# P08235
# Homo sapiens
# Fetched: 1 / 1
# Going through row 318  out of 19378
# P08185
# Homo sapiens
# Fetched: 1 / 1
# Going through row 319  out of 19378
# P04278
# Homo sapiens
# Fetched: 1 / 1
# Going through row 320  out of 19378
# P22199
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 321  out of 19378
# P14324
# Homo sapiens
# Fetched: 1 / 1
# Going through row 322  out of 19378
# Q0GKD7
# Leishmania donovani
# Fetched: 0 / 0
# Going through row 323  out of 19378
# P49356
# Homo sapiens
# Fetched: 1 / 1
# Going through row 324  out of 19378
# P05369
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 325  out of 19378
# P05369
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 326  out of 19378
# Q9NR96
# Homo sapiens
# Fetched: 1 / 1
# Going through row 327  out of 19378
# P0C6X7
# Human SARS coronavirus
# Fetched: 0 / 0
# Going through row 328  out of 19378
# Q932Y6
# Pseudomonas aeruginosa
# Fetched: 0 / 0
# Going through row 329  out of 19378
# Q8WUK0
# Homo sapiens
# Fetched: 1 / 1
# Going through row 330  out of 19378
# P35372
# Homo sapiens
# Fetched: 1 / 1
# Going through row 331  out of 19378
# P08183
# Homo sapiens
# Fetched: 1 / 1
# Going through row 332  out of 19378
# P33535
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 333  out of 19378
# P97266
# Cavia porcellus
# Fetched: 0 / 0
# Going through row 334  out of 19378
# P33533
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 335  out of 19378
# P35348
# Homo sapiens
# Fetched: 1 / 1
# Going through row 336  out of 19378
# P25100
# Homo sapiens
# Fetched: 1 / 1
# Going through row 337  out of 19378
# P35368
# Homo sapiens
# Fetched: 1 / 1
# Going through row 338  out of 19378
# P22303
# Homo sapiens
# Fetched: 1 / 1
# Going through row 339  out of 19378
# O15245
# Homo sapiens
# Fetched: 1 / 1
# Going through row 340  out of 19378
# P23944
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 341  out of 19378
# P18130
# Bos taurus
# Fetched: 0 / 0
# Going through row 342  out of 19378
# P08684
# Homo sapiens
# Fetched: 1 / 1
# Going through row 343  out of 19378
# P08183
# Homo sapiens
# Fetched: 1 / 1
# Going through row 344  out of 19378
# P00797
# Homo sapiens
# Fetched: 1 / 1
# Going through row 345  out of 19378
# Q9TSZ1
# Callithrix jacchus
# Fetched: 1 / 1
# Going through row 346  out of 19378
# Q6DLS0
# Macaca fascicularis
# Fetched: 0 / 0
# Going through row 347  out of 19378
# P08424
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 348  out of 19378
# P06281
# Mus musculus
# Fetched: 1 / 1
# Going through row 349  out of 19378
# Q7M3D2
# Oryctolagus cuniculus
# Fetched: 0 / 0
# Going through row 350  out of 19378
# Q9YQ12
# Human immunodeficiency virus 1
# Fetched: 0 / 0
# Going through row 351  out of 19378
# Q6DLW5
# Macaca mulatta
# Fetched: 0 / 0
# Going through row 352  out of 19378
# P14416
# Homo sapiens
# Fetched: 1 / 1
# Going through row 353  out of 19378
# P18825
# Homo sapiens
# Fetched: 1 / 1
# Going through row 354  out of 19378
# P61169
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 355  out of 19378
# P47989
# Homo sapiens
# Fetched: 1 / 1
# Going through row 356  out of 19378
# P00492
# Homo sapiens
# Fetched: 1 / 1
# Going through row 357  out of 19378
# P80457
# Bos taurus
# Fetched: 0 / 0
# Going through row 358  out of 19378
# P22985
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 359  out of 19378
# Q9FBI2
# Shigella dysenteriae
# Fetched: 0 / 0
# Going through row 360  out of 19378
# P28222
# Homo sapiens
# Fetched: 1 / 1
# Going through row 361  out of 19378
# P28221
# Homo sapiens
# Fetched: 1 / 1
# Going through row 362  out of 19378
# P30939
# Homo sapiens
# Fetched: 1 / 1
# Going through row 363  out of 19378
# Q12809
# Homo sapiens
# Fetched: 1 / 1
# Going through row 364  out of 19378
# P41595
# Homo sapiens
# Fetched: 1 / 1
# Going through row 365  out of 19378
# P46098
# Homo sapiens
# Fetched: 1 / 1
# Going through row 366  out of 19378
# P05177
# Homo sapiens
# Fetched: 1 / 1
# Going through row 367  out of 19378
# P23975
# Homo sapiens
# Fetched: 1 / 1
# Going through row 368  out of 19378
# P11473
# Homo sapiens
# Fetched: 1 / 1
# Going through row 369  out of 19378
# P30531
# Homo sapiens
# Fetched: 1 / 1
# Going through row 370  out of 19378
# P14867
# Homo sapiens
# Fetched: 1 / 1
# Going through row 371  out of 19378
# O09028
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 372  out of 19378
# P18507
# Homo sapiens
# Fetched: 1 / 1
# Going through row 373  out of 19378
# P30536
# Homo sapiens
# Fetched: 1 / 1
# Going through row 374  out of 19378
# O95342
# Homo sapiens
# Fetched: 1 / 1
# Going through row 375  out of 19378
# P16257
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 376  out of 19378
# O09028
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 377  out of 19378
# O70127
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 378  out of 19378
# P30536
# Homo sapiens
# Fetched: 1 / 1
# Going through row 379  out of 19378
# P14867
# Homo sapiens
# Fetched: 1 / 1
# Going through row 380  out of 19378
# P08684
# Homo sapiens
# Fetched: 1 / 1
# Going through row 381  out of 19378
# P25105
# Homo sapiens
# Fetched: 1 / 1
# Going through row 382  out of 19378
# P30551
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 383  out of 19378
# O60885
# Homo sapiens
# Fetched: 1 / 1
# Going through row 384  out of 19378
# P14867
# Homo sapiens
# Fetched: 1 / 1
# Going through row 385  out of 19378
# P18507
# Homo sapiens
# Fetched: 1 / 1
# Going through row 386  out of 19378
# P18507
# Homo sapiens
# Fetched: 1 / 1
# Going through row 387  out of 19378
# P18507
# Homo sapiens
# Fetched: 1 / 1
# Going through row 388  out of 19378
# P08908
# Homo sapiens
# Fetched: 1 / 1
# Going through row 389  out of 19378
# P28223
# Homo sapiens
# Fetched: 1 / 1
# Going through row 390  out of 19378
# P13945
# Homo sapiens
# Fetched: 1 / 1
# Going through row 391  out of 19378
# P19327
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 392  out of 19378
# Q02769
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 393  out of 19378
# Q28044
# Bos taurus
# Fetched: 1 / 1
# Going through row 394  out of 19378
# P08908
# Homo sapiens
# Fetched: 1 / 1
# Going through row 395  out of 19378
# P08588
# Homo sapiens
# Fetched: 1 / 1
# Going through row 396  out of 19378
# P07550
# Homo sapiens
# Fetched: 1 / 1
# Going through row 397  out of 19378
# P34995
# Homo sapiens
# Fetched: 1 / 1
# Going through row 398  out of 19378
# P43115
# Homo sapiens
# Fetched: 1 / 1
# Going through row 399  out of 19378
# P43119
# Homo sapiens
# Fetched: 1 / 1
# Going through row 400  out of 19378
# P43116
# Homo sapiens
# Fetched: 1 / 1
# Going through row 401  out of 19378
# P35408
# Homo sapiens
# Fetched: 1 / 1
# Going through row 402  out of 19378
# Q13258
# Homo sapiens
# Fetched: 1 / 1
# Going through row 403  out of 19378
# P35375
# Mus musculus
# Fetched: 1 / 1
# Going through row 404  out of 19378
# Q62053
# Mus musculus
# Fetched: 1 / 1
# Going through row 405  out of 19378
# P30557
# Mus musculus
# Fetched: 1 / 1
# Going through row 406  out of 19378
# P32240
# Mus musculus
# Fetched: 1 / 1
# Going through row 407  out of 19378
# Q62928
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 408  out of 19378
# P43114
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 409  out of 19378
# Q8NEC5
# Homo sapiens
# Fetched: 1 / 1
# Going through row 410  out of 19378
# Q96P56
# Homo sapiens
# Fetched: 1 / 1
# Going through row 411  out of 19378
# Q86XQ3
# Homo sapiens
# Fetched: 1 / 1
# Going through row 412  out of 19378
# Q7RTX7
# Homo sapiens
# Fetched: 1 / 1
# Going through row 413  out of 19378
# P43252
# Mus musculus
# Fetched: 1 / 1
# Going through row 414  out of 19378
# P34980
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 415  out of 19378
# P70597
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 416  out of 19378
# P05177
# Homo sapiens
# Fetched: 1 / 1
# Going through row 417  out of 19378
# P35372
# Homo sapiens
# Fetched: 1 / 1
# Going through row 418  out of 19378
# P41145
# Homo sapiens
# Fetched: 1 / 1
# Going through row 419  out of 19378
# P41143
# Homo sapiens
# Fetched: 1 / 1
# Going through row 420  out of 19378
# P41144
# Cavia porcellus
# Fetched: 0 / 0
# Going through row 421  out of 19378
# Q99720
# Homo sapiens
# Fetched: 1 / 1
# Going through row 422  out of 19378
# Q96FL8
# Homo sapiens
# Fetched: 1 / 1
# Going through row 423  out of 19378
# P63231
# Influenza A virus (strain A/Udorn/307/1972 H3N2)
# Fetched: 0 / 0
# Going through row 424  out of 19378
# O15399
# Homo sapiens
# Fetched: 1 / 1
# Going through row 425  out of 19378
# Q20MD5
# Influenza A virus (A/udorn/1972(H3N2))
# Fetched: 0 / 0
# Going through row 426  out of 19378
# P05778
# Influenza A virus
# Fetched: 0 / 0
# Going through row 427  out of 19378
# P0DOF8
# Influenza A virus
# Fetched: 0 / 0
# Going through row 428  out of 19378
# P22303
# Homo sapiens
# Fetched: 1 / 1
# Going through row 429  out of 19378
# P21836
# Mus musculus
# Fetched: 1 / 1
# Going through row 430  out of 19378
# P23795
# Bos taurus
# Fetched: 0 / 0
# Going through row 431  out of 19378
# P31645
# Homo sapiens
# Fetched: 1 / 1
# Going through row 432  out of 19378
# P10635
# Homo sapiens
# Fetched: 1 / 1
# Going through row 433  out of 19378
# Q9Y5Y9
# Homo sapiens
# Fetched: 1 / 1
# Going through row 434  out of 19378
# P04062
# Homo sapiens
# Fetched: 1 / 1
# Going through row 435  out of 19378
# P04150
# Homo sapiens
# Fetched: 1 / 1
# Going through row 436  out of 19378
# P19328
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 437  out of 19378
# P15823
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 438  out of 19378
# P35462
# Homo sapiens
# Fetched: 1 / 1
# Going through row 439  out of 19378
# P05186
# Homo sapiens
# Fetched: 1 / 1
# Going through row 440  out of 19378
# O32553
# Escherichia coli
# Fetched: 0 / 0
# Going through row 441  out of 19378
# P37088
# Homo sapiens
# Fetched: 1 / 1
# Going through row 442  out of 19378
# P00749
# Homo sapiens
# Fetched: 1 / 1
# Going through row 443  out of 19378
# P29274
# Homo sapiens
# Fetched: 1 / 1
# Going through row 444  out of 19378
# P21397
# Homo sapiens
# Fetched: 1 / 1
# Going through row 445  out of 19378
# P19634
# Homo sapiens
# Fetched: 1 / 1
# Going through row 446  out of 19378
# O15245
# Homo sapiens
# Fetched: 1 / 1
# Going through row 447  out of 19378
# Q16515
# Homo sapiens
# Fetched: 1 / 1
# Going through row 448  out of 19378
# P78348
# Homo sapiens
# Fetched: 1 / 1
# Going through row 449  out of 19378
# O08590
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 450  out of 19378
# Q9UHC3
# Homo sapiens
# Fetched: 1 / 1
# Going through row 451  out of 19378
# P37088
# Homo sapiens
# Fetched: 1 / 1
# Going through row 452  out of 19378
# Q9W6Q1
# Amphiuma tridactylum
# Fetched: 0 / 0
# Going through row 453  out of 19378
# Q14940
# Homo sapiens
# Fetched: 1 / 1
# Going through row 454  out of 19378
# P26431
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 455  out of 19378
# P50482
# Oryctolagus cuniculus
# Fetched: 0 / 0
# Going through row 456  out of 19378
# P06869
# Mus musculus
# Fetched: 1 / 1
# Going through row 457  out of 19378
# P55926
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 458  out of 19378
# P16083
# Homo sapiens
# Fetched: 1 / 1
# Going through row 459  out of 19378
# P28593
# Trypanosoma cruzi
# Fetched: 0 / 0
# Going through row 460  out of 19378
# P16083
# Homo sapiens
# Fetched: 1 / 1
# Going through row 461  out of 19378
# P23977
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 462  out of 19378
# P00747
# Homo sapiens
# Fetched: 1 / 1
# Going through row 463  out of 19378
# P00750
# Homo sapiens
# Fetched: 1 / 1
# Going through row 464  out of 19378
# P11511
# Homo sapiens
# Fetched: 1 / 1
# Going through row 465  out of 19378
# P24557
# Homo sapiens
# Fetched: 1 / 1
# Going through row 466  out of 19378
# P05108
# Homo sapiens
# Fetched: 1 / 1
# Going through row 467  out of 19378
# P22443
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 468  out of 19378
# P00189
# Bos taurus
# Fetched: 0 / 0
# Going through row 469  out of 19378
# Q4U2R8
# Homo sapiens
# Fetched: 1 / 1
# Going through row 470  out of 19378
# Q8VC69
# Mus musculus
# Fetched: 1 / 1
# Going through row 471  out of 19378
# P35354
# Homo sapiens
# Fetched: 1 / 1
# Going through row 472  out of 19378
# P23219
# Homo sapiens
# Fetched: 1 / 1
# Going through row 473  out of 19378
# Q6XQN6
# Homo sapiens
# Fetched: 1 / 1
# Going through row 474  out of 19378
# P35228
# Homo sapiens
# Fetched: 1 / 1
# Going through row 475  out of 19378
# P14780
# Homo sapiens
# Fetched: 1 / 1
# Going through row 476  out of 19378
# P03956
# Homo sapiens
# Fetched: 1 / 1
# Going through row 477  out of 19378
# P15917
# Bacillus anthracis
# Fetched: 0 / 0
# Going through row 478  out of 19378
# P10845
# Clostridium botulinum
# Fetched: 0 / 0
# Going through row 479  out of 19378
# P08588
# Homo sapiens
# Fetched: 1 / 1
# Going through row 480  out of 19378
# Q14524
# Homo sapiens
# Fetched: 1 / 1
# Going through row 481  out of 19378
# P35372
# Homo sapiens
# Fetched: 1 / 1
# Going through row 482  out of 19378
# P21728
# Homo sapiens
# Fetched: 1 / 1
# Going through row 483  out of 19378
# P14416
# Homo sapiens
# Fetched: 1 / 1
# Going through row 484  out of 19378
# P08913
# Homo sapiens
# Fetched: 1 / 1
# Going through row 485  out of 19378
# Q99720
# Homo sapiens
# Fetched: 1 / 1
# Going through row 486  out of 19378
# P10827
# Homo sapiens
# Fetched: 1 / 1
# Going through row 487  out of 19378
# P10828
# Homo sapiens
# Fetched: 1 / 1
# Going through row 488  out of 19378
# Q12809
# Homo sapiens
# Fetched: 1 / 1
# Going through row 489  out of 19378
# P08684
# Homo sapiens
# Fetched: 1 / 1
# Going through row 490  out of 19378
# Q15125
# Homo sapiens
# Fetched: 1 / 1
# Going through row 491  out of 19378
# P08183
# Homo sapiens
# Fetched: 1 / 1
# Going through row 492  out of 19378
# P31645
# Homo sapiens
# Fetched: 1 / 1
# Going through row 493  out of 19378
# P23975
# Homo sapiens
# Fetched: 1 / 1
# Going through row 494  out of 19378
# P28223
# Homo sapiens
# Fetched: 1 / 1
# Going through row 495  out of 19378
# P41595
# Homo sapiens
# Fetched: 1 / 1
# Going through row 496  out of 19378
# P28335
# Homo sapiens
# Fetched: 1 / 1
# Going through row 497  out of 19378
# P50406
# Homo sapiens
# Fetched: 1 / 1
# Going through row 498  out of 19378
# P18089
# Homo sapiens
# Fetched: 1 / 1
# Going through row 499  out of 19378
# P35462
# Homo sapiens
# Fetched: 1 / 1
# Going through row 500  out of 19378
# P25021
# Homo sapiens
# Fetched: 1 / 1
# Going through row 501  out of 19378
# P11229
# Homo sapiens
# Fetched: 1 / 1
# Going through row 502  out of 19378
# P08172
# Homo sapiens
# Fetched: 1 / 1
# Going through row 503  out of 19378
# P20309
# Homo sapiens
# Fetched: 1 / 1
# Going through row 504  out of 19378
# P08173
# Homo sapiens
# Fetched: 1 / 1
# Going through row 505  out of 19378
# P08912
# Homo sapiens
# Fetched: 1 / 1
# Going through row 506  out of 19378
# P13945
# Homo sapiens
# Fetched: 1 / 1
# Going through row 507  out of 19378
# Q01959
# Homo sapiens
# Fetched: 1 / 1
# Going through row 508  out of 19378
# P0DMS8
# Homo sapiens
# Fetched: 1 / 1
# Going through row 509  out of 19378
# P21917
# Homo sapiens
# Fetched: 1 / 1
# Going through row 510  out of 19378
# P41145
# Homo sapiens
# Fetched: 1 / 1
# Going through row 511  out of 19378
# P41143
# Homo sapiens
# Fetched: 1 / 1
# Going through row 512  out of 19378
# P11712
# Homo sapiens
# Fetched: 1 / 1
# Going through row 513  out of 19378
# O95180
# Homo sapiens
# Fetched: 1 / 1
# Going through row 514  out of 19378
# P25101
# Homo sapiens
# Fetched: 1 / 1
# Going through row 515  out of 19378
# Q14534
# Homo sapiens
# Fetched: 1 / 1
# Going through row 516  out of 19378
# P06241
# Homo sapiens
# Fetched: 1 / 1
# Going through row 517  out of 19378
# P04626
# Homo sapiens
# Fetched: 1 / 1
# Going through row 518  out of 19378
# P37268
# Homo sapiens
# Fetched: 1 / 1
# Going through row 519  out of 19378
# P41597
# Homo sapiens
# Fetched: 1 / 1
# Going through row 520  out of 19378
# P21452
# Homo sapiens
# Fetched: 1 / 1
# Going through row 521  out of 19378
# P15207
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 522  out of 19378
# P15917
# Bacillus anthracis
# Fetched: 0 / 0
# Going through row 523  out of 19378
# Q9Y3Q4
# Homo sapiens
# Fetched: 1 / 1
# Going through row 524  out of 19378
# Q96RP8
# Homo sapiens
# Fetched: 1 / 1
# Going through row 525  out of 19378
# P28564
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 526  out of 19378
# P30411
# Homo sapiens
# Fetched: 1 / 1
# Going through row 527  out of 19378
# P32245
# Homo sapiens
# Fetched: 1 / 1
# Going through row 528  out of 19378
# P33032
# Homo sapiens
# Fetched: 1 / 1
# Going through row 529  out of 19378
# P41968
# Homo sapiens
# Fetched: 1 / 1
# Going through row 530  out of 19378
# P51679
# Homo sapiens
# Fetched: 1 / 1
# Going through row 531  out of 19378
# P70580
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 532  out of 19378
# P32352
# Saccharomyces cerevisiae (strain ATCC 204508 / S288c)
# Fetched: 0 / 0
# Going through row 533  out of 19378
# P25779
# Trypanosoma cruzi
# Fetched: 0 / 0
# Going through row 534  out of 19378
# Q9NVV9
# Homo sapiens
# Fetched: 1 / 1
# Going through row 535  out of 19378
# P15389
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 536  out of 19378
# O75151
# Homo sapiens
# Fetched: 1 / 1
# Going through row 537  out of 19378
# P29375
# Homo sapiens
# Fetched: 1 / 1
# Going through row 538  out of 19378
# Q6ZMT4
# Homo sapiens
# Fetched: 1 / 1
# Going through row 539  out of 19378
# P08913
# Homo sapiens
# Fetched: 1 / 1
# Going through row 540  out of 19378
# P28223
# Homo sapiens
# Fetched: 1 / 1
# Going through row 541  out of 19378
# P41595
# Homo sapiens
# Fetched: 1 / 1
# Going through row 542  out of 19378
# P50406
# Homo sapiens
# Fetched: 1 / 1
# Going through row 543  out of 19378
# P34969
# Homo sapiens
# Fetched: 1 / 1
# Going through row 544  out of 19378
# P28222
# Homo sapiens
# Fetched: 1 / 1
# Going through row 545  out of 19378
# P28221
# Homo sapiens
# Fetched: 1 / 1
# Going through row 546  out of 19378
# P18825
# Homo sapiens
# Fetched: 1 / 1
# Going through row 547  out of 19378
# P21917
# Homo sapiens
# Fetched: 1 / 1
# Going through row 548  out of 19378
# P19020
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 549  out of 19378
# P14416
# Homo sapiens
# Fetched: 1 / 1
# Going through row 550  out of 19378
# P35462
# Homo sapiens
# Fetched: 1 / 1
# Going through row 551  out of 19378
# Q14524
# Homo sapiens
# Fetched: 1 / 1
# Going through row 552  out of 19378
# P21728
# Homo sapiens
# Fetched: 1 / 1
# Going through row 553  out of 19378
# P14416
# Homo sapiens
# Fetched: 1 / 1
# Going through row 554  out of 19378
# P08913
# Homo sapiens
# Fetched: 1 / 1
# Going through row 555  out of 19378
# Q99720
# Homo sapiens
# Fetched: 1 / 1
# Going through row 556  out of 19378
# Q12809
# Homo sapiens
# Fetched: 1 / 1
# Going through row 557  out of 19378
# P31645
# Homo sapiens
# Fetched: 1 / 1
# Going through row 558  out of 19378
# P23975
# Homo sapiens
# Fetched: 1 / 1
# Going through row 559  out of 19378
# P08908
# Homo sapiens
# Fetched: 1 / 1
# Going through row 560  out of 19378
# P28223
# Homo sapiens
# Fetched: 1 / 1
# Going through row 561  out of 19378
# P41595
# Homo sapiens
# Fetched: 1 / 1
# Going through row 562  out of 19378
# P28335
# Homo sapiens
# Fetched: 1 / 1
# Going through row 563  out of 19378
# P50406
# Homo sapiens
# Fetched: 1 / 1
# Going through row 564  out of 19378
# P34969
# Homo sapiens
# Fetched: 1 / 1
# Going through row 565  out of 19378
# P35348
# Homo sapiens
# Fetched: 1 / 1
# Going through row 566  out of 19378
# P18089
# Homo sapiens
# Fetched: 1 / 1
# Going through row 567  out of 19378
# P35462
# Homo sapiens
# Fetched: 1 / 1
# Going through row 568  out of 19378
# P21918
# Homo sapiens
# Fetched: 1 / 1
# Going through row 569  out of 19378
# P35367
# Homo sapiens
# Fetched: 1 / 1
# Going through row 570  out of 19378
# P25021
# Homo sapiens
# Fetched: 1 / 1
# Going through row 571  out of 19378
# Q9H3N8
# Homo sapiens
# Fetched: 1 / 1
# Going through row 572  out of 19378
# P11229
# Homo sapiens
# Fetched: 1 / 1
# Going through row 573  out of 19378
# P08172
# Homo sapiens
# Fetched: 1 / 1
# Going through row 574  out of 19378
# P20309
# Homo sapiens
# Fetched: 1 / 1
# Going through row 575  out of 19378
# P08173
# Homo sapiens
# Fetched: 1 / 1
# Going through row 576  out of 19378
# P08912
# Homo sapiens
# Fetched: 1 / 1
# Going through row 577  out of 19378
# Q06278
# Homo sapiens
# Fetched: 1 / 1
# Going through row 578  out of 19378
# P18825
# Homo sapiens
# Fetched: 1 / 1
# Going through row 579  out of 19378
# Q99250
# Homo sapiens
# Fetched: 1 / 1
# Going through row 580  out of 19378
# Q15858
# Homo sapiens
# Fetched: 1 / 1
# Going through row 581  out of 19378
# Q01959
# Homo sapiens
# Fetched: 1 / 1
# Going through row 582  out of 19378
# P25100
# Homo sapiens
# Fetched: 1 / 1
# Going through row 583  out of 19378
# P07949
# Homo sapiens
# Fetched: 1 / 1
# Going through row 584  out of 19378
# P04629
# Homo sapiens
# Fetched: 1 / 1
# Going through row 585  out of 19378
# O15245
# Homo sapiens
# Fetched: 1 / 1
# Going through row 586  out of 19378
# P15823
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 587  out of 19378
# P28564
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 588  out of 19378
# P43140
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 589  out of 19378
# P19327
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 590  out of 19378
# P31652
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 591  out of 19378
# P14842
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 592  out of 19378
# Q9WTR4
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 593  out of 19378
# P32305
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 594  out of 19378
# P32304
# Mus musculus
# Fetched: 1 / 1
# Going through row 595  out of 19378
# P08909
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 596  out of 19378
# P31390
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 597  out of 19378
# P31388
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 598  out of 19378
# O15244
# Homo sapiens
# Fetched: 1 / 1
# Going through row 599  out of 19378
# P08482
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 600  out of 19378
# P48542
# Mus musculus
# Fetched: 1 / 1
# Going through row 601  out of 19378
# P07949
# Homo sapiens
# Fetched: 1 / 1
# Going through row 602  out of 19378
# Q14164
# Homo sapiens
# Fetched: 1 / 1
# Going through row 603  out of 19378
# Q9UHD2
# Homo sapiens
# Fetched: 1 / 1
# Going through row 604  out of 19378
# Q9HC97
# Homo sapiens
# Fetched: 1 / 1
# Going through row 605  out of 19378
# P27815
# Homo sapiens
# Fetched: 1 / 1
# Going through row 606  out of 19378
# P08913
# Homo sapiens
# Fetched: 1 / 1
# Going through row 607  out of 19378
# P50406
# Homo sapiens
# Fetched: 1 / 1
# Going through row 608  out of 19378
# P35348
# Homo sapiens
# Fetched: 1 / 1
# Going through row 609  out of 19378
# Q06278
# Homo sapiens
# Fetched: 1 / 1
# Going through row 610  out of 19378
# P18825
# Homo sapiens
# Fetched: 1 / 1
# Going through row 611  out of 19378
# Q01959
# Homo sapiens
# Fetched: 1 / 1
# Going through row 612  out of 19378
# P25100
# Homo sapiens
# Fetched: 1 / 1
# Going through row 613  out of 19378
# P35368
# Homo sapiens
# Fetched: 1 / 1
# Going through row 614  out of 19378
# Q06432
# Homo sapiens
# Fetched: 1 / 1
# Going through row 615  out of 19378
# Q13936
# Homo sapiens
# Fetched: 1 / 1
# Going through row 616  out of 19378
# P00915
# Homo sapiens
# Fetched: 1 / 1
# Going through row 617  out of 19378
# P54289
# Homo sapiens
# Fetched: 1 / 1
# Going through row 618  out of 19378
# Q01668
# Homo sapiens
# Fetched: 1 / 1
# Going through row 619  out of 19378
# O95180
# Homo sapiens
# Fetched: 1 / 1
# Going through row 620  out of 19378
# O95069
# Homo sapiens
# Fetched: 1 / 1
# Going through row 621  out of 19378
# P22002
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 622  out of 19378
# Q8HY88
# Bos taurus
# Fetched: 1 / 1
# Going through row 623  out of 19378
# Q12809
# Homo sapiens
# Fetched: 1 / 1
# Going through row 624  out of 19378
# P50135
# Homo sapiens
# Fetched: 1 / 1
# Going through row 625  out of 19378
# Q9Y251
# Homo sapiens
# Fetched: 1 / 1
# Going through row 626  out of 19378
# P05067
# Homo sapiens
# Fetched: 1 / 1
# Going through row 627  out of 19378
# P21728
# Homo sapiens
# Fetched: 1 / 1
# Going through row 628  out of 19378
# P14416
# Homo sapiens
# Fetched: 1 / 1
# Going through row 629  out of 19378
# P08913
# Homo sapiens
# Fetched: 1 / 1
# Going through row 630  out of 19378
# P08183
# Homo sapiens
# Fetched: 1 / 1
# Going through row 631  out of 19378
# P31645
# Homo sapiens
# Fetched: 1 / 1
# Going through row 632  out of 19378
# P23975
# Homo sapiens
# Fetched: 1 / 1
# Going through row 633  out of 19378
# P08908
# Homo sapiens
# Fetched: 1 / 1
# Going through row 634  out of 19378
# P28223
# Homo sapiens
# Fetched: 1 / 1
# Going through row 635  out of 19378
# P41595
# Homo sapiens
# Fetched: 1 / 1
# Going through row 636  out of 19378
# P28335
# Homo sapiens
# Fetched: 1 / 1
# Going through row 637  out of 19378
# P50406
# Homo sapiens
# Fetched: 1 / 1
# Going through row 638  out of 19378
# P34969
# Homo sapiens
# Fetched: 1 / 1
# Going through row 639  out of 19378
# P18089
# Homo sapiens
# ...
# Q14524
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19168  out of 19378
# Q12809
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19169  out of 19378
# Q13936
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19170  out of 19378
# Q12809
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19171  out of 19378
# Q13936
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19172  out of 19378
# Q14524
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19173  out of 19378
# P41146
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19174  out of 19378
# P35372
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19175  out of 19378
# P11532
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19176  out of 19378
# P08887
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19177  out of 19378
# P10275
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19178  out of 19378
# P30874
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19179  out of 19378
# P35968
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19180  out of 19378
# P09619
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19181  out of 19378
# P36888
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19182  out of 19378
# P23458
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19183  out of 19378
# P04629
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19184  out of 19378
# O60674
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19185  out of 19378
# P11362
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19186  out of 19378
# Q08345
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19187  out of 19378
# Q16288
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19188  out of 19378
# P07949
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19189  out of 19378
# P10912
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19190  out of 19378
# P01112
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19191  out of 19378
# P01116
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19192  out of 19378
# P01111
# Homo sapiens
# Retrying in 3s
# Fetched: 1 / 1
# Going through row 19193  out of 19378
# P01112
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19194  out of 19378
# P01116
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19195  out of 19378
# P49354
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19196  out of 19378
# Q9UJM8
# Homo sapiens
# Retrying in 3s
# Fetched: 1 / 1
# Going through row 19197  out of 19378
# P33032
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19198  out of 19378
# P41968
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19199  out of 19378
# Q01726
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19200  out of 19378
# P33032
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19201  out of 19378
# P41968
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19202  out of 19378
# Q01726
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19203  out of 19378
# P32245
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19204  out of 19378
# Q14973
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19205  out of 19378
# P01857
# Homo sapiens
# Retrying in 3s
# Fetched: 1 / 1
# Going through row 19206  out of 19378
# Q12809
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19207  out of 19378
# P36888
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19208  out of 19378
# P35916
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19209  out of 19378
# P07333
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19210  out of 19378
# P07333
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19211  out of 19378
# P35916
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19212  out of 19378
# P36888
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19213  out of 19378
# Q12809
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19214  out of 19378
# P52333
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19215  out of 19378
# O60674
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19216  out of 19378
# P29597
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19217  out of 19378
# P23458
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19218  out of 19378
# P15692
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19219  out of 19378
# Q9NWT6
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19220  out of 19378
# P15692
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19221  out of 19378
# Q8N543
# Homo sapiens
# Retrying in 3s
# Fetched: 1 / 1
# Going through row 19222  out of 19378
# Q9NWT6
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19223  out of 19378
# Q9GZT9
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19224  out of 19378
# Q96KS0
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19225  out of 19378
# Q9H6Z9
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19226  out of 19378
# Q9GZT9
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19227  out of 19378
# Q96KS0
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19228  out of 19378
# Q9H6Z9
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19229  out of 19378
# Q63016
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 19230  out of 19378
# P06239
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19231  out of 19378
# P04626
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19232  out of 19378
# P04626
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19233  out of 19378
# P06239
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19234  out of 19378
# Q15303
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19235  out of 19378
# P51813
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19236  out of 19378
# P42680
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19237  out of 19378
# P42681
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19238  out of 19378
# P51451
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19239  out of 19378
# Q06187
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19240  out of 19378
# Q9NWZ3
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19241  out of 19378
# P08581
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19242  out of 19378
# Q9UNQ0
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19243  out of 19378
# Q4U2R8
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19244  out of 19378
# Q8TCC7
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19245  out of 19378
# P11712
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19246  out of 19378
# Q96S37
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19247  out of 19378
# O75116
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19248  out of 19378
# P52333
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19249  out of 19378
# P23458
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19250  out of 19378
# O60674
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19251  out of 19378
# P29597
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19252  out of 19378
# Q9GZT9
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19253  out of 19378
# Q96KS0
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19254  out of 19378
# Q9H6Z9
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19255  out of 19378
# P20309
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19256  out of 19378
# P07288
# Homo sapiens
# Retrying in 3s
# Fetched: 1 / 1
# Going through row 19257  out of 19378
# P03952
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19258  out of 19378
# P12931
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19259  out of 19378
# P07948
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19260  out of 19378
# P12931
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19261  out of 19378
# P07948
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19262  out of 19378
# P30969
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 19263  out of 19378
# P30969
# Rattus norvegicus
# Fetched: 1 / 1
# Going through row 19264  out of 19378
# P30968
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19265  out of 19378
# P87666
# Zaire ebolavirus (strain Kikwit-95)
# Retrying in 3s
# Fetched: 0 / 0
# Going through row 19266  out of 19378
# P04626
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19267  out of 19378
# P08637
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19268  out of 19378
# P08637
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19269  out of 19378
# P87666
# Zaire ebolavirus (strain Kikwit-95)
# Fetched: 0 / 0
# Going through row 19270  out of 19378
# P87666
# Zaire ebolavirus (strain Kikwit-95)
# Fetched: 0 / 0
# Going through row 19271  out of 19378
# P08637
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19272  out of 19378
# P87666
# Zaire ebolavirus (strain Kikwit-95)
# Fetched: 0 / 0
# Going through row 19273  out of 19378
# P20595
# Rattus norvegicus
# Retrying in 3s
# Fetched: 1 / 1
# Going through row 19274  out of 19378
# Q02153
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19275  out of 19378
# Q76353
# Human immunodeficiency virus 1
# Fetched: 0 / 0
# Going through row 19276  out of 19378
# Q76353
# Human immunodeficiency virus 1
# Fetched: 0 / 0
# Going through row 19277  out of 19378
# Q7ZJM1
# Human immunodeficiency virus 1
# Fetched: 0 / 0
# Going through row 19278  out of 19378
# P42336
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19279  out of 19378
# P42338
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19280  out of 19378
# P48736
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19281  out of 19378
# O00329
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19282  out of 19378
# P49674
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19283  out of 19378
# P36888
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19284  out of 19378
# P06493
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19285  out of 19378
# P24941
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19286  out of 19378
# Q00535
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19287  out of 19378
# P50750
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19288  out of 19378
# P50613
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19289  out of 19378
# Q9H093
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19290  out of 19378
# Q6ZWH5
# Homo sapiens
# Retrying in 3s
# Fetched: 1 / 1
# Going through row 19291  out of 19378
# Q00534
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19292  out of 19378
# P11802
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19293  out of 19378
# P11532
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19294  out of 19378
# Q9NZB8
# Homo sapiens
# Retrying in 3s
# Fetched: 1 / 1
# Going through row 19295  out of 19378
# Q9H228
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19296  out of 19378
# O95977
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19297  out of 19378
# Q99500
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19298  out of 19378
# P21453
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19299  out of 19378
# P47871
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19300  out of 19378
# Q9Y5C1
# Homo sapiens
# Retrying in 3s
# Fetched: 1 / 1
# Going through row 19301  out of 19378
# P03372
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19302  out of 19378
# Q92731
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19303  out of 19378
# Q15116
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19304  out of 19378
# P15391
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19305  out of 19378
# P0DTC2
# Severe acute respiratory syndrome coronavirus 2 (2019-nCoV) (SARS-CoV-2)
# Fetched: 0 / 0
# Going through row 19306  out of 19378
# P0DTC2
# Severe acute respiratory syndrome coronavirus 2 (2019-nCoV) (SARS-CoV-2)
# Fetched: 0 / 0
# Going through row 19307  out of 19378
# P0DTC2
# Severe acute respiratory syndrome coronavirus 2 (2019-nCoV) (SARS-CoV-2)
# Fetched: 0 / 0
# Going through row 19308  out of 19378
# P0DTC2
# Severe acute respiratory syndrome coronavirus 2 (2019-nCoV) (SARS-CoV-2)
# Fetched: 0 / 0
# Going through row 19309  out of 19378
# P01024
# Homo sapiens
# Retrying in 3s
# Fetched: 1 / 1
# Going through row 19310  out of 19378
# Q04609
# Homo sapiens
# Retrying in 3s
# Fetched: 1 / 1
# Going through row 19311  out of 19378
# Q04912
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19312  out of 19378
# P00519
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19313  out of 19378
# P10721
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19314  out of 19378
# P12931
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19315  out of 19378
# P06239
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19316  out of 19378
# P07947
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19317  out of 19378
# P06241
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19318  out of 19378
# P15056
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19319  out of 19378
# P36888
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19320  out of 19378
# P07949
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19321  out of 19378
# P17948
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19322  out of 19378
# P35968
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19323  out of 19378
# P35916
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19324  out of 19378
# P16234
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19325  out of 19378
# P06213
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19326  out of 19378
# O60674
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19327  out of 19378
# P43405
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19328  out of 19378
# Q02763
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19329  out of 19378
# P08581
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19330  out of 19378
# P07948
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19331  out of 19378
# P51813
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19332  out of 19378
# Q9UM73
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19333  out of 19378
# P54762
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19334  out of 19378
# Q16620
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19335  out of 19378
# P29597
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19336  out of 19378
# P08922
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19337  out of 19378
# Q99835
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19338  out of 19378
# P07949
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19339  out of 19378
# P12931
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19340  out of 19378
# P35968
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19341  out of 19378
# O60674
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19342  out of 19378
# P00519
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19343  out of 19378
# P06213
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19344  out of 19378
# P06239
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19345  out of 19378
# P06241
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19346  out of 19378
# P07947
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19347  out of 19378
# P07948
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19348  out of 19378
# P07949
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19349  out of 19378
# P08581
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19350  out of 19378
# P08922
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19351  out of 19378
# P10721
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19352  out of 19378
# P12931
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19353  out of 19378
# P15056
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19354  out of 19378
# P16234
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19355  out of 19378
# P17948
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19356  out of 19378
# P29597
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19357  out of 19378
# P35916
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19358  out of 19378
# P36888
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19359  out of 19378
# P43405
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19360  out of 19378
# P51813
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19361  out of 19378
# P54762
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19362  out of 19378
# Q02763
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19363  out of 19378
# Q04912
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19364  out of 19378
# Q16620
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19365  out of 19378
# Q99835
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19366  out of 19378
# Q9UM73
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19367  out of 19378
# P22607
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19368  out of 19378
# P21802
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19369  out of 19378
# P22455
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19370  out of 19378
# P11362
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19371  out of 19378
# P35372
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19372  out of 19378
# P41145
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19373  out of 19378
# P41143
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19374  out of 19378
# P01116
# Homo sapiens
# Fetched: 1 / 1
# Going through row 19375  out of 19378
# O13428
# Candida albicans
# Fetched: 0 / 0
# Going through row 19376  out of 19378
# Q6FTN8
# Candida glabrata
# Retrying in 3s
# Fetched: 0 / 0
# Going through row 19377  out of 19378
# P87204
# Neosartorya fumigata
# Retrying in 3s
# Fetched: 0 / 0

# %%
df
# Out:
#                  STRUCT_ID                                        TARGET_NAME  \
# DRUG_NAME
# levobupivacaine          4  Potassium voltage-gated channel subfamily H me...
# levobupivacaine          4        Sodium channel protein type 1 subunit alpha
# levobupivacaine          4        Sodium channel protein type 4 subunit alpha
# levobupivacaine          4              Prostaglandin E2 receptor EP1 subtype
# levobupivacaine          4                                Cytochrome P450 2D6
# ...                    ...                                                ...
# samidorphan           5460                         Delta-type opioid receptor
# sotorasib             5461                                        GTPase KRas
# ibrexafungerp         5462       Beta-1,3-glucan synthase catalytic subunit 1
# ibrexafungerp         5462          1,3-Beta-D-glucan-UDP glucosyltransferase
# ibrexafungerp         5462          1,3-Beta-D-glucan-UDP glucosyltransferase
#
#                 TARGET_CLASS ACCESSION    GENE     SWISSPROT  ACT_VALUE  \
# DRUG_NAME
# levobupivacaine  Ion channel    Q12809   KCNH2   KCNH2_HUMAN      4.890
# levobupivacaine  Ion channel    P35498   SCN1A   SCN1A_HUMAN      5.790
# levobupivacaine  Ion channel    P35499   SCN4A   SCN4A_HUMAN        NaN
# levobupivacaine         GPCR    P34995  PTGER1   PE2R1_HUMAN        NaN
# levobupivacaine       Enzyme    P10635  CYP2D6   CP2D6_HUMAN      6.707
# ...                      ...       ...     ...           ...        ...
# samidorphan             GPCR    P41143   OPRD1    OPRD_HUMAN      8.590
# sotorasib             Enzyme    P01116    KRAS    RASK_HUMAN      7.030
# ibrexafungerp         Enzyme    O13428    GSC1  O13428_CANAX      8.350
# ibrexafungerp         Enzyme    Q6FTN8    FKS1  Q6FTN8_CANGA      7.830
# ibrexafungerp         Enzyme    P87204     FKS  P87204_ASPFM      8.970
#
#                  ACT_UNIT ACT_TYPE  \
# DRUG_NAME
# levobupivacaine       NaN     IC50
# levobupivacaine       NaN     IC50
# levobupivacaine       NaN      NaN
# levobupivacaine       NaN      NaN
# levobupivacaine       NaN     IC50
# ...                   ...      ...
# samidorphan           NaN       Ki
# sotorasib             NaN     IC50
# ibrexafungerp         NaN     IC50
# ibrexafungerp         NaN     IC50
# ibrexafungerp         NaN     IC50
#
#                                                        ACT_COMMENT  \
# DRUG_NAME
# levobupivacaine  Inhibition of wild-type human ERG channel expr...
# levobupivacaine                                                NaN
# levobupivacaine                                                NaN
# levobupivacaine                                                NaN
# levobupivacaine  DRUGMATRIX: CYP450, 2D6 enzyme inhibition (sub...
# ...                                                            ...
# samidorphan                                                    NaN
# sotorasib                                       KRAS G12C mutation
# ibrexafungerp    MoA - inhibits the biosynthesis of beta-(1,3)-...
# ibrexafungerp    MoA - inhibits the biosynthesis of beta-(1,3)-...
# ibrexafungerp    MoA - inhibits the biosynthesis of beta-(1,3)-...
#
#                             ACT_SOURCE RELATION  MOA             MOA_SOURCE  \
# DRUG_NAME
# levobupivacaine                 CHEMBL        =  NaN                    NaN
# levobupivacaine              WOMBAT-PK        =  NaN                    NaN
# levobupivacaine              WOMBAT-PK      NaN  1.0                 CHEMBL
# levobupivacaine              WOMBAT-PK      NaN  NaN                    NaN
# levobupivacaine            DRUG MATRIX        =  NaN                    NaN
# ...                                ...      ...  ...                    ...
# samidorphan                 DRUG LABEL        =  NaN                    NaN
# sotorasib                   DRUG LABEL        =  1.0             DRUG LABEL
# ibrexafungerp    SCIENTIFIC LITERATURE        =  1.0             DRUG LABEL
# ibrexafungerp    SCIENTIFIC LITERATURE        =  1.0  SCIENTIFIC LITERATURE
# ibrexafungerp    SCIENTIFIC LITERATURE        =  1.0  SCIENTIFIC LITERATURE
#
#                                                     ACT_SOURCE_URL  \
# DRUG_NAME
# levobupivacaine                                                NaN
# levobupivacaine                                                NaN
# levobupivacaine                                                NaN
# levobupivacaine                                                NaN
# levobupivacaine                                                NaN
# ...                                                            ...
# samidorphan      https://www.accessdata.fda.gov/drugsatfda_docs...
# sotorasib        https://www.accessdata.fda.gov/drugsatfda_docs...
# ibrexafungerp             https://pubmed.ncbi.nlm.nih.gov/24323472
# ibrexafungerp             https://pubmed.ncbi.nlm.nih.gov/24323472
# ibrexafungerp             https://pubmed.ncbi.nlm.nih.gov/24323472
#
#                                                     MOA_SOURCE_URL  \
# DRUG_NAME
# levobupivacaine                                                NaN
# levobupivacaine                                                NaN
# levobupivacaine  https://www.ebi.ac.uk/chembl/compound/inspect/...
# levobupivacaine                                                NaN
# levobupivacaine                                                NaN
# ...                                                            ...
# samidorphan                                                    NaN
# sotorasib        https://www.accessdata.fda.gov/drugsatfda_docs...
# ibrexafungerp    https://www.accessdata.fda.gov/drugsatfda_docs...
# ibrexafungerp    https://www.accessdata.fda.gov/drugsatfda_docs...
# ibrexafungerp    https://www.accessdata.fda.gov/drugsatfda_docs...
#
#                      ACTION_TYPE    TDL              ORGANISM      NEW_ID
# DRUG_NAME
# levobupivacaine              NaN  Tclin          Homo sapiens   HGNC:6251
# levobupivacaine              NaN  Tclin          Homo sapiens  HGNC:10585
# levobupivacaine          BLOCKER  Tclin          Homo sapiens  HGNC:10591
# levobupivacaine              NaN  Tclin          Homo sapiens   HGNC:9593
# levobupivacaine              NaN  Tclin          Homo sapiens   HGNC:2625
# ...                          ...    ...                   ...         ...
# samidorphan      PARTIAL AGONIST  Tclin          Homo sapiens   HGNC:8153
# sotorasib              INHIBITOR  Tchem          Homo sapiens   HGNC:6407
# ibrexafungerp          INHIBITOR    NaN      Candida albicans          NA
# ibrexafungerp          INHIBITOR    NaN      Candida glabrata          NA
# ibrexafungerp          INHIBITOR    NaN  Neosartorya fumigata          NA
#
# [19378 rows x 20 columns]

# %% [markdown]
# Drop rows that don't have a new ID:

# %%
df = df.drop(df[df.NEW_ID == 'NA'].index)

# %% [markdown]
# Keep only rows whose the target is in the Monarch nodes:

# %%
df = df[df['NEW_ID'].isin(list(nodes['id']))]

# %% [markdown]
# Save the Drug-Target dataframe as .csv:

# %%
df.to_csv('drug.target.final.ELA.csv', encoding = 'utf-8-sig')

# %% [markdown]
# Create and save a dataframe containing the drug nodes:

# %%
df['DRUG_NAME'] = df.index
df_drugs = df[['DRUG_NAME', 'STRUCT_ID']]
df_drugs = df_drugs.drop_duplicates()
df_drugs.to_csv('drug_nodes_ELA.csv', encoding = 'utf-8-sig')

# %%
df
# Out:
#                   STRUCT_ID  \
# DRUG_NAME
# (S)-nicardipine           5
# (S)-nitrendipine          6
# (S)-nitrendipine          6
# (S)-nitrendipine          6
# (S)-nitrendipine          6
# ...                     ...
# tirbanibulin           5431
# casimersen             5443
# infigratinib           5459
# infigratinib           5459
# infigratinib           5459
#
#                                                         TARGET_NAME  \
# DRUG_NAME
# (S)-nicardipine                Voltage-gated L-type calcium channel
# (S)-nitrendipine  Voltage-dependent L-type calcium channel subun...
# (S)-nitrendipine  Voltage-dependent L-type calcium channel subun...
# (S)-nitrendipine  Voltage-dependent L-type calcium channel subun...
# (S)-nitrendipine  Voltage-dependent L-type calcium channel subun...
# ...                                                             ...
# tirbanibulin             Proto-oncogene tyrosine-protein kinase Src
# casimersen                           exon 53 of dystrophin pre-mRNA
# infigratinib             Proto-oncogene tyrosine-protein kinase Src
# infigratinib             Proto-oncogene tyrosine-protein kinase Src
# infigratinib             Proto-oncogene tyrosine-protein kinase Src
#
#                  TARGET_CLASS      ACCESSION             GENE  \
# DRUG_NAME
# (S)-nicardipine   Ion channel  Q01668|Q13936  CACNA1D|CACNA1C
# (S)-nitrendipine  Ion channel         Q01668          CACNA1D
# (S)-nitrendipine  Ion channel         O60840          CACNA1F
# (S)-nitrendipine  Ion channel         P22002          Cacna1c
# (S)-nitrendipine  Ion channel         Q02485          Cacna1s
# ...                       ...            ...              ...
# tirbanibulin           Kinase         P12931              SRC
# casimersen                RNA         P11532              DMD
# infigratinib           Kinase         P12931              SRC
# infigratinib           Kinase         P12931              SRC
# infigratinib           Kinase         P12931              SRC
#
#                                 SWISSPROT  ACT_VALUE  ACT_UNIT ACT_TYPE  \
# DRUG_NAME
# (S)-nicardipine   CAC1D_HUMAN|CAC1C_HUMAN        NaN       NaN      NaN
# (S)-nitrendipine              CAC1D_HUMAN       8.40       NaN     IC50
# (S)-nitrendipine              CAC1F_HUMAN       6.00       NaN     IC50
# (S)-nitrendipine                CAC1C_RAT       6.00       NaN     IC50
# (S)-nitrendipine                CAC1S_RAT       6.00       NaN     IC50
# ...                                   ...        ...       ...      ...
# tirbanibulin                    SRC_HUMAN       4.34       NaN     IC50
# casimersen                      DMD_HUMAN        NaN       NaN      NaN
# infigratinib                    SRC_HUMAN       5.53       NaN     IC50
# infigratinib                    SRC_HUMAN       5.53       NaN     IC50
# infigratinib                    SRC_HUMAN       5.53       NaN     IC50
#
#                                                         ACT_COMMENT  ...  \
# DRUG_NAME                                                            ...
# (S)-nicardipine                                 Mechanism of Action  ...
# (S)-nitrendipine  Recombinant Cav1.3 calcium channel complexes e...  ...
# (S)-nitrendipine                                                NaN  ...
# (S)-nitrendipine                                                NaN  ...
# (S)-nitrendipine                                                NaN  ...
# ...                                                             ...  ...
# tirbanibulin      Low affinity is expected because the peptide s...  ...
# casimersen                                      Mechanism of Action  ...
# infigratinib      Inhibition of SRC-mediated proliferation of mo...  ...
# infigratinib      Inhibition of SRC-mediated proliferation of mo...  ...
# infigratinib      Inhibition of SRC-mediated proliferation of mo...  ...
#
#                  RELATION  MOA  MOA_SOURCE  \
# DRUG_NAME
# (S)-nicardipine       NaN  1.0  DRUG LABEL
# (S)-nitrendipine        =  1.0      IUPHAR
# (S)-nitrendipine        ~  NaN         NaN
# (S)-nitrendipine        =  NaN         NaN
# (S)-nitrendipine        =  NaN         NaN
# ...                   ...  ...         ...
# tirbanibulin            =  NaN         NaN
# casimersen            NaN  1.0  DRUG LABEL
# infigratinib            =  NaN         NaN
# infigratinib            =  NaN         NaN
# infigratinib            =  NaN         NaN
#
#                                                      ACT_SOURCE_URL  \
# DRUG_NAME
# (S)-nicardipine   http://www.accessdata.fda.gov/drugsatfda_docs/...
# (S)-nitrendipine                                                NaN
# (S)-nitrendipine                                                NaN
# (S)-nitrendipine                                                NaN
# (S)-nitrendipine                                                NaN
# ...                                                             ...
# tirbanibulin                                                    NaN
# casimersen                                                      NaN
# infigratinib                                                    NaN
# infigratinib                                                    NaN
# infigratinib                                                    NaN
#
#                                                      MOA_SOURCE_URL  \
# DRUG_NAME
# (S)-nicardipine   http://www.accessdata.fda.gov/drugsatfda_docs/...
# (S)-nitrendipine  https://www.ebi.ac.uk/chembl/compound/inspect/...
# (S)-nitrendipine                                                NaN
# (S)-nitrendipine                                                NaN
# (S)-nitrendipine                                                NaN
# ...                                                             ...
# tirbanibulin                                                    NaN
# casimersen        https://www.accessdata.fda.gov/drugsatfda_docs...
# infigratinib                                                    NaN
# infigratinib                                                    NaN
# infigratinib                                                    NaN
#
#                           ACTION_TYPE                      TDL  \
# DRUG_NAME
# (S)-nicardipine               BLOCKER  Tclin|Tclin|Tclin|Tclin
# (S)-nitrendipine     GATING INHIBITOR                    Tclin
# (S)-nitrendipine     GATING INHIBITOR                    Tclin
# (S)-nitrendipine     GATING INHIBITOR                      NaN
# (S)-nitrendipine     GATING INHIBITOR                      NaN
# ...                               ...                      ...
# tirbanibulin                INHIBITOR                    Tclin
# casimersen        ANTISENSE INHIBITOR                    Tclin
# infigratinib                      NaN                    Tclin
# infigratinib                      NaN                    Tclin
# infigratinib                      NaN                    Tclin
#
#                            ORGANISM      NEW_ID         DRUG_NAME
# DRUG_NAME
# (S)-nicardipine        Homo sapiens   HGNC:1391   (S)-nicardipine
# (S)-nitrendipine       Homo sapiens   HGNC:1391  (S)-nitrendipine
# (S)-nitrendipine       Homo sapiens   HGNC:1393  (S)-nitrendipine
# (S)-nitrendipine  Rattus norvegicus    RGD:2245  (S)-nitrendipine
# (S)-nitrendipine  Rattus norvegicus   RGD:70983  (S)-nitrendipine
# ...                             ...         ...               ...
# tirbanibulin           Homo sapiens  HGNC:11283      tirbanibulin
# casimersen             Homo sapiens   HGNC:2928        casimersen
# infigratinib           Homo sapiens  HGNC:11283      infigratinib
# infigratinib           Homo sapiens  HGNC:11283      infigratinib
# infigratinib           Homo sapiens  HGNC:11283      infigratinib
#
# [251 rows x 21 columns]

# %% [markdown]
# ## **Drug-Disease Information**

# %% [markdown]
# ### **Text to CSV**

# %% [markdown]
# If already saved, run only the cell of this section, otherwise continue:

# %% [markdown]
# Create a Dataframe that will contain the Drug-Disease information:

# %%
column_names = ["DRUG_ID", "DRUG_NAME", "DISEASES", 'PHASE']

df = pd.DataFrame(columns = column_names)

# %% [markdown]
# Read the .txt file downloaded from TTD and convert it into a pandas dataframe:

# %%
with open('../data/P1-05-Drug_disease.txt') as f:
  lines = f.readlines()[22:]

# %%
i = 0
id = ''
name = ''
disease = ''
phase = ''

for line in lines: 
  if line.startswith('DRUGNAME'): 
    result = re.search('\t(.*)\n', line)
    name = result.group(1)
  elif line.startswith('TTDDRUID'): 
    result = re.search('\t(.*)\n', line)
    id = result.group(1)
  elif line.startswith('INDICATI'): 
    result = re.search('\t(.*)\[', line)
    result2 = re.search('\](.*)', line)
    disease = result.group(1) 
    phase = result2.group(1) 
    df.loc[i] = [id,name,disease, phase]
    i += 1
  elif line.startswith('\n'): 
    id = ''
    name = ''
    disease = ''
    phase = ''

# %%
df
# Out:
#       DRUG_ID     DRUG_NAME                                   DISEASES  \
# 0      D00ABE       ALD-301                                  Ischemia
# 1      D00ABE       ALD-301               Peripheral arterial disease
# 2      D00ABO       KW-2449                   Acute myeloid leukaemia
# 3      D00ABW      Opterone                        Hormone deficiency
# 4      D00ACC        ND1251                                Depression
# ...       ...           ...                                        ...
# 28973  DZTX12        ASC-J9                   End-stage renal disease
# 28974  DZU72C       OKI 179                       Solid tumour/cancer
# 28975  DZVF15       TRN-110  Attention deficit hyperactivity disorder
# 28976  DZW53X    GSK4069889                Non-small cell lung cancer
# 28977  DZY4R2  JNJ-74699157                       Solid tumour/cancer
#
#                           PHASE
# 0                       Phase 2
# 1                       Phase 2
# 2                       Phase 1
# 3       Discontinued in Phase 1
# 4       Discontinued in Phase 1
# ...                         ...
# 28973                   Phase 2
# 28974                   Phase 1
# 28975            Clinical Trial
# 28976                   Phase 2
# 28977                   Phase 1
#
# [28978 rows x 4 columns]

# %%
df.to_csv('drug_to_disease (1).csv', encoding = 'utf-8-sig')

# %% [markdown]
# Run only this cell if you have already saved the Drug-Disease interactions:

# %%
df = pd.read_csv('drug_to_disease (1).csv', header=0, index_col=0)

# %%
df
# Out:
#       DRUG_ID     DRUG_NAME                                   DISEASES  \
# 0      D00ABE       ALD-301                                  Ischemia
# 1      D00ABE       ALD-301               Peripheral arterial disease
# 2      D00ABO       KW-2449                   Acute myeloid leukaemia
# 3      D00ABW      Opterone                        Hormone deficiency
# 4      D00ACC        ND1251                                Depression
# ...       ...           ...                                        ...
# 28973  DZTX12        ASC-J9                   End-stage renal disease
# 28974  DZU72C       OKI 179                       Solid tumour/cancer
# 28975  DZVF15       TRN-110  Attention deficit hyperactivity disorder
# 28976  DZW53X    GSK4069889                Non-small cell lung cancer
# 28977  DZY4R2  JNJ-74699157                       Solid tumour/cancer
#
#                           PHASE
# 0                       Phase 2
# 1                       Phase 2
# 2                       Phase 1
# 3       Discontinued in Phase 1
# 4       Discontinued in Phase 1
# ...                         ...
# 28973                   Phase 2
# 28974                   Phase 1
# 28975            Clinical Trial
# 28976                   Phase 2
# 28977                   Phase 1
#
# [28978 rows x 4 columns]

# %%
df.to_csv('drug_to_disease (1).csv', encoding = 'utf-8-sig')

# %% [markdown]
# ### **Load CSVs**

# %% [markdown]
# Load the drug nodes (obtained from Drug Central) and the Monarch nodes:

# %%
graph_drugs = pd.read_csv('drug_nodes_ELA.csv', header=0)
nodes = pd.read_csv('monarch/monarch_nodes_v2023-02-20.csv', header=0)

# %% [markdown]
# Get list of unique drugs and diseases:

# %%
graph_diseases = nodes[nodes['semantic_groups'] == 'DISO']
unique_diseases = graph_diseases['name'].unique()
unique_dis_id = graph_diseases['id'].unique()
unique_diseases = [x.lower() for x in unique_diseases]

# %%
unique_drugs = graph_drugs['DRUG_NAME'].unique()
unique_drugs = [x.lower() for x in unique_drugs]
len(unique_drugs)
# Out:
# 193

# %% [markdown]
# At this point you should use SORTA tool (https://sorta.molgeniscloud.org/menu/main/sorta?) to match the IDs of TTD to Human Phenotype Ontology (HPO). The file is also available in the project's Github:

# %%
matched = pd.read_csv('../data/matched_phenotypes.csv', header = 0, delimiter = ';')

# %%
matched
# Out:
#                                                    Name  \
# 0                                   respiratory failure
# 1                                    sexual dysfunction
# 2                                        achondroplasia
# 3                                  glabellar frown line
# 4                           testicular germ cell tumour
# ...                                                 ...
# 1796                              systemic mastocytosis
# 1797                    acute iron or aluminum toxicity
# 1798  chronic inflammatory demyelinating polyneuropathy
# 1799                                    aortic aneurysm
# 1800                                              fever
#
#                           ontologyTermName  \
# 0                      Respiratory failure
# 1                  Male sexual dysfunction
# 2                         Bronchodysplasia
# 3                       Prominent glabella
# 4                      Testicular neoplasm
# ...                                    ...
# 1796                          Mastocytosis
# 1797  Abnormal total iron binding capacity
# 1798    Acute demyelinating polyneuropathy
# 1799                       Aortic aneurysm
# 1800                                 Fever
#
#                                 ontologyTermIRI   score  validated  review
# 0     http://purl.obolibrary.org/obo/HP_0002878  100.00      False   False
# 1     http://purl.obolibrary.org/obo/HP_0040307   86.49      False   False
# 2     http://purl.obolibrary.org/obo/HP_0006533   62.50      False   False
# 3     http://purl.obolibrary.org/obo/HP_0002057   59.46      False   False
# 4     http://purl.obolibrary.org/obo/HP_0010788   71.11      False   False
# ...                                         ...     ...        ...     ...
# 1796  http://purl.obolibrary.org/obo/HP_0100495   77.42      False   False
# 1797  http://purl.obolibrary.org/obo/HP_0033212   48.15      False   False
# 1798  http://purl.obolibrary.org/obo/HP_0007131   64.86      False   False
# 1799  http://purl.obolibrary.org/obo/HP_0004942  100.00      False   False
# 1800  http://purl.obolibrary.org/obo/HP_0001945  100.00      False   False
#
# [1801 rows x 6 columns]

# %% [markdown]
# Select only those IDs with a score greater than 80:

# %%
matched = matched[matched['score'] > 80]

# %% [markdown]
# Create the final ID:

# %%
matched['ID'] = matched['ontologyTermIRI'].str.split('/obo/').str[1]
# Out:
# C:\Users\rosa-\AppData\Local\Temp\ipykernel_14436\1934371214.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched['ID'] = matched['ontologyTermIRI'].str.split('/obo/').str[1]

# %%
new_id = []
for i in matched['ID']: 
  id = re.sub("[^0-9a-zA-Z]+", ":", i)
  new_id.append(id)
matched['ID'] = new_id
# Out:
# C:\Users\rosa-\AppData\Local\Temp\ipykernel_14436\1489851571.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched['ID'] = new_id

# %%
i = 0
for index, row in df.iterrows(): 
  if row['DRUG_NAME'].lower() in unique_drugs: 
    if row['DISEASES'].lower() in unique_diseases: 
      i += 1

# %% [markdown]
# ### **Merging**

# %%
modified = []
for d in df['DISEASES']: 
  new_string = re.sub("[^0-9a-zA-Z]+", " ", d)
  modified.append(new_string.lower())

# %%
df['Name'] = modified

# %%
df['Name'] = df['Name'].str.strip()
matched['Name'] = matched['Name'].str.strip()
# Out:
# C:\Users\rosa-\AppData\Local\Temp\ipykernel_14436\140104363.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched['Name'] = matched['Name'].str.strip()

# %%
final = pd.merge(df, matched, on = 'Name', how = 'left')

# %%
final
# Out:
#       DRUG_ID     DRUG_NAME                                   DISEASES  \
# 0      D00ABE       ALD-301                                  Ischemia
# 1      D00ABE       ALD-301               Peripheral arterial disease
# 2      D00ABO       KW-2449                   Acute myeloid leukaemia
# 3      D00ABW      Opterone                        Hormone deficiency
# 4      D00ACC        ND1251                                Depression
# ...       ...           ...                                        ...
# 29562  DZU72C       OKI 179                       Solid tumour/cancer
# 29563  DZVF15       TRN-110  Attention deficit hyperactivity disorder
# 29564  DZW53X    GSK4069889                Non-small cell lung cancer
# 29565  DZW53X    GSK4069889                Non-small cell lung cancer
# 29566  DZY4R2  JNJ-74699157                       Solid tumour/cancer
#
#                           PHASE                                      Name  \
# 0                       Phase 2                                  ischemia
# 1                       Phase 2               peripheral arterial disease
# 2                       Phase 1                   acute myeloid leukaemia
# 3       Discontinued in Phase 1                        hormone deficiency
# 4       Discontinued in Phase 1                                depression
# ...                         ...                                       ...
# 29562                   Phase 1                       solid tumour cancer
# 29563            Clinical Trial  attention deficit hyperactivity disorder
# 29564                   Phase 2                non small cell lung cancer
# 29565                   Phase 2                non small cell lung cancer
# 29566                   Phase 1                       solid tumour cancer
#
#                                ontologyTermName  \
# 0                                           NaN
# 1                  Peripheral arterial stenosis
# 2                        Acute myeloid leukemia
# 3                                           NaN
# 4                                  Depressivity
# ...                                         ...
# 29562                                       NaN
# 29563  Attention deficit hyperactivity disorder
# 29564             Non-small cell lung carcinoma
# 29565             Non-small cell lung carcinoma
# 29566                                       NaN
#
#                                  ontologyTermIRI  score validated review  \
# 0                                            NaN    NaN       NaN    NaN
# 1      http://purl.obolibrary.org/obo/HP_0004950  100.0     False  False
# 2      http://purl.obolibrary.org/obo/HP_0004808  100.0     False  False
# 3                                            NaN    NaN       NaN    NaN
# 4      http://purl.obolibrary.org/obo/HP_0000716  100.0     False  False
# ...                                          ...    ...       ...    ...
# 29562                                        NaN    NaN       NaN    NaN
# 29563  http://purl.obolibrary.org/obo/HP_0007018  100.0     False  False
# 29564  http://purl.obolibrary.org/obo/HP_0030358  100.0     False  False
# 29565  http://purl.obolibrary.org/obo/HP_0030358  100.0     False  False
# 29566                                        NaN    NaN       NaN    NaN
#
#                ID
# 0             NaN
# 1      HP:0004950
# 2      HP:0004808
# 3             NaN
# 4      HP:0000716
# ...           ...
# 29562         NaN
# 29563  HP:0007018
# 29564  HP:0030358
# 29565  HP:0030358
# 29566         NaN
#
# [29567 rows x 11 columns]

# %%
final.to_csv('drug_to_disease_HP.csv', encoding = 'utf-8-sig')

# %% [markdown]
# ### **Comparison**

# %%
final = pd.read_csv('drug_to_disease_HP.csv', header=0)

# %%
final_filtered = final[final['score'] == 100]

# %%
len(final_filtered)
# Out:
# 12151

# %%
final_filtered
# Out:
#        Unnamed: 0 DRUG_ID                                        DRUG_NAME  \
# 1               1  D00ABE                                          ALD-301
# 2               2  D00ABO                                          KW-2449
# 4               4  D00ACC                                           ND1251
# 11             11  D00AHT  PRAME antigen-specific cancer immunotherapeutic
# 12             12  D00AHT  PRAME antigen-specific cancer immunotherapeutic
# ...           ...     ...                                              ...
# 29556       29556  DZNH43                                          MT-3724
# 29561       29561  DZTX12                                           ASC-J9
# 29563       29563  DZVF15                                          TRN-110
# 29564       29564  DZW53X                                       GSK4069889
# 29565       29565  DZW53X                                       GSK4069889
#
#                                         DISEASES                     PHASE  \
# 1                   Peripheral arterial disease                    Phase 2
# 2                       Acute myeloid leukaemia                    Phase 1
# 4                                    Depression    Discontinued in Phase 1
# 11                   Non-small-cell lung cancer                    Phase 2
# 12                   Non-small-cell lung cancer                    Phase 2
# ...                                          ...                       ...
# 29556                           B-cell lymphoma                    Phase 1
# 29561                   End-stage renal disease                    Phase 2
# 29563  Attention deficit hyperactivity disorder             Clinical Trial
# 29564                Non-small cell lung cancer                    Phase 2
# 29565                Non-small cell lung cancer                    Phase 2
#
#                                            Name  \
# 1                   peripheral arterial disease
# 2                       acute myeloid leukaemia
# 4                                    depression
# 11                   non small cell lung cancer
# 12                   non small cell lung cancer
# ...                                         ...
# 29556                           b cell lymphoma
# 29561                   end stage renal disease
# 29563  attention deficit hyperactivity disorder
# 29564                non small cell lung cancer
# 29565                non small cell lung cancer
#
#                                ontologyTermName  \
# 1                  Peripheral arterial stenosis
# 2                        Acute myeloid leukemia
# 4                                  Depressivity
# 11                Non-small cell lung carcinoma
# 12                Non-small cell lung carcinoma
# ...                                         ...
# 29556                           B-cell lymphoma
# 29561            Stage 5 chronic kidney disease
# 29563  Attention deficit hyperactivity disorder
# 29564             Non-small cell lung carcinoma
# 29565             Non-small cell lung carcinoma
#
#                                  ontologyTermIRI  score validated review  \
# 1      http://purl.obolibrary.org/obo/HP_0004950  100.0     False  False
# 2      http://purl.obolibrary.org/obo/HP_0004808  100.0     False  False
# 4      http://purl.obolibrary.org/obo/HP_0000716  100.0     False  False
# 11     http://purl.obolibrary.org/obo/HP_0030358  100.0     False  False
# 12     http://purl.obolibrary.org/obo/HP_0030358  100.0     False  False
# ...                                          ...    ...       ...    ...
# 29556  http://purl.obolibrary.org/obo/HP_0012191  100.0     False  False
# 29561  http://purl.obolibrary.org/obo/HP_0003774  100.0     False  False
# 29563  http://purl.obolibrary.org/obo/HP_0007018  100.0     False  False
# 29564  http://purl.obolibrary.org/obo/HP_0030358  100.0     False  False
# 29565  http://purl.obolibrary.org/obo/HP_0030358  100.0     False  False
#
#                ID
# 1      HP:0004950
# 2      HP:0004808
# 4      HP:0000716
# 11     HP:0030358
# 12     HP:0030358
# ...           ...
# 29556  HP:0012191
# 29561  HP:0003774
# 29563  HP:0007018
# 29564  HP:0030358
# 29565  HP:0030358
#
# [12151 rows x 12 columns]

# %%
column_names = ["DRUG_ID", "DRUG_NAME", "DISEASES", 'PHASE']

df = pd.DataFrame(columns = column_names)

# %%
unique_drugs
# Out:
# ['(s)-nicardipine',
#  '(s)-nitrendipine',
#  'phenylbutanoic acid',
#  'acepromazine',
#  'adiphenine',
#  'alcuronium',
#  'amitriptyline',
#  'amlodipine',
#  'amodiaquine',
#  'amoxapine',
#  'octatropine methylbromide',
#  'aprindine',
#  'aranidipine',
#  'atracurium',
#  'azathioprine',
#  'azelastine',
#  'azelnidipine',
#  'barnidipine',
#  'bendamustine',
#  'bendroflumethiazide',
#  'diphenidol',
#  'benzthiazide',
#  'benzatropine',
#  'biperiden',
#  'bromperidol',
#  'scopolamine butylbromide',
#  'cadralazine',
#  'caramiphen',
#  'pentoxyverine',
#  'carvedilol',
#  'cevimeline',
#  'chloropyramine',
#  'chlortetracycline',
#  'chlorzoxazone',
#  'cilnidipine',
#  'cinnarizine',
#  'cisatracurium',
#  'clemastine',
#  'clevidipine',
#  'clidinium',
#  'clotiapine',
#  'colforsin daropate',
#  'cyamemazine',
#  'cyclizine',
#  'cyclobenzaprine',
#  'cycrimine',
#  'darifenacin',
#  'decamethonium',
#  'desloratadine',
#  'dexetimide',
#  'dexfenfluramine',
#  'dicycloverine',
#  'dimenhydrinate',
#  'dimetindene',
#  'dimethyltubocurarinium',
#  'diphemanil',
#  'diphenylpyraline',
#  'disopyramide',
#  'dosulepin',
#  'doxepin',
#  'drotaverine',
#  'droxidopa',
#  'efonidipine',
#  'endralazine',
#  'estramustine phosphate',
#  'felodipine',
#  'fenfluramine',
#  'fluphenazine enanthate',
#  'hexocyclium',
#  'homatropine',
#  'hydroxychloroquine',
#  'hyoscyamine',
#  'ipratropium',
#  'isopropamide',
#  'ketorolac',
#  'lacidipine',
#  'levosimendan',
#  'lidocaine',
#  'lofepramine',
#  'loxapine',
#  'maprotiline',
#  'mebhydrolin',
#  'pecazine',
#  'mepenzolate',
#  'mesoridazine',
#  'methacholine',
#  'methapyrilene',
#  'methscopolamine',
#  'methysergide',
#  'mibefradil',
#  'miltefosine',
#  'minaprine',
#  'mirtazapine',
#  'mivacurium',
#  'montelukast',
#  'nilvadipine',
#  'nimodipine',
#  'nisoldipine',
#  'nitrendipine',
#  'nortriptyline',
#  'ondansetron',
#  'orphenadrine',
#  'oxyphencyclimine',
#  'oxybutynin',
#  'oxyphenonium',
#  'pancuronium',
#  'perhexiline',
#  'pilocarpine',
#  'pinacidil',
#  'pipecuronium',
#  'pizotifen',
#  'prenylamine',
#  'pridinol',
#  'procaine',
#  'procyclidine',
#  'propantheline',
#  'propiomazine',
#  'protriptyline',
#  'rocuronium',
#  'solifenacin',
#  'strychnine',
#  'suxamethonium',
#  'suloctidil',
#  'sapropterin',
#  'thiothixene',
#  'tiludronic acid',
#  'tiotropium bromide',
#  'tolterodine',
#  'tridihexethyl',
#  'trihexyphenidyl',
#  'troglitazone',
#  'tropicamide',
#  'trospium',
#  'valethamate',
#  'vecuronium',
#  'vinburnine',
#  'nicotinic acid',
#  'zotepine',
#  'doxacurium',
#  'benzethonium',
#  'bietamiverine',
#  'eburnamonine',
#  'femoxetine',
#  'furtrethonium',
#  'rapacuronium',
#  'ruboxistaurin',
#  'sabcomeline',
#  'vincamine',
#  'xanomeline',
#  'benidipine',
#  'levamlodipine',
#  'asenapine',
#  'romidepsin',
#  'gentian violet',
#  'lercanidipine',
#  'vandetanib',
#  'crizotinib',
#  'fesoterodine',
#  'axitinib',
#  'florbetapir f-18',
#  'flutemetamol (18f)',
#  'glycopyrronium bromide',
#  'aceclidine',
#  'afatinib',
#  'dexchlorpheniramine',
#  'carfilzomib',
#  'aclidinium bromide',
#  'trabectedin',
#  'methylatropine',
#  'betamethasone phosphate',
#  'cabozantinib',
#  'ibrutinib',
#  'umeclidinium',
#  'florbetaben f18',
#  'ceritinib',
#  'imidafenacin',
#  'chidamide',
#  'ixazomib',
#  'eteplirsen',
#  'apatinib',
#  'neratinib',
#  'dacomitinib',
#  'lorlatinib',
#  'revefenacin',
#  'selinexor',
#  'entrectinib',
#  'golodirsen',
#  'brilliant blue g',
#  'oliceridine',
#  'viltolarsen',
#  'tirbanibulin',
#  'casimersen',
#  'infigratinib']

# %%
i = 0
for index, row in final_filtered.iterrows(): 
  if row['DRUG_NAME'].lower() not in unique_drugs or row['ID'] not in unique_dis_id:
   final_filtered = final_filtered.drop(labels = index, axis = 0)
len(final_filtered)
# Out:
# 31

# %%
i = 0
for index, row in final_filtered.iterrows(): 
  drug = row['DRUG_NAME'].lower()
  id = graph_drugs[graph_drugs['DRUG_NAME'] == drug]['STRUCT_ID'].values[0]
  final_filtered.at[index, 'DRUG_ID'] = id
len(final_filtered)
# Out:
# 31

# %%
final_filtered
# Out:
#        Unnamed: 0 DRUG_ID        DRUG_NAME                   DISEASES  \
# 975           975    4483      Carfilzomib    Small-cell lung cancer
# 2389         2389    4225         Axitinib      Renal cell carcinoma
# 2871         2871    5431     Tirbanibulin           Prostate cancer
# 6582         6582     789    Decamethonium              Muscle spasm
# 9416         9416     661    Cisatracurium              Muscle spasm
# 9732         9732     749        Cyclizine                    Nausea
# 9800         9800     183       Amlodipine              Hypertension
# 10669       10669     461      Cadralazine              Hypertension
# 10829       10829    2745  Trihexyphenidyl                  Dystonia
# 10831       10831    2745  Trihexyphenidyl                   Obesity
# 11246       11246    2774      Tropicamide                 Mydriasis
# 11578       11578    1150     Fenfluramine                   Obesity
# 11792       11792    1947     Nitrendipine              Hypertension
# 13096       13096    1576     Levosimendan  Congestive heart failure
# 13097       13097    1576     Levosimendan             Heart failure
# 13599       13599     522       Carvedilol  Congestive heart failure
# 15202       15202     832  Dexfenfluramine                   Obesity
# 16752       16752    4099    Levamlodipine              Hypertension
# 18666       18666    2396       Rocuronium              Muscle spasm
# 18743       18743    4119       Romidepsin      Renal cell carcinoma
# 19257       19257     926     Disopyramide   Ventricular arrhythmias
# 19258       19258     926     Disopyramide      Urinary incontinence
# 20326       20326    5345      Entrectinib             Neuroblastoma
# 21224       21224    4157    Lercanidipine              Hypertension
# 22897       22897    1942      Nisoldipine              Hypertension
# 24230       24230     901   Dimenhydrinate                    Nausea
# 25358       25358     231        Aprindine       Cardiac arrhythmias
# 25448       25448    1797       Mibefradil   Glioblastoma multiforme
# 25467       25467     522       Carvedilol  Congestive heart failure
# 25482       25482     313       Diphenidol                    Nausea
# 25591       25591    1142       Felodipine              Hypertension
#
#                         PHASE                      Name  \
# 975                 Phase 1/2    small cell lung cancer
# 2389                 Approved      renal cell carcinoma
# 2871                  Phase 2           prostate cancer
# 6582                 Approved              muscle spasm
# 9416                 Approved              muscle spasm
# 9732                 Approved                    nausea
# 9800                 Approved              hypertension
# 10669                Approved              hypertension
# 10829                Approved                  dystonia
# 10831           Investigative                   obesity
# 11246                Approved                 mydriasis
# 11578   Withdrawn from market                   obesity
# 11792                Approved              hypertension
# 13096                Approved  congestive heart failure
# 13097                 Phase 4             heart failure
# 13599                Approved  congestive heart failure
# 15202   Withdrawn from market                   obesity
# 16752                 Phase 4              hypertension
# 18666                Approved              muscle spasm
# 18743                 Phase 3      renal cell carcinoma
# 19257                Approved   ventricular arrhythmias
# 19258   Withdrawn from market      urinary incontinence
# 20326                 Phase 1             neuroblastoma
# 21224                Approved              hypertension
# 22897                Approved              hypertension
# 24230                Approved                    nausea
# 25358                Approved       cardiac arrhythmias
# 25448                 Phase 1   glioblastoma multiforme
# 25467                Approved  congestive heart failure
# 25482                Approved                    nausea
# 25591                Approved              hypertension
#
#                 ontologyTermName                            ontologyTermIRI  \
# 975    Small cell lung carcinoma  http://purl.obolibrary.org/obo/HP_0030357
# 2389        Renal cell carcinoma  http://purl.obolibrary.org/obo/HP_0005584
# 2871             Prostate cancer  http://purl.obolibrary.org/obo/HP_0012125
# 6582      Hyperkinetic movements  http://purl.obolibrary.org/obo/HP_0002487
# 9416      Hyperkinetic movements  http://purl.obolibrary.org/obo/HP_0002487
# 9732                      Nausea  http://purl.obolibrary.org/obo/HP_0002018
# 9800                Hypertension  http://purl.obolibrary.org/obo/HP_0000822
# 10669               Hypertension  http://purl.obolibrary.org/obo/HP_0000822
# 10829                   Dystonia  http://purl.obolibrary.org/obo/HP_0001332
# 10831                    Obesity  http://purl.obolibrary.org/obo/HP_0001513
# 11246                  Mydriasis  http://purl.obolibrary.org/obo/HP_0011499
# 11578                    Obesity  http://purl.obolibrary.org/obo/HP_0001513
# 11792               Hypertension  http://purl.obolibrary.org/obo/HP_0000822
# 13096   Congestive heart failure  http://purl.obolibrary.org/obo/HP_0001635
# 13097   Congestive heart failure  http://purl.obolibrary.org/obo/HP_0001635
# 13599   Congestive heart failure  http://purl.obolibrary.org/obo/HP_0001635
# 15202                    Obesity  http://purl.obolibrary.org/obo/HP_0001513
# 16752               Hypertension  http://purl.obolibrary.org/obo/HP_0000822
# 18666     Hyperkinetic movements  http://purl.obolibrary.org/obo/HP_0002487
# 18743       Renal cell carcinoma  http://purl.obolibrary.org/obo/HP_0005584
# 19257     Ventricular arrhythmia  http://purl.obolibrary.org/obo/HP_0004308
# 19258       Urinary incontinence  http://purl.obolibrary.org/obo/HP_0000020
# 20326              Neuroblastoma  http://purl.obolibrary.org/obo/HP_0003006
# 21224               Hypertension  http://purl.obolibrary.org/obo/HP_0000822
# 22897               Hypertension  http://purl.obolibrary.org/obo/HP_0000822
# 24230                     Nausea  http://purl.obolibrary.org/obo/HP_0002018
# 25358                 Arrhythmia  http://purl.obolibrary.org/obo/HP_0011675
# 25448    Glioblastoma multiforme  http://purl.obolibrary.org/obo/HP_0012174
# 25467   Congestive heart failure  http://purl.obolibrary.org/obo/HP_0001635
# 25482                     Nausea  http://purl.obolibrary.org/obo/HP_0002018
# 25591               Hypertension  http://purl.obolibrary.org/obo/HP_0000822
#
#        score validated review          ID
# 975    100.0     False  False  HP:0030357
# 2389   100.0     False  False  HP:0005584
# 2871   100.0     False  False  HP:0012125
# 6582   100.0     False  False  HP:0002487
# 9416   100.0     False  False  HP:0002487
# 9732   100.0     False  False  HP:0002018
# 9800   100.0     False  False  HP:0000822
# 10669  100.0     False  False  HP:0000822
# 10829  100.0     False  False  HP:0001332
# 10831  100.0     False  False  HP:0001513
# 11246  100.0     False  False  HP:0011499
# 11578  100.0     False  False  HP:0001513
# 11792  100.0     False  False  HP:0000822
# 13096  100.0     False  False  HP:0001635
# 13097  100.0     False  False  HP:0001635
# 13599  100.0     False  False  HP:0001635
# 15202  100.0     False  False  HP:0001513
# 16752  100.0     False  False  HP:0000822
# 18666  100.0     False  False  HP:0002487
# 18743  100.0     False  False  HP:0005584
# 19257  100.0     False  False  HP:0004308
# 19258  100.0     False  False  HP:0000020
# 20326  100.0     False  False  HP:0003006
# 21224  100.0     False  False  HP:0000822
# 22897  100.0     False  False  HP:0000822
# 24230  100.0     False  False  HP:0002018
# 25358  100.0     False  False  HP:0011675
# 25448  100.0     False  False  HP:0012174
# 25467  100.0     False  False  HP:0001635
# 25482  100.0     False  False  HP:0002018
# 25591  100.0     False  False  HP:0000822

# %%
final_filtered = final_filtered.drop(labels = ['Unnamed: 0', 'score'], axis =1)

# %%
final_filtered
# Out:
#       DRUG_ID        DRUG_NAME                   DISEASES  \
# 975      4483      Carfilzomib    Small-cell lung cancer
# 2389     4225         Axitinib      Renal cell carcinoma
# 2871     5431     Tirbanibulin           Prostate cancer
# 6582      789    Decamethonium              Muscle spasm
# 9416      661    Cisatracurium              Muscle spasm
# 9732      749        Cyclizine                    Nausea
# 9800      183       Amlodipine              Hypertension
# 10669     461      Cadralazine              Hypertension
# 10829    2745  Trihexyphenidyl                  Dystonia
# 10831    2745  Trihexyphenidyl                   Obesity
# 11246    2774      Tropicamide                 Mydriasis
# 11578    1150     Fenfluramine                   Obesity
# 11792    1947     Nitrendipine              Hypertension
# 13096    1576     Levosimendan  Congestive heart failure
# 13097    1576     Levosimendan             Heart failure
# 13599     522       Carvedilol  Congestive heart failure
# 15202     832  Dexfenfluramine                   Obesity
# 16752    4099    Levamlodipine              Hypertension
# 18666    2396       Rocuronium              Muscle spasm
# 18743    4119       Romidepsin      Renal cell carcinoma
# 19257     926     Disopyramide   Ventricular arrhythmias
# 19258     926     Disopyramide      Urinary incontinence
# 20326    5345      Entrectinib             Neuroblastoma
# 21224    4157    Lercanidipine              Hypertension
# 22897    1942      Nisoldipine              Hypertension
# 24230     901   Dimenhydrinate                    Nausea
# 25358     231        Aprindine       Cardiac arrhythmias
# 25448    1797       Mibefradil   Glioblastoma multiforme
# 25467     522       Carvedilol  Congestive heart failure
# 25482     313       Diphenidol                    Nausea
# 25591    1142       Felodipine              Hypertension
#
#                         PHASE                      Name  \
# 975                 Phase 1/2    small cell lung cancer
# 2389                 Approved      renal cell carcinoma
# 2871                  Phase 2           prostate cancer
# 6582                 Approved              muscle spasm
# 9416                 Approved              muscle spasm
# 9732                 Approved                    nausea
# 9800                 Approved              hypertension
# 10669                Approved              hypertension
# 10829                Approved                  dystonia
# 10831           Investigative                   obesity
# 11246                Approved                 mydriasis
# 11578   Withdrawn from market                   obesity
# 11792                Approved              hypertension
# 13096                Approved  congestive heart failure
# 13097                 Phase 4             heart failure
# 13599                Approved  congestive heart failure
# 15202   Withdrawn from market                   obesity
# 16752                 Phase 4              hypertension
# 18666                Approved              muscle spasm
# 18743                 Phase 3      renal cell carcinoma
# 19257                Approved   ventricular arrhythmias
# 19258   Withdrawn from market      urinary incontinence
# 20326                 Phase 1             neuroblastoma
# 21224                Approved              hypertension
# 22897                Approved              hypertension
# 24230                Approved                    nausea
# 25358                Approved       cardiac arrhythmias
# 25448                 Phase 1   glioblastoma multiforme
# 25467                Approved  congestive heart failure
# 25482                Approved                    nausea
# 25591                Approved              hypertension
#
#                 ontologyTermName                            ontologyTermIRI  \
# 975    Small cell lung carcinoma  http://purl.obolibrary.org/obo/HP_0030357
# 2389        Renal cell carcinoma  http://purl.obolibrary.org/obo/HP_0005584
# 2871             Prostate cancer  http://purl.obolibrary.org/obo/HP_0012125
# 6582      Hyperkinetic movements  http://purl.obolibrary.org/obo/HP_0002487
# 9416      Hyperkinetic movements  http://purl.obolibrary.org/obo/HP_0002487
# 9732                      Nausea  http://purl.obolibrary.org/obo/HP_0002018
# 9800                Hypertension  http://purl.obolibrary.org/obo/HP_0000822
# 10669               Hypertension  http://purl.obolibrary.org/obo/HP_0000822
# 10829                   Dystonia  http://purl.obolibrary.org/obo/HP_0001332
# 10831                    Obesity  http://purl.obolibrary.org/obo/HP_0001513
# 11246                  Mydriasis  http://purl.obolibrary.org/obo/HP_0011499
# 11578                    Obesity  http://purl.obolibrary.org/obo/HP_0001513
# 11792               Hypertension  http://purl.obolibrary.org/obo/HP_0000822
# 13096   Congestive heart failure  http://purl.obolibrary.org/obo/HP_0001635
# 13097   Congestive heart failure  http://purl.obolibrary.org/obo/HP_0001635
# 13599   Congestive heart failure  http://purl.obolibrary.org/obo/HP_0001635
# 15202                    Obesity  http://purl.obolibrary.org/obo/HP_0001513
# 16752               Hypertension  http://purl.obolibrary.org/obo/HP_0000822
# 18666     Hyperkinetic movements  http://purl.obolibrary.org/obo/HP_0002487
# 18743       Renal cell carcinoma  http://purl.obolibrary.org/obo/HP_0005584
# 19257     Ventricular arrhythmia  http://purl.obolibrary.org/obo/HP_0004308
# 19258       Urinary incontinence  http://purl.obolibrary.org/obo/HP_0000020
# 20326              Neuroblastoma  http://purl.obolibrary.org/obo/HP_0003006
# 21224               Hypertension  http://purl.obolibrary.org/obo/HP_0000822
# 22897               Hypertension  http://purl.obolibrary.org/obo/HP_0000822
# 24230                     Nausea  http://purl.obolibrary.org/obo/HP_0002018
# 25358                 Arrhythmia  http://purl.obolibrary.org/obo/HP_0011675
# 25448    Glioblastoma multiforme  http://purl.obolibrary.org/obo/HP_0012174
# 25467   Congestive heart failure  http://purl.obolibrary.org/obo/HP_0001635
# 25482                     Nausea  http://purl.obolibrary.org/obo/HP_0002018
# 25591               Hypertension  http://purl.obolibrary.org/obo/HP_0000822
#
#       validated review          ID
# 975       False  False  HP:0030357
# 2389      False  False  HP:0005584
# 2871      False  False  HP:0012125
# 6582      False  False  HP:0002487
# 9416      False  False  HP:0002487
# 9732      False  False  HP:0002018
# 9800      False  False  HP:0000822
# 10669     False  False  HP:0000822
# 10829     False  False  HP:0001332
# 10831     False  False  HP:0001513
# 11246     False  False  HP:0011499
# 11578     False  False  HP:0001513
# 11792     False  False  HP:0000822
# 13096     False  False  HP:0001635
# 13097     False  False  HP:0001635
# 13599     False  False  HP:0001635
# 15202     False  False  HP:0001513
# 16752     False  False  HP:0000822
# 18666     False  False  HP:0002487
# 18743     False  False  HP:0005584
# 19257     False  False  HP:0004308
# 19258     False  False  HP:0000020
# 20326     False  False  HP:0003006
# 21224     False  False  HP:0000822
# 22897     False  False  HP:0000822
# 24230     False  False  HP:0002018
# 25358     False  False  HP:0011675
# 25448     False  False  HP:0012174
# 25467     False  False  HP:0001635
# 25482     False  False  HP:0002018
# 25591     False  False  HP:0000822

# %%
final_filtered.to_csv('drug_to_disease_final_v2_ELA.csv', encoding = 'utf-8-sig')
