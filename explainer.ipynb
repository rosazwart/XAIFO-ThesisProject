# %%
import pandas as pd
import networkx as nx
import pickle
import copy

from gensim.models import KeyedVectors

import torch
import torch.nn as nn
import torch.nn.functional as F

from deepsnap.graph import Graph

from torch_geometric.nn import SAGEConv
from torch_geometric.explain import Explainer, GNNExplainer, ModelConfig

# %%
dataset_nr = 2

# %% [markdown]
# # Load Necessary Data

# %% [markdown]
# For the node features, load the embeddings yielded from Edge2Vec.

# %%
loaded_node_embedding = KeyedVectors.load(f'output/w2v_{dataset_nr}.dvectors', mmap='r')

node_embeddings = pd.DataFrame(columns = ['Node', 'Embedding'])
for idx, key in enumerate(loaded_node_embedding.index_to_key):
    node_embeddings.loc[int(key)] = pd.Series({'Node':int(key), 'Embedding':list(loaded_node_embedding[key])})
    
node_features = node_embeddings.sort_values('Node')

node_features
# Out:
#         Node                                          Embedding
# 0          0  [0.4429384, -0.64671946, -0.045503706, 0.04694...
# 1          1  [0.7495496, -0.5790302, 0.16192597, 0.03131027...
# 2          2  [-0.21050918, -0.28908953, 0.118277326, -0.162...
# 3          3  [0.2527442, -0.2967686, 0.29164207, 0.8072669,...
# 4          4  [0.41442072, 0.06997513, 0.4540072, -0.0370618...
# ...      ...                                                ...
# 10270  10270  [0.21862394, 0.11319974, 0.31551972, 0.1497048...
# 10271  10271  [0.8747792, -0.7461259, 0.22221777, -0.0425329...
# 10272  10272  [0.5863251, -0.8054981, 0.27565393, 0.516578, ...
# 10273  10273  [0.6474387, -0.38251266, 0.43746328, 0.3413055...
# 10274  10274  [0.56232107, -0.5135573, -0.036642436, 0.09458...
#
# [10275 rows x 2 columns]

# %% [markdown]
# For additional information of nodes, load csv file.

# %%
nodes = pd.read_csv(f'output/indexed_nodes_{dataset_nr}.csv')
nodes
# Out:
#        index_id                          id   semantic
# 0             0                  MP:0004187  phenotype  \
# 1             1                  ZP:0100138  phenotype
# 2             2                 MGI:1346525       gene
# 3             3            OMIM:300377.0044    variant
# 4             4                  ZP:0002210  phenotype
# ...         ...                         ...        ...
# 10270     10270                  ZP:0014934  phenotype
# 10271     10271  ENSEMBL:ENSCAFG00000011207       gene
# 10272     10272  ENSEMBL:ENSXETG00000039922       gene
# 10273     10273  ENSEMBL:ENSACAG00000010058       gene
# 10274     10274         WBPhenotype:0000019  phenotype
#
#                                                    label  semantic_id
# 0                                          cardia bifida            9
# 1      muscle tendon junction myotome increased amoun...            9
# 2                                                   Sgcd            5
# 3                                         DMD, LYS770TER           11
# 4      posterior lateral line neuromast primordium mi...            9
# ...                                                  ...          ...
# 10270  atrioventricular valve development process qua...            9
# 10271                         ENSEMBL:ENSCAFG00000011207            5
# 10272                         ENSEMBL:ENSXETG00000039922            5
# 10273                         ENSEMBL:ENSACAG00000010058            5
# 10274                         pharyngeal pumping reduced            9
#
# [10275 rows x 5 columns]

# %%
node_features = pd.merge(node_features, nodes,
                         left_on='Node', right_on='index_id',
                         how='inner')
node_features
# Out:
#         Node                                          Embedding  index_id
# 0          0  [0.4429384, -0.64671946, -0.045503706, 0.04694...         0  \
# 1          1  [0.7495496, -0.5790302, 0.16192597, 0.03131027...         1
# 2          2  [-0.21050918, -0.28908953, 0.118277326, -0.162...         2
# 3          3  [0.2527442, -0.2967686, 0.29164207, 0.8072669,...         3
# 4          4  [0.41442072, 0.06997513, 0.4540072, -0.0370618...         4
# ...      ...                                                ...       ...
# 10270  10270  [0.21862394, 0.11319974, 0.31551972, 0.1497048...     10270
# 10271  10271  [0.8747792, -0.7461259, 0.22221777, -0.0425329...     10271
# 10272  10272  [0.5863251, -0.8054981, 0.27565393, 0.516578, ...     10272
# 10273  10273  [0.6474387, -0.38251266, 0.43746328, 0.3413055...     10273
# 10274  10274  [0.56232107, -0.5135573, -0.036642436, 0.09458...     10274
#
#                                id   semantic
# 0                      MP:0004187  phenotype  \
# 1                      ZP:0100138  phenotype
# 2                     MGI:1346525       gene
# 3                OMIM:300377.0044    variant
# 4                      ZP:0002210  phenotype
# ...                           ...        ...
# 10270                  ZP:0014934  phenotype
# 10271  ENSEMBL:ENSCAFG00000011207       gene
# 10272  ENSEMBL:ENSXETG00000039922       gene
# 10273  ENSEMBL:ENSACAG00000010058       gene
# 10274         WBPhenotype:0000019  phenotype
#
#                                                    label  semantic_id
# 0                                          cardia bifida            9
# 1      muscle tendon junction myotome increased amoun...            9
# 2                                                   Sgcd            5
# 3                                         DMD, LYS770TER           11
# 4      posterior lateral line neuromast primordium mi...            9
# ...                                                  ...          ...
# 10270  atrioventricular valve development process qua...            9
# 10271                         ENSEMBL:ENSCAFG00000011207            5
# 10272                         ENSEMBL:ENSXETG00000039922            5
# 10273                         ENSEMBL:ENSACAG00000010058            5
# 10274                         pharyngeal pumping reduced            9
#
# [10275 rows x 7 columns]

# %% [markdown]
# For the edges, load csv file.

# %%
edges = pd.read_csv(f'output/indexed_edges_{dataset_nr}.csv')
edges
# Out:
#                           head
# 0      WormBase:WBGene00006787  \
# 1      WormBase:WBGene00006787
# 2      WormBase:WBGene00006787
# 3      WormBase:WBGene00006787
# 4      WormBase:WBGene00006787
# ...                        ...
# 85987                      458
# 85988         OMIM:300377.0080
# 85989                     5297
# 85990    ClinVarVariant:981988
# 85991    ClinVarVariant:584105
#
#                                               label_head  class_head
# 0                                                 unc-52           5  \
# 1                                                 unc-52           5
# 2                                                 unc-52           5
# 3                                                 unc-52           5
# 4                                                 unc-52           5
# ...                                                  ...         ...
# 85987                           scopolamine butylbromide           4
# 85988                              DMD, IVS62, A-G, -285          11
# 85989                                        dacomitinib           4
# 85990  NC_000023.11:g.(31875374_31929595)_(31968515_3...          11
# 85991        NC_000023.11:g.(?_32595737)_(32699313_?)del          11
#
#        index_head                        relation                        tail
# 0             304                  interacts with     WormBase:WBGene00003929  \
# 1             304                  interacts with     WormBase:WBGene00006789
# 2             304  in orthology relationship with  ENSEMBL:ENSSSCG00000015555
# 3             304  in orthology relationship with      ZFIN:ZDB-GENE-021226-3
# 4             304  in orthology relationship with  ENSEMBL:ENSOANG00000001050
# ...           ...                             ...                         ...
# 85987        5945                         targets                      P11229
# 85988        1578                    is allele of                   HGNC:2928
# 85989        8798                         targets                      P12931
# 85990        8189            has affected feature                   HGNC:2928
# 85991        9866                causes condition               MONDO:0010679
#
#                                        label_tail  class_tail  index_tail
# 0                                           pat-2           5        1542  \
# 1                                          unc-54           5        6544
# 2                                           LAMC1           5        9268
# 3                                           lamc1           5        5387
# 4                      ENSEMBL:ENSOANG00000001050           5        2204
# ...                                           ...         ...         ...
# 85987        Muscarinic acetylcholine receptor M1           6        5919
# 85988                                         DMD           5        3310
# 85989  Proto-oncogene tyrosine-protein kinase Src           6        2379
# 85990                                         DMD           5        3310
# 85991                 Duchenne muscular dystrophy           3        1913
#
#        type
# 0         0
# 1         0
# 2         1
# 3         1
# 4         1
# ...     ...
# 85987    17
# 85988    15
# 85989    17
# 85990    11
# 85991     2
#
# [85992 rows x 10 columns]

# %% [markdown]
# Load nodes with their features and edges into graph.

# %%
G = nx.DiGraph()
for ind, node in node_features.iterrows(): 
    G.add_node(int(node['Node']), node_feature = torch.Tensor(node['Embedding']))
for ind, edge in edges.iterrows(): 
    G.add_edge(int(edge['index_head']), int(edge['index_tail']))
  
for node in G.nodes(data=True):
    print(node)
    break
for edge in G.edges(data=True):
    print(edge)
    break

print("Number of edges is {}".format(G.number_of_edges()))
print("Number of nodes is {}".format(G.number_of_nodes()))
# Out:
# (0, {'node_feature': tensor([ 0.4429, -0.6467, -0.0455,  0.0469,  0.3007, -0.4822,  0.2423,  0.0707,
#         -0.5349,  0.4175,  0.7552,  0.0628, -0.3813, -0.3389,  0.5671,  0.4919,
#          0.0854,  0.0053, -0.2314,  0.8349,  0.5443,  0.7359, -0.1399, -0.2049,
#         -0.1793,  0.0314, -0.7152,  0.1764,  0.3586, -0.4770,  0.0838, -0.3013,
#          0.1751, -0.7785, -0.1280,  0.4082,  0.5959,  0.4058,  0.5182,  0.5561,
#          0.3995, -0.1704,  0.3317, -0.1183, -0.1047,  0.2789,  0.3293, -0.1368,
#          0.1259,  0.1704,  0.7724,  0.4460,  0.6070, -0.3315,  0.5776,  0.4367,
#          0.2875, -0.7309,  0.2535,  0.5972,  0.4410, -0.4248, -0.3355,  0.3258])})
# (2, 7693, {})
# Number of edges is 85878
# Number of nodes is 10275

# %%
G_attributes = nx.DiGraph()
for ind, node in node_features.iterrows(): 
    G_attributes.add_node(int(node['Node']), node_label = node['label'], node_semantic = node['semantic'])
for ind, edge in edges.iterrows(): 
    G_attributes.add_edge(int(edge['index_head']), int(edge['index_tail']), edge_label = edge['relation'])
  
for node in G_attributes.nodes(data=True):
    print(node)
    break
for edge in G_attributes.edges(data=True):
    print(edge)
    break

print("Number of edges is {}".format(G_attributes.number_of_edges()))
print("Number of nodes is {}".format(G_attributes.number_of_nodes()))
# Out:
# (0, {'node_label': 'cardia bifida', 'node_semantic': 'phenotype'})
# (2, 7693, {'edge_label': 'found in'})
# Number of edges is 85878
# Number of nodes is 10275

# %%
DeepG = Graph(G)

print(DeepG.node_feature.shape)
print(DeepG.edge_index.shape)
# Out:
# torch.Size([10275, 64])
# torch.Size([2, 85878])

# %%
x = DeepG.node_feature
x
# Out:
# tensor([[ 0.4429, -0.6467, -0.0455,  ..., -0.4248, -0.3355,  0.3258],
#         [ 0.7495, -0.5790,  0.1619,  ..., -0.4995,  0.4305,  0.0857],
#         [-0.2105, -0.2891,  0.1183,  ...,  0.3423, -0.0471,  0.2484],
#         ...,
#         [ 0.5863, -0.8055,  0.2757,  ..., -0.5787, -0.5317, -0.0063],
#         [ 0.6474, -0.3825,  0.4375,  ...,  0.3179, -0.5550, -0.1071],
#         [ 0.5623, -0.5136, -0.0366,  ..., -0.7215, -0.4545, -0.0579]])

# %% [markdown]
# Load arguments and parameters of trained GNN model.

# %%
with open(f'output/best_model_{dataset_nr}_args.pkl', 'rb') as f:
    loaded_args = pickle.load(f)

# Important! Changed the forward function such that it allows input of less edges that are predicted
# and it does not return newly calculated x

class LinkPredModel(torch.nn.Module):
    """
        Architecture contains Batch Normalization layers (https://towardsdatascience.com/batch-norm-explained-visually-how-it-works-and-why-neural-networks-need-it-b18919692739) 
        between the SAGEConvolutional layers.
    """
    def __init__(self, input_size, hidden_size, out_size, num_layers, aggr, dropout, device):
        super(LinkPredModel, self).__init__()

        self.convs = torch.nn.ModuleList()
        self.bns = torch.nn.ModuleList()
        
        self.convs.append(SAGEConv(input_size, hidden_size, normalize=True, aggr=aggr)) # input node embedding features, output is size of hidden layers
        self.bns.append(nn.BatchNorm1d(hidden_size))
        for _ in range(num_layers - 2):
            self.convs.append(SAGEConv(hidden_size, hidden_size, normalize=True, aggr=aggr))
            self.bns.append(nn.BatchNorm1d(hidden_size))
        self.convs.append(SAGEConv(hidden_size, out_size, normalize=True, aggr=aggr))
        self.bns.append(nn.BatchNorm1d(out_size))

        self.dropout = dropout
        self.loss_fn = torch.nn.BCEWithLogitsLoss()
        
        self.device = device


    def forward(self, x, edge_index, edge_label_index, training = False):
        x = x.to(self.device)
        edge_index = edge_index.to(self.device)
        edge_label_index = edge_label_index.to(self.device)

        for i in range(len(self.convs) - 1):
          x = self.convs[i](x, edge_index)
          x = self.bns[i](x)
          x = F.leaky_relu(x)
          x = F.dropout(x, p=self.dropout, training=training)
        
        x = self.convs[-1](x, edge_index)  
        x = self.bns[-1](x)
        

        nodes_first, nodes_second = edge_label_index
        nodes_first_features = x[nodes_first.long()]
        nodes_second_features = x[nodes_second.long()]
        
        pred = torch.sum(nodes_first_features * nodes_second_features, dim=-1)
        
        return pred
    
    def loss(self, pred, label):
        return self.loss_fn(pred, label)

num_node_features = len(node_features['Embedding'][0])

best_model = LinkPredModel(num_node_features, loaded_args['hidden_dim'], loaded_args['output_dim'], 
                           loaded_args['layers'], loaded_args['aggr'], loaded_args['dropout'], 
                           loaded_args['device']).to(loaded_args['device'])

best_model.load_state_dict(torch.load(f'output/best_model_{dataset_nr}.pth'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# # GNNExplainer

# %%
model_config = ModelConfig(
    mode='binary_classification',
    task_level='edge',
    return_type='raw',
)

# %%
explainer = Explainer(
    model=best_model,
    explanation_type='model',
    algorithm=GNNExplainer(epochs=200),
    node_mask_type='attributes',
    edge_mask_type='object',
    model_config=model_config,
)

# %%
import ast

symptoms_drugs = pd.read_csv(f'output/symptom_drugs_{dataset_nr}.csv', converters={1:ast.literal_eval})
symptoms_drugs
# Out:
#        Symptom          Candidates
# 0   HP:0003707   [2774, 176, 1043]
# 1   HP:0003236   [1043, 176, 1971]
# 2   HP:0001256    [65, 1273, 1971]
# 3   HP:0001265   [1273, 1971, 176]
# 4   HP:0001290  [1971, 1043, 2630]
# 5   HP:0003307   [176, 2774, 1043]
# 6   HP:0003202  [1273, 1043, 2774]
# 7   HP:0001263   [1273, 1150, 832]
# 8   HP:0002791   [1273, 1646, 271]
# 9   HP:0001371   [1043, 522, 1273]
# 10  HP:0003701   [1273, 1971, 176]
# 11  HP:0001270   [1273, 176, 1646]
# 12  HP:0003560  [1043, 2774, 1273]
# 13  HP:0008981   [176, 2774, 5345]
# 14  HP:0002650  [1043, 1273, 5345]
# 15  HP:0001638   [176, 2774, 1273]
# 16  HP:0003323    [223, 176, 1971]
# 17  HP:0001635    [1576, 522, 313]
# 18  HP:0000750  [1273, 1646, 1920]
# 19  HP:0003115   [1726, 1043, 223]
# 20  HP:0011675     [231, 2774, 65]
# 21  HP:0003391   [2774, 176, 1273]
# 22  HP:0002093    [1971, 1273, 65]
# 23  HP:0100543  [1273, 1043, 1646]
# 24  HP:0001644    [176, 223, 1043]
# 25  HP:0002515   [176, 1273, 1043]
# 26  HP:0001328    [65, 1273, 1043]

# %%
def explain_edge(node_idx1, node_idx2):
    edge_label_index = torch.tensor([node_idx1, node_idx2]) # Create a tensor as input of the model. Only predict the label of a single edge instead of all edges in current dataset.
    
    done = False
    current_iterations = 0
    total_iterations = 30
    graph_size = 30

    while not done:
        print(f'--- Iteration {current_iterations} ---')

        explanation = explainer(
            x=DeepG.node_feature,
            edge_index=DeepG.edge_index,
            edge_label_index=edge_label_index,
        )
        
        edge_mask = explanation.edge_mask
        
        print(f'A total of {torch.count_nonzero(edge_mask)} edges contributing to prediction.')
        
        sorted_contributions = edge_mask.sort(descending=True)[0]
        print(f'Maximum contribution value is {sorted_contributions[0]}')
        limit = sorted_contributions[graph_size]
        print(f'Based on desired graph size, contribution limit is set to {limit}')
        
        pruned_G = copy.deepcopy(G_attributes)
        for indx, edge in enumerate(G.edges):
            if edge_mask[indx] < limit:
                pruned_G.remove_edge(edge[0], edge[1])
        
        done = nx.has_path(pruned_G, node_idx1, node_idx2)
        
        pruned_G.remove_nodes_from(list(nx.isolates(pruned_G)))
        print('Pruned graph has edge total of:', pruned_G.number_of_edges())
        print('Pruned graph has node total of:', pruned_G.number_of_nodes())
        
        current_iterations += 1
        
        if done:
            print(f'A good explanation has been found!')
            nx.write_gexf(pruned_G, "output/explanation.gexf")
            return True
            
        elif current_iterations == total_iterations and not done:
            done = True
            print(f'No good explanations found after {current_iterations} iterations...')
    
    return False

# %%
def get_node_idx(id, nodes): 
    return nodes[nodes['id'] == id].index.values.astype(int)[0]

found_explanation = []

for ind, edge in symptoms_drugs.iterrows(): 
    symptom_id = edge['Symptom']
    
    for drug_id in edge['Candidates']:
        
        print('Explain for edge between nodes', node_idx1, 'and', node_idx2)

        node_idx1 = get_node_idx(symptom_id, nodes)
        print('node1:')
        print(nodes.loc[[node_idx1]])

        node_idx2 = get_node_idx(str(drug_id), nodes)
        print('node2:')
        print(nodes.loc[[node_idx2]])
        
        explained = explain_edge(node_idx1, node_idx2)
        if explained:
            found_explanation.append({'symptom': symptom_id, 'drug': drug_id})
# Out:
# Explain for edge between nodes 1351 and 7315
# node1:
#       index_id          id   semantic                          label
# 5727      5727  HP:0003707  phenotype  Calf muscle pseudohypertrophy  \
#
#       semantic_id
# 5727            9
# node2:
#       index_id    id semantic        label  semantic_id
# 9663      9663  2774     drug  tropicamide            4
# --- Iteration 0 ---
# A total of 4260 edges contributing to prediction.
# Maximum contribution value is 0.17691539227962494
# Based on desired graph size, contribution limit is set to 0.14854896068572998
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 39
# --- Iteration 1 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.17125378549098969
# Based on desired graph size, contribution limit is set to 0.14849451184272766
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 35
# --- Iteration 2 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.16578319668769836
# Based on desired graph size, contribution limit is set to 0.14848966896533966
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 35
# --- Iteration 3 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.165847510099411
# Based on desired graph size, contribution limit is set to 0.14839567244052887
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 35
# --- Iteration 4 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.1772894561290741
# Based on desired graph size, contribution limit is set to 0.1485842615365982
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 35
# --- Iteration 5 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.17121239006519318
# Based on desired graph size, contribution limit is set to 0.14844630658626556
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 34
# --- Iteration 6 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.16789506375789642
# Based on desired graph size, contribution limit is set to 0.1484932005405426
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 34
# --- Iteration 7 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.17275497317314148
# Based on desired graph size, contribution limit is set to 0.14872944355010986
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 35
# --- Iteration 8 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.17815163731575012
# Based on desired graph size, contribution limit is set to 0.1484563946723938
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 35
# --- Iteration 9 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.17751052975654602
# Based on desired graph size, contribution limit is set to 0.14852192997932434
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 35
# --- Iteration 10 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.1691892147064209
# Based on desired graph size, contribution limit is set to 0.14860963821411133
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 35
# --- Iteration 11 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.17634932696819305
# Based on desired graph size, contribution limit is set to 0.1482432335615158
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 34
# --- Iteration 12 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.16694007813930511
# Based on desired graph size, contribution limit is set to 0.1483328938484192
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 33
# --- Iteration 13 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.17112864553928375
# Based on desired graph size, contribution limit is set to 0.14842896163463593
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 34
# --- Iteration 14 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.1572033315896988
# Based on desired graph size, contribution limit is set to 0.1484317034482956
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 36
# --- Iteration 15 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.17503722012043
# Based on desired graph size, contribution limit is set to 0.14858505129814148
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 35
# --- Iteration 16 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.1602732390165329
# Based on desired graph size, contribution limit is set to 0.14839565753936768
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 34
# --- Iteration 17 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.1685551255941391
# Based on desired graph size, contribution limit is set to 0.14829984307289124
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 34
# --- Iteration 18 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.1675790697336197
# Based on desired graph size, contribution limit is set to 0.14856790006160736
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 35
# --- Iteration 19 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.16699855029582977
# Based on desired graph size, contribution limit is set to 0.14851728081703186
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 34
# --- Iteration 20 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.1679367572069168
# Based on desired graph size, contribution limit is set to 0.14839157462120056
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 35
# --- Iteration 21 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.17075294256210327
# Based on desired graph size, contribution limit is set to 0.14835286140441895
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 34
# --- Iteration 22 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.17001330852508545
# Based on desired graph size, contribution limit is set to 0.1486179232597351
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 33
# --- Iteration 23 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.16797436773777008
# Based on desired graph size, contribution limit is set to 0.14831241965293884
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 35
# --- Iteration 24 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.16781438887119293
# Based on desired graph size, contribution limit is set to 0.14842067658901215
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 35
# --- Iteration 25 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.16614706814289093
# Based on desired graph size, contribution limit is set to 0.14843013882637024
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 35
# --- Iteration 26 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.17334577441215515
# Based on desired graph size, contribution limit is set to 0.14852622151374817
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 35
# --- Iteration 27 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.16902609169483185
# Based on desired graph size, contribution limit is set to 0.1486344337463379
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 35
# --- Iteration 28 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.17497922480106354
# Based on desired graph size, contribution limit is set to 0.14842309057712555
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 34
# --- Iteration 29 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.17262913286685944
# Based on desired graph size, contribution limit is set to 0.14835967123508453
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 34
# No good explanations found after 30 iterations...
# Explain for edge between nodes 5727 and 9663
# node1:
#       index_id          id   semantic                          label
# 5727      5727  HP:0003707  phenotype  Calf muscle pseudohypertrophy  \
#
#       semantic_id
# 5727            9
# node2:
#      index_id   id semantic       label  semantic_id
# 772       772  176     drug  amiodarone            4
# --- Iteration 0 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.19227959215641022
# Based on desired graph size, contribution limit is set to 0.1480652093887329
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 33
# --- Iteration 1 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.19845569133758545
# Based on desired graph size, contribution limit is set to 0.14819222688674927
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 35
# --- Iteration 2 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.19902122020721436
# Based on desired graph size, contribution limit is set to 0.14817167818546295
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 33
# --- Iteration 3 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.20023366808891296
# Based on desired graph size, contribution limit is set to 0.1481882482767105
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 34
# --- Iteration 4 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.19320204854011536
# Based on desired graph size, contribution limit is set to 0.14793652296066284
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 35
# --- Iteration 5 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.1974249929189682
# Based on desired graph size, contribution limit is set to 0.14821481704711914
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 34
# --- Iteration 6 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.21376244723796844
# Based on desired graph size, contribution limit is set to 0.1481621414422989
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 35
# --- Iteration 7 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.19694195687770844
# Based on desired graph size, contribution limit is set to 0.14800599217414856
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 34
# --- Iteration 8 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.19691242277622223
# Based on desired graph size, contribution limit is set to 0.1482628434896469
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 34
# --- Iteration 9 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.20006895065307617
# Based on desired graph size, contribution limit is set to 0.14823921024799347
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 32
# --- Iteration 10 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.20423822104930878
# Based on desired graph size, contribution limit is set to 0.14822649955749512
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 35
# --- Iteration 11 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.20117944478988647
# Based on desired graph size, contribution limit is set to 0.14838097989559174
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 35
# --- Iteration 12 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.20161305367946625
# Based on desired graph size, contribution limit is set to 0.14814524352550507
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 35
# --- Iteration 13 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.19273142516613007
# Based on desired graph size, contribution limit is set to 0.14821738004684448
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 33
# --- Iteration 14 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.17786934971809387
# Based on desired graph size, contribution limit is set to 0.14819616079330444
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 34
# --- Iteration 15 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.19136443734169006
# Based on desired graph size, contribution limit is set to 0.14827430248260498
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 34
# --- Iteration 16 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.19851063191890717
# Based on desired graph size, contribution limit is set to 0.1481267213821411
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 32
# --- Iteration 17 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.1822528839111328
# Based on desired graph size, contribution limit is set to 0.1480887234210968
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 34
# --- Iteration 18 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.18976901471614838
# Based on desired graph size, contribution limit is set to 0.1480596512556076
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 34
# --- Iteration 19 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.18671807646751404
# Based on desired graph size, contribution limit is set to 0.14823538064956665
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 33
# --- Iteration 20 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.19777093827724457
# Based on desired graph size, contribution limit is set to 0.14807669818401337
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 35
# --- Iteration 21 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.1889718770980835
# Based on desired graph size, contribution limit is set to 0.14829501509666443
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 35
# --- Iteration 22 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.18975701928138733
# Based on desired graph size, contribution limit is set to 0.14822813868522644
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 33
# --- Iteration 23 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.188750222325325
# Based on desired graph size, contribution limit is set to 0.14805303514003754
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 34
# --- Iteration 24 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.20559988915920258
# Based on desired graph size, contribution limit is set to 0.14810773730278015
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 34
# --- Iteration 25 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.19752097129821777
# Based on desired graph size, contribution limit is set to 0.14831896126270294
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 34
# --- Iteration 26 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.18706540763378143
# Based on desired graph size, contribution limit is set to 0.1482982337474823
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 33
# --- Iteration 27 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.1915573626756668
# Based on desired graph size, contribution limit is set to 0.14779317378997803
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 33
# --- Iteration 28 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.19910356402397156
# Based on desired graph size, contribution limit is set to 0.14821089804172516
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 33
# --- Iteration 29 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.19597455859184265
# Based on desired graph size, contribution limit is set to 0.14816951751708984
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 33
# No good explanations found after 30 iterations...
# Explain for edge between nodes 5727 and 772
# node1:
#       index_id          id   semantic                          label
# 5727      5727  HP:0003707  phenotype  Calf muscle pseudohypertrophy  \
#
#       semantic_id
# 5727            9
# node2:
#       index_id    id semantic       label  semantic_id
# 7315      7315  1043     drug  ergotamine            4
# --- Iteration 0 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.19142159819602966
# Based on desired graph size, contribution limit is set to 0.1479046642780304
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 32
# --- Iteration 1 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.1843545138835907
# Based on desired graph size, contribution limit is set to 0.14753152430057526
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 34
# --- Iteration 2 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.19073806703090668
# Based on desired graph size, contribution limit is set to 0.1477396935224533
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 30
# --- Iteration 3 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.19636370241641998
# Based on desired graph size, contribution limit is set to 0.14772555232048035
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 34
# --- Iteration 4 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.18825729191303253
# Based on desired graph size, contribution limit is set to 0.14774690568447113
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 35
# --- Iteration 5 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.1960357129573822
# Based on desired graph size, contribution limit is set to 0.14775505661964417
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 34
# --- Iteration 6 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.20547515153884888
# Based on desired graph size, contribution limit is set to 0.14800012111663818
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 35
# --- Iteration 7 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.1967364251613617
# Based on desired graph size, contribution limit is set to 0.14799077808856964
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 33
# --- Iteration 8 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.18340854346752167
# Based on desired graph size, contribution limit is set to 0.14771902561187744
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 35
# --- Iteration 9 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.18049746751785278
# Based on desired graph size, contribution limit is set to 0.14776833355426788
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 35
# --- Iteration 10 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.1874285340309143
# Based on desired graph size, contribution limit is set to 0.14769534766674042
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 34
# --- Iteration 11 ---
# A total of 2958 edges contributing to prediction.
# Maximum contribution value is 0.1890588402748108
# Based on desired graph size, contribution limit is set to 0.14773298799991608
# Pruned graph has edge total of: 31
# Pruned graph has node total of: 32
# --- Iteration 12 ---
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[83], line 21
#      18 print('node2:')
#      19 print(nodes.loc[[node_idx2]])
# ---> 21 explained = explain_edge(node_idx1, node_idx2)
#      22 if explained:
#      23     found_explanation.append({'symptom': symptom_id, 'drug': drug_id})
#
# Cell In[82], line 12, in explain_edge(node_idx1, node_idx2)
#       9 while not done:
#      10     print(f'--- Iteration {current_iterations} ---')
# ---> 12     explanation = explainer(
#      13         x=DeepG.node_feature,
#      14         edge_index=DeepG.edge_index,
#      15         edge_label_index=edge_label_index,
#      16     )
#      18     edge_mask = explanation.edge_mask
#      20     print(f'A total of {torch.count_nonzero(edge_mask)} edges contributing to prediction.')
#
# File c:\Users\rosa-\anaconda3\envs\xaifognn\lib\site-packages\torch_geometric\explain\explainer.py:198, in Explainer.__call__(self, x, edge_index, target, index, **kwargs)
#     195 training = self.model.training
#     196 self.model.eval()
# --> 198 explanation = self.algorithm(
#     199     self.model,
#     200     x,
#     201     edge_index,
#     202     target=target,
#     203     index=index,
#     204     **kwargs,
#     205 )
#     207 self.model.train(training)
#     209 # Add explainer objectives to the `Explanation` object:
#
# File c:\Users\rosa-\anaconda3\envs\xaifognn\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\rosa-\anaconda3\envs\xaifognn\lib\site-packages\torch_geometric\explain\algorithm\gnn_explainer.py:75, in GNNExplainer.forward(self, model, x, edge_index, target, index, **kwargs)
#      71 if isinstance(x, dict) or isinstance(edge_index, dict):
#      72     raise ValueError(f"Heterogeneous graphs not yet supported in "
#      73                      f"'{self.__class__.__name__}'")
# ---> 75 self._train(model, x, edge_index, target=target, index=index, **kwargs)
#      77 node_mask = self._post_process_mask(
#      78     self.node_mask,
#      79     self.hard_node_mask,
#      80     apply_sigmoid=True,
#      81 )
#      82 edge_mask = self._post_process_mask(
#      83     self.edge_mask,
#      84     self.hard_edge_mask,
#      85     apply_sigmoid=True,
#      86 )
#
# File c:\Users\rosa-\anaconda3\envs\xaifognn\lib\site-packages\torch_geometric\explain\algorithm\gnn_explainer.py:120, in GNNExplainer._train(self, model, x, edge_index, target, index, **kwargs)
#     117 optimizer.zero_grad()
#     119 h = x if self.node_mask is None else x * self.node_mask.sigmoid()
# --> 120 y_hat, y = model(h, edge_index, **kwargs), target
#     122 if index is not None:
#     123     y_hat, y = y_hat[index], y[index]
#
# File c:\Users\rosa-\anaconda3\envs\xaifognn\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In[68], line 43, in LinkPredModel.forward(self, x, edge_index, edge_label_index, training)
#      40   x = F.leaky_relu(x)
#      41   x = F.dropout(x, p=self.dropout, training=training)
# ---> 43 x = self.convs[-1](x, edge_index)
#      44 x = self.bns[-1](x)
#      47 nodes_first, nodes_second = edge_label_index
#
# File c:\Users\rosa-\anaconda3\envs\xaifognn\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\rosa-\anaconda3\envs\xaifognn\lib\site-packages\torch_geometric\nn\conv\sage_conv.py:131, in SAGEConv.forward(self, x, edge_index, size)
#     128     x = (self.lin(x[0]).relu(), x[1])
#     130 # propagate_type: (x: OptPairTensor)
# --> 131 out = self.propagate(edge_index, x=x, size=size)
#     132 out = self.lin_l(out)
#     134 x_r = x[1]
#
# File c:\Users\rosa-\anaconda3\envs\xaifognn\lib\site-packages\torch_geometric\nn\conv\message_passing.py:484, in MessagePassing.propagate(self, edge_index, size, **kwargs)
#     481     if res is not None:
#     482         aggr_kwargs = res[0] if isinstance(res, tuple) else res
# --> 484 out = self.aggregate(out, **aggr_kwargs)
#     486 for hook in self._aggregate_forward_hooks.values():
#     487     res = hook(self, (aggr_kwargs, ), out)
#
# File c:\Users\rosa-\anaconda3\envs\xaifognn\lib\site-packages\torch_geometric\nn\conv\message_passing.py:608, in MessagePassing.aggregate(self, inputs, index, ptr, dim_size)
#     595 def aggregate(self, inputs: Tensor, index: Tensor,
#     596               ptr: Optional[Tensor] = None,
#     597               dim_size: Optional[int] = None) -> Tensor:
#     598     r"""Aggregates messages from neighbors as
#     599     :math:`\bigoplus_{j \in \mathcal{N}(i)}`.
#     600
#    (...)
#     606     as specified in :meth:`__init__` by the :obj:`aggr` argument.
#     607     """
# --> 608     return self.aggr_module(inputs, index, ptr=ptr, dim_size=dim_size,
#     609                             dim=self.node_dim)
#
# File c:\Users\rosa-\anaconda3\envs\xaifognn\lib\site-packages\torch_geometric\nn\aggr\base.py:109, in Aggregation.__call__(self, x, index, ptr, dim_size, dim, **kwargs)
#     106     dim_size = int(index.max()) + 1 if index.numel() > 0 else 0
#     108 try:
# --> 109     return super().__call__(x, index, ptr, dim_size, dim, **kwargs)
#     110 except (IndexError, RuntimeError) as e:
#     111     if index is not None:
#
# File c:\Users\rosa-\anaconda3\envs\xaifognn\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\rosa-\anaconda3\envs\xaifognn\lib\site-packages\torch_geometric\nn\aggr\basic.py:34, in MeanAggregation.forward(self, x, index, ptr, dim_size, dim)
#      31 def forward(self, x: Tensor, index: Optional[Tensor] = None,
#      32             ptr: Optional[Tensor] = None, dim_size: Optional[int] = None,
#      33             dim: int = -2) -> Tensor:
# ---> 34     return self.reduce(x, index, ptr, dim_size, dim, reduce='mean')
#
# File c:\Users\rosa-\anaconda3\envs\xaifognn\lib\site-packages\torch_geometric\nn\aggr\base.py:155, in Aggregation.reduce(self, x, index, ptr, dim_size, dim, reduce)
#     152     return segment(x, ptr, reduce=reduce)
#     154 assert index is not None
# --> 155 return scatter(x, index, dim, dim_size, reduce)
#
# File c:\Users\rosa-\anaconda3\envs\xaifognn\lib\site-packages\torch_geometric\utils\scatter.py:82, in scatter(src, index, dim, dim_size, reduce)
#      79     count = count.clamp(min=1)
#      81     index = broadcast(index, src, dim)
# ---> 82     out = src.new_zeros(size).scatter_add_(dim, index, src)
#      84     return out / broadcast(count, out, dim)
#      86 # For "min" and "max" reduction, we prefer `scatter_reduce_` on CPU or
#      87 # in case the input does not require gradients:
#
# KeyboardInterrupt:

# %%
found_explanation
