# %% [markdown]
# Merge all fetched datasets originating from Monarch Initiative, TTD and DrugCentral.
#
# Adapted by Rosa Zwart from Jupyter Notebooks found at https://github.com/PPerdomoQ/rare-disease-explainer

# %%
import pandas as pd
import numpy as np

import util.constants as constants

# %% [markdown]
# #### **Format Monarch data**

# %%
monarch_edges = pd.read_csv('prev/monarch/monarch_connections_v2023-02-20.csv')
monarch_edges.drop_duplicates(inplace=True)
monarch_edges
# Out:
#                        subject_id subject_label    relation_id  \
# 0                     MGI:1202300         Kcnu1     RO:0002200
# 1         WormBase:WBGene00003369         mlc-1     RO:0002434
# 2      ENSEMBL:ENSBTAG00000010660       CACNA1C  RO:HOM0000017
# 3                       MGI:98783         Tnni3  RO:HOM0000020
# 4             FlyBase:FBgn0038129        TBC1D5     RO:0002200
# ...                           ...           ...            ...
# 82669  ENSEMBL:ENSCAFG00000031099         STUB1  RO:HOM0000020
# 82670                   HGNC:6487         LAMB2     RO:0002434
# 82671  ENSEMBL:ENSCAFG00000018952       ARHGEF6  RO:HOM0000020
# 82672                    HGNC:329          AGRN     RO:0002434
# 82673     WormBase:WBGene00000047         acr-8  RO:HOM0000017
#
#                               relation_label                   object_id  \
# 0                              has phenotype                  MP:0002675
# 1                             interacts with     WormBase:WBGene00006585
# 2             in orthology relationship with              SGD:S000003449
# 3      in 1 to 1 orthology relationship with  ENSEMBL:ENSOANG00000039013
# 4                              has phenotype                FBcv:0000349
# ...                                      ...                         ...
# 82669  in 1 to 1 orthology relationship with  ENSEMBL:ENSSSCG00000008008
# 82670                         interacts with                   HGNC:8590
# 82671  in 1 to 1 orthology relationship with  ENSEMBL:ENSOANG00000011671
# 82672                         interacts with                   HGNC:6487
# 82673         in orthology relationship with  ENSEMBL:ENSOANG00000008607
#
#                      object_label  \
# 0               asthenozoospermia
# 1                           tni-3
# 2                            CCH1
# 3      ENSEMBL:ENSOANG00000039013
# 4                          viable
# ...                           ...
# 82669  ENSEMBL:ENSSSCG00000008008
# 82670                        PAK1
# 82671  ENSEMBL:ENSOANG00000011671
# 82672                       LAMB2
# 82673  ENSEMBL:ENSOANG00000008607
#
#                                        reference_id_list
# 0                            PMID:21427226|PMID:20138882
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4      PMID:20371351|PMID:20220848|PMID:21074052|FlyB...
# ...                                                  ...
# 82669                                                NaN
# 82670                                                NaN
# 82671                                                NaN
# 82672                                                NaN
# 82673                                                NaN
#
# [82674 rows x 7 columns]

# %%
monarch_nodes = pd.read_csv('prev/monarch/monarch_nodes_v2023-02-20.csv')
monarch_nodes.drop_duplicates(inplace=True)
monarch_nodes
# Out:
#                               id semantic_groups  \
# 0                    MGI:1202300            ORTH
# 1                     MP:0002675            DISO
# 2        WormBase:WBGene00003369            ORTH
# 3        WormBase:WBGene00006585            ORTH
# 4     ENSEMBL:ENSBTAG00000010660            ORTH
# ...                          ...             ...
# 9836                  ZP:0011545            DISO
# 9837                  ZP:0002302            DISO
# 9838                  ZP:0005847            DISO
# 9839                  ZP:0006358            DISO
# 9840                  ZP:0102118            DISO
#
#                                               preflabel  \
# 0                                                 Kcnu1
# 1                                     asthenozoospermia
# 2                                                 mlc-1
# 3                                                 tni-3
# 4                                               CACNA1C
# ...                                                 ...
# 9836    cell posterior lateral mesoderm shape, abnormal
# 9837                           trunk undulate, abnormal
# 9838  photoreceptor outer segment photoreceptor cell...
# 9839                 swimming decreased speed, abnormal
# 9840  notochord outer sheath cell displaced to centr...
#
#                                                synonyms  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4     CACH2|CACN2|CACNL1A1|CCHL1A1|CaV1.2|LQT8|NEDHL...
# ...                                                 ...
# 9836                                                NaN
# 9837                                                NaN
# 9838                                                NaN
# 9839                                                NaN
# 9840                                                NaN
#
#                                             description  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4     This gene encodes an alpha-1 subunit of a volt...
# ...                                                 ...
# 9836                                                NaN
# 9837                                                NaN
# 9838                                                NaN
# 9839                                                NaN
# 9840                                                NaN
#
#                                                    name
# 0                                                 Kcnu1
# 1                                     asthenozoospermia
# 2                                                 mlc-1
# 3                                                 tni-3
# 4        calcium voltage-gated channel subunit alpha1 C
# ...                                                 ...
# 9836    cell posterior lateral mesoderm shape, abnormal
# 9837                           trunk undulate, abnormal
# 9838  photoreceptor outer segment photoreceptor cell...
# 9839                 swimming decreased speed, abnormal
# 9840  notochord outer sheath cell displaced to centr...
#
# [9841 rows x 6 columns]

# %%
for i, row in monarch_edges.iterrows():
    monarch_edges.loc[i,'id'] = f'MONARCH{i}'
    
    subject_id = row['subject_id']

    monarch_edges.loc[i,'subject_iri'] = np.nan
    monarch_edges.loc[i,'subject_category'] = monarch_nodes.loc[monarch_nodes['id'] == subject_id]['semantic_groups'].values[0]
    monarch_edges.loc[i,'subject_taxon_id'] = np.nan
    monarch_edges.loc[i,'subject_taxon_label'] = np.nan
    
    object_id = row['object_id']
    
    monarch_edges.loc[i,'object_iri'] = np.nan
    monarch_edges.loc[i,'object_category'] = monarch_nodes.loc[monarch_nodes['id'] == object_id]['semantic_groups'].values[0]
    monarch_edges.loc[i,'object_taxon_id'] = np.nan
    monarch_edges.loc[i,'object_taxon_label'] = np.nan
    
    monarch_edges.loc[i,'relation_iri'] = np.nan

# %%
monarch_edges
# Out:
#                        subject_id subject_label    relation_id  \
# 0                     MGI:1202300         Kcnu1     RO:0002200
# 1         WormBase:WBGene00003369         mlc-1     RO:0002434
# 2      ENSEMBL:ENSBTAG00000010660       CACNA1C  RO:HOM0000017
# 3                       MGI:98783         Tnni3  RO:HOM0000020
# 4             FlyBase:FBgn0038129        TBC1D5     RO:0002200
# ...                           ...           ...            ...
# 82669  ENSEMBL:ENSCAFG00000031099         STUB1  RO:HOM0000020
# 82670                   HGNC:6487         LAMB2     RO:0002434
# 82671  ENSEMBL:ENSCAFG00000018952       ARHGEF6  RO:HOM0000020
# 82672                    HGNC:329          AGRN     RO:0002434
# 82673     WormBase:WBGene00000047         acr-8  RO:HOM0000017
#
#                               relation_label                   object_id  \
# 0                              has phenotype                  MP:0002675
# 1                             interacts with     WormBase:WBGene00006585
# 2             in orthology relationship with              SGD:S000003449
# 3      in 1 to 1 orthology relationship with  ENSEMBL:ENSOANG00000039013
# 4                              has phenotype                FBcv:0000349
# ...                                      ...                         ...
# 82669  in 1 to 1 orthology relationship with  ENSEMBL:ENSSSCG00000008008
# 82670                         interacts with                   HGNC:8590
# 82671  in 1 to 1 orthology relationship with  ENSEMBL:ENSOANG00000011671
# 82672                         interacts with                   HGNC:6487
# 82673         in orthology relationship with  ENSEMBL:ENSOANG00000008607
#
#                      object_label  \
# 0               asthenozoospermia
# 1                           tni-3
# 2                            CCH1
# 3      ENSEMBL:ENSOANG00000039013
# 4                          viable
# ...                           ...
# 82669  ENSEMBL:ENSSSCG00000008008
# 82670                        PAK1
# 82671  ENSEMBL:ENSOANG00000011671
# 82672                       LAMB2
# 82673  ENSEMBL:ENSOANG00000008607
#
#                                        reference_id_list            id  \
# 0                            PMID:21427226|PMID:20138882      MONARCH0
# 1                                                    NaN      MONARCH1
# 2                                                    NaN      MONARCH2
# 3                                                    NaN      MONARCH3
# 4      PMID:20371351|PMID:20220848|PMID:21074052|FlyB...      MONARCH4
# ...                                                  ...           ...
# 82669                                                NaN  MONARCH82669
# 82670                                                NaN  MONARCH82670
# 82671                                                NaN  MONARCH82671
# 82672                                                NaN  MONARCH82672
# 82673                                                NaN  MONARCH82673
#
#        subject_iri subject_category  subject_taxon_id  subject_taxon_label  \
# 0              NaN             ORTH               NaN                  NaN
# 1              NaN             ORTH               NaN                  NaN
# 2              NaN             ORTH               NaN                  NaN
# 3              NaN             ORTH               NaN                  NaN
# 4              NaN             ORTH               NaN                  NaN
# ...            ...              ...               ...                  ...
# 82669          NaN             ORTH               NaN                  NaN
# 82670          NaN             GENE               NaN                  NaN
# 82671          NaN             ORTH               NaN                  NaN
# 82672          NaN             GENE               NaN                  NaN
# 82673          NaN             ORTH               NaN                  NaN
#
#        object_iri object_category  object_taxon_id  object_taxon_label  \
# 0             NaN            DISO              NaN                 NaN
# 1             NaN            ORTH              NaN                 NaN
# 2             NaN            ORTH              NaN                 NaN
# 3             NaN            ORTH              NaN                 NaN
# 4             NaN            DISO              NaN                 NaN
# ...           ...             ...              ...                 ...
# 82669         NaN            ORTH              NaN                 NaN
# 82670         NaN            GENE              NaN                 NaN
# 82671         NaN            ORTH              NaN                 NaN
# 82672         NaN            GENE              NaN                 NaN
# 82673         NaN            ORTH              NaN                 NaN
#
#        relation_iri
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 82669           NaN
# 82670           NaN
# 82671           NaN
# 82672           NaN
# 82673           NaN
#
# [82674 rows x 17 columns]

# %%
monarch_associations_df = monarch_edges[list(constants.assoc_tuple_values)]
monarch_associations_df.to_csv(f'{constants.OUTPUT_FOLDER}/prev_monarch_associations.csv', index=None)

# %% [markdown]
# #### **Format TTD data**

# %% [markdown]
# Save a list of all associations between DRUG and GENE in a csv file.

# %%
drug_targets = pd.read_csv('prev/drug.target.final.ELA.csv')
drug_targets
# Out:
#             DRUG_NAME  STRUCT_ID  \
# 0     (S)-nicardipine          5
# 1    (S)-nitrendipine          6
# 2    (S)-nitrendipine          6
# 3    (S)-nitrendipine          6
# 4    (S)-nitrendipine          6
# ..                ...        ...
# 246      tirbanibulin       5431
# 247        casimersen       5443
# 248      infigratinib       5459
# 249      infigratinib       5459
# 250      infigratinib       5459
#
#                                            TARGET_NAME TARGET_CLASS  \
# 0                 Voltage-gated L-type calcium channel  Ion channel
# 1    Voltage-dependent L-type calcium channel subun...  Ion channel
# 2    Voltage-dependent L-type calcium channel subun...  Ion channel
# 3    Voltage-dependent L-type calcium channel subun...  Ion channel
# 4    Voltage-dependent L-type calcium channel subun...  Ion channel
# ..                                                 ...          ...
# 246         Proto-oncogene tyrosine-protein kinase Src       Kinase
# 247                     exon 53 of dystrophin pre-mRNA          RNA
# 248         Proto-oncogene tyrosine-protein kinase Src       Kinase
# 249         Proto-oncogene tyrosine-protein kinase Src       Kinase
# 250         Proto-oncogene tyrosine-protein kinase Src       Kinase
#
#          ACCESSION             GENE                SWISSPROT  ACT_VALUE  \
# 0    Q01668|Q13936  CACNA1D|CACNA1C  CAC1D_HUMAN|CAC1C_HUMAN        NaN
# 1           Q01668          CACNA1D              CAC1D_HUMAN       8.40
# 2           O60840          CACNA1F              CAC1F_HUMAN       6.00
# 3           P22002          Cacna1c                CAC1C_RAT       6.00
# 4           Q02485          Cacna1s                CAC1S_RAT       6.00
# ..             ...              ...                      ...        ...
# 246         P12931              SRC                SRC_HUMAN       4.34
# 247         P11532              DMD                DMD_HUMAN        NaN
# 248         P12931              SRC                SRC_HUMAN       5.53
# 249         P12931              SRC                SRC_HUMAN       5.53
# 250         P12931              SRC                SRC_HUMAN       5.53
#
#      ACT_UNIT ACT_TYPE  ...  ACT_SOURCE RELATION  MOA  MOA_SOURCE  \
# 0         NaN      NaN  ...  DRUG LABEL      NaN  1.0  DRUG LABEL
# 1         NaN     IC50  ...      IUPHAR        =  1.0      IUPHAR
# 2         NaN     IC50  ...      IUPHAR        ~  NaN         NaN
# 3         NaN     IC50  ...      IUPHAR        =  NaN         NaN
# 4         NaN     IC50  ...      IUPHAR        =  NaN         NaN
# ..        ...      ...  ...         ...      ...  ...         ...
# 246       NaN     IC50  ...      IUPHAR        =  NaN         NaN
# 247       NaN      NaN  ...     UNKNOWN      NaN  1.0  DRUG LABEL
# 248       NaN     IC50  ...      CHEMBL        =  NaN         NaN
# 249       NaN     IC50  ...      CHEMBL        =  NaN         NaN
# 250       NaN     IC50  ...      CHEMBL        =  NaN         NaN
#
#                                         ACT_SOURCE_URL  \
# 0    http://www.accessdata.fda.gov/drugsatfda_docs/...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 246                                                NaN
# 247                                                NaN
# 248                                                NaN
# 249                                                NaN
# 250                                                NaN
#
#                                         MOA_SOURCE_URL          ACTION_TYPE  \
# 0    http://www.accessdata.fda.gov/drugsatfda_docs/...              BLOCKER
# 1    https://www.ebi.ac.uk/chembl/compound/inspect/...     GATING INHIBITOR
# 2                                                  NaN     GATING INHIBITOR
# 3                                                  NaN     GATING INHIBITOR
# 4                                                  NaN     GATING INHIBITOR
# ..                                                 ...                  ...
# 246                                                NaN            INHIBITOR
# 247  https://www.accessdata.fda.gov/drugsatfda_docs...  ANTISENSE INHIBITOR
# 248                                                NaN                  NaN
# 249                                                NaN                  NaN
# 250                                                NaN                  NaN
#
#                          TDL           ORGANISM      NEW_ID
# 0    Tclin|Tclin|Tclin|Tclin       Homo sapiens   HGNC:1391
# 1                      Tclin       Homo sapiens   HGNC:1391
# 2                      Tclin       Homo sapiens   HGNC:1393
# 3                        NaN  Rattus norvegicus    RGD:2245
# 4                        NaN  Rattus norvegicus   RGD:70983
# ..                       ...                ...         ...
# 246                    Tclin       Homo sapiens  HGNC:11283
# 247                    Tclin       Homo sapiens   HGNC:2928
# 248                    Tclin       Homo sapiens  HGNC:11283
# 249                    Tclin       Homo sapiens  HGNC:11283
# 250                    Tclin       Homo sapiens  HGNC:11283
#
# [251 rows x 21 columns]

# %% [markdown]
# Get columns that are relevant.

# %%
drug_targets_values = drug_targets.copy()[['STRUCT_ID', 'DRUG_NAME', 'NEW_ID']]
drug_targets_values
# Out:
#      STRUCT_ID         DRUG_NAME      NEW_ID
# 0            5   (S)-nicardipine   HGNC:1391
# 1            6  (S)-nitrendipine   HGNC:1391
# 2            6  (S)-nitrendipine   HGNC:1393
# 3            6  (S)-nitrendipine    RGD:2245
# 4            6  (S)-nitrendipine   RGD:70983
# ..         ...               ...         ...
# 246       5431      tirbanibulin  HGNC:11283
# 247       5443        casimersen   HGNC:2928
# 248       5459      infigratinib  HGNC:11283
# 249       5459      infigratinib  HGNC:11283
# 250       5459      infigratinib  HGNC:11283
#
# [251 rows x 3 columns]

# %%
drug_targets_values.drop_duplicates(inplace=True)
drug_targets_values.shape[0]
# Out:
# 239

# %% [markdown]
# Add new columns that are needed to be included in the dataframe.

# %%
for i, row in drug_targets_values.iterrows():
    drug_targets_values.loc[i,'id'] = f'TTD{i}'
    
    drug_targets_values.loc[i,'subject_id'] = str(row['STRUCT_ID'])
    drug_targets_values.loc[i,'subject_label'] = row['DRUG_NAME']
    drug_targets_values.loc[i,'subject_iri'] = np.nan
    drug_targets_values.loc[i,'subject_category'] = 'DRUG'
    drug_targets_values.loc[i,'subject_taxon_id'] = np.nan
    drug_targets_values.loc[i,'subject_taxon_label'] = np.nan
    
    drug_targets_values.loc[i,'object_id'] = row['NEW_ID']
    drug_targets_values.loc[i,'object_label'] = np.nan
    drug_targets_values.loc[i,'object_iri'] = np.nan
    drug_targets_values.loc[i,'object_category'] = np.nan
    drug_targets_values.loc[i,'object_taxon_id'] = np.nan
    drug_targets_values.loc[i,'object_taxon_label'] = np.nan
    
    drug_targets_values.loc[i,'relation_id'] = 'CustomRO:TTD'
    drug_targets_values.loc[i,'relation_label'] = 'targets'
    drug_targets_values.loc[i,'relation_iri'] = np.nan

# %%
drug_targets_values
# Out:
#      STRUCT_ID         DRUG_NAME      NEW_ID      id subject_id  \
# 0            5   (S)-nicardipine   HGNC:1391    TTD0          5
# 1            6  (S)-nitrendipine   HGNC:1391    TTD1          6
# 2            6  (S)-nitrendipine   HGNC:1393    TTD2          6
# 3            6  (S)-nitrendipine    RGD:2245    TTD3          6
# 4            6  (S)-nitrendipine   RGD:70983    TTD4          6
# ..         ...               ...         ...     ...        ...
# 242       5406       oliceridine   HGNC:1390  TTD242       5406
# 244       5408       viltolarsen   HGNC:2928  TTD244       5408
# 245       5431      tirbanibulin  HGNC:11283  TTD245       5431
# 247       5443        casimersen   HGNC:2928  TTD247       5443
# 248       5459      infigratinib  HGNC:11283  TTD248       5459
#
#         subject_label  subject_iri subject_category  subject_taxon_id  \
# 0     (S)-nicardipine          NaN             DRUG               NaN
# 1    (S)-nitrendipine          NaN             DRUG               NaN
# 2    (S)-nitrendipine          NaN             DRUG               NaN
# 3    (S)-nitrendipine          NaN             DRUG               NaN
# 4    (S)-nitrendipine          NaN             DRUG               NaN
# ..                ...          ...              ...               ...
# 242       oliceridine          NaN             DRUG               NaN
# 244       viltolarsen          NaN             DRUG               NaN
# 245      tirbanibulin          NaN             DRUG               NaN
# 247        casimersen          NaN             DRUG               NaN
# 248      infigratinib          NaN             DRUG               NaN
#
#      subject_taxon_label   object_id  object_label  object_iri  \
# 0                    NaN   HGNC:1391           NaN         NaN
# 1                    NaN   HGNC:1391           NaN         NaN
# 2                    NaN   HGNC:1393           NaN         NaN
# 3                    NaN    RGD:2245           NaN         NaN
# 4                    NaN   RGD:70983           NaN         NaN
# ..                   ...         ...           ...         ...
# 242                  NaN   HGNC:1390           NaN         NaN
# 244                  NaN   HGNC:2928           NaN         NaN
# 245                  NaN  HGNC:11283           NaN         NaN
# 247                  NaN   HGNC:2928           NaN         NaN
# 248                  NaN  HGNC:11283           NaN         NaN
#
#      object_category  object_taxon_id  object_taxon_label   relation_id  \
# 0                NaN              NaN                 NaN  CustomRO:TTD
# 1                NaN              NaN                 NaN  CustomRO:TTD
# 2                NaN              NaN                 NaN  CustomRO:TTD
# 3                NaN              NaN                 NaN  CustomRO:TTD
# 4                NaN              NaN                 NaN  CustomRO:TTD
# ..               ...              ...                 ...           ...
# 242              NaN              NaN                 NaN  CustomRO:TTD
# 244              NaN              NaN                 NaN  CustomRO:TTD
# 245              NaN              NaN                 NaN  CustomRO:TTD
# 247              NaN              NaN                 NaN  CustomRO:TTD
# 248              NaN              NaN                 NaN  CustomRO:TTD
#
#     relation_label  relation_iri
# 0          targets           NaN
# 1          targets           NaN
# 2          targets           NaN
# 3          targets           NaN
# 4          targets           NaN
# ..             ...           ...
# 242        targets           NaN
# 244        targets           NaN
# 245        targets           NaN
# 247        targets           NaN
# 248        targets           NaN
#
# [239 rows x 19 columns]

# %%
drugtarget_associations_df = drug_targets_values[list(constants.assoc_tuple_values)]
drugtarget_associations_df.to_csv(f'{constants.OUTPUT_FOLDER}/prev_ttd_associations.csv', index=None)

# %% [markdown]
# #### **Format DrugCentral data**

# %%
drug_diseases = pd.read_csv('prev/drug_to_disease_final_v2_ELA.csv')
drug_diseases
# Out:
#     Unnamed: 0  DRUG_ID        DRUG_NAME                   DISEASES  \
# 0          975     4483      Carfilzomib    Small-cell lung cancer
# 1         2389     4225         Axitinib      Renal cell carcinoma
# 2         2871     5431     Tirbanibulin           Prostate cancer
# 3         6582      789    Decamethonium              Muscle spasm
# 4         9416      661    Cisatracurium              Muscle spasm
# 5         9732      749        Cyclizine                    Nausea
# 6         9800      183       Amlodipine              Hypertension
# 7        10669      461      Cadralazine              Hypertension
# 8        10829     2745  Trihexyphenidyl                  Dystonia
# 9        10831     2745  Trihexyphenidyl                   Obesity
# 10       11246     2774      Tropicamide                 Mydriasis
# 11       11578     1150     Fenfluramine                   Obesity
# 12       11792     1947     Nitrendipine              Hypertension
# 13       13096     1576     Levosimendan  Congestive heart failure
# 14       13097     1576     Levosimendan             Heart failure
# 15       13599      522       Carvedilol  Congestive heart failure
# 16       15202      832  Dexfenfluramine                   Obesity
# 17       16752     4099    Levamlodipine              Hypertension
# 18       18666     2396       Rocuronium              Muscle spasm
# 19       18743     4119       Romidepsin      Renal cell carcinoma
# 20       19257      926     Disopyramide   Ventricular arrhythmias
# 21       19258      926     Disopyramide      Urinary incontinence
# 22       20326     5345      Entrectinib             Neuroblastoma
# 23       21224     4157    Lercanidipine              Hypertension
# 24       22897     1942      Nisoldipine              Hypertension
# 25       24230      901   Dimenhydrinate                    Nausea
# 26       25358      231        Aprindine       Cardiac arrhythmias
# 27       25448     1797       Mibefradil   Glioblastoma multiforme
# 28       25467      522       Carvedilol  Congestive heart failure
# 29       25482      313       Diphenidol                    Nausea
# 30       25591     1142       Felodipine              Hypertension
#
#                      PHASE                      Name  \
# 0                Phase 1/2    small cell lung cancer
# 1                 Approved      renal cell carcinoma
# 2                  Phase 2           prostate cancer
# 3                 Approved              muscle spasm
# 4                 Approved              muscle spasm
# 5                 Approved                    nausea
# 6                 Approved              hypertension
# 7                 Approved              hypertension
# 8                 Approved                  dystonia
# 9            Investigative                   obesity
# 10                Approved                 mydriasis
# 11   Withdrawn from market                   obesity
# 12                Approved              hypertension
# 13                Approved  congestive heart failure
# 14                 Phase 4             heart failure
# 15                Approved  congestive heart failure
# 16   Withdrawn from market                   obesity
# 17                 Phase 4              hypertension
# 18                Approved              muscle spasm
# 19                 Phase 3      renal cell carcinoma
# 20                Approved   ventricular arrhythmias
# 21   Withdrawn from market      urinary incontinence
# 22                 Phase 1             neuroblastoma
# 23                Approved              hypertension
# 24                Approved              hypertension
# 25                Approved                    nausea
# 26                Approved       cardiac arrhythmias
# 27                 Phase 1   glioblastoma multiforme
# 28                Approved  congestive heart failure
# 29                Approved                    nausea
# 30                Approved              hypertension
#
#              ontologyTermName                            ontologyTermIRI  \
# 0   Small cell lung carcinoma  http://purl.obolibrary.org/obo/HP_0030357
# 1        Renal cell carcinoma  http://purl.obolibrary.org/obo/HP_0005584
# 2             Prostate cancer  http://purl.obolibrary.org/obo/HP_0012125
# 3      Hyperkinetic movements  http://purl.obolibrary.org/obo/HP_0002487
# 4      Hyperkinetic movements  http://purl.obolibrary.org/obo/HP_0002487
# 5                      Nausea  http://purl.obolibrary.org/obo/HP_0002018
# 6                Hypertension  http://purl.obolibrary.org/obo/HP_0000822
# 7                Hypertension  http://purl.obolibrary.org/obo/HP_0000822
# 8                    Dystonia  http://purl.obolibrary.org/obo/HP_0001332
# 9                     Obesity  http://purl.obolibrary.org/obo/HP_0001513
# 10                  Mydriasis  http://purl.obolibrary.org/obo/HP_0011499
# 11                    Obesity  http://purl.obolibrary.org/obo/HP_0001513
# 12               Hypertension  http://purl.obolibrary.org/obo/HP_0000822
# 13   Congestive heart failure  http://purl.obolibrary.org/obo/HP_0001635
# 14   Congestive heart failure  http://purl.obolibrary.org/obo/HP_0001635
# 15   Congestive heart failure  http://purl.obolibrary.org/obo/HP_0001635
# 16                    Obesity  http://purl.obolibrary.org/obo/HP_0001513
# 17               Hypertension  http://purl.obolibrary.org/obo/HP_0000822
# 18     Hyperkinetic movements  http://purl.obolibrary.org/obo/HP_0002487
# 19       Renal cell carcinoma  http://purl.obolibrary.org/obo/HP_0005584
# 20     Ventricular arrhythmia  http://purl.obolibrary.org/obo/HP_0004308
# 21       Urinary incontinence  http://purl.obolibrary.org/obo/HP_0000020
# 22              Neuroblastoma  http://purl.obolibrary.org/obo/HP_0003006
# 23               Hypertension  http://purl.obolibrary.org/obo/HP_0000822
# 24               Hypertension  http://purl.obolibrary.org/obo/HP_0000822
# 25                     Nausea  http://purl.obolibrary.org/obo/HP_0002018
# 26                 Arrhythmia  http://purl.obolibrary.org/obo/HP_0011675
# 27    Glioblastoma multiforme  http://purl.obolibrary.org/obo/HP_0012174
# 28   Congestive heart failure  http://purl.obolibrary.org/obo/HP_0001635
# 29                     Nausea  http://purl.obolibrary.org/obo/HP_0002018
# 30               Hypertension  http://purl.obolibrary.org/obo/HP_0000822
#
#     validated  review          ID
# 0       False   False  HP:0030357
# 1       False   False  HP:0005584
# 2       False   False  HP:0012125
# 3       False   False  HP:0002487
# 4       False   False  HP:0002487
# 5       False   False  HP:0002018
# 6       False   False  HP:0000822
# 7       False   False  HP:0000822
# 8       False   False  HP:0001332
# 9       False   False  HP:0001513
# 10      False   False  HP:0011499
# 11      False   False  HP:0001513
# 12      False   False  HP:0000822
# 13      False   False  HP:0001635
# 14      False   False  HP:0001635
# 15      False   False  HP:0001635
# 16      False   False  HP:0001513
# 17      False   False  HP:0000822
# 18      False   False  HP:0002487
# 19      False   False  HP:0005584
# 20      False   False  HP:0004308
# 21      False   False  HP:0000020
# 22      False   False  HP:0003006
# 23      False   False  HP:0000822
# 24      False   False  HP:0000822
# 25      False   False  HP:0002018
# 26      False   False  HP:0011675
# 27      False   False  HP:0012174
# 28      False   False  HP:0001635
# 29      False   False  HP:0002018
# 30      False   False  HP:0000822

# %%
drug_diseases_values = drug_diseases.copy()[['DRUG_ID', 'ID']]
drug_diseases_values
# Out:
#     DRUG_ID          ID
# 0      4483  HP:0030357
# 1      4225  HP:0005584
# 2      5431  HP:0012125
# 3       789  HP:0002487
# 4       661  HP:0002487
# 5       749  HP:0002018
# 6       183  HP:0000822
# 7       461  HP:0000822
# 8      2745  HP:0001332
# 9      2745  HP:0001513
# 10     2774  HP:0011499
# 11     1150  HP:0001513
# 12     1947  HP:0000822
# 13     1576  HP:0001635
# 14     1576  HP:0001635
# 15      522  HP:0001635
# 16      832  HP:0001513
# 17     4099  HP:0000822
# 18     2396  HP:0002487
# 19     4119  HP:0005584
# 20      926  HP:0004308
# 21      926  HP:0000020
# 22     5345  HP:0003006
# 23     4157  HP:0000822
# 24     1942  HP:0000822
# 25      901  HP:0002018
# 26      231  HP:0011675
# 27     1797  HP:0012174
# 28      522  HP:0001635
# 29      313  HP:0002018
# 30     1142  HP:0000822

# %%
for i, row in drug_diseases_values.iterrows():
    drug_diseases_values.loc[i,'id'] = f'DC{i}'
    
    drug_diseases_values.loc[i,'subject_id'] = row['DRUG_ID']
    drug_diseases_values.loc[i,'subject_label'] = np.nan
    drug_diseases_values.loc[i,'subject_iri'] = np.nan
    drug_diseases_values.loc[i,'subject_category'] = 'DRUG'
    drug_diseases_values.loc[i,'subject_taxon_id'] = np.nan
    drug_diseases_values.loc[i,'subject_taxon_label'] = np.nan
    
    drug_diseases_values.loc[i,'object_id'] = row['ID']
    drug_diseases_values.loc[i,'object_label'] = np.nan
    drug_diseases_values.loc[i,'object_iri'] = np.nan
    drug_diseases_values.loc[i,'object_category'] = np.nan
    drug_diseases_values.loc[i,'object_taxon_id'] = np.nan
    drug_diseases_values.loc[i,'object_taxon_label'] = np.nan
    
    drug_diseases_values.loc[i,'relation_id'] = 'CustomRO:DC'
    drug_diseases_values.loc[i,'relation_label'] = 'is substance that treats'
    drug_diseases_values.loc[i,'relation_iri'] = np.nan

# %%
drug_diseases_values
# Out:
#     DRUG_ID          ID    id  subject_id  subject_label  subject_iri  \
# 0      4483  HP:0030357   DC0      4483.0            NaN          NaN
# 1      4225  HP:0005584   DC1      4225.0            NaN          NaN
# 2      5431  HP:0012125   DC2      5431.0            NaN          NaN
# 3       789  HP:0002487   DC3       789.0            NaN          NaN
# 4       661  HP:0002487   DC4       661.0            NaN          NaN
# 5       749  HP:0002018   DC5       749.0            NaN          NaN
# 6       183  HP:0000822   DC6       183.0            NaN          NaN
# 7       461  HP:0000822   DC7       461.0            NaN          NaN
# 8      2745  HP:0001332   DC8      2745.0            NaN          NaN
# 9      2745  HP:0001513   DC9      2745.0            NaN          NaN
# 10     2774  HP:0011499  DC10      2774.0            NaN          NaN
# 11     1150  HP:0001513  DC11      1150.0            NaN          NaN
# 12     1947  HP:0000822  DC12      1947.0            NaN          NaN
# 13     1576  HP:0001635  DC13      1576.0            NaN          NaN
# 14     1576  HP:0001635  DC14      1576.0            NaN          NaN
# 15      522  HP:0001635  DC15       522.0            NaN          NaN
# 16      832  HP:0001513  DC16       832.0            NaN          NaN
# 17     4099  HP:0000822  DC17      4099.0            NaN          NaN
# 18     2396  HP:0002487  DC18      2396.0            NaN          NaN
# 19     4119  HP:0005584  DC19      4119.0            NaN          NaN
# 20      926  HP:0004308  DC20       926.0            NaN          NaN
# 21      926  HP:0000020  DC21       926.0            NaN          NaN
# 22     5345  HP:0003006  DC22      5345.0            NaN          NaN
# 23     4157  HP:0000822  DC23      4157.0            NaN          NaN
# 24     1942  HP:0000822  DC24      1942.0            NaN          NaN
# 25      901  HP:0002018  DC25       901.0            NaN          NaN
# 26      231  HP:0011675  DC26       231.0            NaN          NaN
# 27     1797  HP:0012174  DC27      1797.0            NaN          NaN
# 28      522  HP:0001635  DC28       522.0            NaN          NaN
# 29      313  HP:0002018  DC29       313.0            NaN          NaN
# 30     1142  HP:0000822  DC30      1142.0            NaN          NaN
#
#    subject_category  subject_taxon_id  subject_taxon_label   object_id  \
# 0              DRUG               NaN                  NaN  HP:0030357
# 1              DRUG               NaN                  NaN  HP:0005584
# 2              DRUG               NaN                  NaN  HP:0012125
# 3              DRUG               NaN                  NaN  HP:0002487
# 4              DRUG               NaN                  NaN  HP:0002487
# 5              DRUG               NaN                  NaN  HP:0002018
# 6              DRUG               NaN                  NaN  HP:0000822
# 7              DRUG               NaN                  NaN  HP:0000822
# 8              DRUG               NaN                  NaN  HP:0001332
# 9              DRUG               NaN                  NaN  HP:0001513
# 10             DRUG               NaN                  NaN  HP:0011499
# 11             DRUG               NaN                  NaN  HP:0001513
# 12             DRUG               NaN                  NaN  HP:0000822
# 13             DRUG               NaN                  NaN  HP:0001635
# 14             DRUG               NaN                  NaN  HP:0001635
# 15             DRUG               NaN                  NaN  HP:0001635
# 16             DRUG               NaN                  NaN  HP:0001513
# 17             DRUG               NaN                  NaN  HP:0000822
# 18             DRUG               NaN                  NaN  HP:0002487
# 19             DRUG               NaN                  NaN  HP:0005584
# 20             DRUG               NaN                  NaN  HP:0004308
# 21             DRUG               NaN                  NaN  HP:0000020
# 22             DRUG               NaN                  NaN  HP:0003006
# 23             DRUG               NaN                  NaN  HP:0000822
# 24             DRUG               NaN                  NaN  HP:0000822
# 25             DRUG               NaN                  NaN  HP:0002018
# 26             DRUG               NaN                  NaN  HP:0011675
# 27             DRUG               NaN                  NaN  HP:0012174
# 28             DRUG               NaN                  NaN  HP:0001635
# 29             DRUG               NaN                  NaN  HP:0002018
# 30             DRUG               NaN                  NaN  HP:0000822
#
#     object_label  object_iri  object_category  object_taxon_id  \
# 0            NaN         NaN              NaN              NaN
# 1            NaN         NaN              NaN              NaN
# 2            NaN         NaN              NaN              NaN
# 3            NaN         NaN              NaN              NaN
# 4            NaN         NaN              NaN              NaN
# 5            NaN         NaN              NaN              NaN
# 6            NaN         NaN              NaN              NaN
# 7            NaN         NaN              NaN              NaN
# 8            NaN         NaN              NaN              NaN
# 9            NaN         NaN              NaN              NaN
# 10           NaN         NaN              NaN              NaN
# 11           NaN         NaN              NaN              NaN
# 12           NaN         NaN              NaN              NaN
# 13           NaN         NaN              NaN              NaN
# 14           NaN         NaN              NaN              NaN
# 15           NaN         NaN              NaN              NaN
# 16           NaN         NaN              NaN              NaN
# 17           NaN         NaN              NaN              NaN
# 18           NaN         NaN              NaN              NaN
# 19           NaN         NaN              NaN              NaN
# 20           NaN         NaN              NaN              NaN
# 21           NaN         NaN              NaN              NaN
# 22           NaN         NaN              NaN              NaN
# 23           NaN         NaN              NaN              NaN
# 24           NaN         NaN              NaN              NaN
# 25           NaN         NaN              NaN              NaN
# 26           NaN         NaN              NaN              NaN
# 27           NaN         NaN              NaN              NaN
# 28           NaN         NaN              NaN              NaN
# 29           NaN         NaN              NaN              NaN
# 30           NaN         NaN              NaN              NaN
#
#     object_taxon_label  relation_id            relation_label  relation_iri
# 0                  NaN  CustomRO:DC  is substance that treats           NaN
# 1                  NaN  CustomRO:DC  is substance that treats           NaN
# 2                  NaN  CustomRO:DC  is substance that treats           NaN
# 3                  NaN  CustomRO:DC  is substance that treats           NaN
# 4                  NaN  CustomRO:DC  is substance that treats           NaN
# 5                  NaN  CustomRO:DC  is substance that treats           NaN
# 6                  NaN  CustomRO:DC  is substance that treats           NaN
# 7                  NaN  CustomRO:DC  is substance that treats           NaN
# 8                  NaN  CustomRO:DC  is substance that treats           NaN
# 9                  NaN  CustomRO:DC  is substance that treats           NaN
# 10                 NaN  CustomRO:DC  is substance that treats           NaN
# 11                 NaN  CustomRO:DC  is substance that treats           NaN
# 12                 NaN  CustomRO:DC  is substance that treats           NaN
# 13                 NaN  CustomRO:DC  is substance that treats           NaN
# 14                 NaN  CustomRO:DC  is substance that treats           NaN
# 15                 NaN  CustomRO:DC  is substance that treats           NaN
# 16                 NaN  CustomRO:DC  is substance that treats           NaN
# 17                 NaN  CustomRO:DC  is substance that treats           NaN
# 18                 NaN  CustomRO:DC  is substance that treats           NaN
# 19                 NaN  CustomRO:DC  is substance that treats           NaN
# 20                 NaN  CustomRO:DC  is substance that treats           NaN
# 21                 NaN  CustomRO:DC  is substance that treats           NaN
# 22                 NaN  CustomRO:DC  is substance that treats           NaN
# 23                 NaN  CustomRO:DC  is substance that treats           NaN
# 24                 NaN  CustomRO:DC  is substance that treats           NaN
# 25                 NaN  CustomRO:DC  is substance that treats           NaN
# 26                 NaN  CustomRO:DC  is substance that treats           NaN
# 27                 NaN  CustomRO:DC  is substance that treats           NaN
# 28                 NaN  CustomRO:DC  is substance that treats           NaN
# 29                 NaN  CustomRO:DC  is substance that treats           NaN
# 30                 NaN  CustomRO:DC  is substance that treats           NaN

# %%
drugdiseases_associations_df = drug_diseases_values[list(constants.assoc_tuple_values)]
drugdiseases_associations_df.to_csv(f'{constants.OUTPUT_FOLDER}/prev_drugcentral_associations.csv', index=None)
