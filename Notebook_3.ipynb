# %% [markdown]
# Merge all fetched datasets originating from Monarch Initiative, TTD and DrugCentral.
#
# Adapted by Rosa Zwart from Jupyter Notebooks found at https://github.com/PPerdomoQ/rare-disease-explainer

# %%
import pandas as pd
import numpy as np

import util.constants as constants
import util.common as common

# %%
PREFIX_DATASET = 'hd'

# %% [markdown]
# #### **Format TTD data**

# %% [markdown]
# Save a list of all associations between DRUG and GENE in a csv file.

# %%
drug_targets = pd.read_csv('prev/drug.target.final.ELA.csv')
drug_targets
# Out:
#                   DRUG_NAME  STRUCT_ID  \
# 0                 adenosine         90
# 1    adenosine triphosphate         91
# 2    adenosine triphosphate         91
# 3                alfentanil        114
# 4                 alvimopan        143
# ..                      ...        ...
# 311             selumetinib       5388
# 312               tucatinib       5389
# 313             oliceridine       5406
# 314             trilaciclib       5442
# 315             samidorphan       5460
#
#                                         TARGET_NAME  TARGET_CLASS ACCESSION  \
# 0    Glyceraldehyde-3-phosphate dehydrogenase liver        Enzyme    P04406
# 1                 Heat shock cognate 71 kDa protein  Unclassified    P11142
# 2                      Heat shock 70 kDa protein 1A  Unclassified    P0DMV8
# 3                           Mu-type opioid receptor          GPCR    P35372
# 4                           Mu-type opioid receptor          GPCR    P35372
# ..                                              ...           ...       ...
# 311                Epidermal growth factor receptor        Kinase    P00533
# 312                Epidermal growth factor receptor        Kinase    P00533
# 313                         Mu-type opioid receptor          GPCR    P35372
# 314                  Cyclin-dependent-like kinase 5        Kinase    Q00535
# 315                         Mu-type opioid receptor          GPCR    P35372
#
#        GENE    SWISSPROT  ACT_VALUE  ACT_UNIT ACT_TYPE  ...  ACT_SOURCE  \
# 0     GAPDH    G3P_HUMAN      4.460       NaN     IC50  ...      CHEMBL
# 1     HSPA8  HSP7C_HUMAN      4.760       NaN     IC50  ...      CHEMBL
# 2    HSPA1A  HS71A_HUMAN      5.470       NaN     IC50  ...      CHEMBL
# 3     OPRM1   OPRM_HUMAN      8.500       NaN     EC50  ...   WOMBAT-PK
# 4     OPRM1   OPRM_HUMAN      9.398       NaN       Ki  ...   WOMBAT-PK
# ..      ...          ...        ...       ...      ...  ...         ...
# 311    EGFR   EGFR_HUMAN      5.660       NaN       Kd  ...      CHEMBL
# 312    EGFR   EGFR_HUMAN      6.350       NaN     IC50  ...      IUPHAR
# 313   OPRM1   OPRM_HUMAN      8.220       NaN       Ki  ...  DRUG LABEL
# 314    CDK5   CDK5_HUMAN      5.830       NaN     IC50  ...  DRUG LABEL
# 315   OPRM1   OPRM_HUMAN     10.280       NaN       Ki  ...  DRUG LABEL
#
#     RELATION  MOA  MOA_SOURCE  \
# 0          =  NaN         NaN
# 1          =  NaN         NaN
# 2          =  NaN         NaN
# 3          =  1.0      CHEMBL
# 4          =  1.0      CHEMBL
# ..       ...  ...         ...
# 311        =  NaN         NaN
# 312        =  NaN         NaN
# 313        =  1.0  DRUG LABEL
# 314        =  NaN         NaN
# 315        =  NaN         NaN
#
#                                         ACT_SOURCE_URL  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 311                                                NaN
# 312                                                NaN
# 313  https://www.accessdata.fda.gov/drugsatfda_docs...
# 314  https://www.accessdata.fda.gov/drugsatfda_docs...
# 315  https://www.accessdata.fda.gov/drugsatfda_docs...
#
#                                         MOA_SOURCE_URL ACTION_TYPE    TDL  \
# 0                                                  NaN         NaN  Tchem
# 1                                                  NaN         NaN  Tchem
# 2                                                  NaN         NaN  Tchem
# 3    https://www.ebi.ac.uk/chembl/compound/inspect/...     AGONIST  Tclin
# 4    https://www.ebi.ac.uk/chembl/compound/inspect/...  ANTAGONIST  Tclin
# ..                                                 ...         ...    ...
# 311                                                NaN         NaN  Tclin
# 312                                                NaN   INHIBITOR  Tclin
# 313  https://www.accessdata.fda.gov/drugsatfda_docs...     AGONIST  Tclin
# 314                                                NaN   INHIBITOR  Tchem
# 315                                                NaN  ANTAGONIST  Tclin
#
#          ORGANISM     NEW_ID
# 0    Homo sapiens  HGNC:4141
# 1    Homo sapiens  HGNC:5241
# 2    Homo sapiens  HGNC:5232
# 3    Homo sapiens  HGNC:8156
# 4    Homo sapiens  HGNC:8156
# ..            ...        ...
# 311  Homo sapiens  HGNC:3236
# 312  Homo sapiens  HGNC:3236
# 313  Homo sapiens  HGNC:8156
# 314  Homo sapiens  HGNC:1774
# 315  Homo sapiens  HGNC:8156
#
# [316 rows x 21 columns]

# %% [markdown]
# Get columns that are relevant.

# %%
drug_targets_values = drug_targets.copy()[['STRUCT_ID', 'DRUG_NAME', 'NEW_ID']]
drug_targets_values
# Out:
#      STRUCT_ID               DRUG_NAME     NEW_ID
# 0           90               adenosine  HGNC:4141
# 1           91  adenosine triphosphate  HGNC:5241
# 2           91  adenosine triphosphate  HGNC:5232
# 3          114              alfentanil  HGNC:8156
# 4          143               alvimopan  HGNC:8156
# ..         ...                     ...        ...
# 311       5388             selumetinib  HGNC:3236
# 312       5389               tucatinib  HGNC:3236
# 313       5406             oliceridine  HGNC:8156
# 314       5442             trilaciclib  HGNC:1774
# 315       5460             samidorphan  HGNC:8156
#
# [316 rows x 3 columns]

# %%
drug_targets_values.drop_duplicates(inplace=True)
drug_targets_values.shape[0]
# Out:
# 305

# %% [markdown]
# Add new columns that are needed to be included in the dataframe.

# %%
dict_list = []

for i, row in drug_targets_values.iterrows():
    tuple_dict = {
        'id': f'TTD{i}',
        'subject_id': str(row['STRUCT_ID']),
        'subject_label': row['DRUG_NAME'],
        'subject_iri': np.nan,
        'subject_category': 'DRUG',
        'subject_taxon_id': np.nan,
        'subject_taxon_label': np.nan,
        'object_id': row['NEW_ID'],
        'object_label': np.nan,
        'object_iri': np.nan,
        'object_category': np.nan,
        'object_taxon_id': np.nan,
        'object_taxon_label': np.nan,
        'relation_id': 'CustomRO:TTD',
        'relation_label': 'targets',
        'relation_iri': np.nan
    }

    dict_list.append(tuple_dict)

drugtarget_associations_df = pd.DataFrame.from_dict(dict_list)

# %%
drugtarget_associations_df
# Out:
#          id subject_id           subject_label  subject_iri subject_category  \
# 0      TTD0         90               adenosine          NaN             DRUG
# 1      TTD1         91  adenosine triphosphate          NaN             DRUG
# 2      TTD2         91  adenosine triphosphate          NaN             DRUG
# 3      TTD3        114              alfentanil          NaN             DRUG
# 4      TTD4        143               alvimopan          NaN             DRUG
# ..      ...        ...                     ...          ...              ...
# 300  TTD311       5388             selumetinib          NaN             DRUG
# 301  TTD312       5389               tucatinib          NaN             DRUG
# 302  TTD313       5406             oliceridine          NaN             DRUG
# 303  TTD314       5442             trilaciclib          NaN             DRUG
# 304  TTD315       5460             samidorphan          NaN             DRUG
#
#      subject_taxon_id  subject_taxon_label  object_id  object_label  \
# 0                 NaN                  NaN  HGNC:4141           NaN
# 1                 NaN                  NaN  HGNC:5241           NaN
# 2                 NaN                  NaN  HGNC:5232           NaN
# 3                 NaN                  NaN  HGNC:8156           NaN
# 4                 NaN                  NaN  HGNC:8156           NaN
# ..                ...                  ...        ...           ...
# 300               NaN                  NaN  HGNC:3236           NaN
# 301               NaN                  NaN  HGNC:3236           NaN
# 302               NaN                  NaN  HGNC:8156           NaN
# 303               NaN                  NaN  HGNC:1774           NaN
# 304               NaN                  NaN  HGNC:8156           NaN
#
#      object_iri  object_category  object_taxon_id  object_taxon_label  \
# 0           NaN              NaN              NaN                 NaN
# 1           NaN              NaN              NaN                 NaN
# 2           NaN              NaN              NaN                 NaN
# 3           NaN              NaN              NaN                 NaN
# 4           NaN              NaN              NaN                 NaN
# ..          ...              ...              ...                 ...
# 300         NaN              NaN              NaN                 NaN
# 301         NaN              NaN              NaN                 NaN
# 302         NaN              NaN              NaN                 NaN
# 303         NaN              NaN              NaN                 NaN
# 304         NaN              NaN              NaN                 NaN
#
#       relation_id relation_label  relation_iri
# 0    CustomRO:TTD        targets           NaN
# 1    CustomRO:TTD        targets           NaN
# 2    CustomRO:TTD        targets           NaN
# 3    CustomRO:TTD        targets           NaN
# 4    CustomRO:TTD        targets           NaN
# ..            ...            ...           ...
# 300  CustomRO:TTD        targets           NaN
# 301  CustomRO:TTD        targets           NaN
# 302  CustomRO:TTD        targets           NaN
# 303  CustomRO:TTD        targets           NaN
# 304  CustomRO:TTD        targets           NaN
#
# [305 rows x 16 columns]

# %%
drugtarget_associations_df.to_csv(f'{constants.OUTPUT_FOLDER}/prev_{PREFIX_DATASET}_ttd_associations_{common.today}.csv', index=None)

# %% [markdown]
# #### **Format DrugCentral data**

# %%
drug_diseases = pd.read_csv('prev/drug_to_disease_final_v2_ELA.csv')
drug_diseases
# Out:
#     Unnamed: 0  DRUG_ID               DRUG_NAME  \
# 0          492     2172                Pimozide
# 1         1301       91  Adenosine triphosphate
# 2         1302       91  Adenosine triphosphate
# 3         2262     2351              Raloxifene
# 4         2281     1990              Omeprazole
# 5         2356      621          Chlorpromazine
# 6         3652      725                 Codeine
# 7         4664      578               Cerulenin
# 8         5972     1200             Flunarizine
# 9         6768     1989             Omapatrilat
# 10        7027      434           Buprenorphine
# 11        7028      434           Buprenorphine
# 12       12007     1353             Haloperidol
# 13       12748     1762              Methyldopa
# 14       13453     2080             Penfluridol
# 15       13486     1599              Loperamide
# 16       13499      700               Clomifene
# 17       13579     1353             Haloperidol
# 18       13599      522              Carvedilol
# 19       13953     5382          Bempedoic acid
# 20       17354      918           Diphenoxylate
# 21       17406     2370               Reserpine
# 22       17544      937              Dobutamine
# 23       18177     3514               Quercetin
# 24       18485     2817             VESNARINONE
# 25       20430     4778           Ridaforolimus
# 26       21288     2123              Phenelzine
# 27       23208     1599              Loperamide
# 28       23377     2286            Promethazine
# 29       23394     1574             Levorphanol
# 30       23558     2054            Pantoprazole
# 31       23674     1996                Orlistat
# 32       23916     2637            Thioridazine
# 33       24093     4392               Cisplatin
# 34       24723      621          Chlorpromazine
# 35       25467      522              Carvedilol
# 36       25825     1878                Naloxone
# 37       25826     1878                Naloxone
# 38       26992      722               Clozapine
#
#                             DISEASES                     PHASE  \
# 0                     Schizophrenia                   Approved
# 1                     Heart disease                    Phase 2
# 2                       Bradycardia    Discontinued in Phase 2
# 3                      Osteoporosis                   Approved
# 4   Gastroesophageal reflux disease                   Approved
# 5                     Schizophrenia                   Approved
# 6                             Cough                    Phase 1
# 7                       Weight loss                   Approved
# 8                          Migraine                   Approved
# 9                      Hypertension                 Terminated
# 10             Psychiatric disorder                    Phase 3
# 11                         Migraine                    Phase 2
# 12                    Schizophrenia                   Approved
# 13                     Hypertension                   Approved
# 14                    Schizophrenia                   Approved
# 15                         Diarrhea                   Approved
# 16               Female infertility                   Approved
# 17                    Schizophrenia                   Approved
# 18         Congestive heart failure                   Approved
# 19    Familial hypercholesterolemia                   Approved
# 20                         Diarrhea                   Approved
# 21                     Hypertension                   Approved
# 22                    Heart failure                   Approved
# 23                          Obesity                   Approved
# 24                  Cardiac failure                   Approved
# 25                          Sarcoma                    Phase 3
# 26                       Depression                   Approved
# 27                         Diarrhea                   Approved
# 28                           Nausea                   Approved
# 29                  Ischemic stroke                 Terminated
# 30  Gastroesophageal reflux disease                   Approved
# 31                          Obesity                   Approved
# 32                    Schizophrenia                   Approved
# 33                     Osteosarcoma                    Phase 2
# 34                    Schizophrenia      Withdrawn from market
# 35         Congestive heart failure                   Approved
# 36           Respiratory depression                    Phase 3
# 37                         Pruritus                    Phase 3
# 38                    Schizophrenia                   Approved
#
#                                Name          ontologyTermName  \
# 0                     schizophrenia             Schizophrenia
# 1                     heart disease            Cardiomyopathy
# 2                       bradycardia               Bradycardia
# 3                      osteoporosis              Osteoporosis
# 4   gastroesophageal reflux disease   Gastroesophageal reflux
# 5                     schizophrenia             Schizophrenia
# 6                             cough                     Cough
# 7                       weight loss               Weight loss
# 8                          migraine                  Migraine
# 9                      hypertension              Hypertension
# 10             psychiatric disorder    Behavioral abnormality
# 11                         migraine                  Migraine
# 12                    schizophrenia             Schizophrenia
# 13                     hypertension              Hypertension
# 14                    schizophrenia             Schizophrenia
# 15                         diarrhea                  Diarrhea
# 16               female infertility        Female infertility
# 17                    schizophrenia             Schizophrenia
# 18         congestive heart failure  Congestive heart failure
# 19    familial hypercholesterolemia      Hypercholesterolemia
# 20                         diarrhea                  Diarrhea
# 21                     hypertension              Hypertension
# 22                    heart failure  Congestive heart failure
# 23                          obesity                   Obesity
# 24                  cardiac failure  Congestive heart failure
# 25                          sarcoma                   Sarcoma
# 26                       depression              Depressivity
# 27                         diarrhea                  Diarrhea
# 28                           nausea                    Nausea
# 29                  ischemic stroke           Ischemic stroke
# 30  gastroesophageal reflux disease   Gastroesophageal reflux
# 31                          obesity                   Obesity
# 32                    schizophrenia             Schizophrenia
# 33                     osteosarcoma              Osteosarcoma
# 34                    schizophrenia             Schizophrenia
# 35         congestive heart failure  Congestive heart failure
# 36           respiratory depression      Respiratory distress
# 37                         pruritus                  Pruritus
# 38                    schizophrenia             Schizophrenia
#
#                               ontologyTermIRI  validated  review          ID
# 0   http://purl.obolibrary.org/obo/HP_0100753      False   False  HP:0100753
# 1   http://purl.obolibrary.org/obo/HP_0001638      False   False  HP:0001638
# 2   http://purl.obolibrary.org/obo/HP_0001662      False   False  HP:0001662
# 3   http://purl.obolibrary.org/obo/HP_0000939      False   False  HP:0000939
# 4   http://purl.obolibrary.org/obo/HP_0002020      False   False  HP:0002020
# 5   http://purl.obolibrary.org/obo/HP_0100753      False   False  HP:0100753
# 6   http://purl.obolibrary.org/obo/HP_0012735      False   False  HP:0012735
# 7   http://purl.obolibrary.org/obo/HP_0001824      False   False  HP:0001824
# 8   http://purl.obolibrary.org/obo/HP_0002076      False   False  HP:0002076
# 9   http://purl.obolibrary.org/obo/HP_0000822      False   False  HP:0000822
# 10  http://purl.obolibrary.org/obo/HP_0000708      False   False  HP:0000708
# 11  http://purl.obolibrary.org/obo/HP_0002076      False   False  HP:0002076
# 12  http://purl.obolibrary.org/obo/HP_0100753      False   False  HP:0100753
# 13  http://purl.obolibrary.org/obo/HP_0000822      False   False  HP:0000822
# 14  http://purl.obolibrary.org/obo/HP_0100753      False   False  HP:0100753
# 15  http://purl.obolibrary.org/obo/HP_0002014      False   False  HP:0002014
# 16  http://purl.obolibrary.org/obo/HP_0008222      False   False  HP:0008222
# 17  http://purl.obolibrary.org/obo/HP_0100753      False   False  HP:0100753
# 18  http://purl.obolibrary.org/obo/HP_0001635      False   False  HP:0001635
# 19  http://purl.obolibrary.org/obo/HP_0003124      False   False  HP:0003124
# 20  http://purl.obolibrary.org/obo/HP_0002014      False   False  HP:0002014
# 21  http://purl.obolibrary.org/obo/HP_0000822      False   False  HP:0000822
# 22  http://purl.obolibrary.org/obo/HP_0001635      False   False  HP:0001635
# 23  http://purl.obolibrary.org/obo/HP_0001513      False   False  HP:0001513
# 24  http://purl.obolibrary.org/obo/HP_0001635      False   False  HP:0001635
# 25  http://purl.obolibrary.org/obo/HP_0100242      False   False  HP:0100242
# 26  http://purl.obolibrary.org/obo/HP_0000716      False   False  HP:0000716
# 27  http://purl.obolibrary.org/obo/HP_0002014      False   False  HP:0002014
# 28  http://purl.obolibrary.org/obo/HP_0002018      False   False  HP:0002018
# 29  http://purl.obolibrary.org/obo/HP_0002140      False   False  HP:0002140
# 30  http://purl.obolibrary.org/obo/HP_0002020      False   False  HP:0002020
# 31  http://purl.obolibrary.org/obo/HP_0001513      False   False  HP:0001513
# 32  http://purl.obolibrary.org/obo/HP_0100753      False   False  HP:0100753
# 33  http://purl.obolibrary.org/obo/HP_0002669      False   False  HP:0002669
# 34  http://purl.obolibrary.org/obo/HP_0100753      False   False  HP:0100753
# 35  http://purl.obolibrary.org/obo/HP_0001635      False   False  HP:0001635
# 36  http://purl.obolibrary.org/obo/HP_0002098      False   False  HP:0002098
# 37  http://purl.obolibrary.org/obo/HP_0000989      False   False  HP:0000989
# 38  http://purl.obolibrary.org/obo/HP_0100753      False   False  HP:0100753

# %%
drug_diseases_values = drug_diseases.copy()[['DRUG_ID', 'ID']]
drug_diseases_values
# Out:
#     DRUG_ID          ID
# 0      2172  HP:0100753
# 1        91  HP:0001638
# 2        91  HP:0001662
# 3      2351  HP:0000939
# 4      1990  HP:0002020
# 5       621  HP:0100753
# 6       725  HP:0012735
# 7       578  HP:0001824
# 8      1200  HP:0002076
# 9      1989  HP:0000822
# 10      434  HP:0000708
# 11      434  HP:0002076
# 12     1353  HP:0100753
# 13     1762  HP:0000822
# 14     2080  HP:0100753
# 15     1599  HP:0002014
# 16      700  HP:0008222
# 17     1353  HP:0100753
# 18      522  HP:0001635
# 19     5382  HP:0003124
# 20      918  HP:0002014
# 21     2370  HP:0000822
# 22      937  HP:0001635
# 23     3514  HP:0001513
# 24     2817  HP:0001635
# 25     4778  HP:0100242
# 26     2123  HP:0000716
# 27     1599  HP:0002014
# 28     2286  HP:0002018
# 29     1574  HP:0002140
# 30     2054  HP:0002020
# 31     1996  HP:0001513
# 32     2637  HP:0100753
# 33     4392  HP:0002669
# 34      621  HP:0100753
# 35      522  HP:0001635
# 36     1878  HP:0002098
# 37     1878  HP:0000989
# 38      722  HP:0100753

# %%
dict_list = []

for i, row in drug_diseases_values.iterrows():
    tuple_dict = {
        'id': f'DC{i}',
        'subject_id': row['DRUG_ID'],
        'subject_label': np.nan,
        'subject_iri': np.nan,
        'subject_category': 'DRUG',
        'subject_taxon_id': np.nan,
        'subject_taxon_label': np.nan,
        'object_id': row['ID'],
        'object_label': np.nan,
        'object_iri': np.nan,
        'object_category': np.nan,
        'object_taxon_id': np.nan,
        'object_taxon_label': np.nan,
        'relation_id': 'CustomRO:DC',
        'relation_label': 'is substance that treats',
        'relation_iri': np.nan
    }

    dict_list.append(tuple_dict)

drugdiseases_associations_df = pd.DataFrame.from_dict(dict_list)

# %%
drugdiseases_associations_df.head(10)
# Out:
#     id  subject_id  subject_label  subject_iri subject_category  \
# 0  DC0        2172            NaN          NaN             DRUG
# 1  DC1          91            NaN          NaN             DRUG
# 2  DC2          91            NaN          NaN             DRUG
# 3  DC3        2351            NaN          NaN             DRUG
# 4  DC4        1990            NaN          NaN             DRUG
# 5  DC5         621            NaN          NaN             DRUG
# 6  DC6         725            NaN          NaN             DRUG
# 7  DC7         578            NaN          NaN             DRUG
# 8  DC8        1200            NaN          NaN             DRUG
# 9  DC9        1989            NaN          NaN             DRUG
#
#    subject_taxon_id  subject_taxon_label   object_id  object_label  \
# 0               NaN                  NaN  HP:0100753           NaN
# 1               NaN                  NaN  HP:0001638           NaN
# 2               NaN                  NaN  HP:0001662           NaN
# 3               NaN                  NaN  HP:0000939           NaN
# 4               NaN                  NaN  HP:0002020           NaN
# 5               NaN                  NaN  HP:0100753           NaN
# 6               NaN                  NaN  HP:0012735           NaN
# 7               NaN                  NaN  HP:0001824           NaN
# 8               NaN                  NaN  HP:0002076           NaN
# 9               NaN                  NaN  HP:0000822           NaN
#
#    object_iri  object_category  object_taxon_id  object_taxon_label  \
# 0         NaN              NaN              NaN                 NaN
# 1         NaN              NaN              NaN                 NaN
# 2         NaN              NaN              NaN                 NaN
# 3         NaN              NaN              NaN                 NaN
# 4         NaN              NaN              NaN                 NaN
# 5         NaN              NaN              NaN                 NaN
# 6         NaN              NaN              NaN                 NaN
# 7         NaN              NaN              NaN                 NaN
# 8         NaN              NaN              NaN                 NaN
# 9         NaN              NaN              NaN                 NaN
#
#    relation_id            relation_label  relation_iri
# 0  CustomRO:DC  is substance that treats           NaN
# 1  CustomRO:DC  is substance that treats           NaN
# 2  CustomRO:DC  is substance that treats           NaN
# 3  CustomRO:DC  is substance that treats           NaN
# 4  CustomRO:DC  is substance that treats           NaN
# 5  CustomRO:DC  is substance that treats           NaN
# 6  CustomRO:DC  is substance that treats           NaN
# 7  CustomRO:DC  is substance that treats           NaN
# 8  CustomRO:DC  is substance that treats           NaN
# 9  CustomRO:DC  is substance that treats           NaN

# %%
drugdiseases_associations_df.to_csv(f'{constants.OUTPUT_FOLDER}/prev_{PREFIX_DATASET}_drugcentral_associations_{common.today}.csv', index=None)
