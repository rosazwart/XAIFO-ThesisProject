# %%
import pandas as pd
import networkx as nx
import pickle
import copy

from gensim.models import KeyedVectors

import torch
import torch.nn as nn
import torch.nn.functional as F

from deepsnap.graph import Graph

from torch_geometric.nn import SAGEConv
from torch_geometric.explain import Explainer, GNNExplainer, ModelConfig

# %%
dataset_nr = 2

# %% [markdown]
# # Load Necessary Data

# %% [markdown]
# For the node features, load the embeddings yielded from Edge2Vec.

# %%
loaded_node_embedding = KeyedVectors.load(f'output/w2v_{dataset_nr}.dvectors', mmap='r')

node_embeddings = pd.DataFrame(columns = ['Node', 'Embedding'])
for idx, key in enumerate(loaded_node_embedding.index_to_key):
    node_embeddings.loc[int(key)] = pd.Series({'Node':int(key), 'Embedding':list(loaded_node_embedding[key])})
    
node_features = node_embeddings.sort_values('Node')

node_features
# Out:
#         Node                                          Embedding
# 0          0  [0.3984332, -0.31286958, 0.5400291, 0.50470465...
# 1          1  [0.44448715, -0.21083395, 0.77053374, 0.059516...
# 2          2  [0.06366989, 0.3194347, 1.0812027, 0.20341216,...
# 3          3  [0.1271398, 0.03148787, 0.27353236, 0.39875212...
# 4          4  [0.5111069, -0.14326268, 0.4403008, 0.511082, ...
# ...      ...                                                ...
# 10270  10270  [0.14994565, 0.14421983, 0.35291353, 0.1048778...
# 10271  10271  [0.57958156, 0.07746426, 0.004016864, -0.28448...
# 10272  10272  [0.74247813, -0.6906312, 0.66188675, 0.8234299...
# 10273  10273  [-0.22202384, -0.9451154, 0.3080682, 0.2242091...
# 10274  10274  [0.27521524, -0.017406194, -0.11163712, 0.4879...
#
# [10275 rows x 2 columns]

# %% [markdown]
# For additional information of nodes, load csv file.

# %%
nodes = pd.read_csv(f'output/indexed_nodes_{dataset_nr}.csv')
nodes
# Out:
#        index_id                          id   semantic
# 0             0                  MP:0004187  phenotype  \
# 1             1                  ZP:0100138  phenotype
# 2             2                 MGI:1346525       gene
# 3             3            OMIM:300377.0044    variant
# 4             4                  ZP:0002210  phenotype
# ...         ...                         ...        ...
# 10270     10270                  ZP:0014934  phenotype
# 10271     10271  ENSEMBL:ENSCAFG00000011207       gene
# 10272     10272  ENSEMBL:ENSXETG00000039922       gene
# 10273     10273  ENSEMBL:ENSACAG00000010058       gene
# 10274     10274         WBPhenotype:0000019  phenotype
#
#                                                    label  semantic_id
# 0                                          cardia bifida            9
# 1      muscle tendon junction myotome increased amoun...            9
# 2                                                   Sgcd            5
# 3                                         DMD, LYS770TER           11
# 4      posterior lateral line neuromast primordium mi...            9
# ...                                                  ...          ...
# 10270  atrioventricular valve development process qua...            9
# 10271                         ENSEMBL:ENSCAFG00000011207            5
# 10272                         ENSEMBL:ENSXETG00000039922            5
# 10273                         ENSEMBL:ENSACAG00000010058            5
# 10274                         pharyngeal pumping reduced            9
#
# [10275 rows x 5 columns]

# %%
node_features = pd.merge(node_features, nodes,
                         left_on='Node', right_on='index_id',
                         how='inner')
node_features
# Out:
#         Node                                          Embedding  index_id
# 0          0  [0.3984332, -0.31286958, 0.5400291, 0.50470465...         0  \
# 1          1  [0.44448715, -0.21083395, 0.77053374, 0.059516...         1
# 2          2  [0.06366989, 0.3194347, 1.0812027, 0.20341216,...         2
# 3          3  [0.1271398, 0.03148787, 0.27353236, 0.39875212...         3
# 4          4  [0.5111069, -0.14326268, 0.4403008, 0.511082, ...         4
# ...      ...                                                ...       ...
# 10270  10270  [0.14994565, 0.14421983, 0.35291353, 0.1048778...     10270
# 10271  10271  [0.57958156, 0.07746426, 0.004016864, -0.28448...     10271
# 10272  10272  [0.74247813, -0.6906312, 0.66188675, 0.8234299...     10272
# 10273  10273  [-0.22202384, -0.9451154, 0.3080682, 0.2242091...     10273
# 10274  10274  [0.27521524, -0.017406194, -0.11163712, 0.4879...     10274
#
#                                id   semantic
# 0                      MP:0004187  phenotype  \
# 1                      ZP:0100138  phenotype
# 2                     MGI:1346525       gene
# 3                OMIM:300377.0044    variant
# 4                      ZP:0002210  phenotype
# ...                           ...        ...
# 10270                  ZP:0014934  phenotype
# 10271  ENSEMBL:ENSCAFG00000011207       gene
# 10272  ENSEMBL:ENSXETG00000039922       gene
# 10273  ENSEMBL:ENSACAG00000010058       gene
# 10274         WBPhenotype:0000019  phenotype
#
#                                                    label  semantic_id
# 0                                          cardia bifida            9
# 1      muscle tendon junction myotome increased amoun...            9
# 2                                                   Sgcd            5
# 3                                         DMD, LYS770TER           11
# 4      posterior lateral line neuromast primordium mi...            9
# ...                                                  ...          ...
# 10270  atrioventricular valve development process qua...            9
# 10271                         ENSEMBL:ENSCAFG00000011207            5
# 10272                         ENSEMBL:ENSXETG00000039922            5
# 10273                         ENSEMBL:ENSACAG00000010058            5
# 10274                         pharyngeal pumping reduced            9
#
# [10275 rows x 7 columns]

# %% [markdown]
# For the edges, load csv file.

# %%
edges = pd.read_csv(f'output/indexed_edges_{dataset_nr}.csv')
edges
# Out:
#                           head
# 0      WormBase:WBGene00006787  \
# 1      WormBase:WBGene00006787
# 2      WormBase:WBGene00006787
# 3      WormBase:WBGene00006787
# 4      WormBase:WBGene00006787
# ...                        ...
# 85987                      458
# 85988         OMIM:300377.0080
# 85989                     5297
# 85990    ClinVarVariant:981988
# 85991    ClinVarVariant:584105
#
#                                               label_head  class_head
# 0                                                 unc-52           5  \
# 1                                                 unc-52           5
# 2                                                 unc-52           5
# 3                                                 unc-52           5
# 4                                                 unc-52           5
# ...                                                  ...         ...
# 85987                           scopolamine butylbromide           4
# 85988                              DMD, IVS62, A-G, -285          11
# 85989                                        dacomitinib           4
# 85990  NC_000023.11:g.(31875374_31929595)_(31968515_3...          11
# 85991        NC_000023.11:g.(?_32595737)_(32699313_?)del          11
#
#        index_head                        relation                        tail
# 0             304                  interacts with     WormBase:WBGene00003929  \
# 1             304                  interacts with     WormBase:WBGene00006789
# 2             304  in orthology relationship with  ENSEMBL:ENSSSCG00000015555
# 3             304  in orthology relationship with      ZFIN:ZDB-GENE-021226-3
# 4             304  in orthology relationship with  ENSEMBL:ENSOANG00000001050
# ...           ...                             ...                         ...
# 85987        5945                         targets                      P11229
# 85988        1578                    is allele of                   HGNC:2928
# 85989        8798                         targets                      P12931
# 85990        8189            has affected feature                   HGNC:2928
# 85991        9866                causes condition               MONDO:0010679
#
#                                        label_tail  class_tail  index_tail
# 0                                           pat-2           5        1542  \
# 1                                          unc-54           5        6544
# 2                                           LAMC1           5        9268
# 3                                           lamc1           5        5387
# 4                      ENSEMBL:ENSOANG00000001050           5        2204
# ...                                           ...         ...         ...
# 85987        Muscarinic acetylcholine receptor M1           6        5919
# 85988                                         DMD           5        3310
# 85989  Proto-oncogene tyrosine-protein kinase Src           6        2379
# 85990                                         DMD           5        3310
# 85991                 Duchenne muscular dystrophy           3        1913
#
#        type
# 0         0
# 1         0
# 2         1
# 3         1
# 4         1
# ...     ...
# 85987    17
# 85988    15
# 85989    17
# 85990    11
# 85991     2
#
# [85992 rows x 10 columns]

# %% [markdown]
# Load nodes with their features and edges into graph.

# %%
G = nx.Graph()
for ind, node in node_features.iterrows(): 
    G.add_node(int(node['Node']), node_feature = torch.Tensor(node['Embedding']))
for ind, edge in edges.iterrows(): 
    G.add_edge(int(edge['index_head']), int(edge['index_tail']))
  
for node in G.nodes(data=True):
    print(node)
    break
for edge in G.edges(data=True):
    print(edge)
    break

print("Number of edges is {}".format(G.number_of_edges()))
print("Number of nodes is {}".format(G.number_of_nodes()))
# Out:
# (0, {'node_feature': tensor([ 0.3984, -0.3129,  0.5400,  0.5047,  0.3606, -0.1538, -0.4962, -0.2255,
#         -0.3281, -0.0869,  0.2944, -0.4044,  0.2928, -0.4601,  0.1927, -0.1504,
#         -0.4191, -0.1028, -0.3842,  0.1555,  0.4455,  0.3406,  0.0176, -0.4781,
#         -0.3071,  0.6394, -0.4143, -0.0489,  0.0523, -0.2817, -0.2545, -0.5112,
#         -0.1196, -0.2351,  0.3489,  0.1787,  0.1554,  0.1126,  0.6581,  0.2639,
#         -0.0216, -0.2815, -0.3214, -0.1436,  0.1828, -0.0387,  0.1260,  0.1041,
#          0.0978,  0.0397,  0.1876,  0.1959,  0.2125,  0.5915,  0.2164, -0.2079,
#         -0.3812, -0.3433, -0.0945,  0.2793, -0.4201, -0.2743, -0.4724, -0.3125])})
# (0, 8472, {})
# Number of edges is 55032
# Number of nodes is 10275

# %%
G_attributes = nx.Graph()
for ind, node in node_features.iterrows(): 
    G_attributes.add_node(int(node['Node']), node_label = node['label'], node_semantic = node['semantic'])
for ind, edge in edges.iterrows(): 
    G_attributes.add_edge(int(edge['index_head']), int(edge['index_tail']), edge_label = edge['relation'])
  
for node in G_attributes.nodes(data=True):
    print(node)
    break
for edge in G_attributes.edges(data=True):
    print(edge)
    break

print("Number of edges is {}".format(G_attributes.number_of_edges()))
print("Number of nodes is {}".format(G_attributes.number_of_nodes()))
# Out:
# (0, {'node_label': 'cardia bifida', 'node_semantic': 'phenotype'})
# (0, 8472, {'edge_label': 'causes condition'})
# Number of edges is 55032
# Number of nodes is 10275

# %%
DeepG = Graph(G)

print(DeepG.node_feature.shape)
print(DeepG.edge_index.shape)
# Out:
# torch.Size([10275, 64])
# torch.Size([2, 110064])

# %%
x = DeepG.node_feature
x
# Out:
# tensor([[ 0.3984, -0.3129,  0.5400,  ..., -0.2743, -0.4724, -0.3125],
#         [ 0.4445, -0.2108,  0.7705,  ..., -0.3755,  0.3339,  0.6621],
#         [ 0.0637,  0.3194,  1.0812,  ...,  0.1435,  0.2400,  0.2337],
#         ...,
#         [ 0.7425, -0.6906,  0.6619,  ..., -0.2799,  0.4221,  0.3836],
#         [-0.2220, -0.9451,  0.3081,  ..., -0.4940,  0.8063, -0.3299],
#         [ 0.2752, -0.0174, -0.1116,  ..., -0.2055, -0.1233,  0.1177]])

# %% [markdown]
# Load arguments and parameters of trained GNN model.

# %%
with open(f'output/best_model_{dataset_nr}_args.pkl', 'rb') as f:
    loaded_args = pickle.load(f)

# Important! Changed the forward function such that it allows input of less edges that are predicted
# and it does not return newly calculated x

class LinkPredModel(torch.nn.Module):
    """
        Architecture contains Batch Normalization layers (https://towardsdatascience.com/batch-norm-explained-visually-how-it-works-and-why-neural-networks-need-it-b18919692739) 
        between the SAGEConvolutional layers.
    """
    def __init__(self, input_size, hidden_size, out_size, num_layers, aggr, dropout, device):
        super(LinkPredModel, self).__init__()

        self.convs = torch.nn.ModuleList()
        self.bns = torch.nn.ModuleList()
        
        self.convs.append(SAGEConv(input_size, hidden_size, normalize=True, aggr=aggr)) # input node embedding features, output is size of hidden layers
        self.bns.append(nn.BatchNorm1d(hidden_size))
        for _ in range(num_layers - 2):
            self.convs.append(SAGEConv(hidden_size, hidden_size, normalize=True, aggr=aggr))
            self.bns.append(nn.BatchNorm1d(hidden_size))
        self.convs.append(SAGEConv(hidden_size, out_size, normalize=True, aggr=aggr))
        self.bns.append(nn.BatchNorm1d(out_size))

        self.dropout = dropout
        self.loss_fn = torch.nn.BCEWithLogitsLoss()
        
        self.device = device


    def forward(self, x, edge_index, edge_label_index, training = False):
        x = x.to(self.device)
        edge_index = edge_index.to(self.device)
        edge_label_index = edge_label_index.to(self.device)

        for i in range(len(self.convs) - 1):
          x = self.convs[i](x, edge_index)
          x = self.bns[i](x)
          x = F.leaky_relu(x)
          x = F.dropout(x, p=self.dropout, training=training)
        
        x = self.convs[-1](x, edge_index)  
        x = self.bns[-1](x)
        

        nodes_first, nodes_second = edge_label_index
        nodes_first_features = x[nodes_first.long()]
        nodes_second_features = x[nodes_second.long()]
        
        pred = torch.sum(nodes_first_features * nodes_second_features, dim=-1)
        
        return pred
    
    def loss(self, pred, label):
        return self.loss_fn(pred, label)

num_node_features = len(node_features['Embedding'][0])

best_model = LinkPredModel(num_node_features, loaded_args['hidden_dim'], loaded_args['output_dim'], 
                           loaded_args['layers'], loaded_args['aggr'], loaded_args['dropout'], 
                           loaded_args['device']).to(loaded_args['device'])

best_model.load_state_dict(torch.load(f'output/best_model_{dataset_nr}.pth'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# # GNNExplainer

# %%
model_config = ModelConfig(
    mode='binary_classification',
    task_level='edge',
    return_type='raw',
)

# %%
explainer = Explainer(
    model=best_model,
    explanation_type='model',
    algorithm=GNNExplainer(epochs=200),
    node_mask_type='attributes',
    edge_mask_type='object',
    model_config=model_config,
)

# %%
import ast

symptoms_drugs = pd.read_csv(f'output/symptom_drugs_{dataset_nr}.csv', converters={1:ast.literal_eval})
symptoms_drugs
# Out:
#        Symptom          Candidates
# 0   HP:0003707    [269, 1576, 926]
# 1   HP:0003236   [1576, 269, 1795]
# 2   HP:0001256   [269, 1576, 5359]
# 3   HP:0001265   [269, 1576, 1795]
# 4   HP:0001290   [1795, 269, 1576]
# 5   HP:0003307   [1576, 1795, 522]
# 6   HP:0003202  [1795, 1576, 5330]
# 7   HP:0001263   [269, 5359, 1795]
# 8   HP:0002791   [1576, 269, 5359]
# 9   HP:0001371   [1576, 1795, 522]
# 10  HP:0003701   [1576, 1795, 269]
# 11  HP:0001270   [1576, 269, 1795]
# 12  HP:0003560     [269, 176, 700]
# 13  HP:0008981   [1576, 1795, 269]
# 14  HP:0002650   [1795, 269, 1576]
# 15  HP:0001638    [1576, 176, 269]
# 16  HP:0003323   [1576, 5359, 269]
# 17  HP:0001635    [1576, 522, 186]
# 18  HP:0000750     [1057, 812, 65]
# 19  HP:0003115   [1576, 176, 4483]
# 20  HP:0011675    [231, 1576, 522]
# 21  HP:0003391   [1576, 269, 1795]
# 22  HP:0002093   [1576, 1795, 269]
# 23  HP:0100543   [269, 5359, 1795]
# 24  HP:0001644  [1576, 3659, 1810]
# 25  HP:0002515   [1576, 1795, 269]
# 26  HP:0001328    [269, 5359, 926]

# %%
graph_nr = 0

def explain_edge(node_idx1, node_idx2):
    edge_label_index = torch.tensor([node_idx1, node_idx2]) # Create a tensor as input of the model. Only predict the label of a single edge instead of all edges in current dataset.
    
    done = False
    current_iterations = 0
    total_iterations = 30
    graph_size = 15

    while not done:
        print(f'--- Iteration {current_iterations} ---')

        explanation = explainer(
            x=DeepG.node_feature,
            edge_index=DeepG.edge_index,
            edge_label_index=edge_label_index,
        )
        
        edge_mask = explanation.edge_mask
        
        print(f'A total of {torch.count_nonzero(edge_mask)} edges contributing to prediction.')
        
        sorted_contributions = edge_mask.sort(descending=True)[0]
        print(f'Maximum contribution value is {sorted_contributions[0]}')
        limit = sorted_contributions[graph_size]
        print(f'Based on desired graph size, contribution limit is set to {limit}')
        
        pruned_G = copy.deepcopy(G_attributes)
        for indx, edge in enumerate(G.edges):
            if edge_mask[indx] < limit:
                pruned_G.remove_edge(edge[0], edge[1])
        
        done = nx.has_path(pruned_G, node_idx1, node_idx2)
        
        pruned_G.remove_nodes_from(list(nx.isolates(pruned_G)))
        print('Pruned graph has edge total of:', pruned_G.number_of_edges())
        print('Pruned graph has node total of:', pruned_G.number_of_nodes())
        
        current_iterations += 1
        
        if done:
            print(f'A good explanation has been found!')
            nx.write_gexf(pruned_G, f"output/explanation{graph_nr}.gexf")
            graph_nr += 1
            return graph_nr
            
        elif current_iterations == total_iterations and not done:
            done = True
            print(f'No good explanations found after {current_iterations} iterations...')
    
    return None

# %%
def get_node_idx(id, nodes): 
    return nodes[nodes['id'] == id].index.values.astype(int)[0]

found_explanations = []

for ind, edge in symptoms_drugs.iterrows(): 
    symptom_id = edge['Symptom']
    
    for drug_id in edge['Candidates']:
        node_idx1 = get_node_idx(symptom_id, nodes)
        print('node1:')
        print(nodes.loc[[node_idx1]])

        node_idx2 = get_node_idx(str(drug_id), nodes)
        print('node2:')
        print(nodes.loc[[node_idx2]])
        
        new_graph_nr = explain_edge(node_idx1, node_idx2)
        
        if new_graph_nr is not None:
            found_explanations.append({'symptom': symptom_id, 'drug': drug_id, 'graphnr': new_graph_nr})
# Out:
# node1:
#       index_id          id   semantic                          label
# 5727      5727  HP:0003707  phenotype  Calf muscle pseudohypertrophy  \
#
#       semantic_id
# 5727            9
# node2:
#       index_id    id semantic         label  semantic_id
# 5262      5262  1576     drug  levosimendan            4
# --- Iteration 0 ---
# A total of 3542 edges contributing to prediction.
# Maximum contribution value is 0.310735285282135
# Based on desired graph size, contribution limit is set to 0.14891646802425385
# Pruned graph has edge total of: 9
# Pruned graph has node total of: 12
# --- Iteration 1 ---
# A total of 3542 edges contributing to prediction.
# Maximum contribution value is 0.29607337713241577
# Based on desired graph size, contribution limit is set to 0.15019941329956055
# Pruned graph has edge total of: 8
# Pruned graph has node total of: 11
# --- Iteration 2 ---
# A total of 3542 edges contributing to prediction.
# Maximum contribution value is 0.32425495982170105
# Based on desired graph size, contribution limit is set to 0.14985407888889313
# Pruned graph has edge total of: 8
# Pruned graph has node total of: 11
# --- Iteration 3 ---
# A total of 3542 edges contributing to prediction.
# Maximum contribution value is 0.30841076374053955
# Based on desired graph size, contribution limit is set to 0.15006211400032043
# Pruned graph has edge total of: 6
# Pruned graph has node total of: 8
# --- Iteration 4 ---
# A total of 3542 edges contributing to prediction.
# Maximum contribution value is 0.2855762243270874
# Based on desired graph size, contribution limit is set to 0.15020835399627686
# Pruned graph has edge total of: 7
# Pruned graph has node total of: 9
# --- Iteration 5 ---
# A total of 3542 edges contributing to prediction.
# Maximum contribution value is 0.3134620785713196
# Based on desired graph size, contribution limit is set to 0.14992165565490723
# Pruned graph has edge total of: 7
# Pruned graph has node total of: 10
# --- Iteration 6 ---
# A total of 3542 edges contributing to prediction.
# Maximum contribution value is 0.30655673146247864
# Based on desired graph size, contribution limit is set to 0.14942723512649536
# Pruned graph has edge total of: 9
# Pruned graph has node total of: 13
# --- Iteration 7 ---
# A total of 3542 edges contributing to prediction.
# Maximum contribution value is 0.28660422563552856
# Based on desired graph size, contribution limit is set to 0.14976827800273895
# Pruned graph has edge total of: 6
# Pruned graph has node total of: 8
# --- Iteration 8 ---
# A total of 3542 edges contributing to prediction.
# Maximum contribution value is 0.3069942891597748
# Based on desired graph size, contribution limit is set to 0.14986899495124817
# Pruned graph has edge total of: 6
# Pruned graph has node total of: 8
# --- Iteration 9 ---
# A total of 3542 edges contributing to prediction.
# Maximum contribution value is 0.32025328278541565
# Based on desired graph size, contribution limit is set to 0.1496715098619461
# Pruned graph has edge total of: 8
# Pruned graph has node total of: 10
# --- Iteration 10 ---
# A total of 3542 edges contributing to prediction.
# Maximum contribution value is 0.326398640871048
# Based on desired graph size, contribution limit is set to 0.14944899082183838
# Pruned graph has edge total of: 8
# Pruned graph has node total of: 10
# --- Iteration 11 ---
# A total of 3542 edges contributing to prediction.
# Maximum contribution value is 0.2872573733329773
# Based on desired graph size, contribution limit is set to 0.14971816539764404
# Pruned graph has edge total of: 8
# Pruned graph has node total of: 11
# --- Iteration 12 ---
# A total of 3542 edges contributing to prediction.
# Maximum contribution value is 0.32285261154174805
# Based on desired graph size, contribution limit is set to 0.14994941651821136
# Pruned graph has edge total of: 8
# Pruned graph has node total of: 11
# --- Iteration 13 ---
# A total of 3542 edges contributing to prediction.
# Maximum contribution value is 0.2742154896259308
# Based on desired graph size, contribution limit is set to 0.1499188095331192
# Pruned graph has edge total of: 8
# Pruned graph has node total of: 12
# --- Iteration 14 ---
# A total of 3542 edges contributing to prediction.
# Maximum contribution value is 0.32671910524368286
# Based on desired graph size, contribution limit is set to 0.14985418319702148
# Pruned graph has edge total of: 8
# Pruned graph has node total of: 11
# --- Iteration 15 ---
# A total of 3542 edges contributing to prediction.
# Maximum contribution value is 0.29122939705848694
# Based on desired graph size, contribution limit is set to 0.1497953087091446
# Pruned graph has edge total of: 7
# Pruned graph has node total of: 9
# --- Iteration 16 ---
# A total of 3542 edges contributing to prediction.
# Maximum contribution value is 0.2972429096698761
# Based on desired graph size, contribution limit is set to 0.14979153871536255
# Pruned graph has edge total of: 7
# Pruned graph has node total of: 10
# --- Iteration 17 ---
# A total of 3542 edges contributing to prediction.
# Maximum contribution value is 0.3280636966228485
# Based on desired graph size, contribution limit is set to 0.15021102130413055
# Pruned graph has edge total of: 8
# Pruned graph has node total of: 10
# --- Iteration 18 ---
# A total of 3542 edges contributing to prediction.
# Maximum contribution value is 0.26738855242729187
# Based on desired graph size, contribution limit is set to 0.14954446256160736
# Pruned graph has edge total of: 6
# Pruned graph has node total of: 9
# --- Iteration 19 ---
# A total of 3542 edges contributing to prediction.
# Maximum contribution value is 0.2983170747756958
# Based on desired graph size, contribution limit is set to 0.15004678070545197
# Pruned graph has edge total of: 8
# Pruned graph has node total of: 10
# --- Iteration 20 ---
# A total of 3542 edges contributing to prediction.
# Maximum contribution value is 0.28989723324775696
# Based on desired graph size, contribution limit is set to 0.1496632695198059
# Pruned graph has edge total of: 6
# Pruned graph has node total of: 8
# --- Iteration 21 ---
# A total of 3542 edges contributing to prediction.
# Maximum contribution value is 0.282538503408432
# Based on desired graph size, contribution limit is set to 0.14995495975017548
# Pruned graph has edge total of: 6
# Pruned graph has node total of: 8
# --- Iteration 22 ---
# A total of 3542 edges contributing to prediction.
# Maximum contribution value is 0.3151610493659973
# Based on desired graph size, contribution limit is set to 0.1497688591480255
# Pruned graph has edge total of: 7
# Pruned graph has node total of: 10
# --- Iteration 23 ---
# A total of 3542 edges contributing to prediction.
# Maximum contribution value is 0.2937453091144562
# Based on desired graph size, contribution limit is set to 0.1496760994195938
# Pruned graph has edge total of: 10
# Pruned graph has node total of: 13
# --- Iteration 24 ---
# A total of 3542 edges contributing to prediction.
# Maximum contribution value is 0.29482322931289673
# Based on desired graph size, contribution limit is set to 0.1495097428560257
# Pruned graph has edge total of: 8
# Pruned graph has node total of: 10
# --- Iteration 25 ---
# A total of 3542 edges contributing to prediction.
# Maximum contribution value is 0.31717586517333984
# Based on desired graph size, contribution limit is set to 0.1497790366411209
# Pruned graph has edge total of: 9
# Pruned graph has node total of: 11
# --- Iteration 26 ---
# A total of 3542 edges contributing to prediction.
# Maximum contribution value is 0.2999303340911865
# Based on desired graph size, contribution limit is set to 0.14964212477207184
# Pruned graph has edge total of: 6
# Pruned graph has node total of: 8
# --- Iteration 27 ---
# A total of 3542 edges contributing to prediction.
# Maximum contribution value is 0.32075533270835876
# Based on desired graph size, contribution limit is set to 0.14985696971416473
# Pruned graph has edge total of: 6
# Pruned graph has node total of: 8
# --- Iteration 28 ---
# A total of 3542 edges contributing to prediction.
# Maximum contribution value is 0.30521973967552185
# Based on desired graph size, contribution limit is set to 0.14964167773723602
# Pruned graph has edge total of: 9
# Pruned graph has node total of: 13
# --- Iteration 29 ---
# A total of 3542 edges contributing to prediction.
# Maximum contribution value is 0.3005366623401642
# Based on desired graph size, contribution limit is set to 0.15003639459609985
# Pruned graph has edge total of: 8
# Pruned graph has node total of: 12
# No good explanations found after 30 iterations...
# node1:
#       index_id          id   semantic                           label
# 1351      1351  HP:0003236  phenotype  Elevated serum creatine kinase  \
#
#       semantic_id
# 1351            9
# node2:
#       index_id    id semantic         label  semantic_id
# 5262      5262  1576     drug  levosimendan            4
# --- Iteration 0 ---
# A total of 6576 edges contributing to prediction.
# Maximum contribution value is 0.21812723577022552
# Based on desired graph size, contribution limit is set to 0.1513543277978897
# Pruned graph has edge total of: 9
# Pruned graph has node total of: 18
# --- Iteration 1 ---
# A total of 6576 edges contributing to prediction.
# Maximum contribution value is 0.24930639564990997
# Based on desired graph size, contribution limit is set to 0.15113604068756104
# Pruned graph has edge total of: 7
# Pruned graph has node total of: 12
# --- Iteration 2 ---
# A total of 6576 edges contributing to prediction.
# Maximum contribution value is 0.2562677264213562
# Based on desired graph size, contribution limit is set to 0.15135377645492554
# Pruned graph has edge total of: 6
# Pruned graph has node total of: 12
# --- Iteration 3 ---
# A total of 6576 edges contributing to prediction.
# Maximum contribution value is 0.2024880051612854
# Based on desired graph size, contribution limit is set to 0.1511213630437851
# Pruned graph has edge total of: 10
# Pruned graph has node total of: 20
# --- Iteration 4 ---
# A total of 6576 edges contributing to prediction.
# Maximum contribution value is 0.22992949187755585
# Based on desired graph size, contribution limit is set to 0.15110673010349274
# Pruned graph has edge total of: 10
# Pruned graph has node total of: 17
# --- Iteration 5 ---
# A total of 6576 edges contributing to prediction.
# Maximum contribution value is 0.2164759337902069
# Based on desired graph size, contribution limit is set to 0.15134510397911072
# Pruned graph has edge total of: 6
# Pruned graph has node total of: 12
# --- Iteration 6 ---
# A total of 6576 edges contributing to prediction.
# Maximum contribution value is 0.2316034883260727
# Based on desired graph size, contribution limit is set to 0.15135060250759125
# Pruned graph has edge total of: 8
# Pruned graph has node total of: 14
# --- Iteration 7 ---
# A total of 6576 edges contributing to prediction.
# Maximum contribution value is 0.22273574769496918
# Based on desired graph size, contribution limit is set to 0.15129254758358002
# Pruned graph has edge total of: 3
# Pruned graph has node total of: 6
# --- Iteration 8 ---
# A total of 6576 edges contributing to prediction.
# Maximum contribution value is 0.2236061990261078
# Based on desired graph size, contribution limit is set to 0.15137115120887756
# Pruned graph has edge total of: 4
# Pruned graph has node total of: 8
# --- Iteration 9 ---
# A total of 6576 edges contributing to prediction.
# Maximum contribution value is 0.2519782781600952
# Based on desired graph size, contribution limit is set to 0.1514538675546646
# Pruned graph has edge total of: 8
# Pruned graph has node total of: 16
# --- Iteration 10 ---
# A total of 6576 edges contributing to prediction.
# Maximum contribution value is 0.21695086359977722
# Based on desired graph size, contribution limit is set to 0.15138524770736694
# Pruned graph has edge total of: 6
# Pruned graph has node total of: 12
# --- Iteration 11 ---
# A total of 6576 edges contributing to prediction.
# Maximum contribution value is 0.22593264281749725
# Based on desired graph size, contribution limit is set to 0.15113987028598785
# Pruned graph has edge total of: 7
# Pruned graph has node total of: 13
# --- Iteration 12 ---
# A total of 6576 edges contributing to prediction.
# Maximum contribution value is 0.24022039771080017
# Based on desired graph size, contribution limit is set to 0.15118561685085297
# Pruned graph has edge total of: 6
# Pruned graph has node total of: 11
# --- Iteration 13 ---
# A total of 6576 edges contributing to prediction.
# Maximum contribution value is 0.21955670416355133
# Based on desired graph size, contribution limit is set to 0.15130384266376495
# Pruned graph has edge total of: 8
# Pruned graph has node total of: 14
# --- Iteration 14 ---
# A total of 6576 edges contributing to prediction.
# Maximum contribution value is 0.2419804334640503
# Based on desired graph size, contribution limit is set to 0.15139274299144745
# Pruned graph has edge total of: 6
# Pruned graph has node total of: 11
# --- Iteration 15 ---
# A total of 6576 edges contributing to prediction.
# Maximum contribution value is 0.21718254685401917
# Based on desired graph size, contribution limit is set to 0.15145890414714813
# Pruned graph has edge total of: 7
# Pruned graph has node total of: 14
# --- Iteration 16 ---
# A total of 6576 edges contributing to prediction.
# Maximum contribution value is 0.20738108456134796
# Based on desired graph size, contribution limit is set to 0.151307612657547
# Pruned graph has edge total of: 7
# Pruned graph has node total of: 13
# --- Iteration 17 ---
# A total of 6576 edges contributing to prediction.
# Maximum contribution value is 0.21248093247413635
# Based on desired graph size, contribution limit is set to 0.15131360292434692
# Pruned graph has edge total of: 7
# Pruned graph has node total of: 14
# --- Iteration 18 ---
# A total of 6576 edges contributing to prediction.
# Maximum contribution value is 0.22827719151973724
# Based on desired graph size, contribution limit is set to 0.15125328302383423
# Pruned graph has edge total of: 7
# Pruned graph has node total of: 14
# --- Iteration 19 ---
# A total of 6576 edges contributing to prediction.
# Maximum contribution value is 0.21180467307567596
# Based on desired graph size, contribution limit is set to 0.15120616555213928
# Pruned graph has edge total of: 10
# Pruned graph has node total of: 20
# --- Iteration 20 ---
# A total of 6576 edges contributing to prediction.
# Maximum contribution value is 0.22630687057971954
# Based on desired graph size, contribution limit is set to 0.1513865888118744
# Pruned graph has edge total of: 9
# Pruned graph has node total of: 16
# --- Iteration 21 ---
# A total of 6576 edges contributing to prediction.
# Maximum contribution value is 0.23172488808631897
# Based on desired graph size, contribution limit is set to 0.1512037068605423
# Pruned graph has edge total of: 5
# Pruned graph has node total of: 10
# --- Iteration 22 ---
# A total of 6576 edges contributing to prediction.
# Maximum contribution value is 0.24482129514217377
# Based on desired graph size, contribution limit is set to 0.15131694078445435
# Pruned graph has edge total of: 7
# Pruned graph has node total of: 13
# --- Iteration 23 ---
# A total of 6576 edges contributing to prediction.
# Maximum contribution value is 0.21447645127773285
# Based on desired graph size, contribution limit is set to 0.15118880569934845
# Pruned graph has edge total of: 7
# Pruned graph has node total of: 14
# --- Iteration 24 ---
# A total of 6576 edges contributing to prediction.
# Maximum contribution value is 0.22255846858024597
# Based on desired graph size, contribution limit is set to 0.15126515924930573
# Pruned graph has edge total of: 8
# Pruned graph has node total of: 16
# --- Iteration 25 ---
# A total of 6576 edges contributing to prediction.
# Maximum contribution value is 0.2089810073375702
# Based on desired graph size, contribution limit is set to 0.1510239541530609
# Pruned graph has edge total of: 9
# Pruned graph has node total of: 17
# --- Iteration 26 ---
# A total of 6576 edges contributing to prediction.
# Maximum contribution value is 0.21475230157375336
# Based on desired graph size, contribution limit is set to 0.1513729840517044
# Pruned graph has edge total of: 4
# Pruned graph has node total of: 8
# --- Iteration 27 ---
# A total of 6576 edges contributing to prediction.
# Maximum contribution value is 0.2167474925518036
# Based on desired graph size, contribution limit is set to 0.1514156311750412
# Pruned graph has edge total of: 4
# Pruned graph has node total of: 7
# --- Iteration 28 ---
# A total of 6576 edges contributing to prediction.
# Maximum contribution value is 0.23524881899356842
# Based on desired graph size, contribution limit is set to 0.15133538842201233
# Pruned graph has edge total of: 5
# Pruned graph has node total of: 10
# --- Iteration 29 ---
# A total of 6576 edges contributing to prediction.
# Maximum contribution value is 0.21683572232723236
# Based on desired graph size, contribution limit is set to 0.1513739973306656
# Pruned graph has edge total of: 3
# Pruned graph has node total of: 6
# No good explanations found after 30 iterations...
# node1:
#       index_id          id   semantic                          label
# 4533      4533  HP:0001256  phenotype  Intellectual disability, mild  \
#
#       semantic_id
# 4533            9
# node2:
#       index_id    id semantic         label  semantic_id
# 5262      5262  1576     drug  levosimendan            4
# --- Iteration 0 ---
# A total of 3587 edges contributing to prediction.
# Maximum contribution value is 0.19029255211353302
# Based on desired graph size, contribution limit is set to 0.14961494505405426
# Pruned graph has edge total of: 8
# Pruned graph has node total of: 12
# --- Iteration 1 ---
# A total of 3587 edges contributing to prediction.
# Maximum contribution value is 0.18118691444396973
# Based on desired graph size, contribution limit is set to 0.14929385483264923
# Pruned graph has edge total of: 11
# Pruned graph has node total of: 16
# --- Iteration 2 ---
# A total of 3587 edges contributing to prediction.
# Maximum contribution value is 0.20576435327529907
# Based on desired graph size, contribution limit is set to 0.14933164417743683
# Pruned graph has edge total of: 8
# Pruned graph has node total of: 12
# --- Iteration 3 ---
# A total of 3587 edges contributing to prediction.
# Maximum contribution value is 0.18025386333465576
# Based on desired graph size, contribution limit is set to 0.14933215081691742
# Pruned graph has edge total of: 7
# Pruned graph has node total of: 10
# --- Iteration 4 ---
# A total of 3587 edges contributing to prediction.
# Maximum contribution value is 0.18634916841983795
# Based on desired graph size, contribution limit is set to 0.1495351493358612
# Pruned graph has edge total of: 11
# Pruned graph has node total of: 14
# --- Iteration 5 ---
# A total of 3587 edges contributing to prediction.
# Maximum contribution value is 0.17285102605819702
# Based on desired graph size, contribution limit is set to 0.14939726889133453
# Pruned graph has edge total of: 9
# Pruned graph has node total of: 13
# --- Iteration 6 ---
# A total of 3587 edges contributing to prediction.
# Maximum contribution value is 0.18759645521640778
# Based on desired graph size, contribution limit is set to 0.14932328462600708
# Pruned graph has edge total of: 9
# Pruned graph has node total of: 14
# --- Iteration 7 ---
# A total of 3587 edges contributing to prediction.
# Maximum contribution value is 0.1789810210466385
# Based on desired graph size, contribution limit is set to 0.14958226680755615
# Pruned graph has edge total of: 8
# Pruned graph has node total of: 11
# --- Iteration 8 ---
# A total of 3587 edges contributing to prediction.
# Maximum contribution value is 0.19068646430969238
# Based on desired graph size, contribution limit is set to 0.149415522813797
# Pruned graph has edge total of: 6
# Pruned graph has node total of: 9
# --- Iteration 9 ---
# A total of 3587 edges contributing to prediction.
# Maximum contribution value is 0.16689248383045197
# Based on desired graph size, contribution limit is set to 0.14935876429080963
# Pruned graph has edge total of: 5
# Pruned graph has node total of: 9
# --- Iteration 10 ---
# A total of 3587 edges contributing to prediction.
# Maximum contribution value is 0.180653378367424
# Based on desired graph size, contribution limit is set to 0.14957964420318604
# Pruned graph has edge total of: 9
# Pruned graph has node total of: 15
# --- Iteration 11 ---
# A total of 3587 edges contributing to prediction.
# Maximum contribution value is 0.2038963884115219
# Based on desired graph size, contribution limit is set to 0.1496354192495346
# Pruned graph has edge total of: 6
# Pruned graph has node total of: 9
# --- Iteration 12 ---
# A total of 3587 edges contributing to prediction.
# Maximum contribution value is 0.19399791955947876
# Based on desired graph size, contribution limit is set to 0.14952702820301056
# Pruned graph has edge total of: 9
# Pruned graph has node total of: 14
# --- Iteration 13 ---
# A total of 3587 edges contributing to prediction.
# Maximum contribution value is 0.17704316973686218
# Based on desired graph size, contribution limit is set to 0.14916165173053741
# Pruned graph has edge total of: 10
# Pruned graph has node total of: 13
# --- Iteration 14 ---
# A total of 3587 edges contributing to prediction.
# Maximum contribution value is 0.19659866392612457
# Based on desired graph size, contribution limit is set to 0.14917919039726257
# Pruned graph has edge total of: 6
# Pruned graph has node total of: 9
# --- Iteration 15 ---
# A total of 3587 edges contributing to prediction.
# Maximum contribution value is 0.18088248372077942
# Based on desired graph size, contribution limit is set to 0.14938195049762726
# Pruned graph has edge total of: 8
# Pruned graph has node total of: 12
# --- Iteration 16 ---
# A total of 3587 edges contributing to prediction.
# Maximum contribution value is 0.18711520731449127
# Based on desired graph size, contribution limit is set to 0.14934320747852325
# Pruned graph has edge total of: 7
# Pruned graph has node total of: 10
# --- Iteration 17 ---
# A total of 3587 edges contributing to prediction.
# Maximum contribution value is 0.17812229692935944
# Based on desired graph size, contribution limit is set to 0.14948847889900208
# Pruned graph has edge total of: 6
# Pruned graph has node total of: 11
# --- Iteration 18 ---
# A total of 3587 edges contributing to prediction.
# Maximum contribution value is 0.20234888792037964
# Based on desired graph size, contribution limit is set to 0.14925183355808258
# Pruned graph has edge total of: 6
# Pruned graph has node total of: 9
# --- Iteration 19 ---
# A total of 3587 edges contributing to prediction.
# Maximum contribution value is 0.18130557239055634
# Based on desired graph size, contribution limit is set to 0.14967896044254303
# Pruned graph has edge total of: 7
# Pruned graph has node total of: 10
# --- Iteration 20 ---
# A total of 3587 edges contributing to prediction.
# Maximum contribution value is 0.17677970230579376
# Based on desired graph size, contribution limit is set to 0.14928671717643738
# Pruned graph has edge total of: 7
# Pruned graph has node total of: 10
# --- Iteration 21 ---
# A total of 3587 edges contributing to prediction.
# Maximum contribution value is 0.1966354250907898
# Based on desired graph size, contribution limit is set to 0.14935968816280365
# Pruned graph has edge total of: 7
# Pruned graph has node total of: 10
# --- Iteration 22 ---
# A total of 3587 edges contributing to prediction.
# Maximum contribution value is 0.18587534129619598
# Based on desired graph size, contribution limit is set to 0.1495852768421173
# Pruned graph has edge total of: 8
# Pruned graph has node total of: 11
# --- Iteration 23 ---
# A total of 3587 edges contributing to prediction.
# Maximum contribution value is 0.17572806775569916
# Based on desired graph size, contribution limit is set to 0.14923125505447388
# Pruned graph has edge total of: 4
# Pruned graph has node total of: 7
# --- Iteration 24 ---
# A total of 3587 edges contributing to prediction.
# Maximum contribution value is 0.18028077483177185
# Based on desired graph size, contribution limit is set to 0.14923998713493347
# Pruned graph has edge total of: 5
# Pruned graph has node total of: 8
# --- Iteration 25 ---
# A total of 3587 edges contributing to prediction.
# Maximum contribution value is 0.19598335027694702
# Based on desired graph size, contribution limit is set to 0.14930638670921326
# Pruned graph has edge total of: 6
# Pruned graph has node total of: 10
# --- Iteration 26 ---
# A total of 3587 edges contributing to prediction.
# Maximum contribution value is 0.19030843675136566
# Based on desired graph size, contribution limit is set to 0.1496468335390091
# Pruned graph has edge total of: 7
# Pruned graph has node total of: 10
# --- Iteration 27 ---
# A total of 3587 edges contributing to prediction.
# Maximum contribution value is 0.20200477540493011
# Based on desired graph size, contribution limit is set to 0.14981749653816223
# Pruned graph has edge total of: 7
# Pruned graph has node total of: 10
# --- Iteration 28 ---
# A total of 3587 edges contributing to prediction.
# Maximum contribution value is 0.18676172196865082
# Based on desired graph size, contribution limit is set to 0.1493414342403412
# Pruned graph has edge total of: 8
# Pruned graph has node total of: 12
# --- Iteration 29 ---
# A total of 3587 edges contributing to prediction.
# Maximum contribution value is 0.1866275668144226
# Based on desired graph size, contribution limit is set to 0.149754598736763
# Pruned graph has edge total of: 6
# Pruned graph has node total of: 10
# No good explanations found after 30 iterations...
# node1:
#       index_id          id   semantic         label  semantic_id
# 6515      6515  HP:0001265  phenotype  Hyporeflexia            9
# node2:
#       index_id    id semantic         label  semantic_id
# 5262      5262  1576     drug  levosimendan            4
# --- Iteration 0 ---
# A total of 3916 edges contributing to prediction.
# Maximum contribution value is 0.25219887495040894
# Based on desired graph size, contribution limit is set to 0.1495981365442276
# Pruned graph has edge total of: 10
# Pruned graph has node total of: 12
# --- Iteration 1 ---
# A total of 3916 edges contributing to prediction.
# Maximum contribution value is 0.23236441612243652
# Based on desired graph size, contribution limit is set to 0.15000766515731812
# Pruned graph has edge total of: 11
# Pruned graph has node total of: 15
# --- Iteration 2 ---
# A total of 3916 edges contributing to prediction.
# Maximum contribution value is 0.24287496507167816
# Based on desired graph size, contribution limit is set to 0.15019378066062927
# Pruned graph has edge total of: 11
# Pruned graph has node total of: 13
# --- Iteration 3 ---
# A total of 3916 edges contributing to prediction.
# Maximum contribution value is 0.22061209380626678
# Based on desired graph size, contribution limit is set to 0.14974810183048248
# Pruned graph has edge total of: 9
# Pruned graph has node total of: 12
# --- Iteration 4 ---
# A total of 3916 edges contributing to prediction.
# Maximum contribution value is 0.2520373463630676
# Based on desired graph size, contribution limit is set to 0.15062007308006287
# Pruned graph has edge total of: 10
# Pruned graph has node total of: 12
# --- Iteration 5 ---
# A total of 3916 edges contributing to prediction.
# Maximum contribution value is 0.24154888093471527
# Based on desired graph size, contribution limit is set to 0.15069864690303802
# Pruned graph has edge total of: 10
# Pruned graph has node total of: 12
# --- Iteration 6 ---
# A total of 3916 edges contributing to prediction.
# Maximum contribution value is 0.23779314756393433
# Based on desired graph size, contribution limit is set to 0.14991609752178192
# Pruned graph has edge total of: 10
# Pruned graph has node total of: 12
# --- Iteration 7 ---
# A total of 3916 edges contributing to prediction.
# Maximum contribution value is 0.22656120359897614
# Based on desired graph size, contribution limit is set to 0.15053533017635345
# Pruned graph has edge total of: 9
# Pruned graph has node total of: 11
# --- Iteration 8 ---
# A total of 3916 edges contributing to prediction.
# Maximum contribution value is 0.24788130819797516
# Based on desired graph size, contribution limit is set to 0.14996810257434845
# Pruned graph has edge total of: 12
# Pruned graph has node total of: 15
# --- Iteration 9 ---
# A total of 3916 edges contributing to prediction.
# Maximum contribution value is 0.2500247359275818
# Based on desired graph size, contribution limit is set to 0.15023736655712128
# Pruned graph has edge total of: 9
# Pruned graph has node total of: 11
# --- Iteration 10 ---
# A total of 3916 edges contributing to prediction.
# Maximum contribution value is 0.24616147577762604
# Based on desired graph size, contribution limit is set to 0.15023218095302582
# Pruned graph has edge total of: 10
# Pruned graph has node total of: 12
# --- Iteration 11 ---
# A total of 3916 edges contributing to prediction.
# Maximum contribution value is 0.23765157163143158
# Based on desired graph size, contribution limit is set to 0.15040139853954315
# Pruned graph has edge total of: 12
# Pruned graph has node total of: 14
# --- Iteration 12 ---
# A total of 3916 edges contributing to prediction.
# Maximum contribution value is 0.24127978086471558
# Based on desired graph size, contribution limit is set to 0.15009404718875885
# Pruned graph has edge total of: 11
# Pruned graph has node total of: 14
# --- Iteration 13 ---
# A total of 3916 edges contributing to prediction.
# Maximum contribution value is 0.2288394570350647
# Based on desired graph size, contribution limit is set to 0.1501840054988861
# Pruned graph has edge total of: 11
# Pruned graph has node total of: 14
# --- Iteration 14 ---
# A total of 3916 edges contributing to prediction.
# Maximum contribution value is 0.21996314823627472
# Based on desired graph size, contribution limit is set to 0.1497514396905899
# Pruned graph has edge total of: 7
# Pruned graph has node total of: 9
# --- Iteration 15 ---
# A total of 3916 edges contributing to prediction.
# Maximum contribution value is 0.24598903954029083
# Based on desired graph size, contribution limit is set to 0.1499207615852356
# Pruned graph has edge total of: 11
# Pruned graph has node total of: 15
# --- Iteration 16 ---
# A total of 3916 edges contributing to prediction.
# Maximum contribution value is 0.2376505434513092
# Based on desired graph size, contribution limit is set to 0.15040525794029236
# Pruned graph has edge total of: 12
# Pruned graph has node total of: 15
# --- Iteration 17 ---
# A total of 3916 edges contributing to prediction.
# Maximum contribution value is 0.2511107623577118
# Based on desired graph size, contribution limit is set to 0.15012623369693756
# Pruned graph has edge total of: 11
# Pruned graph has node total of: 14
# --- Iteration 18 ---
# A total of 3916 edges contributing to prediction.
# Maximum contribution value is 0.21222056448459625
# Based on desired graph size, contribution limit is set to 0.1502406746149063
# Pruned graph has edge total of: 9
# Pruned graph has node total of: 13
# --- Iteration 19 ---
# A total of 3916 edges contributing to prediction.
# Maximum contribution value is 0.2510876953601837
# Based on desired graph size, contribution limit is set to 0.14995652437210083
# Pruned graph has edge total of: 11
# Pruned graph has node total of: 15
# --- Iteration 20 ---
# A total of 3916 edges contributing to prediction.
# Maximum contribution value is 0.22621066868305206
# Based on desired graph size, contribution limit is set to 0.15000925958156586
# Pruned graph has edge total of: 9
# Pruned graph has node total of: 12
# --- Iteration 21 ---
# A total of 3916 edges contributing to prediction.
# Maximum contribution value is 0.2499048113822937
# Based on desired graph size, contribution limit is set to 0.15015050768852234
# Pruned graph has edge total of: 8
# Pruned graph has node total of: 10
# --- Iteration 22 ---
# A total of 3916 edges contributing to prediction.
# Maximum contribution value is 0.22931325435638428
# Based on desired graph size, contribution limit is set to 0.14992982149124146
# Pruned graph has edge total of: 9
# Pruned graph has node total of: 12
# --- Iteration 23 ---
# A total of 3916 edges contributing to prediction.
# Maximum contribution value is 0.2308332622051239
# Based on desired graph size, contribution limit is set to 0.15006288886070251
# Pruned graph has edge total of: 10
# Pruned graph has node total of: 13
# --- Iteration 24 ---
# A total of 3916 edges contributing to prediction.
# Maximum contribution value is 0.2513870894908905
# Based on desired graph size, contribution limit is set to 0.15044854581356049
# Pruned graph has edge total of: 11
# Pruned graph has node total of: 14
# --- Iteration 25 ---
# A total of 3916 edges contributing to prediction.
# Maximum contribution value is 0.20607808232307434
# Based on desired graph size, contribution limit is set to 0.15008127689361572
# Pruned graph has edge total of: 8
# Pruned graph has node total of: 11
# --- Iteration 26 ---
# A total of 3916 edges contributing to prediction.
# Maximum contribution value is 0.22581203281879425
# Based on desired graph size, contribution limit is set to 0.149917334318161
# Pruned graph has edge total of: 6
# Pruned graph has node total of: 8
# --- Iteration 27 ---
# A total of 3916 edges contributing to prediction.
# Maximum contribution value is 0.26636239886283875
# Based on desired graph size, contribution limit is set to 0.15038911998271942
# Pruned graph has edge total of: 11
# Pruned graph has node total of: 14
# --- Iteration 28 ---
# A total of 3916 edges contributing to prediction.
# Maximum contribution value is 0.23128104209899902
# Based on desired graph size, contribution limit is set to 0.14982019364833832
# Pruned graph has edge total of: 10
# Pruned graph has node total of: 12
# --- Iteration 29 ---
# A total of 3916 edges contributing to prediction.
# Maximum contribution value is 0.22672826051712036
# Based on desired graph size, contribution limit is set to 0.1502925455570221
# Pruned graph has edge total of: 9
# Pruned graph has node total of: 12
# No good explanations found after 30 iterations...
# node1:
#       index_id          id   semantic                  label  semantic_id
# 5372      5372  HP:0001290  phenotype  Generalized hypotonia            9
# node2:
#       index_id    id semantic         label  semantic_id
# 5262      5262  1576     drug  levosimendan            4
# --- Iteration 0 ---
# A total of 5596 edges contributing to prediction.
# Maximum contribution value is 0.18108640611171722
# Based on desired graph size, contribution limit is set to 0.15073898434638977
# Pruned graph has edge total of: 6
# Pruned graph has node total of: 12
# --- Iteration 1 ---
# A total of 5596 edges contributing to prediction.
# Maximum contribution value is 0.1920989602804184
# Based on desired graph size, contribution limit is set to 0.1506778597831726
# Pruned graph has edge total of: 8
# Pruned graph has node total of: 16
# --- Iteration 2 ---
# A total of 5596 edges contributing to prediction.
# Maximum contribution value is 0.19013838469982147
# Based on desired graph size, contribution limit is set to 0.15069247782230377
# Pruned graph has edge total of: 6
# Pruned graph has node total of: 12
# --- Iteration 3 ---
# A total of 5596 edges contributing to prediction.
# Maximum contribution value is 0.16999424993991852
# Based on desired graph size, contribution limit is set to 0.1506265252828598
# Pruned graph has edge total of: 6
# Pruned graph has node total of: 11
# --- Iteration 4 ---
# A total of 5596 edges contributing to prediction.
# Maximum contribution value is 0.17197073996067047
# Based on desired graph size, contribution limit is set to 0.15069615840911865
# Pruned graph has edge total of: 9
# Pruned graph has node total of: 16
# --- Iteration 5 ---
# A total of 5596 edges contributing to prediction.
# Maximum contribution value is 0.18444077670574188
# Based on desired graph size, contribution limit is set to 0.15052302181720734
# Pruned graph has edge total of: 7
# Pruned graph has node total of: 13
# --- Iteration 6 ---
# A total of 5596 edges contributing to prediction.
# Maximum contribution value is 0.17485159635543823
# Based on desired graph size, contribution limit is set to 0.15050409734249115
# Pruned graph has edge total of: 7
# Pruned graph has node total of: 12
# --- Iteration 7 ---
# A total of 5596 edges contributing to prediction.
# Maximum contribution value is 0.20780430734157562
# Based on desired graph size, contribution limit is set to 0.1507599949836731
# Pruned graph has edge total of: 9
# Pruned graph has node total of: 16
# --- Iteration 8 ---
# A total of 5596 edges contributing to prediction.
# Maximum contribution value is 0.18625742197036743
# Based on desired graph size, contribution limit is set to 0.15065008401870728
# Pruned graph has edge total of: 5
# Pruned graph has node total of: 10
# --- Iteration 9 ---
# A total of 5596 edges contributing to prediction.
# Maximum contribution value is 0.18807820975780487
# Based on desired graph size, contribution limit is set to 0.15082553029060364
# Pruned graph has edge total of: 6
# Pruned graph has node total of: 12
# --- Iteration 10 ---
# A total of 5596 edges contributing to prediction.
# Maximum contribution value is 0.1881953775882721
# Based on desired graph size, contribution limit is set to 0.15056101977825165
# Pruned graph has edge total of: 7
# Pruned graph has node total of: 12
# --- Iteration 11 ---
# A total of 5596 edges contributing to prediction.
# Maximum contribution value is 0.1781763732433319
# Based on desired graph size, contribution limit is set to 0.15101845562458038
# Pruned graph has edge total of: 6
# Pruned graph has node total of: 12
# --- Iteration 12 ---
# A total of 5596 edges contributing to prediction.
# Maximum contribution value is 0.18635737895965576
# Based on desired graph size, contribution limit is set to 0.150905579328537
# Pruned graph has edge total of: 7
# Pruned graph has node total of: 11
# --- Iteration 13 ---
# A total of 5596 edges contributing to prediction.
# Maximum contribution value is 0.19025883078575134
# Based on desired graph size, contribution limit is set to 0.15081918239593506
# Pruned graph has edge total of: 9
# Pruned graph has node total of: 17
# --- Iteration 14 ---
# A total of 5596 edges contributing to prediction.
# Maximum contribution value is 0.18640866875648499
# Based on desired graph size, contribution limit is set to 0.1508389413356781
# Pruned graph has edge total of: 2
# Pruned graph has node total of: 4
# --- Iteration 15 ---
# A total of 5596 edges contributing to prediction.
# Maximum contribution value is 0.18096600472927094
# Based on desired graph size, contribution limit is set to 0.15041522681713104
# Pruned graph has edge total of: 6
# Pruned graph has node total of: 11
# --- Iteration 16 ---
# A total of 5596 edges contributing to prediction.
# Maximum contribution value is 0.1762114018201828
# Based on desired graph size, contribution limit is set to 0.15070964395999908
# Pruned graph has edge total of: 6
# Pruned graph has node total of: 10
# --- Iteration 17 ---
# A total of 5596 edges contributing to prediction.
# Maximum contribution value is 0.20473845303058624
# Based on desired graph size, contribution limit is set to 0.15084122121334076
# Pruned graph has edge total of: 6
# Pruned graph has node total of: 12
# --- Iteration 18 ---
# A total of 5596 edges contributing to prediction.
# Maximum contribution value is 0.17758414149284363
# Based on desired graph size, contribution limit is set to 0.15080858767032623
# Pruned graph has edge total of: 5
# Pruned graph has node total of: 9
# --- Iteration 19 ---
# A total of 5596 edges contributing to prediction.
# Maximum contribution value is 0.1955215334892273
# Based on desired graph size, contribution limit is set to 0.1508791148662567
# Pruned graph has edge total of: 4
# Pruned graph has node total of: 8
# --- Iteration 20 ---
# A total of 5596 edges contributing to prediction.
# Maximum contribution value is 0.18188881874084473
# Based on desired graph size, contribution limit is set to 0.15079672634601593
# Pruned graph has edge total of: 5
# Pruned graph has node total of: 10
# --- Iteration 21 ---
# A total of 5596 edges contributing to prediction.
# Maximum contribution value is 0.18530277907848358
# Based on desired graph size, contribution limit is set to 0.1505742073059082
# Pruned graph has edge total of: 7
# Pruned graph has node total of: 12
# --- Iteration 22 ---
# A total of 5596 edges contributing to prediction.
# Maximum contribution value is 0.18777818977832794
# Based on desired graph size, contribution limit is set to 0.1508643627166748
# Pruned graph has edge total of: 8
# Pruned graph has node total of: 14
# --- Iteration 23 ---
# A total of 5596 edges contributing to prediction.
# Maximum contribution value is 0.18953025341033936
# Based on desired graph size, contribution limit is set to 0.1506335437297821
# Pruned graph has edge total of: 9
# Pruned graph has node total of: 14
# --- Iteration 24 ---
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\rosa-\Google Drive\Msc_Bioinformatics\thesis\XAIFO-ThesisProject\explainer2.ipynb Cell 23 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/rosa-/Google%20Drive/Msc_Bioinformatics/thesis/XAIFO-ThesisProject/explainer2.ipynb#X31sZmlsZQ%3D%3D?line=15'>16</a> print('node2:')
#      <a href='vscode-notebook-cell:/c%3A/Users/rosa-/Google%20Drive/Msc_Bioinformatics/thesis/XAIFO-ThesisProject/explainer2.ipynb#X31sZmlsZQ%3D%3D?line=16'>17</a> print(nodes.loc[[node_idx2]])
# ---> <a href='vscode-notebook-cell:/c%3A/Users/rosa-/Google%20Drive/Msc_Bioinformatics/thesis/XAIFO-ThesisProject/explainer2.ipynb#X31sZmlsZQ%3D%3D?line=18'>19</a> new_graph_nr = explain_edge(node_idx1, node_idx2)
#      <a href='vscode-notebook-cell:/c%3A/Users/rosa-/Google%20Drive/Msc_Bioinformatics/thesis/XAIFO-ThesisProject/explainer2.ipynb#X31sZmlsZQ%3D%3D?line=20'>21</a> if new_graph_nr is not None:
#      <a href='vscode-notebook-cell:/c%3A/Users/rosa-/Google%20Drive/Msc_Bioinformatics/thesis/XAIFO-ThesisProject/explainer2.ipynb#X31sZmlsZQ%3D%3D?line=21'>22</a>     found_explanations.append({'symptom': symptom_id, 'drug': drug_id, 'graphnr': new_graph_nr})
#
# c:\Users\rosa-\Google Drive\Msc_Bioinformatics\thesis\XAIFO-ThesisProject\explainer2.ipynb Cell 23 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/rosa-/Google%20Drive/Msc_Bioinformatics/thesis/XAIFO-ThesisProject/explainer2.ipynb#X31sZmlsZQ%3D%3D?line=10'>11</a> while not done:
#      <a href='vscode-notebook-cell:/c%3A/Users/rosa-/Google%20Drive/Msc_Bioinformatics/thesis/XAIFO-ThesisProject/explainer2.ipynb#X31sZmlsZQ%3D%3D?line=11'>12</a>     print(f'--- Iteration {current_iterations} ---')
# ---> <a href='vscode-notebook-cell:/c%3A/Users/rosa-/Google%20Drive/Msc_Bioinformatics/thesis/XAIFO-ThesisProject/explainer2.ipynb#X31sZmlsZQ%3D%3D?line=13'>14</a>     explanation = explainer(
#      <a href='vscode-notebook-cell:/c%3A/Users/rosa-/Google%20Drive/Msc_Bioinformatics/thesis/XAIFO-ThesisProject/explainer2.ipynb#X31sZmlsZQ%3D%3D?line=14'>15</a>         x=DeepG.node_feature,
#      <a href='vscode-notebook-cell:/c%3A/Users/rosa-/Google%20Drive/Msc_Bioinformatics/thesis/XAIFO-ThesisProject/explainer2.ipynb#X31sZmlsZQ%3D%3D?line=15'>16</a>         edge_index=DeepG.edge_index,
#      <a href='vscode-notebook-cell:/c%3A/Users/rosa-/Google%20Drive/Msc_Bioinformatics/thesis/XAIFO-ThesisProject/explainer2.ipynb#X31sZmlsZQ%3D%3D?line=16'>17</a>         edge_label_index=edge_label_index,
#      <a href='vscode-notebook-cell:/c%3A/Users/rosa-/Google%20Drive/Msc_Bioinformatics/thesis/XAIFO-ThesisProject/explainer2.ipynb#X31sZmlsZQ%3D%3D?line=17'>18</a>     )
#      <a href='vscode-notebook-cell:/c%3A/Users/rosa-/Google%20Drive/Msc_Bioinformatics/thesis/XAIFO-ThesisProject/explainer2.ipynb#X31sZmlsZQ%3D%3D?line=19'>20</a>     edge_mask = explanation.edge_mask
#      <a href='vscode-notebook-cell:/c%3A/Users/rosa-/Google%20Drive/Msc_Bioinformatics/thesis/XAIFO-ThesisProject/explainer2.ipynb#X31sZmlsZQ%3D%3D?line=21'>22</a>     print(f'A total of {torch.count_nonzero(edge_mask)} edges contributing to prediction.')
#
# File c:\Users\rosa-\anaconda3\envs\xaifognn\lib\site-packages\torch_geometric\explain\explainer.py:198, in Explainer.__call__(self, x, edge_index, target, index, **kwargs)
#     195 training = self.model.training
#     196 self.model.eval()
# --> 198 explanation = self.algorithm(
#     199     self.model,
#     200     x,
#     201     edge_index,
#     202     target=target,
#     203     index=index,
#     204     **kwargs,
#     205 )
#     207 self.model.train(training)
#     209 # Add explainer objectives to the `Explanation` object:
#
# File c:\Users\rosa-\anaconda3\envs\xaifognn\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\rosa-\anaconda3\envs\xaifognn\lib\site-packages\torch_geometric\explain\algorithm\gnn_explainer.py:75, in GNNExplainer.forward(self, model, x, edge_index, target, index, **kwargs)
#      71 if isinstance(x, dict) or isinstance(edge_index, dict):
#      72     raise ValueError(f"Heterogeneous graphs not yet supported in "
#      73                      f"'{self.__class__.__name__}'")
# ---> 75 self._train(model, x, edge_index, target=target, index=index, **kwargs)
#      77 node_mask = self._post_process_mask(
#      78     self.node_mask,
#      79     self.hard_node_mask,
#      80     apply_sigmoid=True,
#      81 )
#      82 edge_mask = self._post_process_mask(
#      83     self.edge_mask,
#      84     self.hard_edge_mask,
#      85     apply_sigmoid=True,
#      86 )
#
# File c:\Users\rosa-\anaconda3\envs\xaifognn\lib\site-packages\torch_geometric\explain\algorithm\gnn_explainer.py:127, in GNNExplainer._train(self, model, x, edge_index, target, index, **kwargs)
#     123     y_hat, y = y_hat[index], y[index]
#     125 loss = self._loss(y_hat, y)
# --> 127 loss.backward()
#     128 optimizer.step()
#     130 # In the first iteration, we collect the nodes and edges that are
#     131 # involved into making the prediction. These are all the nodes and
#     132 # edges with gradient != 0 (without regularization applied).
#
# File c:\Users\rosa-\anaconda3\envs\xaifognn\lib\site-packages\torch\_tensor.py:487, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     477 if has_torch_function_unary(self):
#     478     return handle_torch_function(
#     479         Tensor.backward,
#     480         (self,),
#    (...)
#     485         inputs=inputs,
#     486     )
# --> 487 torch.autograd.backward(
#     488     self, gradient, retain_graph, create_graph, inputs=inputs
#     489 )
#
# File c:\Users\rosa-\anaconda3\envs\xaifognn\lib\site-packages\torch\autograd\__init__.py:200, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     195     retain_graph = create_graph
#     197 # The reason we repeat same the comment below is that
#     198 # some Python versions print out the first line of a multi-line function
#     199 # calls in the traceback and some print out the last line
# --> 200 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     201     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     202     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %%
found_explanations
